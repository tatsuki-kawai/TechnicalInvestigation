# %%
import pandas as pd
import numpy as np
import time
from MyNLP import WordDividerMecab

# %%
df = pd.read_csv("data/2022_11_22/comment_2022_11_22_No1.csv", encoding="cp932", header=None)
comment_list = []
row_data = df[0][1:].to_numpy().tolist()
wd = WordDividerMecab()
stop_word_list = ["まだ", "ある", "なる", "なる", "する", "し", "する", "いる", "なっ", "せ", "い", "やる", "ない"]
for text in row_data:
    if len(text) >= 100:
        text = wd.wakati_text_delete(text=text, stop_word_list=stop_word_list)
        comment_list.append(text)
#comment_list = [comment for comment in comment_list if comment != '']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()
tfidf = vectorizer.fit_transform(comment_list)
voc = vectorizer.vocabulary_
voc = sorted(voc)

# %%
#print(voc)
# print(tfidf)

# %%
print(comment_list[0])
# Out:
# 昨日 報道 今回 事故 起こす 2年前 認知機能 検査 問題 高齢 １ 経つ 認知機能 低下 著しい 進行 可能性 認知機能 反射神経 体力 衰え 考慮 年齢 原則 免許 返納 制度 運転 必要 場合 運転 実技 認知機能 判定 高齢者 専用 運転免許証 交付 免許 制度 抜本 仕組み 再考 必要 更新 期間 1年 見直し 必要 思う

# %%
#print(voc)

# %%
corpus = []

for comment in comment_list:
    list = comment.split(" ")
    corpus.append(list)
filtered_corpus = []
for comment in corpus:
    filtered_comment = []
    for word in comment:
        if word in voc:
            filtered_comment.append(word)
    filtered_corpus.append(filtered_comment)

# %%
#filtered_corpus[0]

# %%
corpus = filtered_corpus
corpus = [comment for comment in corpus if len(comment) != 0]

# %%
#for comment in corpus:
    #print(comment)

# %%
vocab_index = {}
for i, w in enumerate(voc):
    vocab_index[w] = i

# %%
#print(len(voc))
#print(voc[0:100])

# %%
new_corpus = []
corpus = [comment for comment in corpus if comment != '']
for sentence in corpus:
    new_sentence = []
    for word in sentence:
        word_idx = vocab_index[word]
        new_sentence.append(word_idx)
    new_corpus.append(new_sentence)

# %%
print(corpus[0][0:10])
print(new_corpus[0][0:10])
print(len(new_corpus))
print(len(corpus[0]))
print(len(new_corpus[0]))
print(len(new_corpus))
# Out:
# ['昨日', '報道', '今回', '事故', '起こす', '2年前', '認知機能', '検査', '問題', '高齢']
# [2870, 2028, 1272, 1216, 4180, 76, 4073, 3008, 1944, 4672]
# 793
# 49
# 49
# 793

# %%
from hlda.sampler import HierarchicalLDA

#default
n_samples = 500       # no of iterations for the sampler
alpha = 10.0          # smoothing over level distributions
gamma = 1.0           # CRP smoothing parameter; number of imaginary customers at next, as yet unused table
eta = 0.1             # smoothing over topic-word distributions
num_levels = 3        # the number of levels in the tree
display_topics = 50   # the number of iterations between printing a brief summary of the topics so far
n_words = 5           # the number of most probable words to print for each topic after model estimation
with_weights = False  # whether to print the words with the weights

# %%
from hlda.sampler import HierarchicalLDA

n_samples = 500       # サンプラーの反復回数
alpha = 20.0          # smoothing over level distributions
gamma = 0.5           # CRP smoothing parameter; number of imaginary customers at next, as yet unused table
eta = 2.0             # smoothing over topic-word distributions
num_levels = 3        # the number of levels in the tree
display_topics = 10  # the number of iterations between printing a brief summary of the topics so far
n_words = 5          # the number of most probable words to print for each topic after model estimation
with_weights = False  # whether to print the words with the weights

# %%
from hlda.sampler import HierarchicalLDA

n_samples = 1000       # サンプラーの反復回数
alpha = 10.0          # smoothing over level distributions
gamma = 0.5           # CRP smoothing parameter; number of imaginary customers at next, as yet unused table
eta = 1.0             # smoothing over topic-word distributions
num_levels = 3        # the number of levels in the tree
display_topics = 50  # the number of iterations between printing a brief summary of the topics so far
n_words = 3          # the number of most probable words to print for each topic after model estimation
with_weights = True  # whether to print the words with the weights

# %%
#hlda = HierarchicalLDA(new_corpus, voc, alpha=alpha, gamma=gamma, eta=eta, num_levels=num_levels)
#hlda.estimate(n_samples, display_topics=display_topics, n_words=n_words, with_weights=with_weights)

# %%
import pickle
import gzip

def save_zipped_pickle(obj, filename, protocol=-1):
    with gzip.open(filename, 'wb') as f:
        pickle.dump(obj, f, protocol)
        
def load_zipped_pickle(filename):
    with gzip.open(filename, 'rb') as f:
        loaded_object = pickle.load(f)
        return loaded_object

# %%
save_zipped_pickle(hlda, 'model/2022_11_22/yahoo_hlda_default_20221122_No1.pickle')
#save_zipped_pickle(hlda, '2022_11_15/yahoo_hlda_default.pickle')

# %%
hlda = load_zipped_pickle('model/2022_11_22/yahoo_hlda_default_20221122_No1.pickle')
#hlda = load_zipped_pickle('2022_11_15/yahoo_hlda_default.pickle')

# %%
hlda.print_nodes(n_words = 5, with_weights = False)
# Out:
# topic=0 level=0 (documents=793): 運転 (551), 思う (419), 事故 (412), 高齢者 (337), 免許 (282),
#     topic=1 level=1 (documents=243): ない (80), 歩道 (56), 思う (47), 見る (35), 間違える (35),
#         topic=2 level=2 (documents=52): 人生 (28), 亡くなる (22), 最後 (19), 気の毒 (15), 97歳 (15),
#         topic=5 level=2 (documents=35): 踏む (34), ブレーキ (32), アクセル (31), マニュアル車 (11), 間違い (7),
#         topic=6 level=2 (documents=15): 無駄 (8), 施設 (7), 老人 (6), 人口 (4), ある日 (3),
#         topic=20 level=2 (documents=25): 逮捕 (34), 今回 (10), 飯塚 (10), 警察 (7), 上級国民 (6),
#         topic=33 level=2 (documents=25): サービス (13), 買い物 (11), 難しい (9), 公共交通機関 (7), 通院 (7),
#         topic=47 level=2 (documents=10): 道路 (8), 見間 (2), 確保 (2), もたらす (2), 交付 (2),
#         topic=69 level=2 (documents=29): 走る (28), 車線 (11), 怖い (10), 右折 (7), 道路 (7),
#         topic=141 level=2 (documents=7): 自動運転 (3), こえる (2), 時代 (2), 受け入れる (2), 浸透 (2),
#         topic=153 level=2 (documents=7): こないだ (2), 落ちる (2), 合格 (2), 好き (2), 2歳 (1),
#         topic=157 level=2 (documents=13): 記録 (3), 警告 (3), 注目 (2), 取り組む (2), 広い (2),
#         topic=158 level=2 (documents=8): 無罪 (3), 卒業 (2), 老人ホーム (2), 正常 (2), 小学生 (2),
#         topic=189 level=2 (documents=9): 補助 (2), 政府 (1), 1時間 (1), 可能性 (1), 向き合う (1),
#         topic=196 level=2 (documents=5): 年間 (2), 買い替え (2), 重量 (2), 自動車税 (2), 自賠責 (2),
#         topic=201 level=2 (documents=3): 高位 (1), 自信 (1), 田舎 (1), 恐怖心 (1), しょうが (1),
#     topic=3 level=1 (documents=186): ない (58), 認知機能 (45), 高齢者 (41), 思う (36), 歩道 (30),
#         topic=4 level=2 (documents=10): 件数 (6), 防止 (3), 運転者 (3), 報道 (3), 叩き (2),
#         topic=14 level=2 (documents=82): 更新 (38), 試験 (37), 免許 (36), 検査 (27), 免許更新 (25),
#         topic=15 level=2 (documents=13): 若い世代 (5), 遭う (4), 違和感 (3), 操作ミス (3), 世代 (3),
#         topic=22 level=2 (documents=29): タクシー (19), バス (15), スーパー (7), 補助 (5), 暮らす (5),
#         topic=107 level=2 (documents=10): マーク (5), 付ける (4), 速度 (4), 考え (2), ドライバー (2),
#         topic=150 level=2 (documents=11): 犠牲 (5), 政府 (4), 歩ける (3), 伴う (2), 改正 (2),
#         topic=184 level=2 (documents=2): シミュレータ (2), ハンドル (1), 性能 (1), 航空機 (1), 国の責任 (1),
#         topic=187 level=2 (documents=7): 警察署 (4), 販売 (4), 最近 (3), 売る (2), ぶつける (2),
#         topic=188 level=2 (documents=13): 動く (5), 都合 (5), よい (4), 自主返納 (4), 搭載 (4),
#         topic=190 level=2 (documents=9): 診断 (6), 街中 (2), そうだ (2), 諦める (2), おる (1),
#     topic=7 level=1 (documents=94): ない (36), 見る (21), 問題 (19), 間違える (17), 歩道 (14),
#         topic=27 level=2 (documents=5): 農業 (4), 技能 (4), 80代 (2), 会社 (2), 便利 (2),
#         topic=54 level=2 (documents=10): 整形外科 (3), 驚く (3), 免許更新 (3), うち (2), 女性 (2),
#         topic=115 level=2 (documents=13): メーカー (5), 講習 (5), 保険 (4), 結果 (4), 世代 (3),
#         topic=118 level=2 (documents=10): 決める (3), 交通インフラ (2), 家出 (2), 頑固 (2), 短い (2),
#         topic=125 level=2 (documents=11): 特定 (3), 技術 (2), 暗い (2), 視界 (2), 差別 (2),
#         topic=172 level=2 (documents=5): 思い (2), 車など (1), 限界集落 (1), 故意 (1), 関係 (1),
#         topic=174 level=2 (documents=8): お母さん (3), 遠い (2), 義母 (2), ショートカット (2), 母親 (2),
#         topic=175 level=2 (documents=8): 回復 (2), 誕生日 (2), 国会議員 (2), 議員 (2), 是非 (2),
#         topic=181 level=2 (documents=5): 心配 (2), 大丈夫 (2), ハンドル (2), 潔い (1), 年齢的 (1),
#         topic=183 level=2 (documents=11): 安全装置 (3), 悔やむ (3), 支える (3), 模試 (3), 代わり (3),
#         topic=185 level=2 (documents=8): 赤字 (2), どこか (2), 限定 (2), バス (2), 被害 (2),
#     topic=9 level=1 (documents=120): ない (34), 思う (23), 問題 (22), 歩道 (19), 認知機能 (18),
#         topic=12 level=2 (documents=17): テスト (14), 高齢ドライバー (6), 影響 (6), 不調 (5), 調べる (4),
#         topic=41 level=2 (documents=11): クルマ (7), 使う (4), 予算 (4), 整備 (3), 入る (2),
#         topic=56 level=2 (documents=5): 交通手段 (4), 90代 (2), 公共 (2), 車社会 (2), 頼る (2),
#         topic=124 level=2 (documents=9): 時代 (5), 少数 (2), ネット (2), 確認 (2), 都合 (2),
#         topic=132 level=2 (documents=7): 専門家 (9), 改善 (2), 社会 (2), 自称 (2), 都市 (2),
#         topic=143 level=2 (documents=9): 会場 (3), 係員 (3), 指摘 (2), 他人 (2), 仕方がない (2),
#         topic=161 level=2 (documents=5): 利用 (3), 仕様 (2), うい (1), 速度制限 (1), 老化 (1),
#         topic=167 level=2 (documents=6): 開く (2), モラル (2), 増やす (2), 地味 (2), 公共機関 (2),
#         topic=169 level=2 (documents=10): 車両 (5), 車検 (4), 任意保険 (3), 遭う (2), 罰則 (2),
#         topic=171 level=2 (documents=10): 習慣 (4), 父親 (3), 結局 (2), イヤ (2), 近い (2),
#         topic=173 level=2 (documents=8): 医療機関 (5), 車両 (4), 認める (3), 議論 (2), 連携 (2),
#         topic=179 level=2 (documents=5): 駐車 (3), 歩く (2), 店員 (2), 駐車場 (2), 致し方 (1),
#         topic=180 level=2 (documents=10): 反対 (3), 薄い (3), 効果 (2), 交差点 (2), 凄い (1),
#         topic=193 level=2 (documents=8): スマート (3), バス停 (3), 地下鉄 (2), 爆走 (2), 頻繁 (2),
#     topic=17 level=1 (documents=150): ない (46), 歩道 (39), 車道 (39), 問題 (28), 見る (26),
#         topic=18 level=2 (documents=59): 歩道 (69), 間違える (43), 車道 (31), 道路 (27), 広い (25),
#         topic=37 level=2 (documents=8): 移住 (3), 商店街 (3), 困る (2), 一人 (2), 岸田 (2),
#         topic=57 level=2 (documents=4): ボケ (2), 言語道断 (2), ハンドル (1), 以前 (1), 作業車 (1),
#         topic=97 level=2 (documents=14): 公共交通機関 (5), 身体検査 (4), ひとつ (3), 基準 (2), 航空 (2),
#         topic=99 level=2 (documents=6): 行う (3), 保持 (3), 取り上げる (2), 一体 (1), 努める (1),
#         topic=142 level=2 (documents=10): 論外 (3), 特別 (2), 90代 (2), 法律 (2), 役所 (1),
#         topic=191 level=2 (documents=11): 無事故 (4), 標識 (3), 平均寿命 (3), 単独 (2), あたり (2),
#         topic=194 level=2 (documents=8): マーク (4), 値する (3), 一時 (3), 免停 (3), センターライン (2),
#         topic=197 level=2 (documents=11): 親戚 (5), 移り住む (3), 行ける (3), バイク (3), 医者 (2),
#         topic=198 level=2 (documents=13): 酷い (4), インフラ (4), 日々 (3), 大丈夫 (2), 会長 (2),
#         topic=199 level=2 (documents=6): 検査 (3), 2年 (3), 直ぐ (2), そう (2), 率直 (1),

# %%
def get_document_path(hlda, doc_index):
    node = hlda.document_leaves[doc_index]
    path = []
    while node is not None:
        path.append(node.node_id)
        node = node.parent
    path.reverse()
    return path

def get_document_path_list(hlda, corpus):
    document_path_list = []
    for i in range(len(corpus)):
        path = get_document_path(hlda, i)
        document_path_list.append(path)
    return document_path_list

def print_topic_document(corpus, path_list, topic_id):
    document_index_list = []
    for i, path in enumerate(path_list):
        if topic_id in path:
            document_index_list.append(i)
    if len(document_index_list) == 0:
        print(f"{topic_id}がみつかりません")
    for i in document_index_list:
        print(f"[{corpus[i]}]")
        print("\n")

path_list = get_document_path_list(hlda, corpus)
print_topic_document(row_data, path_list, 18)
# Out:
# [歩道と車道を間違うなら歩道は通学路のように緑のラインを引くなり見分けがつくようにすると良いのではないでしょうか。。
#
# 自転車の歩道進入も交通規則では進入できないようになっているようですが狭い車道を走るのは怖いのもありますよ。
# 徐々にでいいですから自転車が専用道を走れるようにしてもらいたいものです。]
#
#
# [歩道と車道を勘違いして走る事故は、若年や中高年のほうが多いみたいなので、高齢者特有の事故とは言えないようです。
# 我々も気をつけないとだし、そのような誤侵入を防ぐような安全装置の開発が待たれます。
#
# ブレーキとアクセルを踏み間違っても、急発進をしないようにする装置はすでに販売されているようですね。オートバックスで売っていました。少し高いですが。。。
# このような装備を標準にするためにも、国のほうで補助制度を作って欲しいところです。]
#
#
# [当時、現場付近は渋滞してたって話だから歩道と車道を間違えたってのはないよ。
# 長年近所に住んでて、買い物もここに来てたみたいだし。
# 意図的に歩道を走ってショッピングモールに入ろうとして、歩行者の女性を跳ねて慌てて右にハンドルきって、車道側の街路樹に衝突しつつ渋滞の車列に突っ込んだんでしょ。
# 年寄りってかなり危険な運転してて、周りが避けて事故になってないだけだよ。
# 現状の運転技能を見るより、ドライブレコーダー義務化して普段の運転状況を見て審査したらどうなの。
# 安全に運転している年寄りから免許を取り上げるのはどうかと思いますが。]
#
#
# [昔は歩道が狭かったので、こういう事故は考えられませんでしたが、今はまれに発生するのですか。少々驚きです。
# 　20代のころ、夜間で雨天で照明も暗くて、大通りの白線やグリーンベルトが見えにくい状態で、一瞬だけ対向車線が進入路に見えて焦ったことがあります。類似の経験をされた人もいるのでは。
# 　視界が悪くて注意散漫だと、進入地点を間違うことは、若くてもあり得ないわけではない。今回のは認知症も疑いたいケースですが、現場を見たわけではないので断定は出来ません。高齢者を叩いてオレは平気と安心せず、自分の運転を振り返ることも大事ですね。]
#
#
# [道路の逆走や、車での歩道侵入、踏切待ちから車で線路に誤って侵入など、これまでのニュースでの共通点はほとんどが高齢者ドライバーであったことす。
#
# 高齢ドライバーの運転能力において平面や空間、方向の認識能力がかなり衰えているのは間違え無いと思います。
#
# ニュースの動画で見ましたが、日が暮れた事故現場の歩道は、車道との境界が分からないほど真っ暗で、視力や認識能力の衰えた高齢者であればうっかり歩道に左折してしまうことはあり得ると思いました。
#
# そこからパニックに陥って、ブレーキとアクセルを踏み間違えたのも高齢者特有の行動です。いろいろな身体的能力が衰えている高齢ドライバーには、他人事と言っていられない事故だったと思います。]
#
#
# [ここは知らないけど、広い殺風景な歩道だと、車道と勘違いすることはたまにある。夜間は運転していても怖い。あとは、片側複数車線の広い国道やバイパス。クロス道路から右折で進入する際に、手前の反対車線に入り込む恐れがある。センターガードレールがあることが多いので、修正も困難。一番危険、特に夜間。路面表示の明瞭化を進めてほしい。９７歳は極度だけど、なんでも老人のせいにするのはおかしい。事実、重大事故は３５歳以下の若年層がはるかに多い。]
#
#
# [ブレーキとアクセルの間違いではなく歩道と車道を間違えるとは…運転して良いか以前の問題で、一人で出かけて大丈夫か心配になるレベル。
#
# 車を手放すのが難しい地域があるのは承知しているのですが、歩道と車道を間違えるのはあまりにも…
# 「通す」ための無意味な高齢者教習に使う税金を地域の足に回して、今回の加害者のような人が無理をして運転しないで済むようになると良いと思います。]
#
#
# [もちろん真相は本人に聞かないとわからないけど、確かに施設から車道に出るとき、手前にあまりに広い歩道があると、それが車道だと勘違いして走りかけたことが一度ありました。
#
# でもこの人の場合には、何度も来たことがあるお店ならそれはないのかなぁ。とはいえ人間年を取ってくると目が見えにくいこと頭の老化で空間の状況把握能力がものすごく衰えるので、何度来たことがある道でも思い込みと勘違いで歩道を車道だと勘違いして走ろうとしたのかもしれないですね。夜になると何度通った道でも間違ったりしますしね。
#
# とにかく、年を取ると若い頃なら絶対にやらないような頓珍漢なことを思わずしてしまうことはあります。私にもその自覚があるのだから９７歳ならそんなことはしょっちゅうあったんじゃないでしょうか。]
#
#
# [歩道と間違える訳ないと思いつつストリートビュー見たら、歩道の幅も広いし、初めての人には難しい構造になっていた。また、車止めもないように見受けられた。
# 加害者が悪いのは当然としても、年齢の問題に集約するのではなく、構造的な欠陥も検証する必要がある。]
#
#
# [オーサーコメントにもありますが、誰もが間違える可能性というのはあるでしょうね。
# 歩道と車道を間違えた…。特にショッピングモールの周りのようなところ。過去にも歩道と間違えたという記事は見たことがあります。歩道が広くなってるところはありますね。
# 私が行くところも歩道が広いです。間違える人はいないことはないかもしれない…。私はいつも行ってるのでわかりますが、初めて、暗かったりしたから…。車が進入できないようにポールとかあったかな、今度気にしてみよう…。
# 初めて通る道で歩道に限らず、車線がわかりにくくなる場面というのは考えられます。そこでどう対処するか、気づけるか…というのは大事ですね。日頃気をつけて運転してるか、というか。何か変、という感覚というか。]
#
#
# [私の住んでいる地域だけの問題かどうかはわからないが、最近道路の区画線が消えかかっており、ひどいところではほとんど見えなくなっている場所が多く見受けられる。
# このことは財政の逼迫により区画線の引き直しができなくなっているせいだと言う。そのせいで夜間、特に雨天時にはどこが車道か路肩かわからない状態だ。
# 高齢者になると夜間に限らず、判断が難しいと思う。
# 最近は歩道の幅は地方であっても広い道路が多い。これはいわゆるシニアカーがすれ違えるためだそうだ。高齢者に配慮した設計ということだが、そのことが車道と間違えて進入してしまう原因だとしたら皮肉な結果となった。
# 高齢者は認知機能の低下でなくても、視力の低下等で判断を謝ることが多い。
# そういった判断ミスを起こさない工夫も併せてお願いしたい。]
#
#
# [高齢のせい、、、、、だとして話すのはたやすいけど、
# それだけと決めつけるのは、問題を単純化しすぎる。
#
# 歩道と車道を勘違いできちゃう道路の構造。。。
# 勘違いして侵入できたたにしても、歩道を自動車でそこそこのスピードで走れちゃうってのも、、
# 高齢じゃなくても、病気、体調、精神状態、飲酒、わき見、考え事、スマホチラ見などで、ふっとしたはずみで、通常はあり得ない行動を起こす可能性はある。
# 道路構造、自動車の事故防止機能の義務化、とかで、なんとかならないかな？]
#
#
# [若い人でも、道の構造や標識の見え方により
# 逆走や、車道と歩道を間違えることもある。
# 後付けできる踏み間違いを防ぐ器具もある。
# 駐車場の車止めは
# ロール付きの物に変えることで
# 店舗に突っ込む危険性を低くできる。
# 年齢だからと返納を言われても、どうしても
# 必要な人もいる。
# まずは、やれる事をやろう。]
#
#
# [車道も歩道も大きくゆったりと作ってある所で間違って入る可能性はあるかもしれない
# かえって狭く危険そうな所は気をつける
# 高速でも逆走があるわけで一般道なら尚更
#
# 今回は薄暗い夕方で暗くなったら高齢者は運転すべきでない時間で時間帯もあると思う]
#
#
# [車が通れるほどの幅がある歩道には、ポールを立てて車の侵入を抑制するような対策も案の一つかと思います
# むやみやたらに立てる訳ではなく、車交通量の多い歩道とか、出入りが多い商業施設に隣接する歩道を優先するなど工夫の仕方はあると思います]
#
#
# [歩道を道路と勘違いした話が本人からなら、これ程曖昧なものは無いだろうな。
# 高齢で無くても事故したショックで記憶が曖昧だったりすると思うし、こうあって欲しいという願望的なものが真実と思い込んでしまう可能性だってある。]
#
#
# [歩道に車輌が突っ込む事故は狭い道路、また郡部の逃げようのない道路に多く発生しています。
# 　いろんな場所で、また繰り返しおきていることから、生命の安全を守るためには、思い切った施策を考えなければいけない。
# 　例えば、歩道と車道を高い段差やガードパイプを設けるとか、道路を広くする、できなければ不自由でも一方通行にするなど徹底した行政施策を願いたい。
# 　命はなによりも大切なものです。]
#
#
# [>この「歩道と車道を間違える」といったような事故は若年層でも起こす可能性はあり、実例も少なくありません。高齢者だけの問題だと誤った認識をすることは避けるべきです。
#
# もっともらしいが、若年層は間違いに気付いて歩行者を轢くまでは行かない。有識者と呼ばれる方が、さも客観的で正しい事を言っているように見せて、やるべき対策の邪魔をしてしまうのは残念。]
#
#
# [もし、歩道を車道と間違えたなら…。
# 整備されすぎた平坦で広い歩道を考え直す時期に来ています。
# 宮崎県で起きた事故も歩道を車道と間違えて暴走しています。
# 繁華街の歩道は広くてきれいに整備されています。
# 以前から危険性を感じていますが、
# なくなるどころか、
# この手の歩道はますます整備されています。
# しかも多くがタイル貼りだから滑りやすい。]
#
#
# [歩道を軽自動車で走行したことは、運転手の高齢の事が原因との見方が多いですが、交差点の歩道のスタート地点にポールやU字バリケードが設置されていたら、そもそも車の侵入は防げたのかと。
# でも、歩道の入口にポール等を設置する事を反対する方々も多いですし。
# ともかく、故人にはご冥福をお祈りします。]
#
#
# [これグーグルマップ見けど、暗がりだったらお年寄りの視力だと縁石の影見えなくて道路と混同する可能性もなくはないなと思ったなぁ。
# ちゃんと見えてて判断できてれば防げたかもしれないけど、逆に言うと見落としやすい気もするので年齢関係なく事故が起きてたかもしれない。
# もうちょっとわかりやすく縁石や歩道に色つけるとかしても良かったんじゃないかなぁ？とも思う。]
#
#
# [車道と歩道を間違えたとしても、人が見えたらブレーキ踏むよね。
# 車何台もにぶつかって、人が見えてもブレーキ踏まずって…。
# さらに踏み間違えもしたのかな。
#
# 75歳で全員免許失効でもいいのでは？
# それか75歳以上は3ヶ月毎に実地試験受けないと更新出来ないとか。
# どちらにしても80歳以上は運転したらダメだよ。
# 元々車なしで生活してる人もたくさんいるんだから。]
#
#
# [こういう事故があると免許証の年齢上限を設けろという意見が必ず出てくるが、高齢者の事故はマスコミが大きく扱い高齢者以外の事故は余程の大事故で無い限り扱わない。
# よって世の中の交通事故の大半は高齢者が起こしていると勘違いする人がいる。
# 高齢者以外の事故でも多くの命が奪われているので年齢上限云々では無く免許制度全体で考える必要がありませんかね。]
#
#
# [刻々と老いて機能低下していくことは誰もが避けられない。
#
# 今回の事故のようになる前に、運転ができなくなるように計らう必要がある。
#
# 運転免許取得の年齢下限があるのに、上限がないのはそもそもおかしい。
#
# 特に、地方は、高齢化社会に対してインフラが貧弱なところが多く、免許返納を阻害していると思う。]
#
#
# [池袋暴走事故では逮捕されなかったが今回は逮捕された。これが上級国民と平民の差なんだな。
# 今回の容疑者も高齢であり逃走はしないはずだ。
# 捜査は適切に行い正しく裁いて欲しい。
# 初心者や高齢者は運転支援装置付き車両限定免許にしましょう。新車には全グレード義務化は必須です。]
#
#
# [歩道と車道を間違えることは年齢だけの問題ではないと思う。一瞬、？と迷うような歩道と車道が紛らわしい道って確かにある・・そのような道は何とか間違わないような対策をしないといけないと思う]
#
#
# [この方が乗っていた車両には自動ブレーキ等の機能はなかったのか？もし、付いていたのなら実際の事故を検証してどういう理由・状況下で作動しないという事を広く周知することも重要だと思う。]
#
#
# [本当にただ【歩道と車道を間違えた】だけなんだろうか。というか普通は歩道と車道を間違えないから。そう考えると90歳過ぎた老人が運転する車は本当に恐ろしい。たとえ精神的に全く問題がなくてもこの年齢になると突然死する確率が高くなりドライバー不在の車がいきなり暴走する可能性もある。]
#
#
# [何が問題かと言えば、足となるべき公共交通機関があまりにも少なすぎるからではないですか？高齢者も日常生活の買い物や通院とかが徒歩で用が足りるならあえて車を運転する必要もないでしょう。
# かような生活環境を変えない限りは、かような事故をなくすことは難しいのではないですか？]
#
#
# [車道と歩道を間違えて進入してしまう可能性は若年でもありうるとして、
# その時点で間違ったと気づく、間違いに気づかなかったとしても前方の歩行者を轢かないという２段階を越えてしまってる点で認知機能の問題では]
#
#
# [免許取得年齢があるように、免許返納年齢も法改正で設けたほうがいいと思います。
# 後期高齢者のベテランドライバー。
# 認知機能がしっかりしているとしても運転しているのを見ると逆に危ないです。]
#
#
# [奥様亡くされてから独居生活で最近になってセダンから軽に替えたとの事。
# なおさら、販売店が売るだけでなく警察署もしくは免許センターに問い合わせをしてから販売するか販売出来ない旨を伝えるべきでしたね。
# あと、遅くても８５歳で強制的に免許返納制を検討してもらいたいですね。]
#
#
# [仮に歩道と車道を間違えても前に歩行者がいれば（この人にとってみれば車道に歩行者がいる状態），止まるか避ける。
# それをしない，アクセルとブレーキを間違えて気付かない。
# 普通の運転者ならしない何重ものミスが重なったということですね。]
#
#
# [私は転勤族で今は主人の実家に住んでいます。これからの人生を考えると、田舎の交通手段を国が考えて欲しいと思います。
# 病院まで、タクシーで14000円かかります。バスは2000円ですが、2時間に一本だったりします。就職先もないので、年寄りばかりです。
# 本当に被害者の方のご冥福をお祈りします。このような悲しい事件がおきないように、多方面の改正、新案をお願いいたします。]
#
#
# [慣れてない道など歩道と車道がわからなかったりする事もある。私の世代でもそうなのだから明日明日１００歳の人は尚更ではないか。いくら検査で通ったとしても１００歳近くは危ないと思う。ひかれた方だけがとても気の毒。検査云々ではなく年齢で９０以上は返納、などが必要だと思う。]
#
#
# [近所の道路が４車線化の途中で、まだ用地立ち退きに年数かかるとかでとりあえず整地終えたところを歩道にしてるんだけど、もともとの歩道幅もとってあるから道路幅より歩道幅の方が広くなってんの。
# んでド真ん中に視覚障害者用の黄色プレートまで敷いてあるもんだから、時々そっちが本線に見えて混乱します。]
#
#
# [歩道をなんの迷いもなく全力走行しての俺様運転で追い越し車線として使う不届き者は時々見かける。
#
# 歩道を車道と間違えたのではなく、俺様運転によって起きたものと思う。
#
# 高齢者だからブレーキアクセル間違いだろうとか認知症で車道と間違えただろうとか勝手に妄想して罪を軽くする必要はない。
#
# 事実を正確に徹底調査してもらいたい。]
#
#
# [免許の資格の制限をかける時期がきたと思う。現実、足の悪い人も運転をしていたりしていて怖い。今回も９０代で運転しているとは信じられないし、家族の責任も問われると思う。]
#
#
# [年齢だけでしょうか？この様なコメント許してください｡認知症等の診断受けたり､無料で自動車教習所で指導受けてもらえば？普段ので買い物に行って駐車場であたふたされてる方を時々見かけます｡以前より自動車の運転か楽になりましたけど､その分事故とかが増えているような…｡]
#
#
# [認知機能検査では問題なかったとされていますが検査と実際の運転では天と地ほど違いがある！検査は良くてもこの年齢では免許返納するべき！家族は何とも思わなかったのか？]
#
#
# [〉車道と歩道を間違えた
#
# 現場が、間違い易い道路だった場合
# 単なる過失致傷になるかも
# （やり手弁護士によっては「無罪」を求めるのでは？）
#
# 道路の標識（看板、路面共）、木で隠れていたり、文字がかすれて見え難い状態だったら違反にならないケースもあるのだから…
#
# 歩道と車道の区別が分かりにくい道も確かにあるからなぁー（慣れた道なら分かるだろうが、初見だと、「あれ？」って思う道が…]
#
#
# [この前老人がスーパー駐車場で停車してた自動車をこすりながら駐車してました。
# 本人に指摘したら、ぶつかった事も気づいてなかった。
# この問題いつまで放置するつもりでしょうかね]
#
#
# [ちょうど先日
# 広めの歩道を逆走している車に遭遇しました
# 80歳前後のおじいさんで、真顔だったのが怖かったです
# その歩道は車が侵入できるような段差は無く
# おそらく結構な距離を走って来ていて・・・。
# 免許の更新にも年齢制限を設けるべき時が来たのではないでしょうか？]
#
#
# [一台目に衝突してからのスピードは単に車道と間違った、ということはなかろう。普通は止まるわな。やはり判断力は落ちてるんやで。体力もな。年齢制限は要るとおもう。]
#
#
# [たとえ車道と歩道を間違えたとしても、ブレーキさえ踏んでれば命までは奪わなかったかも知れない。
# 高齢者には「衝突軽減ブレーキ装備車に限る」みたいな運転条件つけなきゃいけないと思う。]
#
#
# [未然に防ぐにわ、やはり年齢制限は必要かなと思うようになりました。線引きは難しいけど、平均寿命年齢くらいが妥当かなと。]
#
#
# [車がないと生活ができない社会になってしまった。車を手放したくても手放せない。今後高齢者が車がなくてもいいようなシステムを作るしかないね。
# 例えば無料タクシーとか。75歳以上なら1日1往復のみ無料とかかな。]
#
#
# [免許更新できる年齢に上限を設定するべき。
# 基本は８０歳まで。それ以上の年齢で更新するには厳しい実技試験を課して、３カ月ごとの更新に。
#
# この現状を放置しているのは国会議員の怠慢。]
#
#
# [１８歳以下だけじゃなく、上も年齢制限設けて強制的に乗れなくしたらいい。
# 車が無いと困るとか知らん。昔は無かったんだし、無いなりに何とかすればいい。
# 今は色々便利になり過ぎた。それ自体は悪いことじゃないが、人は対応力がある。何とかなる。]
#
#
# [高齢者の適性検査をもっと時間をかけて総合的に判断すべきだと思う。認知検査だけでなく判断力と運動能力も調べてほしい。関係ない人が巻き込まれるのはもうやめてほしい。
# 「運転歴70年なんだから大丈夫だ」と言っていた90歳の近所のお爺さん　自損事故で亡くなりました。]
#
#
# [免許証を返却すべきですよ!
# 今は罪を償うしかないです。
# 死亡事故ですので、刑務所、起訴、前科は確定です。怪我だけですと、量刑は少ないですが死亡事故ですので、刑罰が非常に重いです。97歳ですと、刑務所生活もお気の毒かも知れませんが、社会は現実逃避は出来ません!]
#
#
# [97歳が運転できることを許可した公安委員会の責任なんじゃないの？未成年を保護して制限するんなら高齢者も保護して制限しないといけないでしょ。漫然と長高齢者に車を運転させた公安委員会の怠慢だよこれは。]
#
#
# [記事では市道とある。専門家の指摘にもあるが、どうすれば車道と歩道を間違えるのだろうか。専門家は若年層でも間違えると言うが、どうすれば間違えるのか。滅多に間違わない事例なんだから、どうすれば間違えるのか、どうすれば間違わないのかまで説明しろよ、上西とか高野とか。]
#
#
# [国も自治体も田舎だから、採算が取れないから便を減らすとか廃止する
# 考えを今一度、根本的に見直すべきなのでは？
# 増税だの、保証だの点で見てるし、管轄が違うからとの言い訳でないがしろにしている。]
#
#
# [歩道と車道を間違えたとしても、人や街路樹をなぎ倒します？
# ブレーキー操作が出来ない状況にあったということでしょ？
# 仮に道に人が歩いていたって通常ブレーキ踏むでしょ？
# 国は、超高齢者にこれからも運転させるつもり（したい）なら、自動ブレーキ付きの車限定とかにするしかないんじゃない？な]
#
#
# [原付でも乗れる高齢者用一人乗り電動カーの普及が急がれる。ちょっとした買い物が出来るように、でも、軽自動車以上の車は危ないから、普通免許から原付への切り替えで。]
#
#
# [田舎は車がないと生活は大変ですよね。
# 乗らざるをえない。
# 公共の交通機関がなかったり送迎してくれる人がいなかったり。車がなかったら病院にも買い物にも行けない。
# こういう社会をどうにかしないとこの手の事故は減らないですよね]
#
#
# [この事故、別の意味で悪い影響あるかも。
# 今８０歳台の運転免許保持者は、
# 「97歳まで事故なく運転できるんだ、自分もまだまだ大丈夫！」って
# 勘違いさんがいるのでは。]
#
#
# [刑事罰で償う事が出来ない年齢に免許を与えるべきでない。罰を重くするべき～被害者を生きかえせないなら民事の賠償額も上げるべき。]

# %%
path_list = get_document_path_list(hlda, corpus)
print_topic_document(row_data, path_list, 6)
# Out:
# [家庭を見るに、残された子供は両親を失ったも同然
# 気の毒ではあるけど、生きていかなくてはならない
# とても受け入れられない現実ではあるだろうけど、子供の精神的なケアと教育面での変わらないフォローも大切だと思う]
#
#
# [会社にもメタノールがあります。
# 塗装関係に使用しますが入手はとても容易です。
# 取り扱いには十分注意しています。]
#
#
# [子供のことを1%でも考えたら、そこまではね。]
#
#
# [何があったのでしょうか]
#
#
# [日本初の心臓移植手術の経緯を思い出す。その知識、その技術、その競争の中、栄誉のためなら理性はきかないのか。
#
# 社内の業務上の死では無さそうなのに、社名まで出されるとは、風評被害、大丈夫ですか。]
#
#
# [コナンとか金田一みたいな犯罪すればバレないと思ってたけど
# 大人になって分かったのは今の捜査はすごく発達してるという事です
# でもこの感じだとそんなに苦労せず逮捕されたと思うけど]
#
#
# [勿体ない、製薬会社は年収高いしそんなに殺したいならまず離婚すればいいし人生損になることしちゃいましたね。メチルアルコール等血中濃度で一発だし。]
#
#
# [父親も長期勾留確実だろうし、子どもは児童養護施設にぶち込まれて、現時点で人生詰んだのでは。]
#
#
# [エリートなんだね。
# 見た感じ、会社員だとは思わなかった。
# 自宅で飲まされちゃったのだとしたら、悲しいなぁ。]
#
#
# [薬品の専門家がメタノールなんて一般的な薬品で病死を偽装するもんだろうか？]
#
#
# [冤罪？
# 夫婦仲悪かった？
# もっと知らない薬品とか手に入らない薬とかありそうだけど。
# 本当にやったのかな？]
#
#
# [子供が本当に本当にかわいそう。もう分別つくし、殺したいくらい嫌いならその前に離婚しなよ！！]
#
#
# [新薬の実験台にされたわけじゃなく？]
#
#
# [夫は殺害を否定。これは治験です、失敗しただけです。]
