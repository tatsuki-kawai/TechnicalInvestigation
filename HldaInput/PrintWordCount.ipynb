# %%
import pandas as pd
import numpy as np
import time
from MyNLP import WordDividerMecab

# %%
df = pd.read_csv("../Data/yahoo/2022_11_22/comment_2022_11_22_No1.csv", encoding="cp932", header=None)
comment_list = []
row_data = df[0][1:].to_numpy().tolist()
wd = WordDividerMecab()
stop_word_list = ["まだ", "ある", "なる", "なる", "する", "し", "する", "いる", "なっ", "せ", "い", "やる"]
comment_list = [wd.wakati_text_delete(text=text, stop_word_list=stop_word_list) for text in row_data]
#comment_list = [comment for comment in comment_list if comment != '']

import matplotlib.pyplot as plt
import math
import numpy as np

x = []
comment_count_list = []
for i, comment in enumerate(comment_list):
    comment_count_list.append(len(comment))
    
x = np.linspace(0, max(comment_count_list), max(comment_count_list)+1, dtype=int)
y = np.zeros(max(comment_count_list)+1)

for count in comment_count_list:
    y[count] += 1

plt.plot(x, y)
plt.xlabel('number of characters')
plt.ylabel('Number of comments')
plt.show()

comment_count_list = []
for i, comment in enumerate(row_data):
    comment_count_list.append(len(comment))
    
y = np.zeros(max(comment_count_list)+1)

for count in comment_count_list:
    y[count] += 1

start = 0
max_count = max(comment_count_list)+1
x = []
new_y = []
for num in range(50, max_count, 50):
    new_y.append(sum(y[start:num]))
    finish = num
    start = finish
    x.append(finish)
    
    
plt.plot(x, new_y)
plt.xlabel('number of characters')
plt.ylabel('Number of comments')
plt.show()

def calcNumChar(start, finish, comments):
    #コメントの文字数がstart以上, finish以下のコメント数を表示する
    print(sum(comments[start:finish+1]))

calcNumChar(0, 400, y)
# Out:
# 2104.0

# %%
df = pd.read_csv("data/2022_11_24/comment_2022_11_24_No1.csv", encoding="cp932", header=None)
comment_list = []
row_data = df[0][1:].to_numpy().tolist()
wd = WordDividerMecab()
stop_word_list = ["まだ", "ある", "なる", "なる", "する", "し", "する", "いる", "なっ", "せ", "い", "やる"]
comment_list = [wd.wakati_text_delete(text=text, stop_word_list=stop_word_list) for text in row_data]
#comment_list = [comment for comment in comment_list if comment != '']

import matplotlib.pyplot as plt
import math
import numpy as np

x = []
comment_count_list = []
for i, comment in enumerate(comment_list):
    comment_count_list.append(len(comment))
    
x = np.linspace(0, max(comment_count_list), max(comment_count_list)+1, dtype=int)
y = np.zeros(max(comment_count_list)+1)

for count in comment_count_list:
    y[count] += 1

plt.plot(x, y)
plt.xlabel('number of characters')
plt.ylabel('Number of comments')
plt.show()

comment_count_list = []
for i, comment in enumerate(row_data):
    comment_count_list.append(len(comment))
    
y = np.zeros(max(comment_count_list)+1)

for count in comment_count_list:
    y[count] += 1

start = 0
max_count = max(comment_count_list)+1
x = []
new_y = []
for num in range(50, max_count, 50):
    new_y.append(sum(y[start:num]))
    finish = num
    start = finish
    x.append(finish)
    
    
plt.plot(x, new_y)
plt.xlabel('number of characters')
plt.ylabel('Number of comments')
plt.show()

def calcNumChar(start, finish, comments):
    #コメントの文字数がstart以上, finish以下のコメント数を表示する
    print(sum(comments[start:finish+1]))

calcNumChar(200, 400, y)
# Out:
# 228.0

# %%
df = pd.read_csv("data/2022_09_22/comment_2022_09_22.csv", encoding="cp932", header=None)
comment_list = []
row_data = df[0][1:].to_numpy().tolist()
wd = WordDividerMecab()
stop_word_list = ["まだ", "ある", "なる", "なる", "する", "し", "する", "いる", "なっ", "せ", "い", "やる"]
comment_list = [wd.wakati_text_delete(text=text, stop_word_list=stop_word_list) for text in row_data]
#comment_list = [comment for comment in comment_list if comment != '']

import matplotlib.pyplot as plt
import math
import numpy as np

x = []
comment_count_list = []
for i, comment in enumerate(comment_list):
    comment_count_list.append(len(comment))
    
x = np.linspace(0, max(comment_count_list), max(comment_count_list)+1, dtype=int)
y = np.zeros(max(comment_count_list)+1)

for count in comment_count_list:
    y[count] += 1

plt.plot(x, y)
plt.xlabel('number of characters')
plt.ylabel('Number of comments')
plt.show()

comment_count_list = []
for i, comment in enumerate(row_data):
    comment_count_list.append(len(comment))
    
y = np.zeros(max(comment_count_list)+1)

for count in comment_count_list:
    y[count] += 1

start = 0
max_count = max(comment_count_list)+1
x = []
new_y = []
for num in range(50, max_count, 50):
    new_y.append(sum(y[start:num]))
    finish = num
    start = finish
    x.append(finish)
    
    
plt.plot(x, new_y)
plt.xlabel('number of characters')
plt.ylabel('Number of comments')
plt.show()

def calcNumChar(start, finish, comments):
    #コメントの文字数がstart以上, finish以下のコメント数を表示する
    print(sum(comments[start:finish+1]))

calcNumChar(100, 400, y)
# Out:
# 76.0
