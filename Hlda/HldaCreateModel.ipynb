# %%
import sys
sys.path.append('../Data')

import pandas as pd
import numpy as np
import time
from CommentDataset import CommentDataset

comment_list_name = "20230927_ootani_migihizi_syuzyutu"
comment_list_path = "2023_09_27/" + comment_list_name + ".csv"

# 指定すべき文字コードはファイルによる(cp932 or utf-8)
df = pd.read_csv("../Data/yahoo/"+comment_list_path, encoding="cp932", header=None)
# comment_list = df[0][1:].to_numpy().tolist()
comment_list = df[0][1:].to_numpy().tolist()
comment_dataset = CommentDataset(comment_list)
comment_dataset.delete_comment_specified_string(50)
comment_list = comment_dataset.comment_list
comment_dataset.formatted_input_hlda(appear_tagging_list=["名詞", "形容詞", "動詞"], stop_tagging_list=["助詞", "助動詞", "非自立"])

# %%
from hlda.sampler import HierarchicalLDA

#default
# n_samples = 500       # no of iterations for the sampler
n_samples = 500       # no of iterations for the sampler
alpha = 10.0          # smoothing over level distributions
gamma = 1.0           # CRP smoothing parameter; number of imaginary customers at next, as yet unused table
eta = 0.1             # smoothing over topic-word distributions
num_levels = 3        # the number of levels in the tree
display_topics = 50   # the number of iterations between printing a brief summary of the topics so far
n_words = 10           # the number of most probable words to print for each topic after model estimation
with_weights = False  # whether to print the words with the weights

# %%
hlda = HierarchicalLDA(comment_dataset.comment_list, comment_dataset.voc, alpha=alpha, gamma=gamma, eta=eta, num_levels=num_levels)
hlda.estimate(n_samples, display_topics=display_topics, n_words=n_words, with_weights=with_weights)
# Out:
# HierarchicalLDA sampling
#
# .................................................. 50
# topic=0 level=0 (documents=412): 大谷, 手術, 選手, 思う, 成功, 二刀流, 活躍, 早い, 見る, 良い,
#     topic=1 level=1 (documents=119): 打者, 投手, 手術, 負担, リハビリ, れる, 身体, 大谷翔平, 言う, せる,
#         topic=2 level=2 (documents=8): 与える, 子供, 存在, 世の中, スイーパー, これ, 再来年, ベスト, 向ける, 解説者,
#         topic=7 level=2 (documents=7): 舞台, 聞く, 前向き, こちら, 微笑む, 理由, 気味, 張り, 好く, 自分,
#         topic=9 level=2 (documents=7): どこか, 継続, 決断, 方向性, 運ぶ, 強豪, 進化, 種類, 支える, ブランク,
#         topic=11 level=2 (documents=11): 靭帯, 継続, 鍛える, 記録, 強化, ホームラン, 超える, 早期, 徹底, 出力,
#         topic=17 level=2 (documents=14): マメ, 続ける, 超一流, 感動, 努める, 焦る, 指先, 無理, 治す, プレースタイル,
#         topic=20 level=2 (documents=2): くん, 左腕, 星飛雄馬, 右腕, 大リーグボール, できる, 終わる, 頑張る, 大好き, 3号,
#         topic=24 level=2 (documents=7): 生きる, オーバーワーク, 努力, 熱意, みる, 延びる, シュート, 確実, 勝ち取る, 一足,
#         topic=35 level=2 (documents=5): 9月, 監督, 日本語, 話す, がる, 翔平, 早期, 事実, 悔しい, 稀代,
#         topic=39 level=2 (documents=10): 仕事, アメリカ, 素人, 山本昌, 凄い, 休日, 9割, うれしい, 遅い, 潰す,
#         topic=43 level=2 (documents=18): 途中, 離脱, 打つ, 絞る, 万全, 楽しい, 酷使, ベーブルース, 成績, 状態,
#         topic=44 level=2 (documents=8): 困難, あなた, たくさん, 進化, 箇所, 帰国, 左投手, 起きる, 使用, オペ,
#         topic=46 level=2 (documents=7): 筋肉, パワー, 打撃, しなやか, 作用, 大切, 以降, じん帯, 勝利, 損傷,
#         topic=50 level=2 (documents=7): 出る, 持つ, 期待, 監督, 方向, 勝つ, 残る, 履く, それぞれ, 靴下,
#         topic=59 level=2 (documents=8): 来年度, 大好き, 心配, 付ける, 来期, 2025年, 凄まじい, 精神力, 来年以降, 靱帯,
#     topic=3 level=1 (documents=128): 打者, 投手, リハビリ, 投げる, れる, 手術, チーム, 言う, これ, 今後,
#         topic=4 level=2 (documents=9): 保存, 療法, 迎える, 球速, メンタル, 何より, よる, 太鼓判, ベンチ, 信じる,
#         topic=5 level=2 (documents=6): 遠征, ダブルヘッダー, 帯同, 数多い, 判る, いずれ, 試練, 間違い, ジャッジ, 悔い,
#         topic=6 level=2 (documents=12): 負担, 変化球, 原因, 必要, 減らす, 期間, 多投, 超える, 回数, 鍛える,
#         topic=8 level=2 (documents=13): 悲鳴, 上げる, 酷使, ブランク, 本来, トレーニング, 勇気, 逃れる, マネジメント, ある意味,
#         topic=10 level=2 (documents=9): イチロー, 前回, ピッチャー, 十分, 確実, クリニック, 両方, 濁す, 出す, テレビ,
#         topic=19 level=2 (documents=6): 靭帯, 移植, 年俸, れる, 違う, 環境, 高額, 感覚, 始まる, 打つ,
#         topic=22 level=2 (documents=10): エンゼルス, 早期, 含める, 感じる, 監督, 残留, 予想, タイミング, くん, 契約,
#         topic=25 level=2 (documents=7): カーブ, こだわる, 現役, 25年, 厳しい, 長期契約, 二刀流, 60本, どちら, スイーパー,
#         topic=28 level=2 (documents=10): 十分, さん, 在る, 小生, 体調, トミー, 壊れる, パフォーマンス, 御見舞い, 御座る,
#         topic=30 level=2 (documents=9): 挑戦, ベスト, 目標, タイトル, 打てる, 高校生, 遅れる, 獲得, マウンド, 野球,
#         topic=38 level=2 (documents=3): かける, 安め, 待てる, 完璧, 慌てる, ダイジョーブ博士, いつか, 3年, 二刀流, 鼓舞,
#         topic=52 level=2 (documents=5): 今後, 全休, 判る, 一つ, 改め, とも, 困難, 覚悟, 最初, 打ちまくる,
#         topic=54 level=2 (documents=6): ワールドシリーズ, あちこち, 感謝, 痛い, くる, 終わる, 超える, 移籍先, 兼ねる, 休める,
#         topic=55 level=2 (documents=7): メディア, マスコミ, 話題, 情報, 同質, 冷静さ, 温床, でる, ジャニーズ事務所, 繰り返し,
#         topic=58 level=2 (documents=4): いう, 大リーグボール, 一つ, 複雑, 来年, 滑る, 養生, そのままで, ルール, 進む,
#         topic=60 level=2 (documents=10): スタート, 今年, 塁打, とも, トレード, 渡る, 貴方, 覚える, イイ, 争い,
#         topic=61 level=2 (documents=2): 失敗, 成否, 医師, そのもの, 無理, 経過, 確認, 具合, 勝負, プラン,
#     topic=12 level=1 (documents=97): 投手, 打者, リハビリ, 無理, れる, 二刀流, 言う, 負担, 投げる, さん,
#         topic=13 level=2 (documents=12): ボール, 滑る, メジャー, 多い, 日本, コミッショナー, 怪我人, 真剣, 改善, 会社,
#         topic=21 level=2 (documents=8): 程度, ムリ, 骨折, 登板間隔, 治る, しない, 途中, 段取り, 世界, 誇り,
#         topic=23 level=2 (documents=4): 時間, わかる, 優秀, もらう, 早い, 知る, 見れる, 具体, 3冠王, 60本,
#         topic=26 level=2 (documents=2): もらえる, そうだ, 日本中, 決まる, 報告, 会社, 伸ばす, 伴う, 伝説, 伝わる,
#         topic=29 level=2 (documents=8): 責任, 現役, 2度目, 2025年, バッター, 二刀流, 真骨頂, パワーアップ, 自身, マイル,
#         topic=32 level=2 (documents=15): チーム, 戻れる, グラウンド, 離れる, 仕方, 一日, 経験, 残り, 推測, 大好き,
#         topic=34 level=2 (documents=7): 判断, 新た, 慎重, 疲労, 球種, 送る, 非常, それ, おき, エール,
#         topic=37 level=2 (documents=14): 着る, ユニフォーム, 怖い, キット, 見せる, 健康, 与える, 辛い, ケア, 挑戦,
#         topic=41 level=2 (documents=8): 始まる, 前回, いない, いく, 好成績, 見える, 好き, 改善, 事実, 帰る,
#         topic=53 level=2 (documents=9): 短い, 寿命, すごい, 認識, よい, 事態, 判断, kore, 払拭, そう,
#         topic=56 level=2 (documents=10): 故障, 報道, 出来る, 出し手, 含める, ニュース, 要素, リスク, 作りあげる, 最高峰,
#     topic=14 level=1 (documents=68): 打者, 投手, リハビリ, 二刀流, れる, 無理, 投球, 投げる, ホームラン王, 身体,
#         topic=15 level=2 (documents=15): 取れる, 今期, あと, いける, 勝る, 残念, 期間, あげる, 毎日, 最多勝利,
#         topic=18 level=2 (documents=10): 今回, 不幸, 大谷, 対応, 幸い, 来年, 野手, オペ, 2021年, 全盛期,
#         topic=31 level=2 (documents=9): そこ, 速い, 原因, 2年後, 期間中, 無双, 意味, 投球フォーム, 修正, 規格外,
#         topic=36 level=2 (documents=4): 貰う, サン, 出す, クセ, 残る, お金, 見せつける, 全米, 最終戦, アナハイム,
#         topic=42 level=2 (documents=12): 行動, 決断, 人間, きつい, 振る, みる, 素早い, 悲しい, 速い, 失敗,
#         topic=45 level=2 (documents=8): タイトル, 右肘, 意味, 疲労, スケジュール, 備える, 打席, 減る, 評価, 2倍,
#         topic=48 level=2 (documents=8): 立てる, バッターボックス, 痛み, もらう, 内容, 超人, 走る, トレーニング, 記事, 疲労困憊,
#         topic=49 level=2 (documents=2): ヵ月, ケガ, 集まる, 単純, 無駄, 遅い, 気が付く, 知る, 冷静, 打者,
# .................................................. 100
# topic=0 level=0 (documents=412): 手術, 大谷, 選手, 思う, 成功, 活躍, 二刀流, リハビリ, 早い, 良い,
#     topic=1 level=1 (documents=74): 打者, できる, 投手, れる, 故障, 専念, 球団, それ, 負担, 言う,
#         topic=2 level=2 (documents=8): 言葉, 先生, すごい, 現役生活, 労り, 観る, つくる, 判断, 調子, 包む,
#         topic=11 level=2 (documents=8): 失敗, 靭帯, 感覚, 投手, 受ける, 160km, 転向, 争い, 影響, 豪速球,
#         topic=20 level=2 (documents=4): アスリート, ニュース, 逃れる, 稀代, 始まる, 待ち望む, 快い, バッターボックス, トレーニング, 恥ずかしい,
#         topic=24 level=2 (documents=7): 肉体, 強化, これだけ, 言える, 離脱, 疑問, ファン, 甘い, 好調, 明らか,
#         topic=35 level=2 (documents=8): 今シーズン, 乗り越える, 舞台, 疲労, みんな, 増す, 体力, 登板間隔, 決める, 癒す,
#         topic=50 level=2 (documents=13): 原因, 復帰後, 速い, スライダー, 球速, 確か, 変わる, 印象, 投球, つける,
#         topic=62 level=2 (documents=3): ユニフォーム, 再来, 控える, 年度, 万全, 前人未到, 得る, 注意, 着ける, 払う,
#         topic=74 level=2 (documents=13): 野球, 楽しい, 一つ, ヵ月, 楽しむ, 短い, 人生, 人物, スポーツ, 楽しみ,
#         topic=76 level=2 (documents=4): 筋肉, パワー, しなやか, 投げる, イチロー, 相当, シーズン中, 共存, 稲葉, 作用,
#         topic=81 level=2 (documents=6): マメ, 勝てる, 一人, 問題, 来年度, 指先, それぞれ, 役割, 発生, ブランク,
#     topic=3 level=1 (documents=136): 打者, できる, 投手, れる, 専念, これ, 言う, 大谷, 身体, 二刀流,
#         topic=4 level=2 (documents=9): ピッチャー, 三冠王, 目標, 目指す, 来年, 安心, とんでも, 実行, ここ, 帯同,
#         topic=5 level=2 (documents=7): アメリカ, 一番, 判断, くる, 非常, 残る, よろしくお願いします, テレビ, 至る, ホント,
#         topic=6 level=2 (documents=6): マイル, 減らす, 超える, 期間, 変化球, 軟投, 回数, 仕方, 知れる, 同様,
#         topic=8 level=2 (documents=9): 安堵, 毎日, 寂しい, 多く, 観る, 日本人, 起きる, 上回る, プラス, 映画,
#         topic=22 level=2 (documents=13): 残留, エンゼルス, 可能性, 一流, 問題, 決断, 予想, 契約, 判断, その後,
#         topic=30 level=2 (documents=4): 成否, どこ, 終盤, 数字, 記事, 出し手, 切り上げる, 抜かる, このまま, こっち,
#         topic=52 level=2 (documents=3): ロス, 併せる, 一年, 十二分, 医療, シーズン中, 我慢, 残る, 去年, 明らか,
#         topic=55 level=2 (documents=9): 残念, 前向き, 可能性, 本塁打, 年俸, 量産, 打てる, 高い, 狙う, 三冠王,
#         topic=58 level=2 (documents=5): 十分, れる, 証拠, 始まり, 幸せ, 出す, 思案, ゴミ, 依頼, 生きる,
#         topic=60 level=2 (documents=3): 聞く, 貢献, 疲労, 健康, アプローチ, 生じる, 取り入れる, ムリ, 科学, 第一,
#         topic=61 level=2 (documents=6): 多い, トラウト, 速球, 剛腕, 脱却, いちばん, ボール, 進める, 時点, トラブル,
#         topic=71 level=2 (documents=9): 違う, 難しい, 勝利, 一人, 推測, 2019年, 管理, 種類, 改善, 筋肉,
#         topic=75 level=2 (documents=8): 示す, シーズン終了, 必至, 不安要素, 違い, 残留, 労う, 払拭, 投手部門, シーズン中,
#         topic=87 level=2 (documents=4): 交渉, 盗塁, 怪しい, 延びる, デカ, 残り, 決まる, ロードマップ, 動画, 動き,
#         topic=92 level=2 (documents=5): 比べる, ルール, 優秀, 大リーグボール, そのままで, 診察, ものすごい, ダル, 早急, 過ぎる,
#         topic=93 level=2 (documents=7): 継続, 契約, 結ぶ, 翔平, 今後, 選ぶ, 迎える, 種類, 色あせる, 年齢,
#         topic=94 level=2 (documents=8): マスコミ, メディア, 情報, 一方通行, 痛い, 今度, 加熱, たん, 過ぎる, 冷静さ,
#         topic=95 level=2 (documents=10): メジャー, 療法, 確定, 一緒, ゲーム, 3年間, 人的, 公式, 何より, 絞める,
#         topic=96 level=2 (documents=7): 左腕, 空く, ブランク, くん, 星飛雄馬, 申し上げる, 第一, 舞い降りる, 大丈夫, 切れる,
#         topic=100 level=2 (documents=4): 留学, 期間, アメリカ, 3人目, 母校, 大学, 応援, 設ける, 花巻東, 岩手県,
#     topic=12 level=1 (documents=110): 打者, 投手, れる, 二刀流, 言う, できる, 負担, 投げる, 野球, 身体,
#         topic=13 level=2 (documents=10): ボール, 滑る, 日本, メジャー, 供給, 寿命, コミッショナー, 負担, 聞く, 真剣,
#         topic=26 level=2 (documents=4): 片付ける, ロッカー, 完治, 持つ, 間髪, 悔しい, 一瞬, 終了, 話す, 充分,
#         topic=29 level=2 (documents=12): 困難, あなた, 今後, 箇所, もらえる, 故障, たくさん, 一年, 乗り越える, 左投手,
#         topic=32 level=2 (documents=7): 抜く, 度肝, 完璧, 待てる, 3年, いつか, 我々, 生命線, 2年, ナンバーワン,
#         topic=56 level=2 (documents=6): 程度, ムリ, がんばる, トミー, 身体, ホームラン, 一部分, 変わる, 治癒, 治る,
#         topic=68 level=2 (documents=7): 始まる, 鼓舞, 承知, 短い, 主力, トレード, 移籍, 過酷, チャンピオン, 半年,
#         topic=69 level=2 (documents=8): つく, 1日, 喜ばしい, 早め, 想像, 来年, 期間, 知れる, ホット, 成功率,
#         topic=82 level=2 (documents=5): 祈る, 有る, 現地, ポストシーズン, 過ごす, 好成績, 覚悟, 周囲, 移籍, 静か,
#         topic=85 level=2 (documents=10): ニュース, ベーブルース, 理由, 極限, 周り, 比べる, 20代, 勇姿, 上手, いつ,
#         topic=88 level=2 (documents=7): ホームラン, 元気, 塁打, 休日, スタート, 5時, バッターボックス, 稼働, 可能, 右肘,
#         topic=90 level=2 (documents=9): すごい, 球界, きつい, 実績, 感動, 押す, そこ, さん, この先, 貯める,
#         topic=91 level=2 (documents=13): 限界, 超える, 耐える, 鍛える, 避ける, 強化, 徹底, 個人的, 出力, いく,
#         topic=97 level=2 (documents=8): 9割, 素人, 山本昌, ベスト, 止める, 離脱, 難しい, 遅い, 振り切る, そのため,
#         topic=99 level=2 (documents=4): ピッチャー, 球種, 両方, 年間, おき, 一年, ここ, チェンジアップ, 労う, 夢見る,
#     topic=14 level=1 (documents=92): 打者, 大谷, 投手, 二刀流, 言う, 来年, れる, それ, 専念, 身体,
#         topic=15 level=2 (documents=13): 今期, ホームラン王, 間違い, 球団, オーバーワーク, 期待, 来期, 勝る, 聞く, 変わる,
#         topic=31 level=2 (documents=10): 厳しい, 精神力, 走る, 素晴らしい, 蘇る, 待ち遠しい, 術後, 含める, いない, 痛感,
#         topic=36 level=2 (documents=5): こだわる, 世界, 医療, オフ, 偉大, でる, 永遠, 最先端, バット, 続ける,
#         topic=45 level=2 (documents=4): 報道, ダブルヘッダー, 出し手, 日程, 昨日, 仕振り, 求める, ベンチ入り, 大谷久, この辺,
#         topic=48 level=2 (documents=9): チーム, 貰う, 離れる, 来季, グラウンド, 仕方, さん, 戻れる, 立つ, 出す,
#         topic=64 level=2 (documents=5): 療法, 保存, ユニフォーム, 最善, バッティング, 回復力, 過酷, 過ごす, 構造, 手助け,
#         topic=67 level=2 (documents=10): くん, 大好き, 翔平, 備える, 早期, 聞く, 素敵, 存在, 楽しみ, 大切,
#         topic=70 level=2 (documents=10): 野手, 不幸, 幸い, オペ, 焦る, けが, 出し手, 普段, 向う, 信頼,
#         topic=79 level=2 (documents=6): 行動, 打席, 結果, 個人, 立つ, 伝説, 年代, 病気, 関係, 万が一,
#         topic=80 level=2 (documents=11): 勇気, 我々, 野球選手, 130打点, 3冠王, よう, 興奮, 鍛える, 対応, チーム,
#         topic=98 level=2 (documents=9): 以前, 自身, 最近, サン, 小生, 責任, 増す, 球速, 在る, 心境,
# .................................................. 150
# topic=0 level=0 (documents=412): 手術, 大谷, 思う, 選手, 成功, 活躍, 早い, リハビリ, 見る, できる,
#     topic=1 level=1 (documents=109): 二刀流, 投手, 打者, 言う, メジャー, 来年, 本人, 専念, 野球, 今後,
#         topic=11 level=2 (documents=5): キット, 悔い, 今月中, 伝わる, 祝福, 左右, 苦難, 怖い, 沸かす, 高まる,
#         topic=20 level=2 (documents=8): 好き, 貰う, 継続, ロッカー, 出す, 焦る, 変わる, 影響, 出る, 話す,
#         topic=24 level=2 (documents=5): 始まる, シーズン終了, きつい, 仕事, ドキュメント, 無い, 貯める, 忍耐, 自ら, 前回,
#         topic=62 level=2 (documents=6): 目指す, 判定, 指定薬物, 大人, どこか, スイーパー, 強化, プレー, チーム, 素人目,
#         topic=76 level=2 (documents=11): そこ, 管理, 獲る, 改善, ホント, 一流, ホームラン王, 難しい, 3つ, 投球,
#         topic=81 level=2 (documents=10): 貴方, 感謝, 試練, スタート, 苦難, 塁打, 多い, 多く, 度肝, 正確,
#         topic=113 level=2 (documents=9): クリニック, 十分, 執刀, 医師, 現場, 通用, 雄姿, 消耗品, 治す, 報道,
#         topic=115 level=2 (documents=12): もらう, 打者, 執刀, 始まる, 記事, バッターボックス, 来期, トミー, 比類, 回復,
#         topic=125 level=2 (documents=3): 療養, ブランク, 空く, 有名, 埋める, 2年, 天使, 疲れ, 大変, 大きい,
#         topic=129 level=2 (documents=7): 滑る, ボール, 理由, 負担, たち, 身体, 見せつける, 打点, 使用, 専念,
#         topic=132 level=2 (documents=4): ヵ月, 小生, 在る, 何はともあれ, 痛い, ケガ, まかせる, 御見舞い, 不思議, 説き伏せる,
#         topic=138 level=2 (documents=13): 継続, 選ぶ, 強化, 今後, 終える, 術後, メンテナンス, 何事, 確保, 置く,
#         topic=139 level=2 (documents=6): 分かる, 療法, 2年, 方法, 9月, 保存, 第一線, 患部, 囁く, マジ,
#         topic=140 level=2 (documents=6): 過ぎる, 感じ, だし, 投手, イチロー, 優秀, 程度, 信号, 条項, 本腰,
#         topic=141 level=2 (documents=4): シーズン終了, 記事, 診察, 焦る, 治癒, 世界的, 最初, 速報, 断る, 平癒,
#     topic=3 level=1 (documents=108): 打者, 二刀流, 投手, 負担, 言う, 故障, 投げる, 身体, これ, それ,
#         topic=4 level=2 (documents=7): 取る, 正直, 何色, 相性, ごと, 終える, シーズン中, 記憶, 必然, 時間,
#         topic=5 level=2 (documents=3): 投打, 来期, 泣かせる, 一同, 言葉, 休養, 更新, 最多, くださる, 鍛え上げる,
#         topic=22 level=2 (documents=7): チーム, 仕方, グラウンド, 戻れる, 責任, 目指す, 采配, 立つ, 悪い, 怠る,
#         topic=52 level=2 (documents=10): 観る, うれしい, 希望, 今年, 年間, 仕事, テレビ, 勝手, 休日, 報道,
#         topic=60 level=2 (documents=6): あなた, 箇所, 左投手, 困難, たくさん, リスク, 不安, 語らう, 不透明, そう,
#         topic=61 level=2 (documents=8): 減らす, 寿命, 掛ける, 回数, 短い, 期間, できる, 変化球, 今季, 掛かる,
#         topic=71 level=2 (documents=7): エンゼルス, 契約, 早期, 交渉, タイミング, 監督, 残留, 時期, 予想, ギリギリ,
#         topic=75 level=2 (documents=10): 続く, 年間, 専門, おき, 結果, 素晴らしい, いいかえる, トレーニング, いくら, ここ,
#         topic=100 level=2 (documents=5): 全開, 分かる, 科学, 自制心, 改める, 見据える, 争い, 種類, 内容, 向き合う,
#         topic=107 level=2 (documents=2): コメント, 成績, 鼓舞, 伸びる, 伸ばす, 伴う, 伝説, 伝わる, 会社, 似合う,
#         topic=108 level=2 (documents=10): 2度目, 違う, 普通, 勇気, 前回, 感覚, 筋肉, 絶好調, 有る, 経験,
#         topic=121 level=2 (documents=7): ボール, 願う, 開幕戦, 真剣, 会社, いない, ファン, 寂しい, 供給, 定期的,
#         topic=128 level=2 (documents=13): 程度, 原因, 復帰後, 速い, ムリ, スライダー, スイーパー, 球速, 曲げる, 印象,
#         topic=130 level=2 (documents=4): 現実, 検証, いける, 飛躍, 問題, ボール, でる, 年間, ペース, 最優秀防御率,
#         topic=144 level=2 (documents=9): 以降, 2025年, 無事, 2021年, ショート, 間に合う, 一人, 本塁打, 2倍, 来年以降,
#     topic=12 level=1 (documents=87): 打者, 二刀流, 専念, 言う, 投手, 野球, 本人, 身体, 今後, 負担,
#         topic=13 level=2 (documents=8): 大好き, 失敗, 話題, 大谷, キット, 静養, くい, 最悪, 再出発, 一安心,
#         topic=29 level=2 (documents=9): 本来, どこ, おかしい, 出力, 強化, 専念, 24年, 正直, 向ける, 移籍,
#         topic=56 level=2 (documents=4): 目指す, 来年度, こちら, 入れ直す, 朗報, 年度, 震わす, 一日, 癒す, コメント,
#         topic=97 level=2 (documents=5): 無理, 慌てる, いつか, 執刀, かける, 待てる, 2年, 結果, 成功率, 協議,
#         topic=99 level=2 (documents=12): ピッチャー, そう, 絞る, 成績, いく, 現役, 面白い, イチロー, バッター, 一つ,
#         topic=101 level=2 (documents=7): 筋肉, パワー, 耐える, 観る, しなやか, シーズン中, 言葉, イチロー, 人的, インタビュー,
#         topic=105 level=2 (documents=8): 笑顔, お祈り, 含める, 素敵, 勇姿, もらえる, くん, 過酷, 走攻守, くださる,
#         topic=106 level=2 (documents=7): メディア, マスコミ, 待つ, 来年度, 情報, 一方通行, 2度, これ, 冷静さ, つきまとう,
#         topic=111 level=2 (documents=5): 確立, 個人的, 成否, プレースタイル, 医師, 具合, 故障, 医学, 開始, 生身,
#         topic=117 level=2 (documents=3): 成功, 通り, 取り除く, きたす, 痛み, 支障, 最多勝利, 運動障害, グラウンド, 打撃,
#         topic=135 level=2 (documents=10): 感心, 予定, 終盤, 規格外, 処置, 切り上げる, スムーズ, フル, 待ち, 上積み,
#         topic=137 level=2 (documents=5): 大谷, 部位, 回避, 軟投, 超える, 領域, 仕方, 怪物, マイル, 原因,
#         topic=142 level=2 (documents=3): 左腕, 星飛雄馬, めぐる, 大好き, 希望, 切れる, 仕振り, 昨日, 大リーグボール, 若い,
#         topic=145 level=2 (documents=1): 記事, 快復, 選ぶ, 無くなる, 驚き, 個人, 過去形, 進出, ポストシーズン, 会う,
#     topic=14 level=1 (documents=108): 二刀流, 打者, 投手, それ, 専念, 野球, 身体, これ, 言う, 続ける,
#         topic=15 level=2 (documents=12): 今期, 狙う, ホームラン王, 間違い, オーバーワーク, その間, 安心, いずれ, 勝る, 明らか,
#         topic=31 level=2 (documents=8): 対応, 盗塁, 夢見る, 全盛期, 共有, ホームラン, 野手, 経過, 大変, 疲労,
#         topic=48 level=2 (documents=9): 日本, スーパースター, 130打点, 惜しむ, 後輩, 野球選手, 翌シーズン, 60本, 拾う, 大リーガー,
#         topic=79 level=2 (documents=8): みる, 高額, とはいえ, 短い, 寿命, いつまでも, 速球, 凄い, 3年間, 40歳,
#         topic=80 level=2 (documents=7): 判断, 復帰, 残留, 至る, 非常, スピーディー, 試す, 人間性, 影響, 注目,
#         topic=98 level=2 (documents=8): マメ, 痛める, 一つ, 多い, 入れる, 頼る, 滑る, 大リーグボール, 監督, トラブル,
#         topic=104 level=2 (documents=6): 向く, 超一流, 相当, 球界, 自分, 言う, 育成, 素人, 純粋, 祈る,
#         topic=114 level=2 (documents=7): じん帯, 損傷, 着る, ひじ, 装具, 痛める, ユニフォーム, 払う, グラウンド, 不死身,
#         topic=116 level=2 (documents=6): 9割, 山本昌, 通用, 一緒, 遅い, 素人, 見直す, 運ぶ, れる, 申し訳ない,
#         topic=118 level=2 (documents=8): 行動, ダブルヘッダー, 振る, 入れる, 余裕, 是非, 2試合, 一流, 痛み, 張り,
#         topic=123 level=2 (documents=4): 舞台, 送る, こちら, ボロボロ, 好く, 越し, 興奮, 引き際, 指し手, 歩み,
#         topic=127 level=2 (documents=13): 酷使, 挑戦, トレーニング, 球速, ケア, 奇跡, 最近, マネジメント, ケガ, 上げる,
#         topic=136 level=2 (documents=1): 炎症, 挑戦, 鼓舞, 伝わる, 伸びる, 伸ばす, 伴う, 伝説, 会社, 似合う,
#         topic=143 level=2 (documents=11): 持つ, 才能, ホント, 滑る, 休む, コミッショナー, 疑問, 自分, 私利私欲, 見せる,
# .................................................. 200
# topic=0 level=0 (documents=412): 手術, 大谷, 選手, 成功, 思う, 活躍, リハビリ, 良い, 見る, れる,
#     topic=1 level=1 (documents=91): 二刀流, 打者, 投手, 早い, 専念, これ, 言う, 負担, 無い, メジャー,
#         topic=20 level=2 (documents=12): 難しい, つける, そこ, でる, 痛い, 違う, ドクター, 何処, 何はともあれ, 接触,
#         topic=24 level=2 (documents=11): どちら, 疑問, 小生, つく, 在る, 御座る, パワーアップ, 心身, 判定, 心境,
#         topic=81 level=2 (documents=12): ボール, 日本, 滑る, 多い, それ, 検討, 行く, 供給, 言える, 登板,
#         topic=113 level=2 (documents=1): メディア, マスコミ, 一方通行, 情報, 言う, つきまとう, 倣う, 連日, ジャニーズ事務所, 同質,
#         topic=115 level=2 (documents=13): ピッチャー, 両方, 打てる, 挑戦, 余裕, イチロー, 登板, 目標, いく, 獲得,
#         topic=125 level=2 (documents=8): 場所, スタート, 塁打, おかしい, ごと, 一部, 築く, 生き甲斐, 右肘, ホームラン,
#         topic=132 level=2 (documents=5): マメ, 指先, 壊れる, 専門, ながい, 接触, 改める, 全開, 一人, 出端,
#         topic=139 level=2 (documents=11): 今後, 苦難, あなた, 気持ち, 困難, 全休, 励ます, 2025年, 起きる, たくさん,
#         topic=166 level=2 (documents=1): 感謝, 鼓舞, 位置, 似る, 伸びる, 伸ばす, 伴う, 伝説, 伝わる, 会社,
#         topic=171 level=2 (documents=7): 登板間隔, 欲しい, 一人一人, 靱帯, 映る, 正直, テレビ, 向ける, 組める, プロ野球,
#         topic=177 level=2 (documents=2): 再来, 体制, コメント, ワールドシリーズ, いう, 大切, 休める, 素敵, きた, 休養,
#         topic=179 level=2 (documents=8): 球種, 発表, 年間, どれ, おき, 癒す, 一つ, スタイル, 理解, 明らか,
#     topic=3 level=1 (documents=124): 打者, 二刀流, 早い, 投げる, 投手, できる, 負担, 専念, 言う, シーズン,
#         topic=5 level=2 (documents=9): 延ばす, タイトル, みる, 左投手, 進化, そりゃ, 生きる, 労力, いずれ, 無事,
#         topic=22 level=2 (documents=7): 残る, エンゼルス, 貰う, 方向, 今度, 慎重, 無くなる, 井口, 沸かす, 着る,
#         topic=60 level=2 (documents=3): 嬉しい, ギリギリ, 本気, チームメイト, 一生懸命, 予定, 泣く, ベスト, 来る, 残り,
#         topic=108 level=2 (documents=5): 持つ, 存在, 子供, 世の中, 立てる, バッターボックス, 一流, 疑問, 越える, 嬉しい,
#         topic=121 level=2 (documents=10): 変化球, かかる, 減らす, 登板, 必要, 多投, 球種, 開幕戦, 期間, あれだけ,
#         topic=128 level=2 (documents=7): 原因, 速い, 復帰後, 球速, 無双, そこ, 期間中, 半年, つける, じん帯,
#         topic=130 level=2 (documents=9): 経験, 対応, 万全, 場合, 永遠, 属す, いつまでも, マウンド, 悪い, 順調,
#         topic=144 level=2 (documents=5): コミッショナー, 私利私欲, 稀代, 食い潰す, 療法, 選択, 拝める, 生命, 貰う, 代わる,
#         topic=148 level=2 (documents=5): 自ら, きつい, 望む, 設ける, 他人, オフ, 向く, 貯める, 渡米, 超一流,
#         topic=149 level=2 (documents=13): 観る, 毎日, うれしい, 安堵, テレビ, 勝手, 休日, 日本人, 素人, 開く,
#         topic=154 level=2 (documents=8): 離れる, 戻れる, 環境, 悪い, どれ, グラウンド, 終わる, 個人的, 本意, 2年後,
#         topic=155 level=2 (documents=7): 酷使, 理由, 継続, 説明, 医師, 復帰, 変更, 重き, 印象, 思える,
#         topic=159 level=2 (documents=7): 向ける, じん帯, 一番, 伸びる, 正解, 以降, ニュース, 悪化, スイング, 速報,
#         topic=160 level=2 (documents=10): 大きい, 才能, 事態, 時間, 繋がる, タイミング, 場合, 周囲, 違い, 掛ける,
#         topic=170 level=2 (documents=11): 投手, アメリカ, 観る, 感じ, ブランク, 言える, 継続, これだけ, メンテナンス, 恐怖心,
#         topic=175 level=2 (documents=3): 年俸, 打てる, 手のひら返し, 泣かせる, 言葉, 一同, 思い知らす, 東海岸, とはいえ, バッシング,
#         topic=183 level=2 (documents=5): 逃げ, 中心, 出し手, プロ野球選手, 痛み, 3年間, 40歳, 上回る, カーブ, 野球小僧,
#     topic=12 level=1 (documents=104): 二刀流, 思う, できる, 打者, 長い, 早い, 投げる, 投手, 続ける, シーズン,
#         topic=13 level=2 (documents=4): キレ, そこ, カーブ, 最近, チームメイト, 患部, 頑張る, コントロール, 療法, 相当,
#         topic=99 level=2 (documents=6): 整理, ロッカー, すごい, 好き, 三冠王, 聞く, 遠征, 自身, 全て, はいる,
#         topic=105 level=2 (documents=13): 大好き, 若い, 休める, がんばる, 飛躍, 労う, 大切, 笑顔, 疲れ, くん,
#         topic=111 level=2 (documents=4): 報道, 増税, 死ぬ, 聞かす, 仕振り, いつ, 求める, オペ, この辺, 平癒,
#         topic=117 level=2 (documents=8): ブランク, スーパースター, スポーツ界, 忍耐, オーバーワーク, 始まる, 確実, 来年度, 羽生結弦, 切る,
#         topic=137 level=2 (documents=11): 超える, 仕方, 必要, マイル, 身体, 鍛える, 追求, 靭帯, 領域, 期間,
#         topic=152 level=2 (documents=5): 現役, サン, さん, 付ける, ボール, 靱帯, 仰向け, アメリカ, 歪める, 番組,
#         topic=156 level=2 (documents=6): 本塁打, 以降, 打てる, 打点, もらえる, 明確, 2021年, 踏み切る, 残す, 来年以降,
#         topic=164 level=2 (documents=3): 先生, 送れる, 情報, 心強い, 酷使, 永い, 濃厚, 休み, 適宜, 言葉,
#         topic=167 level=2 (documents=6): エンゼルス, タイミング, 感心, 失敗, 終盤, 経過, 上積み, あれ, 無い, 待ち,
#         topic=172 level=2 (documents=2): 速報, チーム内, 鼓舞, 休養, 伴う, 伝説, 伝わる, 会社, 会う, 休暇,
#         topic=173 level=2 (documents=8): 行動, 現役, 振る, 決める, あと, こだわる, 1年間, 是非, 迷う, いつか,
#         topic=178 level=2 (documents=4): 移植, 争い, 鼓舞, 出場, チャンピオン, どこ, 放出, 大事, ホームラン, 靭帯,
#         topic=180 level=2 (documents=8): 勇気, 帰る, 届ける, 確信, 進化, いない, 駆け抜ける, そう, 3冠王, 60本,
#         topic=181 level=2 (documents=6): プレースタイル, 保存, 出力, 療法, 耐える, 無い, 必要, 見舞う, 開幕, 懸念,
#         topic=182 level=2 (documents=5): 早い, 伝わる, 美しい, 日程, 試合, 純粋, 見事, 間隔, 内容, 驚く,
#         topic=185 level=2 (documents=4): 星飛雄馬, 左腕, 補修, 数多い, 20本, 起用, 勝ち星, 3割, 40本, 打率,
#         topic=186 level=2 (documents=1): 鼓舞, 会う, 伸びる, 伸ばす, 伴う, 伝説, 伝わる, 会社, 休養, 似合う,
#     topic=14 level=1 (documents=93): 二刀流, 打者, 投手, 早い, 思う, 無理, 専念, 長い, できる, シーズン,
#         topic=15 level=2 (documents=14): ホームラン王, 今期, 取れる, 球団, 復活, 普通, 間違い, 三冠王, 変わる, あげる,
#         topic=31 level=2 (documents=6): ヵ月, 遅い, 長い, イエスマン, 十二分, やり方, いいかえる, 冷静, 品柄, 言う,
#         topic=48 level=2 (documents=12): 酷使, 日本, 上げる, 帰る, 剛腕, 一安心, 日々, 移籍, そのため, 再出発,
#         topic=79 level=2 (documents=7): 我々, ひじ, じん帯, 断念, 衝撃, 状況, 接す, 挑戦, 挑む, 再来年,
#         topic=116 level=2 (documents=5): 疲れる, 獲る, バッターボックス, 偉大, ホント, できる, 32歳, 3つ, 3年間, 4つ,
#         topic=118 level=2 (documents=9): 筋肉, 投球, 意見, つける, 9割, イチロー, メジャー, しなやか, パワー, 鍛える,
#         topic=127 level=2 (documents=9): 状況, 判断, 全米, 一足, 変化, 打点, 性格, 諦める, 打つ, 山あり谷あり,
#         topic=150 level=2 (documents=13): 契約, 一つ, 舞台, リハビリ, 大リーグボール, ルール, 面白い, 結ぶ, 早期, 安堵,
#         topic=157 level=2 (documents=5): 挑戦, 感服, 大変, 奇跡, 存分, エール, 精神力, 熱量, 気軽, 再起,
#         topic=161 level=2 (documents=7): 故障, 世界的, とる, 協議, 本意, アプローチ, 本番, 皆んな, プレー, 成し遂げる,
#         topic=174 level=2 (documents=3): 程度, 繋がる, 珍しい, サン, 一緒, 治癒, 治る, バッター, 喜ばしい, 意向,
#         topic=176 level=2 (documents=3): 判断, アメリカ, 岩手県, 画素, 留学, 大谷翔平, 大学, 弱い, 大リーガー, 肩肘,
# .................................................. 250
# topic=0 level=0 (documents=412): 大谷, 手術, 選手, 思う, 成功, 活躍, リハビリ, 良い, 見る, られる,
#     topic=1 level=1 (documents=112): 打者, 二刀流, 早い, 投手, 言う, 来年, 専念, 負担, 日本, 楽しみ,
#         topic=81 level=2 (documents=16): ボール, 滑る, かかる, 故障, 検討, かける, 左投手, 使用, 供給, 活躍,
#         topic=115 level=2 (documents=9): 来年, 元気, 終える, スタート, 投打, 起きる, メジャー, 渡る, 欠かす, 昨日,
#         topic=125 level=2 (documents=8): 貰う, 獲得, 今季, 本塁打, 打つ, 来年, 伝説, 稼げる, エンゼルス, 強打者,
#         topic=166 level=2 (documents=16): エンゼルス, 残留, タイミング, 契約, 感謝, これ, 予想, 予定, 移籍先, メス,
#         topic=179 level=2 (documents=16): 療法, 厳しい, 2度目, 保存, そこ, アメリカ, 選択, トレーニング, 潰す, 走る,
#         topic=190 level=2 (documents=8): 焦る, 笑顔, 期間, 素敵, 属す, 成功率, ホー, 結果, 届ける, 疲れる,
#         topic=192 level=2 (documents=9): 安心, 作る, ルール, 記録, 大リーグボール, 自身, 体調管理, 休み, れる, 減る,
#         topic=202 level=2 (documents=6): 球団, 置く, 持つ, よい, 選ぶ, 継続, 25年, 自ら, 解雇, 言う,
#         topic=218 level=2 (documents=7): 違う, 勝利, 推測, ギリギリ, 種類, そう, 残り, 経験, 疑問, 聞こえる,
#         topic=227 level=2 (documents=6): 記録, 靭帯, パワーアップ, 中途半端, 致し方, 期する, 成熟, 期待, 疲弊, 年間,
#         topic=228 level=2 (documents=11): じん帯, 状態, ひじ, 損傷, 一番, 挑む, 日々, プレーヤー, 細心, 壊れる,
#     topic=3 level=1 (documents=132): 二刀流, 打者, 早い, 投手, 来年, シーズン, 手術, 専念, しれる, 投球,
#         topic=108 level=2 (documents=10): マメ, 様々, 管理, 開ける, 指先, 拒否, 休む, トラブル, 責任, 多い,
#         topic=121 level=2 (documents=4): られる, スタート, 孤軍奮闘, いいんじゃない, 限界, 采配, 貴重, 頑張り, 無茶, 甘い,
#         topic=128 level=2 (documents=12): 球速, 速い, 復帰後, 原因, 最近, 三冠王, 酷使, 一番, 確か, 通り,
#         topic=144 level=2 (documents=9): 療養, 母校, 心強い, 世界中, 大学, 3人目, 労り, どこか, 癒す, 帰る,
#         topic=148 level=2 (documents=7): 筋肉, 舞台, パワー, イチロー, しなやか, 耐える, 共存, 世界一, 好く, ごと,
#         topic=154 level=2 (documents=8): チーム, 離れる, とる, グラウンド, 戻れる, 聞く, 離脱, 本意, こちら, 環境,
#         topic=155 level=2 (documents=11): じん帯, 本来, 現役, 年齢, オフ, 悲鳴, 治す, くる, おかしい, 毎日,
#         topic=160 level=2 (documents=10): キット, 大好き, 静養, 労う, 変える, 再チャレンジ, 一平, 奇跡, シリーズ化, 経験,
#         topic=170 level=2 (documents=11): 普通, 三冠王, 言える, ホームラン王, 日常生活, なんだろう, 離脱, 最多勝利, 評価, 最悪,
#         topic=191 level=2 (documents=9): メディア, マスコミ, 日本, 情報, これ, 日本人, 勇気, 帰る, 一方通行, 日々,
#         topic=194 level=2 (documents=6): ひとまず, 止める, 素人, 遅れる, 打棒, 見舞う, 焦る, 拭う, プッシュ, 大リーグ,
#         topic=203 level=2 (documents=8): 応援, 相当, フルスイング, トレーニング, でる, 永い, 焦る, 視る, 最善, 貰う,
#         topic=204 level=2 (documents=3): ヵ月, 説き伏せる, 論理的, 言う, 集まる, 延びる, イエスマン, 発達, 盗塁, 説得,
#         topic=212 level=2 (documents=12): 行動, 終了, 入れる, 対応, 決断, 痛み, 監督, そこ, 管理, 検討,
#         topic=224 level=2 (documents=8): 判断, 速球, 事態, 剛腕, 寿命, 場合, 進める, 新た, 正直, 動き,
#         topic=229 level=2 (documents=4): オーバーワーク, 飛躍, いない, 終える, マース, 切り替える, プレイオフ, ジャンプ, 痛感, 寂しい,
#     topic=12 level=1 (documents=83): 二刀流, 打者, 早い, 投手, 投げる, 来年, 言う, れる, 専念, できる,
#         topic=13 level=2 (documents=11): 結果, 慎重, 完璧, 何処, 有る, 作りあげる, 最優秀防御率, 流れる, つく, 素質,
#         topic=105 level=2 (documents=11): 毎日, 観る, 希望, 寂しい, 休日, テレビ, 勝手, 乗り越える, 日本人, 印象的,
#         topic=111 level=2 (documents=4): 生きる, 熱意, みる, 時代, プレー, ゴミ, マウンド, 唯一無二, バレー, 再来,
#         topic=137 level=2 (documents=10): 程度, ムリ, しない, 投げる, 備える, 完全, 登板間隔, 定まる, 意向, 検査方法,
#         topic=167 level=2 (documents=2): 2年後, スキャンダル, 消耗品, ケア, 大好き, ゲーム, 漫画, 休暇, 無い, 一日,
#         topic=173 level=2 (documents=3): あなた, 痛い, たくさん, 困難, 明るい, 太陽, 何はともあれ, 一昨日, 彼氏, 不思議,
#         topic=185 level=2 (documents=8): 開幕, 子供, 毎日, 再来年, そう, 個人差, いつ, 税金, 見れる, られる,
#         topic=186 level=2 (documents=7): ピッチャー, 野球, 絞る, なれる, どちら, 目標, 3年間, 一つ, 高校生, 完全,
#         topic=200 level=2 (documents=8): 出力, 挑戦, 強化, パワー, 強力, 評価, 経る, 見せる, これ, わかる,
#         topic=220 level=2 (documents=5): 感じ, 観る, 免れる, 異なる, ピッチャー, 待ち望む, 上げる, 何時, 痛々しい, アスリート,
#         topic=222 level=2 (documents=2): 3割, 70本, ナンバーワン, 抜く, 度肝, 120打点, ピッチング, 楽しむ, 伝説, 似る,
#         topic=223 level=2 (documents=4): 130打点, 結果, 3冠王, 認める, 色褪せる, とてつもない, 手術, 伝説, 3年, 飲みで,
#         topic=225 level=2 (documents=8): 成功, ハイブリッド, 大事, 移植, 継続, ハッスル, 再開, 明らか, マイル, 越し,
#     topic=14 level=1 (documents=85): 二刀流, 投手, 打者, 早い, 負担, 言う, 来年, 専念, 球団, 来期,
#         topic=15 level=2 (documents=10): ホームラン王, 今期, 取れる, あげる, 喜ばしい, 勝る, 数字, 2年連続, その間, 狙う,
#         topic=79 level=2 (documents=6): 多投, 超える, 減らす, 怪物, 軟投, 開幕戦, 仕方, 知れる, 必要, 原因,
#         topic=150 level=2 (documents=2): 星飛雄馬, 左腕, 切れる, イメージ, 振る, 大リーグボール, 3号, 鼓舞, 伸ばす, 似る,
#         topic=157 level=2 (documents=5): 来季, 年間, 扱う, 知れる, 両方, スケジュール, 一年, ここ, イチロー, おき,
#         topic=161 level=2 (documents=7): 不幸, 野手, クリニック, 我々, 出し手, 興奮, 市内, 希望, ボロボロ, 医師,
#         topic=174 level=2 (documents=3): 目標, 実行, 国宝, 記録達成, わかる, 子供, 分析, 未来, 行なう, 見据える,
#         topic=195 level=2 (documents=3): 小生, 在る, 凄い, 何はともあれ, 御見舞い, 活き活き, 体調, 心境, 集中, 超人,
#         topic=211 level=2 (documents=6): 限界, 感心, 送る, 挑戦, 未来, 桑田, 覚悟, 言葉, 過ごす, 正しい,
#         topic=213 level=2 (documents=4): 全開, 主軸, お互い, きつい, 向き合う, 故障, 放出, 素直, チーム, とも,
#         topic=215 level=2 (documents=6): 乗り越える, トミー, 試練, 最強, 他人, 忍耐, 伝説, 向く, 苦しみ, 焦る,
#         topic=216 level=2 (documents=7): 過ぎる, 優秀, 新庄, ベイブルース, キャリアハイ, 治療, カバー, 記録, たまの, 40歳,
#         topic=217 level=2 (documents=3): 執刀, いつか, 2年, 3年, 待てる, 復活, ダイジョーブ博士, 慌てる, 塗り替える, かける,
#         topic=219 level=2 (documents=9): 整理, ダブルヘッダー, ロッカー, 数多い, 驚く, 豪快, 指導, 治す, 余裕, たまらない,
#         topic=221 level=2 (documents=4): 9割, 高額, 試練, 山本昌, 160キロ, 意見, 専念, 通用, 根本的, バッシング,
#         topic=226 level=2 (documents=10): 失敗, 普通, 環境, 感覚, 凄い, アメリカ人, 優先, 蓄える, 入団, 要請,
# .................................................. 300
# topic=0 level=0 (documents=412): 大谷, 手術, 思う, 選手, 成功, 活躍, リハビリ, れる, 見る, できる,
#     topic=1 level=1 (documents=95): 二刀流, 早い, 打者, 投手, 投げる, 来年, 言う, 良い, 大谷翔平, 負担,
#         topic=81 level=2 (documents=9): ボール, 検討, 日本, 時間, 左腕, 憶測, サン, 明らか, 供給, メジャー,
#         topic=179 level=2 (documents=5): 万全, 人智, 完全, 期す, 臨む, コメント, 避ける, 来年度, 調整, 過酷,
#         topic=190 level=2 (documents=7): 問題, マメ, 間隔, 指先, 怪我, 失敗, 壊れる, 接す, 一人, 発生,
#         topic=202 level=2 (documents=5): 備える, 来年度, 反面, 選手生命, 間違い, 悔い, 希望, 選択, 頼もしい, 帯同,
#         topic=218 level=2 (documents=10): ここ, クリニック, ピッチャー, 医師, イチロー, 確実, 両方, 出す, そう, 目標,
#         topic=227 level=2 (documents=5): 問題, 三冠王, スイーパー, 進出, ポストシーズン, 拝める, 休暇, 快復, 選ぶ, 過去形,
#         topic=236 level=2 (documents=15): 酷使, 以前, ケガ, 筋肉, 悲鳴, 上げる, プレーヤー, 耐える, 限界, イチロー,
#         topic=239 level=2 (documents=6): 塁打, 日常生活, 普通, スタート, 場合, 投打, 昨年, 生活, 見据える, とも,
#         topic=242 level=2 (documents=9): 程度, ムリ, オーバーワーク, じん帯, 登板間隔, キャリア, 治癒, 反映, 切る, 切り替える,
#         topic=244 level=2 (documents=9): 喜ばしい, かける, 完璧, 故障, 左投手, そう, 期間, 3年, 右足首, 濃厚,
#         topic=247 level=2 (documents=6): ブランク, 移植, 入魂, 増す, 一安心, 申し上げる, 2年, 2度, ペース, 最多勝利,
#         topic=255 level=2 (documents=7): フル, 完全, 望む, 悲しい, 人間, 豪速球, フルスイング, 通用, いつまでも, 6月,
#         topic=259 level=2 (documents=2): 在る, 小生, ダブルヘッダー, 御座る, 日程, 自身, 強い, 見通し, 数多い, 余裕,
#     topic=3 level=1 (documents=105): 二刀流, 打者, 投手, 早い, 言う, 大谷翔平, 決断, 来年, 良い, 負担,
#         topic=108 level=2 (documents=9): ホームラン王, オフ, 長期契約, 心持ち, 決める, 報告, 目指, スーパーマン, 不可能を可能に, 出来過ぎ,
#         topic=121 level=2 (documents=4): 時間, プレースタイル, 優秀, 続ける, ひとまず, 野球少年, 記録達成, 限界, 拭う, 大きい,
#         topic=128 level=2 (documents=10): 来季, 状態, 貰う, ユニフォーム, 着る, ホームラン, 出す, 前人未到, 専念, 井口,
#         topic=148 level=2 (documents=10): 苦難, 乗り越える, ピッチング, 本塁打, クビ, 休む, よい, 悔い, 来年以降, 来シーズン,
#         topic=154 level=2 (documents=8): 離れる, 戻れる, グラウンド, 環境, 個人的, 痛い, ピッチャー, 悪い, ダメ, 補強,
#         topic=170 level=2 (documents=14): 超える, 鍛える, 今後, 継続, 限界, 怪物, 使う, 確保, 行動, マイル,
#         topic=194 level=2 (documents=11): つく, 開幕戦, あれだけ, 必要, どれ, 負担, 定期的, 残す, ただ, 勇姿,
#         topic=212 level=2 (documents=6): 右肘, ユニホーム, 待ち遠しい, 含める, 接す, 見せる, 痛々しい, ボールパーク, 生まれる, 25年,
#         topic=224 level=2 (documents=6): 原因, 速い, 球速, 復帰後, 期間中, つける, 状態, 確か, たす, スイーパー,
#         topic=229 level=2 (documents=3): コミッショナー, 目指す, 訪れる, 生命, 任期, 2年, 思考, 私利私欲, 滑る, 持つ,
#         topic=237 level=2 (documents=8): シーズン終了, 時期, 必然, もらう, ごと, 映画, 他人, 再チャレンジ, 戻る, フル,
#         topic=238 level=2 (documents=5): 日本, 勇気, 駆け抜ける, 届ける, 移植, 違う, 素敵, 素晴らしい, 戦う, トップリーグ,
#         topic=243 level=2 (documents=5): 王貞治, 打席, ダルビッシュ, からだ, イチロー, 根尾, 巡る, これだけ, 向う, 程度,
#         topic=253 level=2 (documents=4): 強化, 出力, 部分, 耐える, 判定, 24年, プレースタイル, 指定薬物, どこか, 維持,
#         topic=256 level=2 (documents=2): 立てる, 心待ち, 治療, 辛い, 皆んな, 一流, プラン, 休養, 会う, 会社,
#     topic=12 level=1 (documents=123): 二刀流, 打者, 投手, 早い, 言う, 良い, 投げる, 出来る, 来年, 負担,
#         topic=105 level=2 (documents=13): 観る, 毎日, 希望, うれしい, グランド, 慎重, 1年間, 身体, 記録, 休日,
#         topic=111 level=2 (documents=10): 入れる, メス, 一つ, いう, くださる, 明らか, 渡る, 同様, どれ, 見れる,
#         topic=167 level=2 (documents=9): 感動, とんでも, 異次元, 高額, 年俸, 来年, 期待, 欠場, 米国, 瞬間,
#         topic=173 level=2 (documents=7): 筋肉, 違う, パワー, しなやか, ギリギリ, 勝利, 推測, でる, 残り, 何処,
#         topic=185 level=2 (documents=7): 立つ, 乗り越える, 他人, 打席, すごい, 事態, 投球, 向く, 短い, 与える,
#         topic=186 level=2 (documents=5): おき, 一年, 時期, トミー, スタイル, 行う, 歴史, スケジュール, どれ, 二刀流,
#         topic=200 level=2 (documents=3): 待ち望む, 解雇, 学生時代, 打球, 同様, 役割, 勝てる, 伸びる, アスリート, 色褪せる,
#         topic=220 level=2 (documents=5): 最高峰, トラウト, マジ, 改める, 素直, 向き合う, 死ぬ, 無い, 走行, 久し振り,
#         topic=222 level=2 (documents=13): こちら, 始まる, 成績, 絞る, 聞く, 量産, キット, 前向き, 残せる, 怖い,
#         topic=232 level=2 (documents=9): ルール, 大リーグボール, 有る, 慎重, 大騒ぎ, 決める, 言える, 超える, プロ野球, 迷う,
#         topic=240 level=2 (documents=7): 医師, 感動, 成否, 勇気, 抜かる, マース, 回復, 記事, 思い, 帰る,
#         topic=245 level=2 (documents=4): マスコミ, メディア, 情報, 一方通行, 日々, 温床, 連日, ジャニーズ事務所, 自覚, 静か,
#         topic=250 level=2 (documents=5): 投手, 感心, 舞台, 掛かる, 同様, スムーズ, 様々, タイヤ, 交ぜる, 意志,
#         topic=252 level=2 (documents=9): 日々, 帰る, 長島, 金田, 野球ファン, 短い, 応援, ハッスル, 近日中, 勝負,
#         topic=254 level=2 (documents=6): 周り, ケガ, 出し手, 見れる, 2回, 昨日, くん, 報道, 怪我, 大谷久,
#         topic=258 level=2 (documents=11): エンゼルス, タイミング, これ, 話題, 130打点, 3冠王, 60本, 怪我, 予言, ジャッジ,
#     topic=14 level=1 (documents=89): 二刀流, 打者, 投手, 早い, 球団, 決断, 休む, 負担, 手術, 投げる,
#         topic=15 level=2 (documents=8): 今期, 存在, 数字, ホームラン王, 勝る, 間違い, 2年連続, 変わる, その間, 世の中,
#         topic=79 level=2 (documents=5): 本人, そこ, 成し遂げる, カバー, そりゃ, いいかえる, 満足, 張り, 改善, 脇腹,
#         topic=157 level=2 (documents=6): じん帯, 伸びる, 悲鳴, おかしい, 勇姿, 上げる, 留める, いつ, 悪化, 再来,
#         topic=195 level=2 (documents=5): 困難, あなた, たくさん, 責任, 追求, 好き, 不安, チームメート, 輝く, 愛す,
#         topic=211 level=2 (documents=5): 続く, バッター, 送る, 接触, 適宜, 歩み, 超一流, 再開, 怪しい, アスリート,
#         topic=215 level=2 (documents=11): エンゼルス, 契約, 早期, 残留, 間に合う, 結ぶ, 医師, 予想, 手術, 無い,
#         topic=216 level=2 (documents=7): 故障者リスト, 報道, 患者, 自ら, これ, 明確, 保存, バッティング, 繋がる, 必至,
#         topic=217 level=2 (documents=10): アメリカ, 仕事, 重ねる, さん, きつい, 静養, 2倍, 一平, 真骨頂, 自信,
#         topic=219 level=2 (documents=2): 見据える, 迷い, 分析, 大事, 向ける, 判断力, 実行, 実行力, 子供, 目標,
#         topic=231 level=2 (documents=7): 挑戦, 強い, 9割, 大変, 遅い, 帰る, 投手, 努力, いない, 素人,
#         topic=233 level=2 (documents=5): 多い, 剛腕, じん帯, そこ, 怪我人, 滑る, おとなしい, トラブル, 公式, 無くす,
#         topic=246 level=2 (documents=5): 行動, スポーツ, 例える, 傷める, 好き, 凄い, 良い, 振る, 一生, 使命,
#         topic=249 level=2 (documents=4): 判断, 非常, アメリカ, 至る, 疲労, 一流, 推察, 保証, 兼ねる, プロセス,
#         topic=257 level=2 (documents=8): 抜く, 度肝, 評価, 医療, 属す, 二人, 岩手県, 花巻東, 大リーガー, 超富裕層,
#         topic=260 level=2 (documents=1): 日本, 疲れる, 偉大, バッターボックス, 休める, 名刀, 構える, バット, 会う, 伝説,
# .................................................. 350
# topic=0 level=0 (documents=412): 手術, 大谷, 選手, 思う, 成功, 活躍, リハビリ, 良い, 来年, 見る,
#     topic=1 level=1 (documents=80): 二刀流, できる, 打者, 投手, 早い, 言う, 回復, 身体, 負担, 投球,
#         topic=81 level=2 (documents=5): 速い, 復帰後, 原因, 期間中, 無双, 作る, 確か, フル, 変わる, 稼働,
#         topic=179 level=2 (documents=7): 分かる, きつい, 本当, 2025年, デカ, 怪しい, 一流, 結果, つく, 動画,
#         topic=239 level=2 (documents=11): 意味, 目指す, 確信, 2度目, 控える, 通り, 本当, 数カ月, 判る, 決まる,
#         topic=242 level=2 (documents=6): 補修, 明け, ベスト, 自己, そのため, せる, 人生, ヒーロー, ごと, 必要,
#         topic=259 level=2 (documents=6): 筋肉, しなやか, 意見, 無事, パワー, 評価, 以前, 語る, プレーヤー, 共存,
#         topic=263 level=2 (documents=7): 以前, 最近, 勝利, 球速, 増す, チームメイト, 結局, 個人差, 見れる, どちら,
#         topic=265 level=2 (documents=12): 超える, 鍛える, 限界, 強化, 故障, 肉体, 怪物, 言える, 人間, 徹底,
#         topic=273 level=2 (documents=8): 9割, 勝てる, 備える, シーズン, メジャー, 離脱, タイトル, 何処, 当時, 条件,
#         topic=275 level=2 (documents=7): チーム, 残念, 分析, 子供, 視る, いける, がる, 打点王, 見せる, 最善,
#         topic=282 level=2 (documents=7): タイミング, エンゼルス, 交渉, 絞る, クリニック, 野球, 楽しい, とおす, 好き, 帯同,
#         topic=294 level=2 (documents=4): 養生, 仕事, 重圧, プレッシャー, 拝める, 医者, 仕上がり, 超一流, 担当, 雄姿,
#     topic=3 level=1 (documents=97): 二刀流, 早い, 打者, できる, 負担, 身体, シーズン, 復帰, 回復, いい,
#         topic=108 level=2 (documents=9): 早い, ホームラン, 出し手, カーブ, 聞かす, 6人, 50本, 万全, 関係者, 捻る,
#         topic=121 level=2 (documents=13): 野球, わかる, 時間, シーズン終了, 含める, 対応, 走攻守, 発表, 何れ, オペ,
#         topic=128 level=2 (documents=8): 存在, 希望, 子供, 世の中, 貴重, お願い, 怪我, 順調, 再来年, 周り,
#         topic=154 level=2 (documents=6): 安堵, 再検討, 原因, 運ぶ, 快方, 印象, 帰国, なのかな, フルスペック, 安め,
#         topic=194 level=2 (documents=6): 抜く, 減らす, 診察, 濃厚, ナンバーワン, 一流, 回数, 度肝, 休養, 3割,
#         topic=224 level=2 (documents=8): 療法, 保存, 左腕, 星飛雄馬, くん, 選択, 読み解く, 接す, 電光石火, 大リーグボール,
#         topic=237 level=2 (documents=10): あと, 感心, 出場, 執刀, いない, 2年後, 始まる, 成功, 見れる, 協力,
#         topic=238 level=2 (documents=2): あなた, たくさん, チームメート, がんばろう, 及ぶ, 足元, めげる, 輝く, 思い出す, 故障,
#         topic=253 level=2 (documents=10): 悲鳴, 上げる, じん帯, 痛める, ケガ, おかしい, 本来, 損傷, トレーニング, 難しい,
#         topic=274 level=2 (documents=4): くん, 完璧, 取り入れる, 健康, 45本, 素敵, 最高, 最優秀防御率, 励む, 1人,
#         topic=279 level=2 (documents=3): 自分, こだわる, 長い, 珍しい, 不可能を可能に, 優れる, 覚悟, でる, 出来過ぎ, オフ,
#         topic=283 level=2 (documents=8): マスコミ, メディア, 情報, チーム, 一方通行, 怪我, 活躍, 勇気, 連日, 日本人,
#         topic=290 level=2 (documents=4): 無理, マメ, 指先, 壊れる, 努める, 悪化, かばう, 怪我, 関係者, 次第,
#         topic=293 level=2 (documents=6): 程度, ムリ, 骨折, 向く, 意向, 防止, 疲労, イチ, 自ら, 自分,
#     topic=12 level=1 (documents=112): 打者, 投手, 二刀流, 早い, 復帰, できる, 専念, 楽しみ, 負担, 投げる,
#         topic=105 level=2 (documents=9): 観る, 毎日, 希望, うれしい, テレビ, 2度, 休日, サン, 寂しい, 経る,
#         topic=173 level=2 (documents=4): 熱意, 筋力トレーニング, 惜しむ, 消耗品, 心持ち, ケガ, 拾う, プレー, 世界, 引退,
#         topic=185 level=2 (documents=5): 鼓舞, 貰う, よう, 靭帯, 常識, フル回転, 考え方, 投打, ピッチング, 御疲れ様,
#         topic=186 level=2 (documents=6): 2年, ヵ月, 決まる, 税金, 過ごす, 久し振り, 気が付く, ビッグモーター, 決める, 悪い,
#         topic=222 level=2 (documents=14): 投手, 変化球, 無理, スイーパー, あれだけ, 速球, 球種, 開幕戦, チェンジアップ, 年間,
#         topic=232 level=2 (documents=6): 大切, 故障, 医療, ワールドシリーズ, ながい, 素直, ブレーキ, チーム, 持つ, 再来,
#         topic=245 level=2 (documents=4): 行動, 振る, 速い, 奥川, 一流, 移籍, 響く, 是非, 恐怖心, 大好き,
#         topic=252 level=2 (documents=11): 挑戦, いく, 凄い, 続く, 違う, 年俸, 高額, 打てる, もったいない, 記事,
#         topic=254 level=2 (documents=11): ボール, 滑る, メジャー, 日本, 多い, コミッショナー, 2年, 検討, 寿命, 怪我人,
#         topic=258 level=2 (documents=7): 感謝, タイプ, きめる, やめる, 見直す, 頑張り, 40歳, 休める, 短い, いいかえる,
#         topic=272 level=2 (documents=5): 望む, 小生, 在る, 多く, 御座る, キャリア, スーパースター, 活き活き, 切り替える, じん帯,
#         topic=288 level=2 (documents=10): 打点, ユニフォーム, 着る, 発達, 与える, 低い, そうだ, 後ろ, 楽しい, 最悪,
#         topic=289 level=2 (documents=16): 驚く, 貰う, クセ, 治す, お金, 野球ファン, 精神, 祈念, 年度, アナハイム,
#         topic=292 level=2 (documents=4): 失敗, 片付ける, 流す, ワイドショー, 見れる, アメリカ人, チャンス, 本塁打王, プラン, 絶対,
#     topic=14 level=1 (documents=123): 二刀流, 打者, 早い, できる, 復帰, 専念, 投手, 試合, 大谷, チーム,
#         topic=15 level=2 (documents=5): 今期, ホームラン王, 忍耐, 来期, 狙う, 数字, 勝る, 取れる, その間, 間違い,
#         topic=157 level=2 (documents=7): 辛い, 残念, 立証, 勝手, でる, 量産, あれだけ, 申し訳ない, 打てる, 頑張れる,
#         topic=195 level=2 (documents=7): 故障, 休養, 左投手, 事態, ピッチング, 移植, 判断, 右肩, 使用, どちら,
#         topic=215 level=2 (documents=1): トミー, 2年, 一切, 行う, 会う, 伸びる, 伸ばす, 伴う, 伝説, 伝わる,
#         topic=216 level=2 (documents=5): ピッチャー, どちら, 高校生, ここ, 両方, 改善, 目標, 予言, こなせる, 大車輪,
#         topic=217 level=2 (documents=5): 奇跡, 辛い, 挑戦, 大変, 来年度, 感覚, 戦う, 応援, ナチュラル, 比べる,
#         topic=231 level=2 (documents=8): じん帯, 130打点, ボロボロ, 3冠王, ある意味, スーパースター, ブランク, 60本, 楽しみ, 野球選手,
#         topic=246 level=2 (documents=11): 戻れる, 離れる, チーム, グラウンド, 違う, 難しい, 仕方, 環境, 管理, 種類,
#         topic=249 level=2 (documents=4): 日々, 痛み, 偉大, 怪我, 走る, 啓示, つける, 疲れる, 疲労困憊, 休息,
#         topic=257 level=2 (documents=8): 予定, 大きい, 上積み, 起きる, 合える, 離れる, 集中, 満身創痍, ベスト, 遅れる,
#         topic=260 level=2 (documents=10): 言葉, 先生, 一つ, 心強い, ルール, 大リーグボール, 執刀, 大きい, 耐える, 話題,
#         topic=268 level=2 (documents=4): プレースタイル, 成否, びっくり, 具合, 見舞う, 生身, 勝負, 確立, 限界, 執刀,
#         topic=270 level=2 (documents=16): エンゼルス, 早期, 契約, 残留, 継続, ポストシーズン, 結ぶ, 選ぶ, 予想, 強い,
#         topic=276 level=2 (documents=1): 大谷翔平, 右肘, 不死身, ベッド, 仰向け, 異なる, 番組, 痛々しい, 靱帯, あれ,
#         topic=281 level=2 (documents=10): 投打, 打撃, 塁打, 渡る, ホームラン, 苦難, 理由, 右肘, 舞台, スタート,
#         topic=284 level=2 (documents=14): 普通, 時間, 比べる, 支障, 有る, 辛い, 周囲, 2度目, 明らか, 気持ち,
#         topic=287 level=2 (documents=7): アメリカ, 判断, 非常, 至る, 留学, 観る, 再建, 一流, 手法, 大リーガー,
# .................................................. 400
# topic=0 level=0 (documents=412): 手術, 大谷, 選手, 成功, 活躍, 思う, 見る, 良い, 復帰, られる,
#     topic=1 level=1 (documents=98): 二刀流, 投手, 打者, できる, 思う, 早い, 負担, 言う, 専念, 投げる,
#         topic=81 level=2 (documents=6): 登板, 減らす, 変化球, とる, 160キロ, 回数, 変える, 拘る, 昨今, 同様,
#         topic=239 level=2 (documents=9): 年俸, スタート, 打てる, 高額, メジャー, 塁打, させる, 凄い, 圧巻, 登板間隔,
#         topic=242 level=2 (documents=5): 星飛雄馬, 左腕, くん, 大リーグボール, 2023年, ホームラン王, アジア人, 掛かる, 3号, 切れる,
#         topic=265 level=2 (documents=12): 超える, 鍛える, 限界, 靭帯, よう, 怪物, 強化, 徹底, 部位, ケア,
#         topic=273 level=2 (documents=6): 感服, 岩手県, 順調, 一報, 全開, 種類, アスリート, 留学, 内容, アメリカ,
#         topic=282 level=2 (documents=2): 山本昌, 投球, 選手, 棒に振る, 遅い, すい, いける, こなす, 痛める, 影響,
#         topic=305 level=2 (documents=7): 十分, クリニック, 実力, 記録達成, 絶望, 続く, 最適, 相当, 切り上げる, 投手,
#         topic=307 level=2 (documents=10): 言える, これだけ, 責任, 登板間隔, 労う, 痛い, 持つ, 全部, 具合, しない,
#         topic=310 level=2 (documents=8): 取る, 去年, 送る, 球種, 休み, 時期, ホームラン王, どちら, スタイル, 速球,
#         topic=311 level=2 (documents=4): 人生, 現役, 完璧, みる, しれる, がん, うれしい, 悩む, バレー, 治る,
#         topic=313 level=2 (documents=8): 3冠王, 張り, 一つ, 見れる, 130打点, 60本, 獲る, 回避, 悩む, いたわる,
#         topic=314 level=2 (documents=6): 全う, 公式, 最善, エンゼルス, 舞台, 優れる, 要素, なん, どちら, 契約,
#         topic=318 level=2 (documents=8): 新しい, 2年, 最悪, がんばる, 記録, 多い, 患部, 傷める, よる, オーバーハンド,
#         topic=320 level=2 (documents=7): 一つ, こちら, 残留, 報道, 移籍先, 身体, 移る, 絞る, どちら, 場所,
#     topic=3 level=1 (documents=69): 二刀流, 打者, 言う, 専念, 思う, できる, リハビリ, 投手, 負担, れる,
#         topic=121 level=2 (documents=3): 人生, 抜本的, 世代, 改善, 立てる, 嬉しい, ルール, 云う, 育成, バッターボックス,
#         topic=194 level=2 (documents=9): 終える, せる, 打席, どこか, とる, 個人, 潰す, 疲労, 結局, 結果,
#         topic=224 level=2 (documents=6): 来年度, 理由, 再来, ながい, 走行, わかる, 向き合う, くださる, 素手, いう,
#         topic=253 level=2 (documents=12): 有る, 大切, 結ぶ, 契約, 大騒ぎ, 盗塁王, 設ける, 軽減, 一緒, 残す,
#         topic=279 level=2 (documents=7): 速い, わかる, 原因, 時間, 努力, 優秀, 状態, 復帰後, 比べる, すごい,
#         topic=290 level=2 (documents=8): 大谷翔平, ユニフォーム, 着る, 状態, 損傷, 装具, つく, 重さ, 不死身, 能力,
#         topic=299 level=2 (documents=9): ピッチャー, 神様, 目標, 両方, 登板, 野球, 思い知らす, バッター, 無い, 記事,
#         topic=303 level=2 (documents=3): 筋肉, つける, しなやか, パワー, バット, 振る, 世界一, イチロー, インタビュー, 硬い,
#         topic=312 level=2 (documents=10): さん, 今後, つく, 在る, 超人, 本塁打, 小生, 御座る, 必要, 次第,
#         topic=317 level=2 (documents=2): 処置, 療法, 最善, 最初, 無い, 来年, 成し遂げる, 休息, 休日, 休暇,
#     topic=12 level=1 (documents=115): 二刀流, 打者, リハビリ, 思う, 投手, 早い, 言う, できる, 無理, 休養,
#         topic=105 level=2 (documents=7): 本来, 強化, どこ, いう, 精神, スキャンダル, 極限, うれしい, いつ, 速報,
#         topic=186 level=2 (documents=7): 人間, 相性, 確定, 1日, 悪い, マウンド, 再建, 順調, トップ, くい,
#         topic=222 level=2 (documents=8): マメ, 熱意, 痛める, 間隔, 入り, 減る, 早め, 頼る, 生きる, 時間,
#         topic=232 level=2 (documents=4): 2025年, 辛い, 考え, 引き寄せる, 熱量, 気軽, 間に合う, 再起, 立つ, 薄手,
#         topic=245 level=2 (documents=9): 観る, 希望, 毎日, テレビ, 感心, 休日, 多く, こっち, 言葉, 久しぶり,
#         topic=252 level=2 (documents=7): 寂しい, キット, 毎日, 帰る, 再チャレンジ, プレー, 無くなる, 大丈夫, 怖い, プラス,
#         topic=254 level=2 (documents=5): ボール, 滑る, 日本, コミッショナー, 2年, 供給, 聞く, 会社, かける, 検討,
#         topic=258 level=2 (documents=6): 成否, 定期的, 変化球, 開幕戦, 多投, あれだけ, 9月, 暗い, 失敗, 具合,
#         topic=288 level=2 (documents=14): 感動, 想像, 仕事, 勇気, ハイブリッド, お金, 球界, 今後, 祈る, さん,
#         topic=292 level=2 (documents=6): サン, もらえる, ポストシーズン, 無くなる, オフ, 個人, 静養, 選ぶ, 過去形, がんばる,
#         topic=295 level=2 (documents=3): タイミング, 話題, 違い, 言える, 無い, 靭帯損傷, ホームゲーム, よう, 費用, 帯同,
#         topic=296 level=2 (documents=7): 大きい, ブランク, 舞台, 限界, グラウンド, 羽生結弦, 耐える, 望み, 練習, ピッチャー,
#         topic=302 level=2 (documents=3): くん, 故障, 本意, 他人, 素敵, 焦る, 1人, 発達, 充実感, 盗塁,
#         topic=308 level=2 (documents=9): 痛める, 影響, 明らか, メス, 多い, オーバーワーク, 止める, 切り替える, 拍手, ボール,
#         topic=315 level=2 (documents=7): メディア, マスコミ, 情報, 一方通行, 検討, 意図, 欠く, 事件, 連日, いずれ,
#         topic=319 level=2 (documents=13): 数多い, 疲れ, ダブルヘッダー, 飛躍, 3割, ピッチング, 2試合, 温泉, 常識, 世界中,
#     topic=14 level=1 (documents=130): 思う, 二刀流, 早い, 打者, 投手, できる, 専念, 無理, 球団, 決断,
#         topic=15 level=2 (documents=6): 今期, 休める, ホームラン王, 変わる, その間, あげる, 勝る, 間違い, 存在, 2年連続,
#         topic=157 level=2 (documents=9): 程度, 人間, ムリ, タイミング, 治癒, じん帯, 繋がる, 後半, そこ, 治る,
#         topic=195 level=2 (documents=4): 判断, あなた, 箇所, 至る, 困難, たくさん, 肩肘, 手法, 結局, 弱い,
#         topic=215 level=2 (documents=10): 行動, 予想, 痛み, 振る, エンゼルス, 関係, 見習う, 時期, 見据える, 向ける,
#         topic=216 level=2 (documents=12): 驚く, ロッカー, 希望, 対応, 周り, 翔平, 伝わる, 凄い, 終了, ジャッジ,
#         topic=217 level=2 (documents=6): できる, 貰う, 出す, 今季, 3位, 持つ, 残念, 残る, 解雇, 選ぶ,
#         topic=246 level=2 (documents=7): チーム, 試合, 離れる, 戻れる, グラウンド, 何処, 出場, 備える, 獲る, タイトル,
#         topic=249 level=2 (documents=7): ヵ月, 乗り越える, 集まる, 巡る, 頑張り, 2回目, 遅い, 予定, 説き伏せる, 周り,
#         topic=257 level=2 (documents=3): 左投手, 故障, 人智, ムリ, 疲労蓄積, 避ける, 溜まる, 使用, 不透明, 臨む,
#         topic=260 level=2 (documents=9): 滑る, ボール, 怪我, 要因, 起きる, 始まり, 大リーグボール, 守る, 怪我人, ルール,
#         topic=276 level=2 (documents=11): 短い, 数年, 寿命, すごい, 速球, こだわる, 剛腕, 野手, 事態, 機会,
#         topic=281 level=2 (documents=9): 継続, 説明, 本塁打, 構える, 当時, 開幕戦, 受け手, 一人, よう, 見せる,
#         topic=298 level=2 (documents=14): 来年, 悲鳴, 上げる, ケガ, 普通, 鍛える, 一安心, 投球, 支障, 日常生活,
#         topic=301 level=2 (documents=8): びっくり, グランド, 検討, 続く, 戻る, 9月, 電光石火, 啓示, 離れる, 怪しい,
#         topic=304 level=2 (documents=3): 感覚, 比べる, 2度目, 靭帯, 普通, 争い, 移植, 失う, チーム内, 戦う,
#         topic=309 level=2 (documents=12): 乗り越える, 選手, 伝説, 試練, 自ら, シーズン終了, 苦難, 与える, チャンピオン, スピーディ,
# .................................................. 450
# topic=0 level=0 (documents=412): 手術, 大谷, 選手, 思う, 成功, 活躍, リハビリ, 早い, 見る, られる,
#     topic=1 level=1 (documents=96): 二刀流, 打者, 投手, できる, 投げる, 言う, 来年, それ, 長い, 決断,
#         topic=81 level=2 (documents=10): 一つ, 短い, ルール, 絞る, 面白い, いく, くる, 現役, 両方, 痛い,
#         topic=265 level=2 (documents=6): ピッチャー, 耐える, 余裕, ダブルヘッダー, 言葉, 筋肉, イチロー, 目標, 戦力, 濁す,
#         topic=273 level=2 (documents=2): 慎重, きめる, あわてる, ベーブルース, 関係者, 40本, 40歳, 進める, やめる, 20代,
#         topic=305 level=2 (documents=10): 行動, 酷使, 振る, 決断, 繰り返す, 回避, 相手, 判る, 原因, ピーク,
#         topic=310 level=2 (documents=8): 改善, 確定, 失敗, 成否, 2試合, イニング, 集中, 勝負, トップ, そのもの,
#         topic=313 level=2 (documents=8): 貰う, つく, 小生, お金, 望む, 出す, 在る, 何度, 治す, 御見舞い,
#         topic=314 level=2 (documents=5): 人間, 故障, 左投手, 一年, 山あり谷あり, 療法, 試す, 超人, 短命, 稀代,
#         topic=318 level=2 (documents=4): 離脱, 新しい, 勝星, 始まる, 二刀流, 落ちる, チャンピオン, 放出, 本当, コントロール,
#         topic=320 level=2 (documents=11): 疲労, ムリ, 骨折, 存在, 違和感, しない, 治る, 程度, 場合, そうだ,
#         topic=342 level=2 (documents=12): 靭帯, 成功, 移植, ハイブリッド, 期待, 三冠王, 普通, 日常生活, 支障, 記録,
#         topic=349 level=2 (documents=15): 野球, 挑戦, 靭帯, 記録, 着る, 打点, 限界, ユニフォーム, 鍛える, 挑む,
#         topic=351 level=2 (documents=5): 持つ, 理由, いく, 自分, なれる, 衰える, なんだろう, もったいない, 良い, 自由,
#     topic=3 level=1 (documents=77): 二刀流, 打者, 投手, 来年, 手術, できる, 続ける, 言う, 負担, 選手,
#         topic=121 level=2 (documents=7): 気持ち, 早い, 2度, 体調, 子供, 改める, 希望, 向き合う, 素手, いう,
#         topic=194 level=2 (documents=10): 監督, くん, 早期, 大変, しれる, 予想, タイミング, 契約, 翔平, 全世界,
#         topic=279 level=2 (documents=9): 痛める, 9割, 160キロ, 申し訳ない, 大きい, 幸い, 譲る, 怖い, 幾ら, 負担,
#         topic=299 level=2 (documents=6): 止める, 方向性, 最初, 支える, 遅れる, 移籍, シーズン, 問題, 最優秀防御率, 診察,
#         topic=303 level=2 (documents=8): どれ, 成績, いう, 1日, 歴史, オフ, スタイル, スケジュール, ここ, ポストシーズン,
#         topic=323 level=2 (documents=9): 感動, 勇気, 与える, ユニホーム, 駆け抜ける, 届ける, 何色, 払える, しそう, しれる,
#         topic=344 level=2 (documents=11): 休む, 有る, 繋がる, 聞く, 人気, ボロボロ, 成功, 無い, 帯同, いいんじゃない,
#         topic=353 level=2 (documents=8): こちら, オーバーワーク, トレーニング, 気味, 聞く, プレイオフ, 靭帯損傷, 走る, ホント, シュート,
#         topic=354 level=2 (documents=4): 位置, 靱帯, 不死身, 凄まじい, 踏まえる, 2025年, 歪める, 甦る, 内容, 本来,
#         topic=355 level=2 (documents=2): 起きる, くつろぐ, 帰国, なのかな, 会う, 伸びる, 伸ばす, 伴う, 伝説, 伝わる,
#         topic=357 level=2 (documents=2): 接触, デカ, 動画, ランナー, 専門, 怪しい, 来季, 本当, 仕方無い, 続く,
#         topic=358 level=2 (documents=1): 速報, 鼓舞, 会う, 伸びる, 伸ばす, 伴う, 伝説, 伝わる, 会社, 休養,
#     topic=12 level=1 (documents=78): 言う, 二刀流, 打者, 投手, できる, 投げる, 無理, 球団, 来年, 負担,
#         topic=186 level=2 (documents=2): マスコミ, 情報, メディア, 言う, つきまとう, 生む, 事件, 偏り, 倣う, 同質,
#         topic=245 level=2 (documents=9): 毎日, 観る, 多く, 希望, 寂しい, 休日, 勇姿, エンゼルス, 感心, サラリー,
#         topic=252 level=2 (documents=5): 左腕, 星飛雄馬, 避ける, いない, 理解, 切れる, いく, プレー, 向ける, フル,
#         topic=258 level=2 (documents=16): 変化球, 負担, マイル, 同様, 登板, 減らす, 抜く, 立つ, 知れる, 責任,
#         topic=295 level=2 (documents=9): 怪我, 復活, 大リーガー, 与える, 微妙, 体調管理, 盗塁, 40本, 夢見る, 先輩,
#         topic=319 level=2 (documents=5): 対応, 決断, 入れる, ロッカー, 終了, 悔しい, 周り, 再開, 曲げる, 一瞬,
#         topic=343 level=2 (documents=12): 困難, ケガ, あなた, 報告, いつまでも, 契約, 問題, ヵ月, 含める, 乗り越える,
#         topic=346 level=2 (documents=9): 離れる, グラウンド, 戻れる, 環境, コミッショナー, 思考, 良い, どこ, 悪い, 健闘,
#         topic=347 level=2 (documents=4): 専任, 体調, 延ばす, ベンチ, 太鼓判, もらえる, 本拠地, どこか, いずれ, 良い,
#         topic=350 level=2 (documents=7): クリニック, ピッチング, 前回, 結果, 確実, ポストシーズン, 市内, 色褪せる, 十分, 一刻,
#     topic=14 level=1 (documents=161): 二刀流, 打者, 投手, できる, 専念, それ, 大谷, 無理, れる, 来年,
#         topic=15 level=2 (documents=9): ホームラン王, 今期, 取れる, 休養, 来期, その間, 休める, 間違い, 残念, 勝る,
#         topic=157 level=2 (documents=6): 超一流, 協議, 望む, 言う, 苦しみ, 他人, 共有, 無念, 成功率, 程度,
#         topic=195 level=2 (documents=8): 判断, 疲労, 最適, 至る, 非常, 実力, 含める, 切り上げる, 70本, 待てる,
#         topic=217 level=2 (documents=13): 療法, 速い, 球速, 復帰後, 保存, 原因, 状態, つける, 選択, 医師,
#         topic=246 level=2 (documents=4): 舞台, 全快, 好く, 気掛かり, 絶つ, 1日, 一足, 似合う, 来季, 理由,
#         topic=260 level=2 (documents=14): ボール, 滑る, 時間, 多い, 優秀, 受ける, 行く, 検討, 真剣, 会社,
#         topic=276 level=2 (documents=8): 速球, 寿命, アメリカ, すごい, きつい, 事態, 進める, 短い, 潰す, ハード,
#         topic=298 level=2 (documents=8): 上げる, じん帯, 痛める, 悪化, 伸びる, 絶好調, 生きる, 速報, スイング, 治す,
#         topic=309 level=2 (documents=3): 好き, 医療, 監督, 座る, 以前, 描く, 滲む, たまらない, 靴下, 指導,
#         topic=322 level=2 (documents=7): 療養, 世界中, 今シーズン, みせる, 塞ぎ, 登板間隔, それぞれ, 癒す, 7勝, 強い,
#         topic=325 level=2 (documents=12): 乗り越える, マメ, 方々, 強化, 喜ばしい, 感謝, 苦難, またす, 応援, 悲鳴,
#         topic=328 level=2 (documents=12): 戻れる, ギリギリ, 祈る, 進化, ハイブリッド, 違う, 2019年, 残り, 一人, 相当,
#         topic=329 level=2 (documents=6): スタート, 元気, サン, ホームラン, 塁打, 生活, 築く, 2時, どうし, 起きる,
#         topic=333 level=2 (documents=4): 筋肉, パワー, しなやか, 話題, これ, 恩恵, 属す, 必至, 作用, 超富裕層,
#         topic=335 level=2 (documents=6): 管理, じん帯, はやる, 開始, くっつく, ドクター, 私達, 準備, 終了, 半年,
#         topic=336 level=2 (documents=4): 投球, 年俸, 高額, 打てる, 帰る, いない, 好き, 配慮, 豪快, バッシング,
#         topic=341 level=2 (documents=8): 酷使, 送る, 先生, 言葉, 歩み, 恥ずかしい, 必至, 頑張る, 一刀流, 適宜,
#         topic=345 level=2 (documents=8): 以前, 去年, 増す, 2度, プレースタイル, ケガ, 何とか, 個人差, 技巧派, 選択,
#         topic=348 level=2 (documents=9): スーパースター, ブランク, 信じる, 来年度, トミー, 熱意, 試合, 取り組む, バッターボックス, お話,
#         topic=352 level=2 (documents=11): ホームラン王, 右肘, タイトル, 祈る, 獲る, 打撃, 挑戦, 翌年, 一年, 長い,
#         topic=356 level=2 (documents=1): 打棒, 見る, 来期, 25年, 18ヶ月, 決断, 伸びる, 伸ばす, 伴う, 伝説,
# .................................................. 500
# topic=0 level=0 (documents=412): 手術, 大谷, 選手, 成功, 思う, 活躍, 早い, リハビリ, 見る, 良い,
#     topic=1 level=1 (documents=91): 二刀流, 打者, 投手, 負担, できる, それ, 専念, 長い, 続ける, 感動,
#         topic=310 level=2 (documents=11): 上げる, 酷使, 悲鳴, おかしい, 自身, アスリート, 期待, 言葉, 本来, 連日,
#         topic=318 level=2 (documents=9): バッターボックス, 勝てる, プレー, 届ける, 勇気, もらう, サン, 駆け抜ける, 来季, 素敵,
#         topic=320 level=2 (documents=8): 2025年, 記録, 前回, 走る, 貢献, イイ, 関節, 無事, ホームラン, 指摘,
#         topic=342 level=2 (documents=7): スタート, 塁打, 投打, 渡る, 球場, スーパースター, 昨年, 来期, 起きる, 生命線,
#         topic=369 level=2 (documents=4): マメ, 明らか, 指先, 充分, 頼る, 発生, 開ける, 療養, 翔平, 痛める,
#         topic=370 level=2 (documents=5): 感心, ブランク, 進む, 練習, こっち, 義理堅い, ある意味, このまま, 申し上げる, 大丈夫,
#         topic=371 level=2 (documents=9): 早期, 盗塁, チーム, プラス, 快復, 快い, 適す, 場合, 変える, 9月,
#         topic=377 level=2 (documents=16): 観る, 仕事, 希望, 寂しい, お金, 精神, 凄い, 好き, 休日, 沸かす,
#         topic=386 level=2 (documents=5): 遅れる, 入れる, 存在, メス, 満身創痍, あれ, 右腕, 努力, 出し手, 変わる,
#         topic=396 level=2 (documents=9): 経験, 進化, 勇気, 復帰, 違う, 2度目, 一人, 確信, 戻れる, 過ごす,
#         topic=398 level=2 (documents=8): 故障, ベンチ, 左投手, 困難, 箇所, あなた, たくさん, 使用, 張り裂ける, 本拠地,
#     topic=3 level=1 (documents=79): 打者, 二刀流, 投手, 言う, 専念, できる, 野球, 投球, 故障, 負担,
#         topic=121 level=2 (documents=4): 最高, 現実, 似合う, ペース, 出場, 最優秀防御率, 最多勝利, 望み, キング, 絶つ,
#         topic=323 level=2 (documents=8): 凄い, 来年度, 高額, 神様, 年俸, 貴方, でる, あと, よう, 舞い降りる,
#         topic=354 level=2 (documents=4): そりゃ, 小生, 体調, 在る, 五十路, 望む, つく, 満足, 一筋, 流す,
#         topic=355 level=2 (documents=6): 話題, 接触, デカ, 本当, 穏やか, 違い, これ, 拝める, 左右, ボール,
#         topic=357 level=2 (documents=9): 強化, かかる, 存在, 子供, 肉体, 判断力, 判定, 変わる, 影響, 実行力,
#         topic=358 level=2 (documents=6): 戻れる, 離れる, グラウンド, 環境, ぬるま湯, 申す, チーム, 悪い, 労り, 決定的,
#         topic=375 level=2 (documents=10): 継続, 球団, 強化, 今後, できる, 明らか, 出力, 置く, 楽しむ, 追求,
#         topic=376 level=2 (documents=11): 期間, 負担, 球種, 減らす, 変化球, 知れる, 怪物, プレー, 変える, おき,
#         topic=380 level=2 (documents=4): マスコミ, メディア, 情報, 意図, スタッフ, 権力, 追っかける, 日々, 欠く, 空間,
#         topic=393 level=2 (documents=13): 本塁打, 130打点, 60本, 3冠王, 抜本的, 翌シーズン, 終わる, 暗い, 万全, 度肝,
#         topic=397 level=2 (documents=4): いい, 2年後, はやる, 聞く, だし, 準備, 設ける, 一緒, 強制, そりゃ,
#     topic=12 level=1 (documents=96): 二刀流, 打者, 投手, できる, 負担, それ, これ, 言う, 思う, 出場,
#         topic=346 level=2 (documents=10): 故障, 選手生命, 絞る, 認識, すごい, 繋がる, 事態, 専念, いつまでも, 他人,
#         topic=347 level=2 (documents=5): イチロー, 聞く, 確実, 間に合う, こちら, 一生, ドジャース, 度目, メンタル, ベイブルース,
#         topic=364 level=2 (documents=9): 以前, 最近, 辛い, 最善, 球速, 努力, 選択, 躍動, 精神力, 視る,
#         topic=367 level=2 (documents=8): 筋肉, 作用, 日々, しなやか, 体調管理, パワー, プロ野球選手, つける, 過ごす, 運動障害,
#         topic=372 level=2 (documents=3): 9割, 160キロ, 山本昌, すい, いける, 抑える, 大きい, こなす, 潰す, 選手,
#         topic=378 level=2 (documents=7): 成績, 結果, 2025年, 実績, 楽しみ, 歪める, ドキュメント, あれ, 忘れる, パワーアップ,
#         topic=381 level=2 (documents=2): 世界, スーパースター, 熱意, オーバーワーク, 切り替える, 生きる, 拾う, プレー, 切る, プレイオフ,
#         topic=383 level=2 (documents=12): 意味, 変化球, 必要, 多投, あれだけ, それ, 最高, 凄い, 定期的, 過酷,
#         topic=395 level=2 (documents=2): どちら, 戦力, 書く, 焦点, 支援, ホームラン王, ベスト, 打てる, 目指す, 優勝,
#         topic=399 level=2 (documents=12): 着る, ユニフォーム, 状態, 今季, 打点, グラウンド, 違う, 星飛雄馬, くん, 状況,
#         topic=400 level=2 (documents=11): 判断, 長い, 安心, 至る, 静養, シーズン, 治療, 素人目, 集中, 一流,
#         topic=401 level=2 (documents=10): そうだ, 早い, 決まる, 痛い, あちこち, 不平不満, 報告, 何はともあれ, 不思議, 治す,
#         topic=402 level=2 (documents=5): 投打, タイミング, 本当, 鼓舞, 回避, 管理下, ダメージ, 争い, 主軸, 主力,
#     topic=14 level=1 (documents=146): 二刀流, 打者, 投手, できる, 言う, 長い, それ, 今後, 投げる, エンゼルス,
#         topic=15 level=2 (documents=8): ホームラン王, 今期, 間違い, 休める, 変わる, 酷使, あげる, 勝る, 2年連続, 数字,
#         topic=217 level=2 (documents=3): ケガ, ヵ月, 諦める, 冷静, 集まる, イエスマン, 証拠, 説き伏せる, 翌日, 誰か,
#         topic=246 level=2 (documents=7): 専念, 不幸, オペ, グランド, 楽しみ, 幸い, 気持ち, 確か, 出来る, 訪れる,
#         topic=260 level=2 (documents=5): 多い, 滑る, 怪我人, 検査, ボール, 6日, 代理人, トラブル, 消耗, トラウト,
#         topic=276 level=2 (documents=5): 程度, ムリ, 治癒, 火傷, 無念, 豪速球, 評価, 進める, がんばる, 半年,
#         topic=322 level=2 (documents=4): 出し手, 痛める, 悪化, 6人, 吉報, 捻る, 仕振り, 聞かす, 止める, セカンドオピニオン,
#         topic=328 level=2 (documents=7): ピッチャー, 筋肉, 記事, イチロー, 耐える, トミー, ギリギリ, ビックリ, 濁す, 十二分,
#         topic=329 level=2 (documents=9): 失敗, 勝負, 絶対, プレースタイル, 受ける, 成否, 拭う, 間隔, プラン, 子供達,
#         topic=336 level=2 (documents=9): 状態, かける, 意思, 執刀, 励ます, 素晴らしい, 手術, 打つ, 知る, 本塁打王,
#         topic=345 level=2 (documents=9): 速い, 行動, 決断, 原因, 振る, 無双, 期間中, 球速, 復帰後, 是非,
#         topic=348 level=2 (documents=6): 有る, 貰う, 出す, 目指す, グランド, 年度, 素敵, 残る, 疲れる, 周囲,
#         topic=352 level=2 (documents=10): ボール, 滑る, 日本, 真剣, 供給, 2回目, 速球, 会社, 期間, コミッショナー,
#         topic=356 level=2 (documents=9): 保存, 療法, 余裕, 2年, スタート, 患部, 作りあげる, 50本, 頑張り, いいかえる,
#         topic=359 level=2 (documents=4): 好き, 描く, 舞台, ポストシーズン, 伝わる, 内容, 靴下, 指導, たまらない, ロッカー,
#         topic=374 level=2 (documents=12): クリニック, 打席, 何事, 試練, 終える, 博士, 名前, 患者, 市内, 失敗,
#         topic=379 level=2 (documents=5): ユニホーム, 右肘, 今シーズン, 含める, 裏切る, 走攻守, 順調, 接す, 言う, 満塁本塁打,
#         topic=387 level=2 (documents=7): 療法, ダブルヘッダー, 2試合, バッティング, 保存, 活力, 明確, 炎症, 田中, 常識,
#         topic=388 level=2 (documents=6): 時間, シーズン終了, 比べる, 優秀, ダル, ビジネスマン, 言及, 凄い, 大きい, 痛み,
#         topic=389 level=2 (documents=11): 現役, こだわる, ブランク, 感覚, 始まる, 壮絶, 時期, 打棒, 不死鳥, 情報,
#         topic=394 level=2 (documents=10): 早期, 間に合う, 笑顔, 感じる, 含める, 予想, くん, しそう, さん, 払える,

# %%
from model.HldaModel import ExpandHldaModel
import os

create_date = "2023_09_27"
parameter_name = "default"
model_name = comment_list_name + "_" + parameter_name + ".pickle"
model_dir = "model/pickle/" + create_date + "/" +model_name
create_date_path = "model/pickle/" + create_date

if not os.path.exists(create_date_path):
    os.makedirs(create_date_path)

expandHlda = ExpandHldaModel(pickle_path=hlda)
expandHlda.save_zipped_pickle(filename=model_dir)

# %%
# expandHlda.get_topic_multi_document(comment_list=comment_list, corpus=comment_dataset.comment_list)

# %%
expandHlda.print_phrases(comment_list=comment_list, corpus=comment_dataset.comment_list, n_phrase=3, with_score=True)

# %%
# expandHlda.print_multi_node(comment_list=comment_list, corpus=comment_dataset.comment_list, n_phrase=3, with_score=True)

# %%
expandHlda.get_topic_by_sentence(comment_list=comment_list, corpus=comment_dataset.comment_list, n_words=5)
# Out:
# 0:今の日本の運転免許証ってとても優秀なものだと思うんですけどね。
# node_id:628, node_words:エラー(4.0),それぞれ(4.0),推し進める(3.0),出る(3.0),脆弱(3.0), probability:0.025
# 1:数年に一度必ず本人出向いて更新するから身元確認にもなるし顔写真ついてるからすぐその場で本人確認できるし。
# node_id:116, node_words:更新(27.0),ゴールド(6.0),ブルー(4.0),即日(3.0),会場(2.0), probability:0.189
# 2:なんにせよあらゆることを一つだけに絞るとそれがダメになった時にどうしようもなくなるのでリスクが大きくなると思います。
# node_id:776, node_words:ダメ(6.0),くっつける(2.0),警察官(2.0),絡む(2.0),一つ(2.0), probability:0.17
# 3:昭和おっさんの記憶ですが、テレビとビデオをくっつけたものは結局すたれたし、ファミコンとディスクシステム？だったかな？、をくっつけてもダメでしたね。
# node_id:776, node_words:ダメ(6.0),くっつける(2.0),警察官(2.0),絡む(2.0),一つ(2.0), probability:0.189
# 4:一つダメになると他も使えなくなるので。
# node_id:776, node_words:ダメ(6.0),くっつける(2.0),警察官(2.0),絡む(2.0),一つ(2.0), probability:0.151
# ------------------------------------------------------------------
# 0:紛失時のリスクをマイナカードに集約してしまうと、再発行されるまで病院にも行けない、車にも乗れない、となりますね。
# node_id:9, node_words:紛失(31.0),発行(30.0),リスク(14.0),無くす(14.0),病院(13.0), probability:0.266
# 1:役所が休みの土日や盆暮れだと、相当生活に影響が出そう。
# node_id:791, node_words:普及(7.0),値する(2.0),普通(2.0),身元(1.0),今更(1.0), probability:0.037
# 2:資産の預け先を分散するのと同様、免許証や保険証はリスク分散の意味でも一本化は避けるべき。
# node_id:632, node_words:いく(3.0),連携(2.0),注ぐ(2.0),集約(2.0),説明(2.0), probability:0.091
# 3:管理する政策側のメリットしかなく、利用者側のリスクが大きすぎです。
# node_id:632, node_words:いく(3.0),連携(2.0),注ぐ(2.0),集約(2.0),説明(2.0), probability:0.061
# ------------------------------------------------------------------
# 0:運行管理者の補助者として、点呼と運転免許証の確認をしており、券面の有効期限や免許されている車種、また裏書で免許停止になっていないかの確認を行い、免許失効や無免許運転や資格外運転の防止を行なっているが、運転免許証がマイナンバーカードに移行してしまうと、これらの確認ができないため、しっこした免許や所有する免許の条件等種類の確認が出来なくなり、無資格運転等の問題が起きる危険性がある。
# node_id:794, node_words:まとめる(4.0),運行(4.0),大型(3.0),点呼(2.0),断る(2.0), probability:0.245
# 1:貨物自動車運送事業法で運行管理者の方が点呼の責任を取るために、万が一警察の取り締まりや事故等で発覚した場合には、運送会社と運行管理者はかなりの責任を取らされる事になる。
# node_id:794, node_words:まとめる(4.0),運行(4.0),大型(3.0),点呼(2.0),断る(2.0), probability:0.208
# 2:制服は安易にマイナンバー制度化でマイナンバーカードにまとめようとしているが、運転免許証の廃止は運行管理上の問題もあり安易に廃止してまとめてしまうのは問題だと思う。
# node_id:794, node_words:まとめる(4.0),運行(4.0),大型(3.0),点呼(2.0),断る(2.0), probability:0.069
# ------------------------------------------------------------------
# 0:マイナ保険証だけなら、病院に行く時だけで使わないときは自宅保管でもいいけど、免許証が一体化となると常に携帯しないとだめになりますね。
# node_id:793, node_words:見る(2.0),私利(1.0),ゴリ押し(1.0),今度(1.0),よる(1.0), probability:0.143
# 1:保険所1枚、免許証1枚だけでなく紛失時は財産丸ごと落とすことになりますね。
# node_id:9, node_words:紛失(31.0),発行(30.0),リスク(14.0),無くす(14.0),病院(13.0), probability:0.096
# 2:怖い怖い（財産も持ってないけど笑）
# node_id:632, node_words:いく(3.0),連携(2.0),注ぐ(2.0),集約(2.0),説明(2.0), probability:0.03
# 3:紛失時に1回ですべて事足りるという解釈もありますが、そうなるとマイナ紛失して紛失にかかわる手続きすると口座も保険証も免許証もクレカも1度に全部、停止になるのかな・・・。
# node_id:9, node_words:紛失(31.0),発行(30.0),リスク(14.0),無くす(14.0),病院(13.0), probability:0.255
# 4:見つかった時、再交付の時も1度の手続きですむならいいけど。
# node_id:9, node_words:紛失(31.0),発行(30.0),リスク(14.0),無くす(14.0),病院(13.0), probability:0.012
# 5:でも、安全を担保できていない今の状況を見れば、これを1元で政府の制度にお任せするのも怖い怖い。
# node_id:673, node_words:値上がり(3.0),給料(2.0),なれる(1.0),近づく(1.0),あんた(1.0), probability:0.031
# ------------------------------------------------------------------
# 0:全部紐付けしたマイナンバーカードを紛失して窓口での手続きの際、「本人を証明する物を出して」と言われたら何を出すのでしょうね。
# node_id:9, node_words:紛失(31.0),発行(30.0),リスク(14.0),無くす(14.0),病院(13.0), probability:0.102
# 1:ちなみにパスポートは持たないし、介護保険証も持っていません。
# node_id:793, node_words:見る(2.0),私利(1.0),ゴリ押し(1.0),今度(1.0),よる(1.0), probability:0.071
# ------------------------------------------------------------------
# 0:国が公的な手続きや書類をデジタル化を目指すのは良い事だと思うけど、現実問題で国のデジタルレベルが民間よりもかなり劣っている現状が問題だと思う、国で管理をするのであれば委託などはせずに公務員が優秀なエンジニアになる必要があると思う。
# node_id:628, node_words:エラー(4.0),それぞれ(4.0),推し進める(3.0),出る(3.0),脆弱(3.0), probability:0.105
# ------------------------------------------------------------------
# 0:みなさん「デジタル社会の実現に向けた重点計画 (案)」を読んでいないから議論が変な方向に向かっています。
# node_id:58, node_words:認証(9.0),コピー(7.0),指紋(5.0),書類(4.0),計画(4.0), probability:0.061
# 1:この計画には、非対面での本人確認を公的個人認証に一本化するということ、それから対面でも公的個人認証「など」を推進して、コピーを取る現状のやり方をやめると書かれています。
# node_id:58, node_words:認証(9.0),コピー(7.0),指紋(5.0),書類(4.0),計画(4.0), probability:0.341
# 2:本人確認書類のコピーを取るやり方は安全性を考えると将来的には廃止されるべきで、その代替手法は公的個人認証が一番使いやすいとは思いますが、運転免許証にも電子的に券面情報を取得できる機能があるので、それでも良いだろうと考えます。
# node_id:58, node_words:認証(9.0),コピー(7.0),指紋(5.0),書類(4.0),計画(4.0), probability:0.272
# ------------------------------------------------------------------
# 0:では、銀行口座は今のうちに沢山作っておくか。
# node_id:26, node_words:銀行(22.0),口座(16.0),作る(11.0),開設(8.0),電話(6.0), probability:0.199
# 1:すでに大手都市銀行４行と地元都市銀行の口座は持っているので、どの銀行にしようかな。
# node_id:26, node_words:銀行(22.0),口座(16.0),作る(11.0),開設(8.0),電話(6.0), probability:0.371
# 2:地元信用金庫と農協かな。
# node_id:785, node_words:たち(7.0),かも(3.0),スポーツマン(2.0),三流(2.0),一流(2.0), probability:0.028
# 3:それ以上作ってもATMが近くにないから使えない。
# node_id:720, node_words:説明(4.0),不足(4.0),競争(3.0),続出(2.0),有る(2.0), probability:0.015
# 4:家族名義の口座も作っておこう。
# node_id:26, node_words:銀行(22.0),口座(16.0),作る(11.0),開設(8.0),電話(6.0), probability:0.094
# 5:携帯電話は、契約させてもらえないなら、その時点で解約で良いや。
# node_id:26, node_words:銀行(22.0),口座(16.0),作る(11.0),開設(8.0),電話(6.0), probability:0.063
# 6:ほとんど使ってないから、金がもったないと思っていた。
# node_id:776, node_words:ダメ(6.0),くっつける(2.0),警察官(2.0),絡む(2.0),一つ(2.0), probability:0.0
# 7:仕事用携帯電話で受電して、PCのg-mailだけで十分だと感じている。
# node_id:780, node_words:携帯(1.0),各所(1.0),場所(1.0),負け(1.0),支給(1.0), probability:0.043
# ------------------------------------------------------------------
# 0:もう、ここまで一体化されるのであれば、マイナカードは、カード型に拘る必要が無いのでは。
# node_id:793, node_words:見る(2.0),私利(1.0),ゴリ押し(1.0),今度(1.0),よる(1.0), probability:0.071
# 1:ドックタグ型にして、ネックチェーンで、肌身離さず持ち歩くように、変えたらどうでしょうか。
# node_id:696, node_words:チップ(5.0),埋め込む(5.0),マイクロ(4.0),ここ(2.0),バカ(2.0), probability:0.086
# 2:それとも、体にチップを埋設する方式にするとか、本人が意図せず手放せない様な、物にしないとね。
# node_id:696, node_words:チップ(5.0),埋め込む(5.0),マイクロ(4.0),ここ(2.0),バカ(2.0), probability:0.114
# 3:肌身から離すから、落としたり、無くしたりするのだから。
# node_id:696, node_words:チップ(5.0),埋め込む(5.0),マイクロ(4.0),ここ(2.0),バカ(2.0), probability:0.057
# ------------------------------------------------------------------
# 0:建前だけ任意として政府は一切責任を負おうとせず、それでいて生活に必須な健康保険や身分証明書などを人質に取り、実質的には強制するやり方が、あまりにも姑息で不誠実だ。
# node_id:451, node_words:任意(12.0),義務(6.0),実質(5.0),やり方(4.0),ふざける(3.0), probability:0.233
# 1:こんなやり方は信用できないし、信用できない人たちに口座番号などの個人情報を渡すのは、危険極まりないと思う。
# node_id:785, node_words:たち(7.0),かも(3.0),スポーツマン(2.0),三流(2.0),一流(2.0), probability:0.149
# 2:民間のカード会社や金融機関は、消費者の信用を得るためにたいへんな努力を行っているが、「マイナンバーカード」には、誠意の欠片もなく、あるのは連日のトラブルと、国民を見下す上から目線だけだ。
# node_id:731, node_words:割合(2.0),天下り(2.0),トラブル(2.0),推奨(2.0),在席(1.0), probability:0.061
# 3:国民の生活状況や健康状態、財産などの個人情報を政府に渡すことで、さらなる増税や負担増を押し付けられることは目に見えている。
# node_id:759, node_words:手帳(5.0),資産(4.0),個人(4.0),公安(3.0),銀行(3.0), probability:0.058
# 4:こんな危険で有害な制度は、今すぐやめるべきだが、そのためには、今の総理大臣をはじめとした政治家に、やめてもらうことが欠かせない。
# node_id:17, node_words:支持(6.0),有る(5.0),勝手(5.0),総理(5.0),公的(4.0), probability:0.065
# 5:そのためには、選挙で意思表示をすることが、国民がとれる一番の解決策だ。
# node_id:447, node_words:投票(6.0),選挙(5.0),政党(4.0),彼ら(3.0),時代(2.0), probability:0.052
# ------------------------------------------------------------------
# 0:ともかく紙の保険証廃止だけは止めるべきでしょう。
# node_id:793, node_words:見る(2.0),私利(1.0),ゴリ押し(1.0),今度(1.0),よる(1.0), probability:0.071
# 1:きょうのテレビ欄で各局のワイドショーの項目をみたら、マイナカードという項目は一つもなかった。
# node_id:798, node_words:項目(2.0),基本(1.0),祈る(1.0),多く(1.0),パイプ(1.0), probability:0.205
# 2:大いに失望した。
# node_id:776, node_words:ダメ(6.0),くっつける(2.0),警察官(2.0),絡む(2.0),一つ(2.0), probability:0.0
# 3:つまり政府の方針は「鎮圧」にかたまったってこと。
# node_id:798, node_words:項目(2.0),基本(1.0),祈る(1.0),多く(1.0),パイプ(1.0), probability:0.027
# 4:テレビ局も政権側からのパイプが切られたら情報ももらえなくなる。
# node_id:798, node_words:項目(2.0),基本(1.0),祈る(1.0),多く(1.0),パイプ(1.0), probability:0.054
# 5:いまこそ国民世論の沸騰しかない、あと有力なコメンテーターやインフルエンサーが紙の保険証維持の立場に立ってくれることを祈るしかない
# node_id:798, node_words:項目(2.0),基本(1.0),祈る(1.0),多く(1.0),パイプ(1.0), probability:0.216
# ------------------------------------------------------------------
# 0:ついに出ましたね。
# node_id:451, node_words:任意(12.0),義務(6.0),実質(5.0),やり方(4.0),ふざける(3.0), probability:0.01
# 1:マイナカードと個人のあらゆる情報を紐づけて国が監視できる体制が。
# node_id:744, node_words:犯罪(3.0),履歴(2.0),クレジットカード(2.0),売買(2.0),体制(2.0), probability:0.043
# 2:戸籍、勤め先、納税、健康保険証、通院投薬歴、運転免許、交通違反歴、保有している車両、携帯電話番号、銀行口座と取引履歴。
# node_id:26, node_words:銀行(22.0),口座(16.0),作る(11.0),開設(8.0),電話(6.0), probability:0.241
# 3:個人的な予測としていずれは学校就学、勤め先などの個人の職歴学歴、警察にある犯罪歴と指紋、パスポート、クレジットカード、ショッピングサイトやSNS、お店やレンタルショップの会員情報、通勤定期などなどもうなんでもありです。
# node_id:744, node_words:犯罪(3.0),履歴(2.0),クレジットカード(2.0),売買(2.0),体制(2.0), probability:0.207
# 4:これらが紐づけられるとビックデータとマイナカードから得られる関連情報をくし刺しして、誰がどの経路をたどってどこへ行ったのか、誰と連絡を取っていて何を話したのか、どんなものを検索して何に興味があって何を購入したのかまで全てバレバレ。
# node_id:744, node_words:犯罪(3.0),履歴(2.0),クレジットカード(2.0),売買(2.0),体制(2.0), probability:0.117
# 5:きっとマイナカードに忘れ物タグに使っているようなチップも搭載するんじゃないかな、末恐ろしい監視社会。
# node_id:696, node_words:チップ(5.0),埋め込む(5.0),マイクロ(4.0),ここ(2.0),バカ(2.0), probability:0.1
# ------------------------------------------------------------------
# 0:免許証とマイナンバーカードの一体化が始まった直後は、道路で行われる検問では超大渋滞が予想されますね。
# node_id:19, node_words:関わる(5.0),諮問(1.0),仕向ける(1.0),重ねる(1.0),なりふり(1.0), probability:0.023
# 1:だって、免許証見れば済むような検問でもいちいち一人一人機械でカードを読まなきゃならないし、ひょっとすると暗証番号入力もあるかも知れないし。
# node_id:14, node_words:番号(13.0),暗証(12.0),記載(5.0),役所(4.0),高齢(4.0), probability:0.156
# 2:車での旅行も大変な時代が到来する恐れありですね。
# node_id:599, node_words:コメント(3.0),レベル(3.0),大変(2.0),つまり(1.0),比較(1.0), probability:0.04
# ------------------------------------------------------------------
# 0:何でもかんでも一体化すれば良いものではない！、運転免許証の更新はその日のうちに完結するがマイナンバーカードの更新は現段階では複雑。
# node_id:116, node_words:更新(27.0),ゴールド(6.0),ブルー(4.0),即日(3.0),会場(2.0), probability:0.318
# 1:運転免許証と同じような更新手続きにすべきである。
# node_id:116, node_words:更新(27.0),ゴールド(6.0),ブルー(4.0),即日(3.0),会場(2.0), probability:0.189
# 2:よくわからないのは免許停止処分時の免許取り上げ、免停解除後に引き渡しとなるがマイナンバーカードになった場合の運用方法が明確でない。
# node_id:798, node_words:項目(2.0),基本(1.0),祈る(1.0),多く(1.0),パイプ(1.0), probability:0.054
# 3:すべての仕組みを理解しないで運用しようとしているところに今後もマイナンバーカードのトラブルが続くような気がする
# node_id:788, node_words:環境(2.0),セキュリティ(2.0),理解(2.0),通信(2.0),優良(1.0), probability:0.1
# ------------------------------------------------------------------
# 0:保険証との紐付けができていないと自己負担になるのと同様に運転免許証の紐付けができてないと免許不携帯になる可能性がある。
# node_id:780, node_words:携帯(1.0),各所(1.0),場所(1.0),負け(1.0),支給(1.0), probability:0.087
# 1:マイナンバーカードと一体化してしまうのは危ないと思う。
# node_id:780, node_words:携帯(1.0),各所(1.0),場所(1.0),負け(1.0),支給(1.0), probability:0.043
# ------------------------------------------------------------------
# 0:先日、郵便局で本人確認にマイナンバーカードを使いましたが、職員さんは裏の番号を見てはいけないらしく、他の人が裏面を見ないようにカードを持ち上げることもできないので、さっと見るだけで確認を終えていました。
# node_id:793, node_words:見る(2.0),私利(1.0),ゴリ押し(1.0),今度(1.0),よる(1.0), probability:0.143
# 1:正直このくらいのチェックなら偽造とか簡単そうだなぁ、と思うんですがどうなんでしょうね。というか詳しくチェックしちゃいけない身分確認証って役に立たない気がする。
# node_id:58, node_words:認証(9.0),コピー(7.0),指紋(5.0),書類(4.0),計画(4.0), probability:0.079
# ------------------------------------------------------------------
# 0:なぜマイナンバー「カード」に政府がこだわるのか理解出来ません。
# node_id:788, node_words:環境(2.0),セキュリティ(2.0),理解(2.0),通信(2.0),優良(1.0), probability:0.067
# 1:速やかな給付などのため、マイナンバーは必要だと思います。
# node_id:787, node_words:来る(3.0),田舎(2.0),無い(2.0),いま(2.0),説明(2.0), probability:0.043
# 2:でも、物理カードを国民の大多数が持つことに、何の意味があるのでしょうか？
# node_id:681, node_words:成立(2.0),内閣(2.0),上手い(2.0),文句(2.0),知る(1.0), probability:0.03
# 3:リモートで各種手続きができて便利といいますが、それは税理士さんとか頻繁に公的手続きをする仕事の方の話であって、一般には、住民票を取ることすら数年に一度の方が多いのではないかと思います。
# node_id:787, node_words:来る(3.0),田舎(2.0),無い(2.0),いま(2.0),説明(2.0), probability:0.102
# 4:印鑑証明カードのように、必要な人が取得できる仕組みで、何の不都合があるのでしょう？
# node_id:768, node_words:かける(2.0),お前(2.0),役人(2.0),照会(2.0),引きずる(2.0), probability:0.045
# 5:百歩譲って、何かの理由で個人を特定するICチップを持たせたいのなら、スマホのICチップに記録するとか、運転免許証のICチップに記録するとか、既に持っているICチップで一定のセキュリティ規格を満たすものなら何でも良いと思いますが、なぜマイナンバー「カード」に統合なのでしよう？
# node_id:696, node_words:チップ(5.0),埋め込む(5.0),マイクロ(4.0),ここ(2.0),バカ(2.0), probability:0.279
# 6:いまいち、理解できません。
# node_id:788, node_words:環境(2.0),セキュリティ(2.0),理解(2.0),通信(2.0),優良(1.0), probability:0.067
# 7:持ってますけど。
# node_id:776, node_words:ダメ(6.0),くっつける(2.0),警察官(2.0),絡む(2.0),一つ(2.0), probability:0.0
# ------------------------------------------------------------------
# 0:マイナンバーカードを返納している人が増えているとの記事を読みました。
# node_id:789, node_words:公式(2.0),犯罪(2.0),苦情(2.0),反対(2.0),そう(1.0), probability:0.023
# 1:作ってしまった人達は、今からでも遅くないので、返納して反対の意志を示すのが大事だと思います。
# node_id:787, node_words:来る(3.0),田舎(2.0),無い(2.0),いま(2.0),説明(2.0), probability:0.064
# 2:貰ったポイントも返さなくて良いそうですよ。
# node_id:193, node_words:禁止(3.0),本来(2.0),許可(1.0),大差(1.0),メリット(1.0), probability:0.05
# 3:そして今度の選挙では、自民党ではなくマイナ一本化に否定的な人に投票しましょう。
# node_id:447, node_words:投票(6.0),選挙(5.0),政党(4.0),彼ら(3.0),時代(2.0), probability:0.096
# ------------------------------------------------------------------
# 0:これ交通違反の取締りのときはどうするの。
# node_id:36, node_words:チップ(7.0),交通(4.0),住所(3.0),専用(3.0),表面(3.0), probability:0.078
# 1:パトロール中に信号無視をした車を発見しました、車を停めて免許証を提示させました、マイナ免許証の表面には免許証としての情報は載っていません、免許証としての情報を確認するためはICチップを読む専用の機械が必要です、でもパトカーにはその専用の機械がなくて確認できませんでした。
# node_id:36, node_words:チップ(7.0),交通(4.0),住所(3.0),専用(3.0),表面(3.0), probability:0.16
# 2:こうした事態を避けるためには、全国に配属されているパトカーや白バイなどのすべての警察車両にICチップを読み取る専用の機械が必要になるということだよね。
# node_id:36, node_words:チップ(7.0),交通(4.0),住所(3.0),専用(3.0),表面(3.0), probability:0.181
# 3:そうしないと交通違反の取締りすらできなくなるのだから。
# node_id:36, node_words:チップ(7.0),交通(4.0),住所(3.0),専用(3.0),表面(3.0), probability:0.078
# 4:全国に何万台とある警察車両に搭載するのにどれだけの費用と年月がかかるのか。
# node_id:157, node_words:スマート(6.0),フォン(6.0),モバイル(5.0),搭載(4.0),変える(3.0), probability:0.065
# 5:はたしてマイナンバーカードと運転免許証との一体化にそれに見合うだけの効果があるか疑問だな。
# node_id:755, node_words:芋づる(2.0),登録(2.0),期限(2.0),悪い(1.0),みな(1.0), probability:0.022
# ------------------------------------------------------------------
# 0:確認手段は複数個用意しておく方が、安全。
# node_id:786, node_words:ごまかし(1.0),流れ(1.0),誤謬(1.0),譲る(1.0),かざす(1.0), probability:0.067
# 1:免許証ないときは、保険証と公的郵便物で本人確認とかもありましたよね。
# node_id:793, node_words:見る(2.0),私利(1.0),ゴリ押し(1.0),今度(1.0),よる(1.0), probability:0.071
# 2:そうやってリスクは、重要な事柄に関しては分散させるものだと考えます。
# node_id:632, node_words:いく(3.0),連携(2.0),注ぐ(2.0),集約(2.0),説明(2.0), probability:0.091
# 3:一つしか手段がないと簡単に行き詰まりまります。
# node_id:766, node_words:役場(2.0),公的(2.0),設置(1.0),近い(1.0),普及(1.0), probability:0.044
# 4:何より強靭なシステムとか鉄壁のシステムでもない限り電子系だけに頼るのは危険。
# node_id:735, node_words:増やす(2.0),友達(2.0),大勢(1.0),共産党(1.0),繰り返す(1.0), probability:0.071
# ------------------------------------------------------------------
# 0:そもそも、自民党政治と言うのは昔から利権の塊でありますから、元々、国民の為に仕事はしておりません。
# node_id:673, node_words:値上がり(3.0),給料(2.0),なれる(1.0),近づく(1.0),あんた(1.0), probability:0.031
# 1:一部の奴の為に仕事をしておりますから一般庶民は何時も困っています。
# node_id:447, node_words:投票(6.0),選挙(5.0),政党(4.0),彼ら(3.0),時代(2.0), probability:0.043
# 2:何故、日本人は選挙になると自民党に投票してしまうのか？
# node_id:447, node_words:投票(6.0),選挙(5.0),政党(4.0),彼ら(3.0),時代(2.0), probability:0.096
# 3:非常に不思議でもありますし、何故なのか？
# node_id:628, node_words:エラー(4.0),それぞれ(4.0),推し進める(3.0),出る(3.0),脆弱(3.0), probability:0.025
# 4:此のままだと日本は更に、とんでもない事になって仕舞いますから、近いうちに衆議院選挙がありますから、自公に非常に危険ですし警戒をする必要があると思っています。
# node_id:787, node_words:来る(3.0),田舎(2.0),無い(2.0),いま(2.0),説明(2.0), probability:0.122
# 5:政権交代を目標に我々日本人は頑張らなければなりません。
# node_id:780, node_words:携帯(1.0),各所(1.0),場所(1.0),負け(1.0),支給(1.0), probability:0.043
# 6:今後、日本の舵取りを補って貰うのは、れいわ新選組を中心とした政権と致します。
# node_id:447, node_words:投票(6.0),選挙(5.0),政党(4.0),彼ら(3.0),時代(2.0), probability:0.035
# 7:皆さんも当然、意義は無いと思いますから絶対に皆の為に政権交代をしようじゃないですか。
# node_id:787, node_words:来る(3.0),田舎(2.0),無い(2.0),いま(2.0),説明(2.0), probability:0.085
# ------------------------------------------------------------------
# 0:免許証との一体化だけは賛成出来ないかな、こんなもん提示する時トラブル起きるの分かってるし こんな穴だらけのシステムで情報が垂れ流しされたらたまったもんじゃないよな、それに一体化されたら常に携帯してなくちゃならんし落とす可能性も高くなるのに再発行まで何ヶ月も掛かって手続きもめちゃくちゃ面倒くさいくなるのは分かってるのに民意を無視して進めるなと言いたい
# node_id:9, node_words:紛失(31.0),発行(30.0),リスク(14.0),無くす(14.0),病院(13.0), probability:0.124
# ------------------------------------------------------------------
# 0:運転免許証をマイナンバーカードに組み込んじゃうと、日常運転する人は常時マイナンバーカードを携帯しとかないと不携帯って事になるという事ですよね？
# node_id:780, node_words:携帯(1.0),各所(1.0),場所(1.0),負け(1.0),支給(1.0), probability:0.083
# 1:個人情報を詰め込んだカードを常時携帯させるような行為を見過ごして良いのか？
# node_id:780, node_words:携帯(1.0),各所(1.0),場所(1.0),負け(1.0),支給(1.0), probability:0.043
# 2:それとも不携帯の罰則を見直してくれるのか？
# node_id:780, node_words:携帯(1.0),各所(1.0),場所(1.0),負け(1.0),支給(1.0), probability:0.043
# 3:マイナンバーカードには番号も記載されてるし、本当に必要な時にしか携帯したくないというのが本音です。
# node_id:14, node_words:番号(13.0),暗証(12.0),記載(5.0),役所(4.0),高齢(4.0), probability:0.097
# ------------------------------------------------------------------
# 0:データの一元管理をマイナンバーシステムでするだけで良いのでは？とも思います。
# node_id:787, node_words:来る(3.0),田舎(2.0),無い(2.0),いま(2.0),説明(2.0), probability:0.043
# 1:個人的には、保険証、免許証、マイナと3枚持ち歩かなくて済むのは歓迎です。
# node_id:793, node_words:見る(2.0),私利(1.0),ゴリ押し(1.0),今度(1.0),よる(1.0), probability:0.071
# 2:言うなら、指紋やら声紋やら顔やらの生体認証情報を登録してればカードすら必要なく、病院に通えたり、車運転出来たりすればいいね。
# node_id:58, node_words:認証(9.0),コピー(7.0),指紋(5.0),書類(4.0),計画(4.0), probability:0.123
# 3:車自体に認証機能を搭載してれば、無免許とか更新切れとかだと車が動かなければいいし、納税や還付も確定申告なんかしなくても自動でしてくれるとか、給付金も手続きなしで給付してくれるとかになれば便利ですね。
# node_id:116, node_words:更新(27.0),ゴールド(6.0),ブルー(4.0),即日(3.0),会場(2.0), probability:0.189
# 4:あと国会議員や地方議員さんなんかは率先して、デジタル化に取り組んでみたらいいですね。
# node_id:379, node_words:議員(16.0),国会(11.0),さん(7.0),役人(5.0),河野(4.0), probability:0.282
# 5:一円単位で使途を公開するとか、選挙投票出来るとか議員さんの評価を簡単にできる仕組みにも活用してください。
# node_id:379, node_words:議員(16.0),国会(11.0),さん(7.0),役人(5.0),河野(4.0), probability:0.157
# 6:現状メリットが少ないのと、情報漏洩の懸念で歓迎されないのでしょうね。
# node_id:193, node_words:禁止(3.0),本来(2.0),許可(1.0),大差(1.0),メリット(1.0), probability:0.05
# 7:便利で住みやすい日本になっていくことを望みます。
# node_id:632, node_words:いく(3.0),連携(2.0),注ぐ(2.0),集約(2.0),説明(2.0), probability:0.091
# ------------------------------------------------------------------
# 0:結局、運転免許証の更新制度は変わらないのでしょう？
# node_id:116, node_words:更新(27.0),ゴールド(6.0),ブルー(4.0),即日(3.0),会場(2.0), probability:0.189
# 1:それなら、顔写真の更新も兼ねて悪くはないと思います。
# node_id:116, node_words:更新(27.0),ゴールド(6.0),ブルー(4.0),即日(3.0),会場(2.0), probability:0.203
# 2:本人確認の媒体としても一定の効力はあるのですし。
# node_id:786, node_words:ごまかし(1.0),流れ(1.0),誤謬(1.0),譲る(1.0),かざす(1.0), probability:0.067
# 3:マイナカードに免許証情報を加えるまでは構わないです。
# node_id:751, node_words:端末(4.0),見せる(2.0),加える(2.0),電子(2.0),住所(2.0), probability:0.029
# 4:ただ、結局所持しなきゃいけないのはどうなんだと。
# node_id:790, node_words:対策(4.0),整備(3.0),示す(3.0),整える(2.0),居る(2.0), probability:0.055
# 5:確認時は警察側の端末で専用サイトにアクセスして、名前や生年月日、住所などから顔写真付きの本人データを呼び出して、本人と一緒に確認とかで良いのかなと。
# node_id:751, node_words:端末(4.0),見せる(2.0),加える(2.0),電子(2.0),住所(2.0), probability:0.147
# 6:そうすれば、不携帯での取締対象にならないし、利用する側も紛失リスクは下げられますしね。
# node_id:9, node_words:紛失(31.0),発行(30.0),リスク(14.0),無くす(14.0),病院(13.0), probability:0.15
# 7:そもそも今も、仮に旅先で財布とかにいれて紛失したら、警察に届け出てもその後運転できないって、現実的にどうなのよ思っています。
# node_id:9, node_words:紛失(31.0),発行(30.0),リスク(14.0),無くす(14.0),病院(13.0), probability:0.093
# 8:とにかく、身分証は複数、系統の違うものは必要かなと思います。
# node_id:787, node_words:来る(3.0),田舎(2.0),無い(2.0),いま(2.0),説明(2.0), probability:0.043
# 9:現時点で代表格は運転免許証かなと。
# node_id:751, node_words:端末(4.0),見せる(2.0),加える(2.0),電子(2.0),住所(2.0), probability:0.029
# 10:加えて警察なりで管理される公的身分証が加われば運転しない人でも助かるかなと思う次第です。
# node_id:766, node_words:役場(2.0),公的(2.0),設置(1.0),近い(1.0),普及(1.0), probability:0.045
# ------------------------------------------------------------------
# 0:一本化するには早すぎる進行だと思う。
# node_id:161, node_words:アナログ(5.0),増やす(3.0),言える(3.0),世界(2.0),デジタル(2.0), probability:0.025
# 1:そもそもシステムの確立ができていない状況だし確立するのにある程度の年月は必要。
# node_id:161, node_words:アナログ(5.0),増やす(3.0),言える(3.0),世界(2.0),デジタル(2.0), probability:0.072
# 2:そもそもアナログを廃止するというのもちょっとどうなのかと感じる。
# node_id:161, node_words:アナログ(5.0),増やす(3.0),言える(3.0),世界(2.0),デジタル(2.0), probability:0.074
# 3:一本化するにしてちゃんと不足の事態の場合の対処の体制はできているんだろうか？
# node_id:720, node_words:説明(4.0),不足(4.0),競争(3.0),続出(2.0),有る(2.0), probability:0.06
# 4:代替としてアナログでの方法も多少面倒になっても残しておいた方がいいように感じる。
# node_id:161, node_words:アナログ(5.0),増やす(3.0),言える(3.0),世界(2.0),デジタル(2.0), probability:0.074
# 5:少なくとも1年ちょっとですべて万全なんてことは無理かと。
# node_id:161, node_words:アナログ(5.0),増やす(3.0),言える(3.0),世界(2.0),デジタル(2.0), probability:0.025
# ------------------------------------------------------------------
# 0:マイナンバーカードの作成は「任意」でしたよね。
# node_id:451, node_words:任意(12.0),義務(6.0),実質(5.0),やり方(4.0),ふざける(3.0), probability:0.117
# 1:いつから強制に変わったのでしょうか。
# node_id:776, node_words:ダメ(6.0),くっつける(2.0),警察官(2.0),絡む(2.0),一つ(2.0), probability:0.0
# 2:また、カードナンバーが流出しないよう「必要な時以外は携帯はしないで下さい」でしたよね。
# node_id:693, node_words:想像(2.0),流出(2.0),利用(1.0),危機(1.0),無い(1.0), probability:0.08
# 3:健康保険証、免許証の紐付け、本人確認と必ず携帯するモノに変わってますよね。
# node_id:793, node_words:見る(2.0),私利(1.0),ゴリ押し(1.0),今度(1.0),よる(1.0), probability:0.071
# 4:国民のコンセンサス取ったのでしょうか？
# node_id:794, node_words:まとめる(4.0),運行(4.0),大型(3.0),点呼(2.0),断る(2.0), probability:0.01
# 5:また、マイナンバーカードを紛失した時、病院に掛かると10割負担ですか？
# node_id:9, node_words:紛失(31.0),発行(30.0),リスク(14.0),無くす(14.0),病院(13.0), probability:0.138
# 6:免許不携帯になりますか？
# node_id:780, node_words:携帯(1.0),各所(1.0),場所(1.0),負け(1.0),支給(1.0), probability:0.043
# 7:確かに保険証や免許無くしたりすれば、そうなりますけど、バラバラであれば全部一遍に無くすリスクは回避されます。
# node_id:9, node_words:紛失(31.0),発行(30.0),リスク(14.0),無くす(14.0),病院(13.0), probability:0.105
# 8:それから、無くした場合の本人確認どうするのでしょうか？
# node_id:786, node_words:ごまかし(1.0),流れ(1.0),誤謬(1.0),譲る(1.0),かざす(1.0), probability:0.067
# 9:即時発行できるのですか？
# node_id:9, node_words:紛失(31.0),発行(30.0),リスク(14.0),無くす(14.0),病院(13.0), probability:0.102
# 10:手続きは簡単ですか？
# node_id:9, node_words:紛失(31.0),発行(30.0),リスク(14.0),無くす(14.0),病院(13.0), probability:0.015
# 11:数々の問題を棚上げにして、国民を不安に貶めているマイナンバーカードの紐付け、はっきり言って不要です。
# node_id:7, node_words:保持(5.0),補完(4.0),統一(3.0),賛成(3.0),検討(3.0), probability:0.026
# 12:単体のみの活用にして下さい。
# node_id:628, node_words:エラー(4.0),それぞれ(4.0),推し進める(3.0),出る(3.0),脆弱(3.0), probability:0.025
# ------------------------------------------------------------------
# 0:通信がうまくいかなかったり、サーバーのトラブルで確認できなかった場合に警察官は運転することを認めることができるのか。
# node_id:788, node_words:環境(2.0),セキュリティ(2.0),理解(2.0),通信(2.0),優良(1.0), probability:0.133
# 1:大規模災害時など身分を証明するものもなくなる。
# node_id:762, node_words:対策(2.0),盗難(1.0),嫌がる(1.0),言いきる(1.0),痛い(1.0), probability:0.032
# 2:緊急時、非常時に余計なトラブル、時間の無駄が発生して被害は拡大するばかりだ。
# node_id:678, node_words:余計(1.0),でる(1.0),勘弁(1.0),かける(1.0),結果(1.0), probability:0.2
# 3:そう考えると今の免許証は身分証明として非常に優れている。
# node_id:17, node_words:支持(6.0),有る(5.0),勝手(5.0),総理(5.0),公的(4.0), probability:0.032
# ------------------------------------------------------------------
# 0:運転免許証とマイナンバーカードが一体化されるのも困りますね。
# node_id:755, node_words:芋づる(2.0),登録(2.0),期限(2.0),悪い(1.0),みな(1.0), probability:0.022
# 1:紛失した場合、その日のうちに再発行してもらえればいいのでしょうが、そういうシステムができるまでは、一体化すべきではありませんね。
# node_id:9, node_words:紛失(31.0),発行(30.0),リスク(14.0),無くす(14.0),病院(13.0), probability:0.249
# 2:運転を仕事にしている人が、マイナンバーカードを紛失したら、一大事になりますよね。
# node_id:9, node_words:紛失(31.0),発行(30.0),リスク(14.0),無くす(14.0),病院(13.0), probability:0.102
# 3:再発行されるまで運転の仕事ができないのも痛手でしょうし。
# node_id:9, node_words:紛失(31.0),発行(30.0),リスク(14.0),無くす(14.0),病院(13.0), probability:0.099
# ------------------------------------------------------------------
# 0:デジタル化で世の中の色々な物が便利になるのには賛成だが、マイナンバーカードはどうなのだろう。
# node_id:739, node_words:船舶(2.0),順番(2.0),続く(1.0),物事(1.0),理想(1.0), probability:0.056
# 1:なんだか、行き当たりばったりで物事を進め副作用や矛盾が起きることを考えているのだろうか。
# node_id:682, node_words:起きる(3.0),矛盾(2.0),公平(2.0),影響(2.0),隠す(2.0), probability:0.081
# 2:どうして日本はこうなのだろう。
# node_id:760, node_words:オランダ(4.0),任意(3.0),強引(2.0),外国(2.0),取り上げる(2.0), probability:0.02
# 3:なぜ将来を見据えた構造改革を根本から見直してできないのだろう。
# node_id:682, node_words:起きる(3.0),矛盾(2.0),公平(2.0),影響(2.0),隠す(2.0), probability:0.035
# 4:今あるものを使って新しく何かしようとしても、そのシステムの限界を超えると問題が起きることはビジネスマンなら知っている。
# node_id:682, node_words:起きる(3.0),矛盾(2.0),公平(2.0),影響(2.0),隠す(2.0), probability:0.081
# 5:お金がかかるからできないというなら、起きた問題の後始末にかかる時間とお金を考えてみては？
# node_id:682, node_words:起きる(3.0),矛盾(2.0),公平(2.0),影響(2.0),隠す(2.0), probability:0.057
# 6:行政のシステムは、なによりも信頼が大事だと思うのは私だけでしょうか。
# node_id:682, node_words:起きる(3.0),矛盾(2.0),公平(2.0),影響(2.0),隠す(2.0), probability:0.047
# ------------------------------------------------------------------
# 0:オランダに駐在した時、オランダの運転免許証に書き換えした際に日本の運転免許証を取り上げられました。
# node_id:760, node_words:オランダ(4.0),任意(3.0),強引(2.0),外国(2.0),取り上げる(2.0), probability:0.185
# 1:日本の運転免許証と交換したことになります。
# node_id:760, node_words:オランダ(4.0),任意(3.0),強引(2.0),外国(2.0),取り上げる(2.0), probability:0.04
# 2:在オランダ日本大使館とオランダ政府との間で特別に日本の運転免許証を本人に返す約束ができていたので、数カ月後に戻ってきました。
# node_id:760, node_words:オランダ(4.0),任意(3.0),強引(2.0),外国(2.0),取り上げる(2.0), probability:0.255
# 3:もし、マイナンバーカードが運転免許証を兼ねるとなれば、免許の記載事項が明記されていないので外国で用を足さない。
# node_id:760, node_words:オランダ(4.0),任意(3.0),強引(2.0),外国(2.0),取り上げる(2.0), probability:0.08
# 4:記載されたとして、取り上げられて返却されないとなった場合、帰国した時、どうすればいいのでしょうかね？
# node_id:760, node_words:オランダ(4.0),任意(3.0),強引(2.0),外国(2.0),取り上げる(2.0), probability:0.04
# 5:　外国の運転免許証でマイナンバーカードを発行してくれるのでしょうか？
# node_id:9, node_words:紛失(31.0),発行(30.0),リスク(14.0),無くす(14.0),病院(13.0), probability:0.093
# 6:　今の政府はこのようなことまで考えていないでしょうね。
# node_id:755, node_words:芋づる(2.0),登録(2.0),期限(2.0),悪い(1.0),みな(1.0), probability:0.022
# ------------------------------------------------------------------
# 0:希望者だけマイナンバーカードで使える様にするだけにして欲しい。
# node_id:145, node_words:中国(4.0),老害(2.0),一族(2.0),好き(2.0),移住(2.0), probability:0.026
# 1:紐付けは漢字一つの間違いもなく紐付けするなら勝手にどうぞですが、免許証は免許証として単独で持ちたい人まで巻き込まないで欲しい。
# node_id:17, node_words:支持(6.0),有る(5.0),勝手(5.0),総理(5.0),公的(4.0), probability:0.147
# 2:私、免許取得後無事故無違反ですが、今のマイナンバーの杜撰さみるにつけ、知らない間に勝手に点数削られて免停になったりあるんじゃないかと本気で思います。
# node_id:17, node_words:支持(6.0),有る(5.0),勝手(5.0),総理(5.0),公的(4.0), probability:0.086
# 3:全てはシステムトラブルやヒューマンエラーでしょうが、責任逃れでたらい回しにされる未来しか思い浮かばない。
# node_id:35, node_words:あげる(3.0),作れる(2.0),逃れ(2.0),マトモ(2.0),破産(2.0), probability:0.068
# 4:もちろん誰も責任取らないでしょうしね。
# node_id:795, node_words:破綻(5.0),違い(4.0),振り回す(2.0),沙汰(2.0),狂気(2.0), probability:0.018
# 5:被害者だけが苦しむだけと。
# node_id:762, node_words:対策(2.0),盗難(1.0),嫌がる(1.0),言いきる(1.0),痛い(1.0), probability:0.032
# 6:なんでもむやみやたらに国が強制してやるのは辞めて欲しい。
# node_id:14, node_words:番号(13.0),暗証(12.0),記載(5.0),役所(4.0),高齢(4.0), probability:0.005
# ------------------------------------------------------------------
# 0:紛失問題は、常に、なんにでもあるだろう。
# node_id:9, node_words:紛失(31.0),発行(30.0),リスク(14.0),無くす(14.0),病院(13.0), probability:0.093
# 1:国家試験免状もそうだ。
# node_id:193, node_words:禁止(3.0),本来(2.0),許可(1.0),大差(1.0),メリット(1.0), probability:0.05
# 2:「紙で配布され、本人が保管し、何かあれば持参する」という現状が、マイナカードで単純になれば、書類の保管も不要で、よほど便利になるような気がする。
# node_id:793, node_words:見る(2.0),私利(1.0),ゴリ押し(1.0),今度(1.0),よる(1.0), probability:0.133
# 3:何事にも全て光と影がある訳で、影だけを強調して反対するのはどうなのか。
# node_id:789, node_words:公式(2.0),犯罪(2.0),苦情(2.0),反対(2.0),そう(1.0), probability:0.045
# 4:多分、生涯変わらないとする指紋を登録し、本人確認の一助とするのは如何か。
# node_id:58, node_words:認証(9.0),コピー(7.0),指紋(5.0),書類(4.0),計画(4.0), probability:0.07
# 5:写真と指紋のダブル認識で、安全性がグンと増すと思うが。
# node_id:58, node_words:認証(9.0),コピー(7.0),指紋(5.0),書類(4.0),計画(4.0), probability:0.079
# ------------------------------------------------------------------
# 0:今は新規に銀行口座を作るとに、運転免許証か保険証が必要だった。
# node_id:26, node_words:銀行(22.0),口座(16.0),作る(11.0),開設(8.0),電話(6.0), probability:0.267
# 1:それが、運転免許証と保険証がマイナカードに完全統合された後は、全ての新規銀行口座は、マイナカードが必要、すなわちマイナンバーと紐付く事になります。
# node_id:26, node_words:銀行(22.0),口座(16.0),作る(11.0),開設(8.0),電話(6.0), probability:0.209
# 2:少なくとも100年後には、ほぼ100%の銀行口座はマイナンバーに紐づいているでしょう。
# node_id:26, node_words:銀行(22.0),口座(16.0),作る(11.0),開設(8.0),電話(6.0), probability:0.199
# 3:誰が考えたか知らないけど、遠大な計画ですね。
# node_id:58, node_words:認証(9.0),コピー(7.0),指紋(5.0),書類(4.0),計画(4.0), probability:0.035
# 4:日本の官僚もまだまだなかなか優秀です。
# node_id:145, node_words:中国(4.0),老害(2.0),一族(2.0),好き(2.0),移住(2.0), probability:0.026
# ------------------------------------------------------------------
# 0:記事にもある通り、マイナカードを失くした時の本人確認や再発行の手順、かかる日にちはどうなるのでしょうか。
# node_id:9, node_words:紛失(31.0),発行(30.0),リスク(14.0),無くす(14.0),病院(13.0), probability:0.111
# 1:今までは運転免許証や保険証、パスポートなどで本人確認ができたから、万が一が起こった時も何とか再発行に進むことができました。
# node_id:9, node_words:紛失(31.0),発行(30.0),リスク(14.0),無くす(14.0),病院(13.0), probability:0.12
# 2:マイナンバーに運転免許証や保険証を紐づけるのは構わないけれど、発行はそのまま続けてほしいです。
# node_id:9, node_words:紛失(31.0),発行(30.0),リスク(14.0),無くす(14.0),病院(13.0), probability:0.093
# 3:ほぼ毎日運転している私としては、たった一枚の身分証明書をずっと身につけなくてはいけないのはリスクがありすぎだと思います。
# node_id:632, node_words:いく(3.0),連携(2.0),注ぐ(2.0),集約(2.0),説明(2.0), probability:0.061
# ------------------------------------------------------------------
# 0:僕はですけど、多少不便でも、リスクが少なく小さい方が絶対にいいです。
# node_id:632, node_words:いく(3.0),連携(2.0),注ぐ(2.0),集約(2.0),説明(2.0), probability:0.061
# 1:政府や官庁にはメリットが大きいのかもしれませんが、一国民としては不安とリスクが大きすぎて、今のシステムレベルでは絶対に移行したくないです。
# node_id:632, node_words:いく(3.0),連携(2.0),注ぐ(2.0),集約(2.0),説明(2.0), probability:0.061
# 2:民間の販売しているシステムって、イレギュラーな事態も想定してこれでもかっていろいろなテストを行いリリースしていると思いますが、現状のマイナシステムはとりあえず作ったレベルで問題だらけです。
# node_id:800, node_words:統合(2.0),リリース(2.0),民間(1.0),自国(1.0),販売(1.0), probability:0.2
# 3:それでもって問題起きても国は責任とらないと断言しているのだから話にならないと思います。
# node_id:787, node_words:来る(3.0),田舎(2.0),無い(2.0),いま(2.0),説明(2.0), probability:0.043
# 4:せめて明らかになっている国民の判断で譲れないを解決し不安を解消しない限りリリースなどもってのほかです。
# node_id:800, node_words:統合(2.0),リリース(2.0),民間(1.0),自国(1.0),販売(1.0), probability:0.2
# ------------------------------------------------------------------
# 0:考え方を切り替えて、運転免許証（運転経歴証明書）にマイナンバーカードの機能をつければいいのに。
# node_id:755, node_words:芋づる(2.0),登録(2.0),期限(2.0),悪い(1.0),みな(1.0), probability:0.043
# 1:もちろん非保持者はマイナンバーカードをIDとして使えば良い。
# node_id:7, node_words:保持(5.0),補完(4.0),統一(3.0),賛成(3.0),検討(3.0), probability:0.064
# 2:運転免許証保持者限定ですが、実務上長らくIDカードとして通用しており、転居しても最寄りの警察で簡単に処理してもらえる。
# node_id:7, node_words:保持(5.0),補完(4.0),統一(3.0),賛成(3.0),検討(3.0), probability:0.103
# 3:保持者にとっては一番便利ですよ。
# node_id:7, node_words:保持(5.0),補完(4.0),統一(3.0),賛成(3.0),検討(3.0), probability:0.064
# ------------------------------------------------------------------
# 0:マイナンバーカードの普及のために保険証を廃止し更に運転免許証を廃止するとは手段と目的を取り違えている。
# node_id:791, node_words:普及(7.0),値する(2.0),普通(2.0),身元(1.0),今更(1.0), probability:0.259
# 1:マイナンバーカードを持つことにメリットがあれば自然と普及するが、ポイントを付与するという飴をぶら下げたり、それでもだめなら強制的に保険証や免許証を取り上げるぞと脅しをかける。
# node_id:791, node_words:普及(7.0),値する(2.0),普通(2.0),身元(1.0),今更(1.0), probability:0.259
# 2:そこまでやらないと普及しないマイナンバーカードは必要だろうか。
# node_id:791, node_words:普及(7.0),値する(2.0),普通(2.0),身元(1.0),今更(1.0), probability:0.259
# 3:市場経済ではメリットがないものはいずれ淘汰される。
# node_id:193, node_words:禁止(3.0),本来(2.0),許可(1.0),大差(1.0),メリット(1.0), probability:0.05
# 4:既にポイントをもらった人はマイナンバーカードは家の引き出しにしまわれているだろうし、保険証や運転免許証も抜け道があればみんな抜け道に殺到するだろう。
# node_id:802, node_words:普段(2.0),写し(2.0),抜け道(2.0),保管(1.0),無駄(1.0), probability:0.143
# 5:困るのは既にシステムが確立しているのに新たな対応を迫られる医療機関や警察署だ。
# node_id:802, node_words:普段(2.0),写し(2.0),抜け道(2.0),保管(1.0),無駄(1.0), probability:0.064
# 6:そこに莫大な無駄なお金が必要になる。
# node_id:802, node_words:普段(2.0),写し(2.0),抜け道(2.0),保管(1.0),無駄(1.0), probability:0.064
# 7:常時使う保険証や運転免許証と普段は使わないけど無くすと困るマイナンバーカードを一体化するというのは発想が貧困すぎる。
# node_id:802, node_words:普段(2.0),写し(2.0),抜け道(2.0),保管(1.0),無駄(1.0), probability:0.128
# ------------------------------------------------------------------
# 0:日本は世界的にも少子化が著しく進行しており、まもなくアナログ対応では日常生活が対応できなくなる事は明らかです。
# node_id:161, node_words:アナログ(5.0),増やす(3.0),言える(3.0),世界(2.0),デジタル(2.0), probability:0.148
# 1:従ってデジタル化は必須で、全てが処理可能なマイナンバーカードは必須です。
# node_id:161, node_words:アナログ(5.0),増やす(3.0),言える(3.0),世界(2.0),デジタル(2.0), probability:0.084
# 2:今起こっているマイナンバーカードの問題点はアナログ対応からデジタル化に移行する時に必ず起こるアナログ人間によるミスです。
# node_id:161, node_words:アナログ(5.0),増やす(3.0),言える(3.0),世界(2.0),デジタル(2.0), probability:0.151
# 3:これを否定すればデジタル化は不可能で、20年もすれば日本の行政はパンクし、日常生活が困難に直面する事は明白です。
# node_id:161, node_words:アナログ(5.0),増やす(3.0),言える(3.0),世界(2.0),デジタル(2.0), probability:0.099
# 4:世界でデジタル化が最も遅れている国の一つの日本は、まず追いつく事を優先しましょう。
# node_id:161, node_words:アナログ(5.0),増やす(3.0),言える(3.0),世界(2.0),デジタル(2.0), probability:0.074
# 5:どんな仕組みも最初から最善だった事例は人類史にありません。
# node_id:767, node_words:撒く(3.0),市町村(3.0),どん(3.0),ばら(3.0),都道府県(2.0), probability:0.041
# 6:継続的改善でより良きシステムにしていきましょう。
# node_id:735, node_words:増やす(2.0),友達(2.0),大勢(1.0),共産党(1.0),繰り返す(1.0), probability:0.037
# ------------------------------------------------------------------
# 0:未だに平成表記の運転免許証を所持しているのだが、このまま行くと最後の運転免許証所持者になってしまうのかもしれないな。
# node_id:785, node_words:たち(7.0),かも(3.0),スポーツマン(2.0),三流(2.0),一流(2.0), probability:0.042
# 1:でもなぁ。
# node_id:776, node_words:ダメ(6.0),くっつける(2.0),警察官(2.0),絡む(2.0),一つ(2.0), probability:0.0
# 2:マイナンバーカードはマスターキーみたいなもので、普段持ち歩くものではない気がします。
# node_id:802, node_words:普段(2.0),写し(2.0),抜け道(2.0),保管(1.0),無駄(1.0), probability:0.043
# 3:利便性とセキュリティは相反するものですので、どこでバランスさせるかを個人が選択できるようなシステムだといいのになぁ。
# node_id:735, node_words:増やす(2.0),友達(2.0),大勢(1.0),共産党(1.0),繰り返す(1.0), probability:0.074
# ------------------------------------------------------------------
# 0:春に厚木基地に行きましたが、免許証だけでは入れなかったようです。
# node_id:379, node_words:議員(16.0),国会(11.0),さん(7.0),役人(5.0),河野(4.0), probability:0.017
# 1:パスポートなりマイナンバーカードならOKでした。
# node_id:755, node_words:芋づる(2.0),登録(2.0),期限(2.0),悪い(1.0),みな(1.0), probability:0.022
# 2:横田基地は免許証でも入れましたけど。
# node_id:379, node_words:議員(16.0),国会(11.0),さん(7.0),役人(5.0),河野(4.0), probability:0.017
# 3:恐らくですが免許証は偽造しやすいんでしょう。
# node_id:9, node_words:紛失(31.0),発行(30.0),リスク(14.0),無くす(14.0),病院(13.0), probability:0.003
# 4:ただ、免許証も一本化するなら即日発行はしてもらいたい。
# node_id:9, node_words:紛失(31.0),発行(30.0),リスク(14.0),無くす(14.0),病院(13.0), probability:0.09
# ------------------------------------------------------------------
# 0:一つにするというメリットもあるんだろうけど。
# node_id:193, node_words:禁止(3.0),本来(2.0),許可(1.0),大差(1.0),メリット(1.0), probability:0.05
# 1:纏めるリスクの方が勝っているように思える。
# node_id:632, node_words:いく(3.0),連携(2.0),注ぐ(2.0),集約(2.0),説明(2.0), probability:0.061
# 2:紛失というリスクは誰でもあることに対して、纏めた後に1箇所で全て再発行できるのだろうか。
# node_id:9, node_words:紛失(31.0),発行(30.0),リスク(14.0),無くす(14.0),病院(13.0), probability:0.237
# 3:極端に24時間対応してくれるのかな？
# node_id:766, node_words:役場(2.0),公的(2.0),設置(1.0),近い(1.0),普及(1.0), probability:0.015
# 4:無理に進めずともいいように思える事が、政府は起こり得るリスク把握せずに進めようとすることがリスクだな、これ。
# node_id:632, node_words:いく(3.0),連携(2.0),注ぐ(2.0),集約(2.0),説明(2.0), probability:0.114
# ------------------------------------------------------------------
# 0:問題が多発しているのに、ここまで強引に拙速にカードに集約したいのは国民の為と言うより、カード関連業者との癒着そして国の管理強化の為と言わざるを得ない。
# node_id:793, node_words:見る(2.0),私利(1.0),ゴリ押し(1.0),今度(1.0),よる(1.0), probability:0.071
# 1:もし違うと言うなら法的には任意のカードを姑息な手段で実質義務化にしないで、正面から国民に理由を丁寧に説明し法律的に義務化して下さい。
# node_id:451, node_words:任意(12.0),義務(6.0),実質(5.0),やり方(4.0),ふざける(3.0), probability:0.33
# ------------------------------------------------------------------
# 0:カードの取得を義務づければシンプルで分かりやすいのに、反対派の説得に自信がなかったり、選挙に影響するから出来ないのかな。
# node_id:451, node_words:任意(12.0),義務(6.0),実質(5.0),やり方(4.0),ふざける(3.0), probability:0.058
# 1:義務でないものを取得しないと生活が成り立たなくする。
# node_id:451, node_words:任意(12.0),義務(6.0),実質(5.0),やり方(4.0),ふざける(3.0), probability:0.058
# 2:政策の矛盾としか言えません。
# node_id:682, node_words:起きる(3.0),矛盾(2.0),公平(2.0),影響(2.0),隠す(2.0), probability:0.023
# 3:公平ということを口実にしてシステムを複雑にして、使うためには相当な勉強が必要になり、結局使える人と使えない人が出てきて不公平になる。
# node_id:682, node_words:起きる(3.0),矛盾(2.0),公平(2.0),影響(2.0),隠す(2.0), probability:0.102
# 4:そんなシステムばかりじゃないですか、この国は。
# node_id:735, node_words:増やす(2.0),友達(2.0),大勢(1.0),共産党(1.0),繰り返す(1.0), probability:0.037
# 5:マイナンバーカードも、公平性や個人情報を守ろうとすると、複雑な手続や届出などが必要で、しかもそういうことができることを積極的に国民に知らせず、一部の人しか権利を享受できないものになっている。
# node_id:682, node_words:起きる(3.0),矛盾(2.0),公平(2.0),影響(2.0),隠す(2.0), probability:0.081
# 6:いつものパターンが繰り返されるのではないでしょうか。
# node_id:766, node_words:役場(2.0),公的(2.0),設置(1.0),近い(1.0),普及(1.0), probability:0.015
# 7:その最悪なシステムが構築されそうですね。
# node_id:682, node_words:起きる(3.0),矛盾(2.0),公平(2.0),影響(2.0),隠す(2.0), probability:0.047
# ------------------------------------------------------------------
# 0:現状のマイナカードの記載は名前や住所に生年月日に個人番号といった固定情報の記載のみで『免許証情報の記載箇所』は存在していない。
# node_id:14, node_words:番号(13.0),暗証(12.0),記載(5.0),役所(4.0),高齢(4.0), probability:0.179
# 1:マイナカードは『デジタル管理が前提』にあり、万一、天災停電があった際に電気を使い、通信を必要とする認証機器が使えない状態で『どうやって免許証対応』するのか。
# node_id:782, node_words:機器(4.0),配備(2.0),作業(2.0),得る(2.0),於く(2.0), probability:0.08
# 2:今の医療機関で事故や意識不明で搬送された患者は暗証番号が入力出来るとは限らず、そこでマイナ保険証の有効確認も、対応ガイドラインも確立していない中途半端な状態で免許証一体型は有り得ない。
# node_id:14, node_words:番号(13.0),暗証(12.0),記載(5.0),役所(4.0),高齢(4.0), probability:0.215
# 3:早かれ
# node_id:776, node_words:ダメ(6.0),くっつける(2.0),警察官(2.0),絡む(2.0),一つ(2.0), probability:0.0
# 4:遅かれマイナ
# node_id:704, node_words:基本(6.0),コード(5.0),なに(3.0),年寄り(3.0),取り扱い(3.0), probability:0.017
# 5:カード一体型免許証になるかもしれない。
# node_id:785, node_words:たち(7.0),かも(3.0),スポーツマン(2.0),三流(2.0),一流(2.0), probability:0.042
# 6:けど今の役所の情報管理体制や情報漏洩、システム不具合といった様々な情報管理体制を整えて安定してから記事の免許証の話をして欲しい。
# node_id:735, node_words:増やす(2.0),友達(2.0),大勢(1.0),共産党(1.0),繰り返す(1.0), probability:0.074
# 7:まあ･･･免許証とマイナカード比較だと主に免許証番号と個人番号の掲載があるか否かの違いと、更新手続きする場所の違いだと思うが。
# node_id:116, node_words:更新(27.0),ゴールド(6.0),ブルー(4.0),即日(3.0),会場(2.0), probability:0.196
# ------------------------------------------------------------------
# 0:保険証ではまだ黙っていた人たちも、運転免許証となると声を荒げるかも。
# node_id:785, node_words:たち(7.0),かも(3.0),スポーツマン(2.0),三流(2.0),一流(2.0), probability:0.139
# 1:保険証だけでこれだけたくさんのミスの発覚。
# node_id:793, node_words:見る(2.0),私利(1.0),ゴリ押し(1.0),今度(1.0),よる(1.0), probability:0.071
# 2:運転免許証の場合はもっといろいろなミスや不整備が予想される。
# node_id:781, node_words:認める(3.0),整備(2.0),インフラ(2.0),対策(1.0),心情(1.0), probability:0.069
# 3:一体化が国民にとって利益のあるような言い方だが、実は国の思惑のためにカードによって支配されているように思える。
# node_id:145, node_words:中国(4.0),老害(2.0),一族(2.0),好き(2.0),移住(2.0), probability:0.051
# ------------------------------------------------------------------
# 0:マイナンバーカードは個人情報があるから無闇矢鱈に証明書に使う方が危険でもし詐欺やスキミングにあえばどうするのか！
# node_id:35, node_words:あげる(3.0),作れる(2.0),逃れ(2.0),マトモ(2.0),破産(2.0), probability:0.045
# 1:一枚紛失しただけで運転出来ないから免許の再交付や病院代も全額負担になり暗証番号を間違えただけで何度も役所に行く事になる！
# node_id:14, node_words:番号(13.0),暗証(12.0),記載(5.0),役所(4.0),高齢(4.0), probability:0.161
# 2:仕事してるのに運転出来ないし再登録さえ大変になる！
# node_id:599, node_words:コメント(3.0),レベル(3.0),大変(2.0),つまり(1.0),比較(1.0), probability:0.06
# 3:免許証だけでも別なら運転出来るので再交付や仕事で運転もできる！
# node_id:787, node_words:来る(3.0),田舎(2.0),無い(2.0),いま(2.0),説明(2.0), probability:0.064
# ------------------------------------------------------------------
# 0:国が欲しいのは、すべての行政組織で一貫して使える国民背番号。
# node_id:14, node_words:番号(13.0),暗証(12.0),記載(5.0),役所(4.0),高齢(4.0), probability:0.07
# 1:過去数十年、導入しようとしてきたけど、国民の反対でうまくいかなかった。
# node_id:789, node_words:公式(2.0),犯罪(2.0),苦情(2.0),反対(2.0),そう(1.0), probability:0.045
# 2:だからマイナンバーを事実上の国民背番号にしようとしているのでしょう。
# node_id:14, node_words:番号(13.0),暗証(12.0),記載(5.0),役所(4.0),高齢(4.0), probability:0.07
# 3:私たちも年金制度の混乱、コロナの時の対応の遅れ、こんなのは国民背番号があれば回避できていたので、国に健康保険と一緒にする代わりに、すべての行政組織で横断して使えるようにしてくださいとでも言うべきと思います。
# node_id:785, node_words:たち(7.0),かも(3.0),スポーツマン(2.0),三流(2.0),一流(2.0), probability:0.097
# ------------------------------------------------------------------
# 0:色々問題があるんだから、先ず簡単なところから手を付けて欲しい。
# node_id:781, node_words:認める(3.0),整備(2.0),インフラ(2.0),対策(1.0),心情(1.0), probability:0.069
# 1:例えば、色々な手続きで何回も住所と名前を書くのをやめて欲しい。
# node_id:36, node_words:チップ(7.0),交通(4.0),住所(3.0),専用(3.0),表面(3.0), probability:0.052
# 2:この間も、銀行で通帳を再発行するのに本人確認書から紛失届、再発行申請等、４，５回住所と名前を書いたよ。
# node_id:9, node_words:紛失(31.0),発行(30.0),リスク(14.0),無くす(14.0),病院(13.0), probability:0.255
# 3:そういうのを無くしながらバグを修正していけば良いのに。
# node_id:9, node_words:紛失(31.0),発行(30.0),リスク(14.0),無くす(14.0),病院(13.0), probability:0.03
# ------------------------------------------------------------------
# 0:とにかく自民党嫌いな人たちの理屈なしの反対意見がすごい。
# node_id:785, node_words:たち(7.0),かも(3.0),スポーツマン(2.0),三流(2.0),一流(2.0), probability:0.097
# 1:結局騒いだところで（一旦停止するとか、マイナンバーカードへの一本化廃止という以外の）代替案もない今の状態だと、選挙やっても今の政権与党に入れるしかなくなるんだよね。
# node_id:698, node_words:与党(9.0),潰す(4.0),存在(3.0),正しい(3.0),内閣(3.0), probability:0.089
# 2:行政の効率化（税金の無駄遣い削減）が必要だとずっといいながらも、議員定数削減とか文書費ばかり話題に上がるのではなくて、マイナンバーカードへの一本化をはじめとした（本当の）効率化を進めないと本当にまずいですよ。
# node_id:732, node_words:効率(7.0),行政(3.0),スピード(2.0),太郎(2.0),徴収(2.0), probability:0.319
# ------------------------------------------------------------------
# 0:何かあったら責任の擦り付けあいで、電話対応もたらい回しの状態。
# node_id:17, node_words:支持(6.0),有る(5.0),勝手(5.0),総理(5.0),公的(4.0), probability:0.054
# 1:まずはどこが責任を取るのかしっかり決めてほしい。
# node_id:795, node_words:破綻(5.0),違い(4.0),振り回す(2.0),沙汰(2.0),狂気(2.0), probability:0.018
# 2:今の状態で何でも間でも紐付けるのはどうでしょうか。
# node_id:17, node_words:支持(6.0),有る(5.0),勝手(5.0),総理(5.0),公的(4.0), probability:0.022
# 3:あまりにも危険すぎる。
# node_id:729, node_words:無能(4.0),ヒューマン(2.0),行為(2.0),危険(2.0),行う(2.0), probability:0.034
# 4:運転免許の情報はマイナンバーと共有でいいのでは？
# node_id:704, node_words:基本(6.0),コード(5.0),なに(3.0),年寄り(3.0),取り扱い(3.0), probability:0.017
# 5:運転免許自体無くすのは反対です。
# node_id:789, node_words:公式(2.0),犯罪(2.0),苦情(2.0),反対(2.0),そう(1.0), probability:0.045
# 6:警察に運転免許出してと言われたらマイナンバーカード出すんですか？
# node_id:755, node_words:芋づる(2.0),登録(2.0),期限(2.0),悪い(1.0),みな(1.0), probability:0.022
# 7:アプリなどで身分証明してくださいって時にマイナンバーカード出すんですか？
# node_id:17, node_words:支持(6.0),有る(5.0),勝手(5.0),総理(5.0),公的(4.0), probability:0.032
# 8:まずは一個一個議論を十分に重ね、確実にやるべきです。
# node_id:762, node_words:対策(2.0),盗難(1.0),嫌がる(1.0),言いきる(1.0),痛い(1.0), probability:0.032
# 9:国民の声を聞く総理ではなかったの？
# node_id:17, node_words:支持(6.0),有る(5.0),勝手(5.0),総理(5.0),公的(4.0), probability:0.086
# ------------------------------------------------------------------
# 0:色々心配事があり大変ですね。
# node_id:599, node_words:コメント(3.0),レベル(3.0),大変(2.0),つまり(1.0),比較(1.0), probability:0.04
# 1:ただコメント欄に記載されている懸念事項は想定の範囲内。
# node_id:599, node_words:コメント(3.0),レベル(3.0),大変(2.0),つまり(1.0),比較(1.0), probability:0.1
# 2:つまりは運用面の問題ばかり。
# node_id:599, node_words:コメント(3.0),レベル(3.0),大変(2.0),つまり(1.0),比較(1.0), probability:0.02
# 3:こんな事って作る側から見れば10週回って既に承知済み。
# node_id:26, node_words:銀行(22.0),口座(16.0),作る(11.0),開設(8.0),電話(6.0), probability:0.058
# 4:これらが発生した場合にどのように対応するかはある程度は検討されている筈。とは言え、思ったようには進まない事も多々ある。
# node_id:7, node_words:保持(5.0),補完(4.0),統一(3.0),賛成(3.0),検討(3.0), probability:0.038
# 5:エラーが出る事もあるが、それを確認し修復しながら精度を上げていけば問題無いしシステム設計とはそういうもの。
# node_id:628, node_words:エラー(4.0),それぞれ(4.0),推し進める(3.0),出る(3.0),脆弱(3.0), probability:0.099
# 6:最初から完全なものは作れない。
# node_id:751, node_words:端末(4.0),見せる(2.0),加える(2.0),電子(2.0),住所(2.0), probability:0.015
# 7:少子化が進み働き手が減るこの国において、デジタル化は必然。
# node_id:599, node_words:コメント(3.0),レベル(3.0),大変(2.0),つまり(1.0),比較(1.0), probability:0.04
# 8:自分が面倒とか大変とか自分の事しか考えていないコメントが散見されるが、大事なのは10年先、20年先を考える事。
# node_id:599, node_words:コメント(3.0),レベル(3.0),大変(2.0),つまり(1.0),比較(1.0), probability:0.157
# 9:国民皆保険等、様々な分野から受けている今のサービスレベル、延いては国力を今後も維持するためにはデジタル化は必須だし、今はその過渡期である事を理解すべき。
# node_id:599, node_words:コメント(3.0),レベル(3.0),大変(2.0),つまり(1.0),比較(1.0), probability:0.16
# ------------------------------------------------------------------
# 0:先日マイナカード無くした。
# node_id:755, node_words:芋づる(2.0),登録(2.0),期限(2.0),悪い(1.0),みな(1.0), probability:0.022
# 1:本人確認が免許証だと。
# node_id:786, node_words:ごまかし(1.0),流れ(1.0),誤謬(1.0),譲る(1.0),かざす(1.0), probability:0.067
# 2:一緒になったら、いちいち有料の印鑑証明取るのかな？
# node_id:17, node_words:支持(6.0),有る(5.0),勝手(5.0),総理(5.0),公的(4.0), probability:0.032
# 3:再発行に6か月。
# node_id:9, node_words:紛失(31.0),発行(30.0),リスク(14.0),無くす(14.0),病院(13.0), probability:0.093
# 4:紛失届は警察行ってから、自分で連絡する、再発行データを送っても登録まで2週間。
# node_id:9, node_words:紛失(31.0),発行(30.0),リスク(14.0),無くす(14.0),病院(13.0), probability:0.198
# 5:つまり、無くしてから再発行開始まで謎の空白ができる。
# node_id:9, node_words:紛失(31.0),発行(30.0),リスク(14.0),無くす(14.0),病院(13.0), probability:0.096
# 6:紛失と、再発行申請登録は同時にできない。
# node_id:9, node_words:紛失(31.0),発行(30.0),リスク(14.0),無くす(14.0),病院(13.0), probability:0.183
# 7:その間に本人確認のいい加減な携帯買われたり、サラ金いかれたらどうしよう。
# node_id:786, node_words:ごまかし(1.0),流れ(1.0),誤謬(1.0),譲る(1.0),かざす(1.0), probability:0.067
# 8:病院も割高な診察料がかかる。
# node_id:9, node_words:紛失(31.0),発行(30.0),リスク(14.0),無くす(14.0),病院(13.0), probability:0.057
# ------------------------------------------------------------------
# 0:個人事業主でマイナカードは電子認証に使用して仕事をしているので、パソコンのリーダーに挿しっぱなしです。
# node_id:797, node_words:操作(2.0),電子(2.0),自治体(2.0),従業(2.0),インストール(2.0), probability:0.119
# 1:私以外に従業員も当方のマイナカードを使用して仕事を使用しています。
# node_id:797, node_words:操作(2.0),電子(2.0),自治体(2.0),従業(2.0),インストール(2.0), probability:0.148
# 2:持ち歩くことは５年に１度の更新のときとたまに住民票や印鑑証明等が必要なときのみです。
# node_id:116, node_words:更新(27.0),ゴールド(6.0),ブルー(4.0),即日(3.0),会場(2.0), probability:0.189
# 3:マイナカードが保険証と一体化されたら平日病院に行けなくなります。
# node_id:793, node_words:見る(2.0),私利(1.0),ゴリ押し(1.0),今度(1.0),よる(1.0), probability:0.071
# 4:だって従業員が仕事で当方のマイナカードを使用していますから。
# node_id:797, node_words:操作(2.0),電子(2.0),自治体(2.0),従業(2.0),インストール(2.0), probability:0.119
# ------------------------------------------------------------------
# 0:昔は、就職に運転免許は不可欠だったけど、通信インフラが発達した現在では、運転免許証の持つ意味が、若者のステータス・シンボルに変わりつつある。
# node_id:16, node_words:若者(3.0),費用(3.0),腐る(2.0),滅茶苦茶(2.0),見切り(2.0), probability:0.162
# 1:　マイナカードと一体化されては、若者の車離れに拍車がかかるんじゃないの。
# node_id:16, node_words:若者(3.0),費用(3.0),腐る(2.0),滅茶苦茶(2.0),見切り(2.0), probability:0.068
# ------------------------------------------------------------------
# 0:身分証明書をマイナンバーカードだけにするならマイナンバーカードさえ盗むか、偽造するかもしくはサーバーにはいって
# node_id:17, node_words:支持(6.0),有る(5.0),勝手(5.0),総理(5.0),公的(4.0), probability:0.065
# 1:変更してしまえば悪用し放題になるが、いいのか？
# node_id:58, node_words:認証(9.0),コピー(7.0),指紋(5.0),書類(4.0),計画(4.0), probability:0.044
# 2:役所で紛失したといえば
# node_id:9, node_words:紛失(31.0),発行(30.0),リスク(14.0),無くす(14.0),病院(13.0), probability:0.102
# 3:他人が再発行できるのではないか？
# node_id:9, node_words:紛失(31.0),発行(30.0),リスク(14.0),無くす(14.0),病院(13.0), probability:0.09
# 4:紛失時の再発行には、どうやって身分証明書なしで再発行するのでしょうか？
# node_id:9, node_words:紛失(31.0),発行(30.0),リスク(14.0),無くす(14.0),病院(13.0), probability:0.258
# ------------------------------------------------------------------
# 0:記者が無知ｗ
# node_id:751, node_words:端末(4.0),見せる(2.0),加える(2.0),電子(2.0),住所(2.0), probability:0.029
# 1:すでにマイナカードのスマホ用電子証明書搭載サービスが開始されてます
# node_id:157, node_words:スマート(6.0),フォン(6.0),モバイル(5.0),搭載(4.0),変える(3.0), probability:0.097
# 2:マイナカードを持ち歩くことなく、スマホで同等の機能が利用できます
# node_id:693, node_words:想像(2.0),流出(2.0),利用(1.0),危機(1.0),無い(1.0), probability:0.04
# 3:将来的に車のキーとして機能したら、誰が運転していたか本人確認ができたり、盗難や無免許運転の防止等々、色々便利になると思います
# node_id:786, node_words:ごまかし(1.0),流れ(1.0),誤謬(1.0),譲る(1.0),かざす(1.0), probability:0.067
# ------------------------------------------------------------------
# 0:これ、カードにしちゃうからいろいろ問題があるんですよ。
# node_id:786, node_words:ごまかし(1.0),流れ(1.0),誤謬(1.0),譲る(1.0),かざす(1.0), probability:0.067
# 1:思い切って、指紋＋顔認証システムからのマイナンバー紐付けにしてしまえば、カード持たなくても問題がないはずです。
# node_id:58, node_words:認証(9.0),コピー(7.0),指紋(5.0),書類(4.0),計画(4.0), probability:0.123
# 2:無論認証システムは行政側しか使えないようにすることは重要ですが。
# node_id:58, node_words:認証(9.0),コピー(7.0),指紋(5.0),書類(4.0),計画(4.0), probability:0.079
# 3:また、お店などの入会については、スマホ、クレジットカードなどで認証し、顔も登録てしまえば、特にあとあと、店側に不利益になるような問題は起きないと思うんですけどね。
# node_id:755, node_words:芋づる(2.0),登録(2.0),期限(2.0),悪い(1.0),みな(1.0), probability:0.087
# ------------------------------------------------------------------
# 0:マイナンバーカード作成の規約には、取得した情報に対し、政府はいっさいの責任はないというような無責任な姿勢です。
# node_id:795, node_words:破綻(5.0),違い(4.0),振り回す(2.0),沙汰(2.0),狂気(2.0), probability:0.052
# 1:故意でない情報漏洩や改ざん、目的外の利用も、故意でなければ仕方ないというのです。
# node_id:16, node_words:若者(3.0),費用(3.0),腐る(2.0),滅茶苦茶(2.0),見切り(2.0), probability:0.079
# 2:マイナンバーカードは任意とすることで始まった政策がいつの間にか強制のステータスに入ってきました。
# node_id:451, node_words:任意(12.0),義務(6.0),実質(5.0),やり方(4.0),ふざける(3.0), probability:0.126
# 3:保険も運転免許も口座も、全て紐付けて、情報漏洩しても、誰も助けてはくれません。
# node_id:26, node_words:銀行(22.0),口座(16.0),作る(11.0),開設(8.0),電話(6.0), probability:0.084
# 4:マスクの時もそうですが、日本政府は少しずつ協力から強制に切り替えていきます。
# node_id:762, node_words:対策(2.0),盗難(1.0),嫌がる(1.0),言いきる(1.0),痛い(1.0), probability:0.032
# 5:国民はそれを素直に受け入れる体質のようで、不思議でなりません。
# node_id:16, node_words:若者(3.0),費用(3.0),腐る(2.0),滅茶苦茶(2.0),見切り(2.0), probability:0.041
# 6:本人確認する方法を明確に定めていただければ、必要あれば準備しますが、金融機関も図書館もリサイクルショップも、大変でしょうね。。
# node_id:16, node_words:若者(3.0),費用(3.0),腐る(2.0),滅茶苦茶(2.0),見切り(2.0), probability:0.068
# ------------------------------------------------------------------
# 0:これは、危険な発想である。
# node_id:797, node_words:操作(2.0),電子(2.0),自治体(2.0),従業(2.0),インストール(2.0), probability:0.034
# 1:1枚のカードに重要情報を集約したり本人確認機能をそこだけに集約した場合、紛失リスクが途轍もなく大きい。
# node_id:632, node_words:いく(3.0),連携(2.0),注ぐ(2.0),集約(2.0),説明(2.0), probability:0.2
# 2:そして、システム上の欠陥があるため、情報漏洩や誤登録、本人の誤認など大きな問題を抱える。
# node_id:755, node_words:芋づる(2.0),登録(2.0),期限(2.0),悪い(1.0),みな(1.0), probability:0.043
# 3:認証機能も他人を認証したり不完全なシステムであることが発覚した。
# node_id:58, node_words:認証(9.0),コピー(7.0),指紋(5.0),書類(4.0),計画(4.0), probability:0.171
# 4:このまま進めれば大混乱は必至である。
# node_id:797, node_words:操作(2.0),電子(2.0),自治体(2.0),従業(2.0),インストール(2.0), probability:0.017
# ------------------------------------------------------------------
# 0:> 運転免許証などを送信する方法や、顔写真のない本人確認書類などは廃止すると明記しています。
# node_id:786, node_words:ごまかし(1.0),流れ(1.0),誤謬(1.0),譲る(1.0),かざす(1.0), probability:0.067
# 1:> 　また対面の場合であっても公的個人認証による本人確認を進めるなどし、本人確認書類のコピーは取らないこととする運転免許証やマイナンバーカードの券面ですら、偽造される可能性が否定できない世の中です。
# node_id:58, node_words:認証(9.0),コピー(7.0),指紋(5.0),書類(4.0),計画(4.0), probability:0.254
# 2:ましてや本人確認書類のコピーなんて偽造し放題で、むしろそれで本人確認ができてしまうと、コピー提出先の人はなりすましできてしまうことになります。
# node_id:58, node_words:認証(9.0),コピー(7.0),指紋(5.0),書類(4.0),計画(4.0), probability:0.165
# 3:公的個人認証の秘密鍵は偽造できないので、そうなっていくのはある意味当然です。
# node_id:58, node_words:認証(9.0),コピー(7.0),指紋(5.0),書類(4.0),計画(4.0), probability:0.114
# 4:>
# node_id:776, node_words:ダメ(6.0),くっつける(2.0),警察官(2.0),絡む(2.0),一つ(2.0), probability:0.0
# 5:「運転免許証すら使えないとマイナンバーカードを万が一紛失したらどうなるの!?」
# node_id:9, node_words:紛失(31.0),発行(30.0),リスク(14.0),無くす(14.0),病院(13.0), probability:0.117
# 6:マイナンバーカードがない時代に運転免許証と健康保険証を入れたお財布を紛失するのとほぼ同じです。
# node_id:9, node_words:紛失(31.0),発行(30.0),リスク(14.0),無くす(14.0),病院(13.0), probability:0.096
# 7:紛失したら困るのはいつの時代も同じで、むしろ紛失手続きが1回で済むメリットの方が生きると思います。
# node_id:9, node_words:紛失(31.0),発行(30.0),リスク(14.0),無くす(14.0),病院(13.0), probability:0.173
# ------------------------------------------------------------------
# 0:子どもが生まれたばかりの頃、お年玉などを貯めておくように銀行口座を作った時は、保険証だけでＯＫでした。
# node_id:26, node_words:銀行(22.0),口座(16.0),作る(11.0),開設(8.0),電話(6.0), probability:0.199
# 1:子どもが大きくなって、アルバイト代の受取口座を作った時は、「マイナカードでなければ複数の身分証が必要です」とリストを渡されました。
# node_id:26, node_words:銀行(22.0),口座(16.0),作る(11.0),開設(8.0),電話(6.0), probability:0.084
# 2:そのリストの中に母子手帳があって、絶句したものです。
# node_id:759, node_words:手帳(5.0),資産(4.0),個人(4.0),公安(3.0),銀行(3.0), probability:0.071
# 3:保険証に母子手帳を加えて本人確認することに、なんの意味があるんでしょう？
# node_id:793, node_words:見る(2.0),私利(1.0),ゴリ押し(1.0),今度(1.0),よる(1.0), probability:0.071
# 4:政府はマイナカードの利便性を喧伝していますが、何のことはない、マイナカードがないと不便なように諸制度を歪めているだけです。
# node_id:798, node_words:項目(2.0),基本(1.0),祈る(1.0),多く(1.0),パイプ(1.0), probability:0.054
# 5:国が発行する運転免許証が本人確認に使えなくなるって、終わってる感すごすぎですね。
# node_id:9, node_words:紛失(31.0),発行(30.0),リスク(14.0),無くす(14.0),病院(13.0), probability:0.09
# 6:ましてや、モバイル免許証とは…。
# node_id:157, node_words:スマート(6.0),フォン(6.0),モバイル(5.0),搭載(4.0),変える(3.0), probability:0.081
# 7:鉄道やタクシーでの忘れ物ナンバーワンはスマホだということを、お偉方は知らないのでしょうか？
# node_id:800, node_words:統合(2.0),リリース(2.0),民間(1.0),自国(1.0),販売(1.0), probability:0.033
# ------------------------------------------------------------------
# ...
# node_id:785, node_words:たち(7.0),かも(3.0),スポーツマン(2.0),三流(2.0),一流(2.0), probability:0.167
# 1:NHK と同じですね！
# node_id:776, node_words:ダメ(6.0),くっつける(2.0),警察官(2.0),絡む(2.0),一つ(2.0), probability:0.0
# 2:NHKも昔から既得権益を守るため受信料制度を廃止したくないんです。
# node_id:673, node_words:値上がり(3.0),給料(2.0),なれる(1.0),近づく(1.0),あんた(1.0), probability:0.031
# 3:ズルイ！
# node_id:776, node_words:ダメ(6.0),くっつける(2.0),警察官(2.0),絡む(2.0),一つ(2.0), probability:0.0
# 4:NHK は 完全民営化させて自助努力させるのが一番いいんですよ 民放各社ではそうやって頑張っているんですからね。
# node_id:632, node_words:いく(3.0),連携(2.0),注ぐ(2.0),集約(2.0),説明(2.0), probability:0.03
# ------------------------------------------------------------------
# 0:ね、能力の無い政治家に投票する民度の低い人間が大勢いるせいで、こういう状況になるんですよ。
# node_id:735, node_words:増やす(2.0),友達(2.0),大勢(1.0),共産党(1.0),繰り返す(1.0), probability:0.111
# 1:消えた年金の際もそうですが、すぐに忘れてまた同じような事を繰り返す政治家に投票する事を止めるのが先決なんですが・・・マイナンバーもごり押しされて数年後には支持率が戻るのかなぁ（苦笑）
# node_id:735, node_words:増やす(2.0),友達(2.0),大勢(1.0),共産党(1.0),繰り返す(1.0), probability:0.148
# 2:それでも共産党には投票しないけどね、明言しとかないと。
# node_id:447, node_words:投票(6.0),選挙(5.0),政党(4.0),彼ら(3.0),時代(2.0), probability:0.052
# ------------------------------------------------------------------
# 0:※ デジタル顔写真の方が、別人の顔に挿げ替え易いのは言うまでもない。
# node_id:795, node_words:破綻(5.0),違い(4.0),振り回す(2.0),沙汰(2.0),狂気(2.0), probability:0.053
# 1:　デジタル得意の犯罪者達は、手ぐすね引いて待っているに違いない。
# node_id:795, node_words:破綻(5.0),違い(4.0),振り回す(2.0),沙汰(2.0),狂気(2.0), probability:0.123
# 2:※・いつからこの国には、「時にはしっかり立ち止まってでも、物事を冷静に多方面から検討し、英断できる。」
# node_id:739, node_words:船舶(2.0),順番(2.0),続く(1.0),物事(1.0),理想(1.0), probability:0.056
# 3:そんな、まともな政治家はいなくなったのだろうか。
# node_id:673, node_words:値上がり(3.0),給料(2.0),なれる(1.0),近づく(1.0),あんた(1.0), probability:0.031
# ------------------------------------------------------------------
# 0:大陸人や半島人が、日本人にすり替わるための政策に必死な自由売国党。
# node_id:777, node_words:アメリカ(6.0),独裁(3.0),優先(2.0),奴隷(2.0),民族(2.0), probability:0.054
# 1:このまますべてが紐づけされれば、日本人になりに来たあちらの人の手を煩わせることなく、すぐに日本人になれますからね？
# node_id:780, node_words:携帯(1.0),各所(1.0),場所(1.0),負け(1.0),支給(1.0), probability:0.083
# 2:車の運転もできちゃう♪
# node_id:776, node_words:ダメ(6.0),くっつける(2.0),警察官(2.0),絡む(2.0),一つ(2.0), probability:0.0
# 3:基本的には本人が亡くなったときに入れ替わるんだろうけど、万一本人生きてるうちにやっちゃった場合も、すべてがマイナに乗ってる以上いくら本人が騒いでも証明できないから便利よね？
# node_id:632, node_words:いく(3.0),連携(2.0),注ぐ(2.0),集約(2.0),説明(2.0), probability:0.171
# ------------------------------------------------------------------
# 0:問題が何一つ解決していないのに次の案を出す政府の考えが分からない現状のまま進んでいけば、また免許証が一体化した時に問題が起こるのが目に見えている、登録ミスで本人じゃないのが登録され交通違反をしたら？
# node_id:755, node_words:芋づる(2.0),登録(2.0),期限(2.0),悪い(1.0),みな(1.0), probability:0.125
# 1:マイナンバーカードの利用期限、保健所の利用期限、免許証の利用期限、ただでさえバラバラなのに年三回も平日の8：00～17：00に区役所に出向けって馬鹿か。
# node_id:755, node_words:芋づる(2.0),登録(2.0),期限(2.0),悪い(1.0),みな(1.0), probability:0.22
# 2:そのうちマイナンバーカードに縛られて身動き取れなくなるぞバカ総理。
# node_id:755, node_words:芋づる(2.0),登録(2.0),期限(2.0),悪い(1.0),みな(1.0), probability:0.065
# ------------------------------------------------------------------
# 0:体から離脱するモノに全てを集約するのは恐ろしい。
# node_id:632, node_words:いく(3.0),連携(2.0),注ぐ(2.0),集約(2.0),説明(2.0), probability:0.061
# 1:こうなったら人体にICチップを埋め込むしかないだろう。
# node_id:696, node_words:チップ(5.0),埋め込む(5.0),マイクロ(4.0),ここ(2.0),バカ(2.0), probability:0.157
# ------------------------------------------------------------------
# 0:何のためのマイナンバーなのだろう？
# node_id:704, node_words:基本(6.0),コード(5.0),なに(3.0),年寄り(3.0),取り扱い(3.0), probability:0.017
# 1:国民を混乱させるために強制的にさせようとするのだろうか？
# node_id:632, node_words:いく(3.0),連携(2.0),注ぐ(2.0),集約(2.0),説明(2.0), probability:0.03
# 2:自民党の現内閣は閣僚一同精神科に受診される事をお勧めします。
# node_id:35, node_words:あげる(3.0),作れる(2.0),逃れ(2.0),マトモ(2.0),破産(2.0), probability:0.068
# 3:何の為に政治してるのだろう？
# node_id:673, node_words:値上がり(3.0),給料(2.0),なれる(1.0),近づく(1.0),あんた(1.0), probability:0.031
# 4:そんな政治家とも呼べない政治屋は日本にはいらない。
# node_id:673, node_words:値上がり(3.0),給料(2.0),なれる(1.0),近づく(1.0),あんた(1.0), probability:0.061
# ------------------------------------------------------------------
# 0:記憶力は、ずば抜けて優秀でＩＱの高い人たちが、現場の苦労の経験のないド素人集団が制度を机上論だけで設計することが間違いの根源です。
# node_id:795, node_words:破綻(5.0),違い(4.0),振り回す(2.0),沙汰(2.0),狂気(2.0), probability:0.228
# 1:創造力と責任感の欠落している人達が、このような様々な機関、組織、制度の違いを一つにまとめることはできません。
# node_id:795, node_words:破綻(5.0),違い(4.0),振り回す(2.0),沙汰(2.0),狂気(2.0), probability:0.14
# 2:デナオシナサイ。
# node_id:776, node_words:ダメ(6.0),くっつける(2.0),警察官(2.0),絡む(2.0),一つ(2.0), probability:0.0
# ------------------------------------------------------------------
# 0:法案成立により、LGBTの人はマイナカードの通名記載が認められたようですが、LGBTの人だけなんでしょうか。
# node_id:781, node_words:認める(3.0),整備(2.0),インフラ(2.0),対策(1.0),心情(1.0), probability:0.103
# 1:在日外国人の方の通名記載も認められるようになるのでしょうか。
# node_id:781, node_words:認める(3.0),整備(2.0),インフラ(2.0),対策(1.0),心情(1.0), probability:0.069
# ------------------------------------------------------------------
# 0:お前の私利私欲や利権ゴリ押しのためのマイナンバーカードなのか？？？？とあの人の顔を見ると怒りがわいてくるので、なるべくあの顔を見たくないです。
# node_id:793, node_words:見る(2.0),私利(1.0),ゴリ押し(1.0),今度(1.0),よる(1.0), probability:0.286
# 1:本当にひどい。
# node_id:451, node_words:任意(12.0),義務(6.0),実質(5.0),やり方(4.0),ふざける(3.0), probability:0.019
# 2:国民の安全や要望をまるっとブロックして、ただ突き進んでいますよね。
# node_id:793, node_words:見る(2.0),私利(1.0),ゴリ押し(1.0),今度(1.0),よる(1.0), probability:0.071
# 3:突破力ではなくいですよね。
# node_id:16, node_words:若者(3.0),費用(3.0),腐る(2.0),滅茶苦茶(2.0),見切り(2.0), probability:0.027
# 4:日本て独裁政権なんですかね？
# node_id:777, node_words:アメリカ(6.0),独裁(3.0),優先(2.0),奴隷(2.0),民族(2.0), probability:0.032
# ------------------------------------------------------------------
# 0:こんなトラブルだらけなのに免許証までとか頭
# node_id:731, node_words:割合(2.0),天下り(2.0),トラブル(2.0),推奨(2.0),在席(1.0), probability:0.061
# 1:おかしいだろ？
# node_id:16, node_words:若者(3.0),費用(3.0),腐る(2.0),滅茶苦茶(2.0),見切り(2.0), probability:0.027
# 2:今まで何か失くしても身分証明として免許証が当たり前なのに免許証も一体化してマイナンバーカード無くしたらどうするの？
# node_id:17, node_words:支持(6.0),有る(5.0),勝手(5.0),総理(5.0),公的(4.0), probability:0.032
# 3:リスクを何も考えてない利権まみれの見切り発車だろ？
# node_id:16, node_words:若者(3.0),費用(3.0),腐る(2.0),滅茶苦茶(2.0),見切り(2.0), probability:0.095
# 4:もう次勝てないから滅茶苦茶やって次の政権の足引っ張るつもりなの丸わかりだろ？
# node_id:16, node_words:若者(3.0),費用(3.0),腐る(2.0),滅茶苦茶(2.0),見切り(2.0), probability:0.054
# 5:どこまで腐ってんだ自民党は？
# node_id:759, node_words:手帳(5.0),資産(4.0),個人(4.0),公安(3.0),銀行(3.0), probability:0.019
# ------------------------------------------------------------------
# 0:こんなトラブルだらけなのに免許証までとか頭
# node_id:731, node_words:割合(2.0),天下り(2.0),トラブル(2.0),推奨(2.0),在席(1.0), probability:0.061
# 1:おかしいだろ？
# node_id:16, node_words:若者(3.0),費用(3.0),腐る(2.0),滅茶苦茶(2.0),見切り(2.0), probability:0.027
# 2:今まで何か失くしても身分証明として免許証が当たり前なのに免許証も一体化してマイナンバーカード無くしたらどうするの？
# node_id:17, node_words:支持(6.0),有る(5.0),勝手(5.0),総理(5.0),公的(4.0), probability:0.032
# 3:リスクを何も考えてない利権まみれの見切り発車だろ？
# node_id:16, node_words:若者(3.0),費用(3.0),腐る(2.0),滅茶苦茶(2.0),見切り(2.0), probability:0.095
# 4:もう次勝てないから滅茶苦茶やって次の政権の足引っ張るつもりなの丸わかりだろ？
# node_id:16, node_words:若者(3.0),費用(3.0),腐る(2.0),滅茶苦茶(2.0),見切り(2.0), probability:0.054
# 5:どこまで腐ってんだ自民党は？
# node_id:759, node_words:手帳(5.0),資産(4.0),個人(4.0),公安(3.0),銀行(3.0), probability:0.019
# ------------------------------------------------------------------
# 0:いい加減にしなくては何処かの国からの不正アクセスだけで国が終わるね。
# node_id:790, node_words:対策(4.0),整備(3.0),示す(3.0),整える(2.0),居る(2.0), probability:0.055
# 1:この国のショボいIT技術では国中の土地が某国の物になっていても対処できないだろう。
# node_id:729, node_words:無能(4.0),ヒューマン(2.0),行為(2.0),危険(2.0),行う(2.0), probability:0.085
# 2:正に今の政府の連中は売国奴さ。
# node_id:729, node_words:無能(4.0),ヒューマン(2.0),行為(2.0),危険(2.0),行う(2.0), probability:0.034
# 3:ひょっとしたら分かってやってるんじゃないの?
# node_id:14, node_words:番号(13.0),暗証(12.0),記載(5.0),役所(4.0),高齢(4.0), probability:0.005
# ------------------------------------------------------------------
# 0:マイナカード持ってないと口座も開けなきゃ携帯の契約もできないって？
# node_id:26, node_words:銀行(22.0),口座(16.0),作る(11.0),開設(8.0),電話(6.0), probability:0.11
# 1:マイナカードは任意でしかも運転免許証より遥かに本人確認の信用度が低いのは日本国民みんな知ってるのに？
# node_id:451, node_words:任意(12.0),義務(6.0),実質(5.0),やり方(4.0),ふざける(3.0), probability:0.117
# 2:アホちゃうか？
# node_id:632, node_words:いく(3.0),連携(2.0),注ぐ(2.0),集約(2.0),説明(2.0), probability:0.03
# ------------------------------------------------------------------
# 0:「政府の動向が注視されます」
# node_id:26, node_words:銀行(22.0),口座(16.0),作る(11.0),開設(8.0),電話(6.0), probability:0.021
# 1:マスコミが政府広報に成り下がったことを自身さえ感じていない。
# node_id:26, node_words:銀行(22.0),口座(16.0),作る(11.0),開設(8.0),電話(6.0), probability:0.021
# 2:お上のされるままで結構が江戸時代からの日本国民に刻まれたDNA。
# node_id:782, node_words:機器(4.0),配備(2.0),作業(2.0),得る(2.0),於く(2.0), probability:0.04
# ------------------------------------------------------------------
# 0:普通に考えて逆だろ！
# node_id:791, node_words:普及(7.0),値する(2.0),普通(2.0),身元(1.0),今更(1.0), probability:0.074
# 1:免許持ってる人はその免許証にマイナンバーを勝手にくっつけりゃいいだろうが！
# node_id:17, node_words:支持(6.0),有る(5.0),勝手(5.0),総理(5.0),公的(4.0), probability:0.054
# 2:マイナンバーがどこの管轄か知らねーけど、国交省より上の省なんだろ！
# node_id:51, node_words:公安(4.0),与える(3.0),横行(3.0),委員(3.0),偽札(2.0), probability:0.048
# 3:役人の上下関係を国民に押し付けるんじゃねーよ、お前らの都合で国民に不便な生活をさせるな。
# node_id:768, node_words:かける(2.0),お前(2.0),役人(2.0),照会(2.0),引きずる(2.0), probability:0.114
# 4:そもそもお前らなんかより、お前らに給料くれてやってる国民が１番大事なんじゃねーのか、なにを偉そうに好き勝手やってんだよ、いい加減にしろ！
# node_id:768, node_words:かける(2.0),お前(2.0),役人(2.0),照会(2.0),引きずる(2.0), probability:0.152
# ------------------------------------------------------------------
# 0:マイナンバー導入の動機が不純すぎるから、嫌になります。
# node_id:161, node_words:アナログ(5.0),増やす(3.0),言える(3.0),世界(2.0),デジタル(2.0), probability:0.037
# 1:余計な仕事を辞める増やして、公務員とそれに紐づく税金泥棒を増やしたいだけ。
# node_id:678, node_words:余計(1.0),でる(1.0),勘弁(1.0),かける(1.0),結果(1.0), probability:0.2
# ------------------------------------------------------------------
# 0:まあ国家がアメリカ様に（べつの先にかわってるかもしれませんが）お国の情報すべて提供するための貢物がマイナ情報なのでカード100％普及が必要なのですよ
# node_id:791, node_words:普及(7.0),値する(2.0),普通(2.0),身元(1.0),今更(1.0), probability:0.259
# 1:家畜整理カードがマイナカード
# node_id:755, node_words:芋づる(2.0),登録(2.0),期限(2.0),悪い(1.0),みな(1.0), probability:0.043
# ------------------------------------------------------------------
# 0:紛失した時のリスクが大きすぎる考えた人達は、リスク管理能力が無いと思うよ！
# node_id:9, node_words:紛失(31.0),発行(30.0),リスク(14.0),無くす(14.0),病院(13.0), probability:0.17
# 1:原発は絶対安全って言ってたのと同じで、問題が発生したら想定外とでも言うのか？
# node_id:800, node_words:統合(2.0),リリース(2.0),民間(1.0),自国(1.0),販売(1.0), probability:0.033
# 2:アホとしか思えませんねぇ！
# node_id:632, node_words:いく(3.0),連携(2.0),注ぐ(2.0),集約(2.0),説明(2.0), probability:0.03
# ------------------------------------------------------------------
# 0:免許更新も役所でやってくれるのかよ？
# node_id:116, node_words:更新(27.0),ゴールド(6.0),ブルー(4.0),即日(3.0),会場(2.0), probability:0.196
# 1:岸田は頭が悪すぎ。
# node_id:789, node_words:公式(2.0),犯罪(2.0),苦情(2.0),反対(2.0),そう(1.0), probability:0.023
# 2:何故中国の悪いとこだけ真似する。
# node_id:145, node_words:中国(4.0),老害(2.0),一族(2.0),好き(2.0),移住(2.0), probability:0.205
# 3:そんなに中国好きなら、老害二階と一緒に一族で中国に移住しろよ！
# node_id:145, node_words:中国(4.0),老害(2.0),一族(2.0),好き(2.0),移住(2.0), probability:0.372
# ------------------------------------------------------------------
# 0:免許更新も役所でやってくれるのかよ？
# node_id:116, node_words:更新(27.0),ゴールド(6.0),ブルー(4.0),即日(3.0),会場(2.0), probability:0.196
# 1:岸田は頭が悪すぎ。
# node_id:789, node_words:公式(2.0),犯罪(2.0),苦情(2.0),反対(2.0),そう(1.0), probability:0.023
# 2:何故中国の悪いとこだけ真似する。
# node_id:145, node_words:中国(4.0),老害(2.0),一族(2.0),好き(2.0),移住(2.0), probability:0.205
# 3:そんなに中国好きなら、老害二階と一緒に一族で中国に移住しろよ！
# node_id:145, node_words:中国(4.0),老害(2.0),一族(2.0),好き(2.0),移住(2.0), probability:0.372
# ------------------------------------------------------------------
# 0:本当に何の責任も負わずに、自分たちのやりたい事だけ勝手に押し付けていくというつもりだな。
# node_id:785, node_words:たち(7.0),かも(3.0),スポーツマン(2.0),三流(2.0),一流(2.0), probability:0.097
# 1:国が滅びようが国民が死に絶えようが、今やりたい事をやりたい放題に強制する。
# node_id:58, node_words:認証(9.0),コピー(7.0),指紋(5.0),書類(4.0),計画(4.0), probability:0.018
# 2:コイツら終わってる。
# node_id:776, node_words:ダメ(6.0),くっつける(2.0),警察官(2.0),絡む(2.0),一つ(2.0), probability:0.0
# ------------------------------------------------------------------
# 0:そりゃ国はないも責任取らないって言ってるから、気楽に紐付けさせけ自由に管理するよ。
# node_id:735, node_words:増やす(2.0),友達(2.0),大勢(1.0),共産党(1.0),繰り返す(1.0), probability:0.037
# 1:都合が悪くなったら消えればいいんだから。
# node_id:768, node_words:かける(2.0),お前(2.0),役人(2.0),照会(2.0),引きずる(2.0), probability:0.023
# ------------------------------------------------------------------
# 0:まったくもってアホの極みだね
# node_id:632, node_words:いく(3.0),連携(2.0),注ぐ(2.0),集約(2.0),説明(2.0), probability:0.03
# 1:運転免許で本人確認ができないって事は運転免許自体が偽物なんだよね？
# node_id:786, node_words:ごまかし(1.0),流れ(1.0),誤謬(1.0),譲る(1.0),かざす(1.0), probability:0.067
# 2:なら、警察は免許みても意味がないですよね？
# node_id:681, node_words:成立(2.0),内閣(2.0),上手い(2.0),文句(2.0),知る(1.0), probability:0.03
# ------------------------------------------------------------------
# 0:保険証も含めて現行制度で誰も困っていないのにわざわざ弄る辺りが無能の極み。
# node_id:793, node_words:見る(2.0),私利(1.0),ゴリ押し(1.0),今度(1.0),よる(1.0), probability:0.071
# 1:この事業の推進に関わった人間は全てクビにしてもらいたい。
# node_id:767, node_words:撒く(3.0),市町村(3.0),どん(3.0),ばら(3.0),都道府県(2.0), probability:0.027
# ------------------------------------------------------------------
# 0:顔写真がない＝◯国人や第三者が他人のカードを使って通院したり車を運転してても本人なのかどうか確認できない・・・。
# node_id:779, node_words:狙い(1.0),特定(1.0),スムーズ(1.0),吸い上げる(1.0),源泉(1.0), probability:0.077
# 1:最初からそれが狙いなんですか？
# node_id:779, node_words:狙い(1.0),特定(1.0),スムーズ(1.0),吸い上げる(1.0),源泉(1.0), probability:0.077
# ------------------------------------------------------------------
# 0:一体化は素晴らしいじゃないか反対してる奴は日本人じゃないだろ？
# node_id:800, node_words:統合(2.0),リリース(2.0),民間(1.0),自国(1.0),販売(1.0), probability:0.067
# 1:そんなに通名が嫌なら自国に帰ったらどうですか？
# node_id:800, node_words:統合(2.0),リリース(2.0),民間(1.0),自国(1.0),販売(1.0), probability:0.033
# ------------------------------------------------------------------
# 0:なんか面倒になってきたなーいっそうの事出生したらマイクロチップ埋めたら？
# node_id:696, node_words:チップ(5.0),埋め込む(5.0),マイクロ(4.0),ここ(2.0),バカ(2.0), probability:0.143
# 1:　バカな政治家が行う失政に嫌でも付きあわにゃならんってのもおかしなはなし。
# node_id:696, node_words:チップ(5.0),埋め込む(5.0),マイクロ(4.0),ここ(2.0),バカ(2.0), probability:0.057
# ------------------------------------------------------------------
# 0:リスクは分散しろって言葉をマイナンバーカードに何から何まで紐付けようとしてる人は知らないのかな。
# node_id:632, node_words:いく(3.0),連携(2.0),注ぐ(2.0),集約(2.0),説明(2.0), probability:0.061
# 1:馬鹿なのかな。
# node_id:720, node_words:説明(4.0),不足(4.0),競争(3.0),続出(2.0),有る(2.0), probability:0.015
# ------------------------------------------------------------------
# 0:一片の言葉尻を拡大解釈し、思い込み、決めつけ、大騒ぎして、それにそーだそーだと祭りのごとくノリまくるのがヤフコメクオリティ。
# node_id:797, node_words:操作(2.0),電子(2.0),自治体(2.0),従業(2.0),インストール(2.0), probability:0.119
# ------------------------------------------------------------------
# 0:もう、狂ってるね。
# node_id:776, node_words:ダメ(6.0),くっつける(2.0),警察官(2.0),絡む(2.0),一つ(2.0), probability:0.0
# 1:自分たちが何をやっているのかさえ判断できなくなってるのでしょう。
# node_id:785, node_words:たち(7.0),かも(3.0),スポーツマン(2.0),三流(2.0),一流(2.0), probability:0.097
# 2:ま、それもこれも、そういうヤツラに投票したオレの責任なんだけどね、オレの。
# node_id:447, node_words:投票(6.0),選挙(5.0),政党(4.0),彼ら(3.0),時代(2.0), probability:0.052
# ------------------------------------------------------------------
# 0:無理でしょ。
# node_id:451, node_words:任意(12.0),義務(6.0),実質(5.0),やり方(4.0),ふざける(3.0), probability:0.01
# 1:iPhoneに搭載なんて、100年経ってもできそうにないし。
# node_id:157, node_words:スマート(6.0),フォン(6.0),モバイル(5.0),搭載(4.0),変える(3.0), probability:0.065
# 2:もういい加減、諦めなさいよ。
# node_id:768, node_words:かける(2.0),お前(2.0),役人(2.0),照会(2.0),引きずる(2.0), probability:0.023
# 3:能力ないんだから。
# node_id:693, node_words:想像(2.0),流出(2.0),利用(1.0),危機(1.0),無い(1.0), probability:0.04
# ------------------------------------------------------------------
# 0:ワクチン打ちなさい。
# node_id:776, node_words:ダメ(6.0),くっつける(2.0),警察官(2.0),絡む(2.0),一つ(2.0), probability:0.0
# 1:コオロギ食べなさい。
# node_id:696, node_words:チップ(5.0),埋め込む(5.0),マイクロ(4.0),ここ(2.0),バカ(2.0), probability:0.014
# 2:マイクロチップ体に打ち込みなさい。
# node_id:696, node_words:チップ(5.0),埋め込む(5.0),マイクロ(4.0),ここ(2.0),バカ(2.0), probability:0.129
# 3:←これ真剣に考えているから恐い。
# node_id:755, node_words:芋づる(2.0),登録(2.0),期限(2.0),悪い(1.0),みな(1.0), probability:0.022
# ------------------------------------------------------------------
# 0:役人や政治家って、バカなの？？
# node_id:768, node_words:かける(2.0),お前(2.0),役人(2.0),照会(2.0),引きずる(2.0), probability:0.045
# 1:市井のフツーの生活が解らないの？？
# node_id:7, node_words:保持(5.0),補完(4.0),統一(3.0),賛成(3.0),検討(3.0), probability:0.013
# 2:そんな奴らが制度設計しちゃダメでしょ。
# node_id:776, node_words:ダメ(6.0),くっつける(2.0),警察官(2.0),絡む(2.0),一つ(2.0), probability:0.113
# ------------------------------------------------------------------
# 0:日本が中国化しとる…
# node_id:145, node_words:中国(4.0),老害(2.0),一族(2.0),好き(2.0),移住(2.0), probability:0.103
# 1:まさか、憲法より上にアホ自民を位置付けたりせんやろな？
# node_id:632, node_words:いく(3.0),連携(2.0),注ぐ(2.0),集約(2.0),説明(2.0), probability:0.03
# 2:あゝ、恐ロシア…まさに、狂気の沙汰や。
# node_id:795, node_words:破綻(5.0),違い(4.0),振り回す(2.0),沙汰(2.0),狂気(2.0), probability:0.088
# ------------------------------------------------------------------
# 0:河野、岸田お前たちの頭狂っているのではないのか、これ以上馬鹿な政策は止めろ、狂気の沙汰としか見えないぞ。
# node_id:785, node_words:たち(7.0),かも(3.0),スポーツマン(2.0),三流(2.0),一流(2.0), probability:0.097
# ------------------------------------------------------------------

# %%
# sentence="河野、岸田お前たちの頭狂っているのではないのか、これ以上馬鹿な政策は止めろ、狂気の沙汰としか見えないぞ"
# expandHlda.get_topic_one_sentence(sentence=sentence, corpus=comment_dataset.comment_list, n_words=10, node_id=7)

# %%
# sentence="河野、岸田お前たちの頭狂っているのではないのか、これ以上馬鹿な政策は止めろ、狂気の沙汰としか見えないぞ"
# expandHlda.get_topic_one_sentence_with_color(sentence=sentence, corpus=comment_dataset.comment_list, n_words=10, node_id=7)

# %%
expandHlda.get_topic_with_color(comment_list=comment_list, corpus=comment_dataset.comment_list, n_words=10)
# Out:
# 0:今の日本の運転免許証ってとても優秀だものだと思うんですけどね。
# node_id:533, node_words:デジタル(12.0),対応(6.0),世界(5.0),企業(4.0),状態(4.0),日本(4.0),必須(3.0),優先(3.0),言える(3.0),大事(3.0), probability:0.033
# 1:数年に一度必ず本人出向くて更新するから身元確認にもなるき顔写真ついてるからすぐその場で本人確認できるし。
# node_id:764, node_words:更新(24.0),ゴールド(4.0),即日(3.0),読み取り(2.0),検査(2.0),いく(2.0),こっち(2.0),手間(2.0),装置(2.0),政権(2.0), probability:0.255
# 2:**なんにするあらゆることを一つだけに絞るとそれがダメになるた時にどうしようもなくなるのでリスクが大きいなると思うます。
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.092
# 3:*
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.0
# 4:昭和おっさんの記憶ですが、テレビとビデオをくっつけるたものは結局すたれるたし、ファミコンとディスクシステム？だたかな？、をくっつけるてもダメですたね。
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.092
# 5:一つダメになると他も使えるないなるので。
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.069
# ------------------------------------------------------------------
# 0:紛失時のリスクを*に集約するてしまうと、再発行するれるまで病院にも行けるない、車にも乗れるない、となるますね。
# node_id:8, node_words:発行(27.0),紛失(12.0),場合(10.0),かかる(7.0),そう(6.0),週間(5.0),大変(5.0),病院(5.0),申請(5.0),万が一(5.0), probability:0.203
# 1:**
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.0
# 2:役所が休みの土日や盆暮れだと、相当生活に影響が出るそう。
# node_id:2, node_words:番号(14.0),暗証(13.0),役所(8.0),記載(4.0),間違える(4.0),住所(3.0),設定(3.0),意識(3.0),交付(3.0),誕生(3.0), probability:0.05
# 3:**
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.0
# 4:資産の預け先を分散するのと同様、免許証や保険証はリスク分散の意味でも一本化は避けるべし。
# node_id:8, node_words:発行(27.0),紛失(12.0),場合(10.0),かかる(7.0),そう(6.0),週間(5.0),大変(5.0),病院(5.0),申請(5.0),万が一(5.0), probability:0.05
# 5:*管理する政策側のメリットしかない、利用者側のリスクが大きいすぎです。
# node_id:116, node_words:中国(6.0),好き(2.0),狂気(2.0),恐い(2.0),移住(2.0),すぎ(2.0),沙汰(2.0),いとこ(2.0),真似(2.0),一族(2.0), probability:0.05
# ------------------------------------------------------------------
# 0:運行管理者の補助者として、点呼と運転免許証の確認をするておる、券面の有効期限や免許するれるている車種、また裏書で免許停止になるているないかの確認を行う、免許失効や無免許運転や資格外運転の防止を行なうているが、運転免許証が*に移行するてしまうと、これらの確認ができるないため、しっこした免許や所有する免許の条件等種類の確認が出来るないなる、無資格運転等の問題が起きる危険性がある。
# node_id:869, node_words:運行(4.0),原案(3.0),点呼(2.0),運送(2.0),ラーメン(2.0),特殊(2.0),種類(2.0),断る(2.0),中型(2.0),券面(2.0), probability:0.292
# 1:**
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.0
# 2:貨物自動車運送事業法で運行管理者の方が点呼の責任を取るために、万が一警察の取り締まりや事故等で発覚するた場合には、運送会社と運行管理者はかなりの責任を取るするれる事になる。
# node_id:869, node_words:運行(4.0),原案(3.0),点呼(2.0),運送(2.0),ラーメン(2.0),特殊(2.0),種類(2.0),断る(2.0),中型(2.0),券面(2.0), probability:0.221
# 3:**制服は安易にマイナンバー制度化で*にまとめるうとするているが、運転免許証の廃止は運行管理上の問題もある安易に廃止するてまとめるてしまうのは問題だと思う。
# node_id:869, node_words:運行(4.0),原案(3.0),点呼(2.0),運送(2.0),ラーメン(2.0),特殊(2.0),種類(2.0),断る(2.0),中型(2.0),券面(2.0), probability:0.13
# ------------------------------------------------------------------
# 0:*保険証だけだ、病院に行く時だけで使うないときは自宅保管でもいいけど、免許証が一体化となると常に携帯するないとだめになるますね。
# node_id:853, node_words:リーダー(2.0),携帯(2.0),起きる(2.0),歓迎(2.0),いける(2.0),財布(1.0),疲れる(1.0),障害(1.0),大丈夫(1.0),今度(1.0), probability:0.079
# 1:*保険所*枚、免許証*枚だけだない紛失時は財産丸ごと落とすことになるますね。
# node_id:8, node_words:発行(27.0),紛失(12.0),場合(10.0),かかる(7.0),そう(6.0),週間(5.0),大変(5.0),病院(5.0),申請(5.0),万が一(5.0), probability:0.051
# 2:怖い怖い（財産も持つてるないけど笑）
# node_id:783, node_words:怖い(4.0),得る(4.0),失敗(3.0),アメリカ(2.0),愚策(2.0),恐ろしい(2.0),停止(2.0),暴走(2.0),見つかる(2.0),強行(2.0), probability:0.083
# 3:*紛失時に*回ですべて事足りるという解釈もあるますが、そうなると*紛失するて紛失にかかわる手続きすると口座も保険証も免許証も*も*度に全部、停止になるのかな・・・。
# node_id:8, node_words:発行(27.0),紛失(12.0),場合(10.0),かかる(7.0),そう(6.0),週間(5.0),大変(5.0),病院(5.0),申請(5.0),万が一(5.0), probability:0.162
# 4:見つかるた時、再交付の時も*度の手続きですむだいいけど。
# node_id:853, node_words:リーダー(2.0),携帯(2.0),起きる(2.0),歓迎(2.0),いける(2.0),財布(1.0),疲れる(1.0),障害(1.0),大丈夫(1.0),今度(1.0), probability:0.026
# 5:でも、安全を担保できるているない今の状況を見るば、これを*元で政府の制度にお任せるするのも怖い怖い。
# node_id:783, node_words:怖い(4.0),得る(4.0),失敗(3.0),アメリカ(2.0),愚策(2.0),恐ろしい(2.0),停止(2.0),暴走(2.0),見つかる(2.0),強行(2.0), probability:0.092
# ------------------------------------------------------------------
# 0:全部紐付けするた*を紛失するて窓口での手続きの際、「本人を証明する物を出すて」と言うれるた何を出すのですうね。
# node_id:5, node_words:身分(8.0),おかしい(8.0),無い(6.0),証明(6.0),付け(5.0),忘れる(4.0),落とす(3.0),認める(3.0),負う(3.0),当たり前(2.0), probability:0.098
# 1:ちなみにパスポートは持つないし、介護保険証も持つているますん。
# node_id:802, node_words:整備(5.0),政策(4.0),整える(3.0),インフラ(2.0),選択肢(2.0),いま(2.0),対策(2.0),クビ(2.0),しな(2.0),得る(2.0), probability:0.025
# ------------------------------------------------------------------
# 0:国が公的だ手続きや書類をデジタル化を目指すのは良い事だと思うけど、現実問題で国のデジタルレベルが民間よりもかなり劣るている現状が問題だと思う、国で管理をするのだあるば委託などはするぬに公務員が優秀だエンジニアになる必要があると思う。
# node_id:81, node_words:コピー(6.0),公的(6.0),認証(4.0),計画(4.0),やり方(3.0),対面(3.0),確認(3.0),思う(3.0),保管(2.0),時代(2.0), probability:0.152
# ------------------------------------------------------------------
# 0:みなさん「デジタル社会の実現に向けるた重点計画*案*を読むでいるないから議論が変だ方向に向かうているます。
# node_id:81, node_words:コピー(6.0),公的(6.0),認証(4.0),計画(4.0),やり方(3.0),対面(3.0),確認(3.0),思う(3.0),保管(2.0),時代(2.0), probability:0.118
# 1:この計画には、非対面での本人確認を公的個人認証に一本化するということ、それから対面でも公的個人認証「など」を推進するて、コピーを取る現状のやり方をやめると書くれるているます。
# node_id:81, node_words:コピー(6.0),公的(6.0),認証(4.0),計画(4.0),やり方(3.0),対面(3.0),確認(3.0),思う(3.0),保管(2.0),時代(2.0), probability:0.406
# 2:*本人確認書類のコピーを取るやり方は安全性を考えると将来的には廃止するれるべしだ、その代替手法は公的個人認証が一番使うやすいとは思うますが、運転免許証にも電子的に券面情報を取得できる機能があるので、それでも良いだうと考えるます。
# node_id:81, node_words:コピー(6.0),公的(6.0),認証(4.0),計画(4.0),やり方(3.0),対面(3.0),確認(3.0),思う(3.0),保管(2.0),時代(2.0), probability:0.29
# ------------------------------------------------------------------
# 0:では、銀行口座は今のうちに沢山作るておくか。
# node_id:13, node_words:銀行(22.0),口座(19.0),携帯(14.0),開設(8.0),電話(7.0),本人(7.0),契約(6.0),ライセンス(3.0),作る(3.0),見え(2.0), probability:0.189
# 1:*すでに大手都市銀行４行と地元都市銀行の口座は持つているので、どの銀行にするうかな。
# node_id:13, node_words:銀行(22.0),口座(19.0),携帯(14.0),開設(8.0),電話(7.0),本人(7.0),契約(6.0),ライセンス(3.0),作る(3.0),見え(2.0), probability:0.344
# 2:*地元信用金庫と農協かな。
# node_id:3, node_words:信用(13.0),公安(4.0),管轄(4.0),お前(3.0),やり方(3.0),一切(3.0),実質(3.0),横行(3.0),取り扱い(3.0),渡す(2.0), probability:0.123
# 3:それ以上作るても*が近くにないから使えるない。
# node_id:881, node_words:船舶(2.0),基地(2.0),貴方(2.0),それ(1.0),血税(1.0),厚木(1.0),沈没(1.0),横田(1.0),国政(1.0),始動(1.0), probability:0.059
# 4:*家族名義の口座も作るておくう。
# node_id:13, node_words:銀行(22.0),口座(19.0),携帯(14.0),開設(8.0),電話(7.0),本人(7.0),契約(6.0),ライセンス(3.0),作る(3.0),見え(2.0), probability:0.097
# 5:**携帯電話は、契約するせるてもらえるないだ、その時点で解約で良いや。
# node_id:13, node_words:銀行(22.0),口座(19.0),携帯(14.0),開設(8.0),電話(7.0),本人(7.0),契約(6.0),ライセンス(3.0),作る(3.0),見え(2.0), probability:0.134
# 6:*ほとんど使うてるないから、金がもつたないと思うているた。
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.0
# 7:*仕事用携帯電話で受電するて、*の***だけで十分だと感じるている。
# node_id:13, node_words:銀行(22.0),口座(19.0),携帯(14.0),開設(8.0),電話(7.0),本人(7.0),契約(6.0),ライセンス(3.0),作る(3.0),見え(2.0), probability:0.101
# ------------------------------------------------------------------
# 0:もう、ここまで一体化するれるのだあるば、*は、カード型に拘る必要が無いのだは。
# node_id:453, node_words:仕方(3.0),解決(2.0),ケース(2.0),愚策(2.0),止める(2.0),指摘(2.0),無理(2.0),ウクライナ(1.0),為る(1.0),供与(1.0), probability:0.062
# 1:ドックタグ型にするて、ネックチェーンで、肌身離すぬ持ち歩くように、変えるたどうですうか。
# node_id:865, node_words:賛成(3.0),離す(2.0),つながり(1.0),ドック(1.0),インフラ(1.0),ネック(1.0),離れ(1.0),予測(1.0),陰謀(1.0),防止(1.0), probability:0.088
# 2:*それとも、体にチップを埋設する方式にするとか、本人が意図するぬ手放せるない様だ、物にするないとね。
# node_id:850, node_words:埋め込む(5.0),チップ(5.0),マイクロ(3.0),落とす(3.0),一体(3.0),高い(2.0),めちゃくちゃ(2.0),掛かる(2.0),人体(2.0),分かる(2.0), probability:0.07
# 3:*肌身から離すから、落とすたり、無くすたりするのだから。
# node_id:865, node_words:賛成(3.0),離す(2.0),つながり(1.0),ドック(1.0),インフラ(1.0),ネック(1.0),離れ(1.0),予測(1.0),陰謀(1.0),防止(1.0), probability:0.059
# ------------------------------------------------------------------
# 0:建前だけ任意として政府は一切責任を負ううとするぬ、それでいて生活に必須だ健康保険や身分証明書などを人質に取る、実質的には強制するやり方が、あまりにも姑息だ不誠実だ。
# node_id:5, node_words:身分(8.0),おかしい(8.0),無い(6.0),証明(6.0),付け(5.0),忘れる(4.0),落とす(3.0),認める(3.0),負う(3.0),当たり前(2.0), probability:0.152
# 1:*
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.0
# 2:こんなやり方は信用できるないし、信用できるない人たちに口座番号などの個人情報を渡すのは、危険極まりないと思う。
# node_id:3, node_words:信用(13.0),公安(4.0),管轄(4.0),お前(3.0),やり方(3.0),一切(3.0),実質(3.0),横行(3.0),取り扱い(3.0),渡す(2.0), probability:0.261
# 3:*民間のカード会社や金融機関は、消費者の信用を得るためにたいへんだ努力を行うているが、「*」には、誠意の欠片もない、あるのは連日のトラブルと、国民を見下す上から目線だけだ。
# node_id:3, node_words:信用(13.0),公安(4.0),管轄(4.0),お前(3.0),やり方(3.0),一切(3.0),実質(3.0),横行(3.0),取り扱い(3.0),渡す(2.0), probability:0.179
# 4:*国民の生活状況や健康状態、財産などの個人情報を政府に渡すことだ、さらなる増税や負担増を押し付けるられることは目に見えるている。
# node_id:874, node_words:負担(5.0),減る(4.0),更新(3.0),関わる(3.0),費用(3.0),窓口(3.0),削減(2.0),統一(2.0),業務(1.0),購入(1.0), probability:0.061
# 5:*こんな危険だ有害だ制度は、今すぐやめるべしだが、そのためには、今の総理大臣をはじめとするた政治家に、やめるてもらうことが欠くせるない。
# node_id:858, node_words:逮捕(2.0),守る(2.0),公平(2.0),民間(1.0),民営(1.0),お上(1.0),手続(1.0),民放(1.0),利権(1.0),取得(1.0), probability:0.038
# 6:*
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.0
# 7:そのためには、選挙で意思表示をすることが、国民がとれる一番の解決策だ。
# node_id:12, node_words:選挙(23.0),自民党(20.0),政権(17.0),与党(10.0),公明党(7.0),政治(7.0),たち(7.0),投票(6.0),潰す(4.0),行く(4.0), probability:0.071
# ------------------------------------------------------------------
# 0:ともかく紙の保険証廃止だけは止めるべしですう。
# node_id:453, node_words:仕方(3.0),解決(2.0),ケース(2.0),愚策(2.0),止める(2.0),指摘(2.0),無理(2.0),ウクライナ(1.0),為る(1.0),供与(1.0), probability:0.043
# 1:きょうのテレビ欄で各局のワイドショーの項目をみるた、*という項目は一つもないた。
# node_id:98, node_words:皆さん(5.0),オランダ(4.0),倒す(2.0),項目(2.0),慎重(2.0),宜しい(2.0),危なっかしい(2.0),お願い(2.0),ちかい(1.0),祈る(1.0), probability:0.079
# 2:大いに失望するた。
# node_id:98, node_words:皆さん(5.0),オランダ(4.0),倒す(2.0),項目(2.0),慎重(2.0),宜しい(2.0),危なっかしい(2.0),お願い(2.0),ちかい(1.0),祈る(1.0), probability:0.014
# 3:つまり政府の方針は「鎮圧」にかたまるたってこと。
# node_id:98, node_words:皆さん(5.0),オランダ(4.0),倒す(2.0),項目(2.0),慎重(2.0),宜しい(2.0),危なっかしい(2.0),お願い(2.0),ちかい(1.0),祈る(1.0), probability:0.014
# 4:テレビ局も政権側からのパイプが切るれるた情報ももらえるないなる。
# node_id:12, node_words:選挙(23.0),自民党(20.0),政権(17.0),与党(10.0),公明党(7.0),政治(7.0),たち(7.0),投票(6.0),潰す(4.0),行く(4.0), probability:0.052
# 5:いまこそ国民世論の沸騰しかない、あと有力だコメンテーターや*が紙の保険証維持の立場に立つてくれることを祈るしかない
# node_id:98, node_words:皆さん(5.0),オランダ(4.0),倒す(2.0),項目(2.0),慎重(2.0),宜しい(2.0),危なっかしい(2.0),お願い(2.0),ちかい(1.0),祈る(1.0), probability:0.095
# ------------------------------------------------------------------
# 0:ついに出るますたね。
# node_id:3, node_words:信用(13.0),公安(4.0),管轄(4.0),お前(3.0),やり方(3.0),一切(3.0),実質(3.0),横行(3.0),取り扱い(3.0),渡す(2.0), probability:0.009
# 1:*と個人のあらゆる情報を紐づけるて国が監視できる体制が。
# node_id:453, node_words:仕方(3.0),解決(2.0),ケース(2.0),愚策(2.0),止める(2.0),指摘(2.0),無理(2.0),ウクライナ(1.0),為る(1.0),供与(1.0), probability:0.043
# 2:戸籍、勤め先、納税、健康保険証、通院投薬歴、運転免許、交通違反歴、保有するている車両、携帯電話番号、銀行口座と取引履歴。
# node_id:13, node_words:銀行(22.0),口座(19.0),携帯(14.0),開設(8.0),電話(7.0),本人(7.0),契約(6.0),ライセンス(3.0),作る(3.0),見え(2.0), probability:0.29
# 3:*個人的だ予測としていずれは学校就学、勤め先などの個人の職歴学歴、警察にある犯罪歴と指紋、パスポート、クレジットカード、ショッピングサイトや*、お店やレンタルショップの会員情報、通勤定期などなどもうなるだもあるです。
# node_id:768, node_words:来る(3.0),購入(2.0),田舎(2.0),出る(2.0),連絡(2.0),監視(2.0),バレ(2.0),勤め先(2.0),投薬(1.0),くし(1.0), probability:0.162
# 4:*これらが紐づけるられると*と*から得るられる関連情報をくし刺しするて、誰がどの経路をたどるてどこへ行くたのか、誰と連絡を取るているて何を話すたのか、どんなものを検索するて何に興味があるて何を購入するたのかまで全てバレバレ。
# node_id:768, node_words:来る(3.0),購入(2.0),田舎(2.0),出る(2.0),連絡(2.0),監視(2.0),バレ(2.0),勤め先(2.0),投薬(1.0),くし(1.0), probability:0.184
# 5:*
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.0
# 6:きっと*に忘れ物タグに使うているようだチップも搭載するんじゃないかな、末恐ろしい監視社会。
# node_id:850, node_words:埋め込む(5.0),チップ(5.0),マイクロ(3.0),落とす(3.0),一体(3.0),高い(2.0),めちゃくちゃ(2.0),掛かる(2.0),人体(2.0),分かる(2.0), probability:0.085
# ------------------------------------------------------------------
# 0:免許証と*の一体化が始まるた直後は、道路で行うれる検問では超大渋滞が予想するれるますね。
# node_id:453, node_words:仕方(3.0),解決(2.0),ケース(2.0),愚策(2.0),止める(2.0),指摘(2.0),無理(2.0),ウクライナ(1.0),為る(1.0),供与(1.0), probability:0.043
# 1:*だって、免許証見るば済むようだ検問でもいちいち一人一人機械でカードを読むないなるないし、ひょっとすると暗証番号入力もあるかも知れるないし。
# node_id:2, node_words:番号(14.0),暗証(13.0),役所(8.0),記載(4.0),間違える(4.0),住所(3.0),設定(3.0),意識(3.0),交付(3.0),誕生(3.0), probability:0.161
# 2:*車での旅行も大変だ時代が到来する恐れあるですね。
# node_id:671, node_words:違反(3.0),白バイ(3.0),機械(3.0),専用(3.0),交通(3.0),パトカー(3.0),表面(2.0),車両(2.0),警察官(2.0),全国(2.0), probability:0.026
# ------------------------------------------------------------------
# 0:何でもかんでも一体化するば良いものだはない！、運転免許証の更新は*
# node_id:764, node_words:更新(24.0),ゴールド(4.0),即日(3.0),読み取り(2.0),検査(2.0),いく(2.0),こっち(2.0),手間(2.0),装置(2.0),政権(2.0), probability:0.245
# 1:その日のうちに完結するが*の更新は現段階では複雑。
# node_id:764, node_words:更新(24.0),ゴールド(4.0),即日(3.0),読み取り(2.0),検査(2.0),いく(2.0),こっち(2.0),手間(2.0),装置(2.0),政権(2.0), probability:0.245
# 2:*運転免許証と同じようだ更新手続きにするべしだある。
# node_id:764, node_words:更新(24.0),ゴールド(4.0),即日(3.0),読み取り(2.0),検査(2.0),いく(2.0),こっち(2.0),手間(2.0),装置(2.0),政権(2.0), probability:0.245
# 3:よくわかるないのは*免許停止処分時の免許取り上げる、免停る解除後に引き渡しとなるがマイナンバー*カードになるた場合の運用方法が明確だない。
# node_id:870, node_words:記録(2.0),仕組み(2.0),特定(1.0),引き渡し(1.0),明確(1.0),給付(1.0),規格(1.0),印鑑(1.0),税理士(1.0),見せる(1.0), probability:0.083
# 4:すべての仕組みを理解するないで*運用するうとするているところに今後も*のトラブルが*続くようだ気がする
# node_id:870, node_words:記録(2.0),仕組み(2.0),特定(1.0),引き渡し(1.0),明確(1.0),給付(1.0),規格(1.0),印鑑(1.0),税理士(1.0),見せる(1.0), probability:0.125
# ------------------------------------------------------------------
# 0:保険証との紐付けができるているないと自己負担になるのと同様に運転免許証の紐付けができるてるないと免許不携帯になる可能性がある。
# node_id:210, node_words:支持(5.0),上がる(3.0),付け(3.0),公的(3.0),絶対(3.0),順番(2.0),普及(2.0),ふざける(2.0),運転(2.0),確約(2.0), probability:0.095
# 1:**と一体化するてしまうのは危ないと思う。
# node_id:453, node_words:仕方(3.0),解決(2.0),ケース(2.0),愚策(2.0),止める(2.0),指摘(2.0),無理(2.0),ウクライナ(1.0),為る(1.0),供与(1.0), probability:0.043
# ------------------------------------------------------------------
# 0:先日、郵便局で本人確認に*を使うますたが、職員さんは裏の番号を見るてはいけるないらしい、他の人が裏面を見るないようにカードを持ち上げることもできるないので、さっと見るだけで確認を終えるているますた。
# node_id:2, node_words:番号(14.0),暗証(13.0),役所(8.0),記載(4.0),間違える(4.0),住所(3.0),設定(3.0),意識(3.0),交付(3.0),誕生(3.0), probability:0.078
# 1:**正直このくらいのチェックだ偽造とか簡単そうだなぁ、と思うんですがどうだんですうね。
# node_id:81, node_words:コピー(6.0),公的(6.0),認証(4.0),計画(4.0),やり方(3.0),対面(3.0),確認(3.0),思う(3.0),保管(2.0),時代(2.0), probability:0.043
# 2:*というか詳しいチェックするちゃいけるない身分確認証って役に立つない気がする。
# node_id:81, node_words:コピー(6.0),公的(6.0),認証(4.0),計画(4.0),やり方(3.0),対面(3.0),確認(3.0),思う(3.0),保管(2.0),時代(2.0), probability:0.075
# ------------------------------------------------------------------
# 0:なぜマイナンバー「カード」に政府がこだわるのか理解出来るますん。
# node_id:453, node_words:仕方(3.0),解決(2.0),ケース(2.0),愚策(2.0),止める(2.0),指摘(2.0),無理(2.0),ウクライナ(1.0),為る(1.0),供与(1.0), probability:0.043
# 1:**
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.0
# 2:速やかだ給付などのため、マイナンバーは必要だと思うます。
# node_id:870, node_words:記録(2.0),仕組み(2.0),特定(1.0),引き渡し(1.0),明確(1.0),給付(1.0),規格(1.0),印鑑(1.0),税理士(1.0),見せる(1.0), probability:0.083
# 3:*でも、物理カードを国民の大多数が持つことに、何の意味があるのですうか？
# node_id:870, node_words:記録(2.0),仕組み(2.0),特定(1.0),引き渡し(1.0),明確(1.0),給付(1.0),規格(1.0),印鑑(1.0),税理士(1.0),見せる(1.0), probability:0.042
# 4:**リモートで各種手続きができるて便利というますが、それは税理士さんとか頻繁に公的手続きをする仕事の方の話だあるて、一般には、住民票を取ることすら数年に一度の方が多いのだはないかと思うます。
# node_id:870, node_words:記録(2.0),仕組み(2.0),特定(1.0),引き渡し(1.0),明確(1.0),給付(1.0),規格(1.0),印鑑(1.0),税理士(1.0),見せる(1.0), probability:0.167
# 5:*印鑑証明カードのように、必要だ人が取得できる仕組みで、何の不都合があるのですう？
# node_id:870, node_words:記録(2.0),仕組み(2.0),特定(1.0),引き渡し(1.0),明確(1.0),給付(1.0),規格(1.0),印鑑(1.0),税理士(1.0),見せる(1.0), probability:0.125
# 6:**
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.0
# 7:百歩譲るて、何かの理由で個人を特定する*チップを持つせるたいのだ、スマホの*チップに記録するとか、運転免許証の*チップに記録するとか、既に持つている*チップで一定のセキュリティ規格を満たすものだ何でも良いと思うますが、なぜマイナンバー「カード」に統合だのでするう？**いまいち、理解できるますん。
# node_id:870, node_words:記録(2.0),仕組み(2.0),特定(1.0),引き渡し(1.0),明確(1.0),給付(1.0),規格(1.0),印鑑(1.0),税理士(1.0),見せる(1.0), probability:0.308
# 8:**持つてますけど。
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.0
# ------------------------------------------------------------------
# 0:*を返納するている人が増えるているとの記事を読むますた。
# node_id:882, node_words:漏れる(1.0),返納(1.0),ほける(1.0),割合(0.0),加減(0.0),加入(0.0),加わる(0.0),加える(0.0),功績(0.0),創造(0.0), probability:0.333
# 1:*作るてしまうた人達は、今からだも遅いないので、返納するて反対の意志を示すのが大事だと思うます。
# node_id:882, node_words:漏れる(1.0),返納(1.0),ほける(1.0),割合(0.0),加減(0.0),加入(0.0),加わる(0.0),加える(0.0),功績(0.0),創造(0.0), probability:0.333
# 2:*貰うたポイントも返すないて良いそうですよ。
# node_id:55, node_words:普及(15.0),ここ(5.0),ポイント(5.0),メリット(4.0),やり方(3.0),いやらしい(2.0),なくす(2.0),考え(2.0),外堀(2.0),抜け道(2.0), probability:0.051
# 3:*
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.0
# 4:そして今度の選挙では、自民党ではない*一本化に否定的だ人に投票するますう。
# node_id:12, node_words:選挙(23.0),自民党(20.0),政権(17.0),与党(10.0),公明党(7.0),政治(7.0),たち(7.0),投票(6.0),潰す(4.0),行く(4.0), probability:0.164
# ------------------------------------------------------------------
# 0:これ交通違反の取締りのときはどうするの。**
# node_id:671, node_words:違反(3.0),白バイ(3.0),機械(3.0),専用(3.0),交通(3.0),パトカー(3.0),表面(2.0),車両(2.0),警察官(2.0),全国(2.0), probability:0.105
# 1:パトロール中に信号無視をするた車を発見するますた、車を停めるて免許証を提示するせるますた、*免許証の表面には免許証としての情報は載るているますん、免許証としての情報を確認するためは*チップを読む専用の機械が必要です、でもパトカーにはその専用の機械がないて確認できるますんですた。
# node_id:671, node_words:違反(3.0),白バイ(3.0),機械(3.0),専用(3.0),交通(3.0),パトカー(3.0),表面(2.0),車両(2.0),警察官(2.0),全国(2.0), probability:0.256
# 2:**
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.0
# 3:こうした事態を避けるためには、全国に配属するれるているパトカーや白バイなどのすべての警察車両に*チップを読み取る専用の機械が必要になるということだよね。
# node_id:671, node_words:違反(3.0),白バイ(3.0),機械(3.0),専用(3.0),交通(3.0),パトカー(3.0),表面(2.0),車両(2.0),警察官(2.0),全国(2.0), probability:0.25
# 4:*そうするないと交通違反の取締りすらできるないなるのだから。
# node_id:671, node_words:違反(3.0),白バイ(3.0),機械(3.0),専用(3.0),交通(3.0),パトカー(3.0),表面(2.0),車両(2.0),警察官(2.0),全国(2.0), probability:0.105
# 5:*全国に何万台とある警察車両に搭載するのにどれだけの費用と年月がかかるのか。
# node_id:671, node_words:違反(3.0),白バイ(3.0),機械(3.0),専用(3.0),交通(3.0),パトカー(3.0),表面(2.0),車両(2.0),警察官(2.0),全国(2.0), probability:0.079
# 6:*はたして*と運転免許証との一体化にそれに見合うだけの効果があるか疑問だな。
# node_id:881, node_words:船舶(2.0),基地(2.0),貴方(2.0),それ(1.0),血税(1.0),厚木(1.0),沈没(1.0),横田(1.0),国政(1.0),始動(1.0), probability:0.059
# ------------------------------------------------------------------
# 0:確認手段は複数個用意するておく方が、安全。
# node_id:81, node_words:コピー(6.0),公的(6.0),認証(4.0),計画(4.0),やり方(3.0),対面(3.0),確認(3.0),思う(3.0),保管(2.0),時代(2.0), probability:0.065
# 1:*免許証ないときは、保険証と公的郵便物で本人確認とかもあるますたよね。
# node_id:81, node_words:コピー(6.0),公的(6.0),認証(4.0),計画(4.0),やり方(3.0),対面(3.0),確認(3.0),思う(3.0),保管(2.0),時代(2.0), probability:0.108
# 2:*そうやるてリスクは、重要だ事柄に関しては分散するせるものだと考えるます。
# node_id:8, node_words:発行(27.0),紛失(12.0),場合(10.0),かかる(7.0),そう(6.0),週間(5.0),大変(5.0),病院(5.0),申請(5.0),万が一(5.0), probability:0.051
# 3:一つしか手段がないと簡単に行き詰まりまります。
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.034
# 4:*何より強靭だシステムとか鉄壁のシステムでもない限り電子系だけに頼るのは危険。
# node_id:81, node_words:コピー(6.0),公的(6.0),認証(4.0),計画(4.0),やり方(3.0),対面(3.0),確認(3.0),思う(3.0),保管(2.0),時代(2.0), probability:0.032
# ------------------------------------------------------------------
# 0:そもそも、自民党政治と言うのは昔から利権の塊だあるますから、元々、国民の為に仕事はするておるますん。
# node_id:12, node_words:選挙(23.0),自民党(20.0),政権(17.0),与党(10.0),公明党(7.0),政治(7.0),たち(7.0),投票(6.0),潰す(4.0),行く(4.0), probability:0.09
# 1:一部の奴の為に仕事をするておるますから一般庶民は何時も困るているます。
# node_id:702, node_words:使用(4.0),仕事(3.0),役場(2.0),当方(2.0),平日(2.0),リーダー(2.0),クルー(1.0),取り締まり(1.0),温床(1.0),挿す(1.0), probability:0.088
# 2:何故、日本人は選挙になると自民党に投票するてしまうのか？
# node_id:12, node_words:選挙(23.0),自民党(20.0),政権(17.0),与党(10.0),公明党(7.0),政治(7.0),たち(7.0),投票(6.0),潰す(4.0),行く(4.0), probability:0.157
# 3:非常に不思議でもあるますし、何故だのか？
# node_id:747, node_words:市町村(3.0),撒く(3.0),ばら(3.0),都道府県(2.0),少子化(1.0),不都合(1.0),世界中(1.0),家族(1.0),個人(1.0),被る(1.0), probability:0.019
# 4:*のままだと日本は更に、とんでもない事になるて仕舞うますから、近いうちに衆議院選挙があるますから、自公に非常に危険ですし警戒をする必要があると思うているます。
# node_id:12, node_words:選挙(23.0),自民党(20.0),政権(17.0),与党(10.0),公明党(7.0),政治(7.0),たち(7.0),投票(6.0),潰す(4.0),行く(4.0), probability:0.09
# 5:政権交代を目標に我々日本人は頑張るないばなるますん。
# node_id:825, node_words:反発(5.0),日本人(4.0),選挙(4.0),移行(3.0),怒り(3.0),強行(3.0),自公(2.0),独裁(2.0),自民党(2.0),日本(2.0), probability:0.076
# 6:今後、日本の舵取りを補うて貰うのは、れいわ新選組を中心とするた政権と致すます。
# node_id:12, node_words:選挙(23.0),自民党(20.0),政権(17.0),与党(10.0),公明党(7.0),政治(7.0),たち(7.0),投票(6.0),潰す(4.0),行く(4.0), probability:0.065
# 7:皆さんも当然、意義は無いと思うますから絶対に皆の為に政権交代をするうじゃないですか。
# node_id:98, node_words:皆さん(5.0),オランダ(4.0),倒す(2.0),項目(2.0),慎重(2.0),宜しい(2.0),危なっかしい(2.0),お願い(2.0),ちかい(1.0),祈る(1.0), probability:0.081
# ------------------------------------------------------------------
# 0:免許証との一体化だけは賛成出来るないかな、こんなもん提示する時トラブル起きるの分かるてるしこんな穴だらけのシステムで情報が垂れ流しするれるたたまるたもんじゃないよな、それに一体化するれるた常に携帯するてるないちゃならぶし落とす可能性も高いなるのに再発行まで何ヶ月も掛かるて手続きもめちゃくちゃ面倒いさいくなるのは分かるてるのに民意を無視するて進めるなと言うたい
# node_id:850, node_words:埋め込む(5.0),チップ(5.0),マイクロ(3.0),落とす(3.0),一体(3.0),高い(2.0),めちゃくちゃ(2.0),掛かる(2.0),人体(2.0),分かる(2.0), probability:0.243
# ------------------------------------------------------------------
# 0:運転免許証を*に組み込むじゃうと、日常運転する人は常時*を携帯するとくないと不携帯って事になるという事ですよね？
# node_id:13, node_words:銀行(22.0),口座(19.0),携帯(14.0),開設(8.0),電話(7.0),本人(7.0),契約(6.0),ライセンス(3.0),作る(3.0),見え(2.0), probability:0.13
# 1:個人情報を詰め込むだカードを常時携帯するせるようだ行為を見過ごすて良いのか？
# node_id:13, node_words:銀行(22.0),口座(19.0),携帯(14.0),開設(8.0),電話(7.0),本人(7.0),契約(6.0),ライセンス(3.0),作る(3.0),見え(2.0), probability:0.074
# 2:それとも不携帯の罰則を見直すてくれるのか？
# node_id:13, node_words:銀行(22.0),口座(19.0),携帯(14.0),開設(8.0),電話(7.0),本人(7.0),契約(6.0),ライセンス(3.0),作る(3.0),見え(2.0), probability:0.074
# 3:*には番号も記載するれるてるし、本当に必要だ時にしか携帯するたいないというのが本音です。
# node_id:2, node_words:番号(14.0),暗証(13.0),役所(8.0),記載(4.0),間違える(4.0),住所(3.0),設定(3.0),意識(3.0),交付(3.0),誕生(3.0), probability:0.1
# ------------------------------------------------------------------
# 0:データの一元管理を*でするだけだ良いのだは？とも思うます。
# node_id:859, node_words:考え直す(1.0),内容(1.0),退職(1.0),反旗(1.0),チェック(1.0),返納(1.0),利権(1.0),検挙(1.0),日本国(1.0),ぶる(1.0), probability:0.034
# 1:**
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.0
# 2:個人的には、保険証、免許証、*と*枚持ち歩くないて済むのは歓迎です。
# node_id:853, node_words:リーダー(2.0),携帯(2.0),起きる(2.0),歓迎(2.0),いける(2.0),財布(1.0),疲れる(1.0),障害(1.0),大丈夫(1.0),今度(1.0), probability:0.053
# 3:*言うだ、指紋やら声紋やら顔やらの生体認証情報を登録するてるばカードすら必要ない、病院に通えるたり、車運転出来るたりするばいいね。
# node_id:81, node_words:コピー(6.0),公的(6.0),認証(4.0),計画(4.0),やり方(3.0),対面(3.0),確認(3.0),思う(3.0),保管(2.0),時代(2.0), probability:0.043
# 4:**車自体に認証機能を搭載するてるば、無免許とか更新切れとかだと*車が動くないばいいし、納税や還付も確定申告なんかするないても自動ですてくれるとか、給付金も手続きないだ給付するてくれるとかになるば便利ですね。**
# node_id:764, node_words:更新(24.0),ゴールド(4.0),即日(3.0),読み取り(2.0),検査(2.0),いく(2.0),こっち(2.0),手間(2.0),装置(2.0),政権(2.0), probability:0.245
# 5:あと国会議員や地方議員さんなんかは率先するて、デジタル化に取り組むでみるたいいですね。
# node_id:834, node_words:議員(8.0),役人(4.0),値上がり(3.0),破綻(3.0),仕組み(2.0),給付(2.0),メリット(2.0),自体(2.0),合格(2.0),バッチ(2.0), probability:0.226
# 6:*一円単位で使途を公開するとか、選挙投票出来るとか議員さんの評価を簡単にできる仕組みにも活用するてくださる。
# node_id:834, node_words:議員(8.0),役人(4.0),値上がり(3.0),破綻(3.0),仕組み(2.0),給付(2.0),メリット(2.0),自体(2.0),合格(2.0),バッチ(2.0), probability:0.197
# 7:**現状メリットが少ないのと、情報漏洩の懸念で歓迎するれるないのですうね。
# node_id:853, node_words:リーダー(2.0),携帯(2.0),起きる(2.0),歓迎(2.0),いける(2.0),財布(1.0),疲れる(1.0),障害(1.0),大丈夫(1.0),今度(1.0), probability:0.053
# 8:**
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.0
# 9:便利で住むやすい日本になるていくことを望むます。
# node_id:857, node_words:いく(3.0),結果(2.0),マジ(2.0),注ぐ(2.0),どこ(2.0),腐る(2.0),見える(2.0),役立つ(2.0),本来(2.0),購入(1.0), probability:0.071
# ------------------------------------------------------------------
# 0:結局、運転免許証の更新制度は変わるないのですう？
# node_id:764, node_words:更新(24.0),ゴールド(4.0),即日(3.0),読み取り(2.0),検査(2.0),いく(2.0),こっち(2.0),手間(2.0),装置(2.0),政権(2.0), probability:0.245
# 1:*それなら、顔写真の更新も兼ねるて悪いはないと思うます。
# node_id:764, node_words:更新(24.0),ゴールド(4.0),即日(3.0),読み取り(2.0),検査(2.0),いく(2.0),こっち(2.0),手間(2.0),装置(2.0),政権(2.0), probability:0.255
# 2:本人確認の媒体としても一定の効力はあるのですし。
# node_id:872, node_words:思える(2.0),年寄り(2.0),確率(2.0),纏める(2.0),勝つ(1.0),どこ(1.0),圧力(1.0),悪党(1.0),起こる(1.0),無言(1.0), probability:0.048
# 3:**に免許証情報を加えるまでは構うないです。
# node_id:453, node_words:仕方(3.0),解決(2.0),ケース(2.0),愚策(2.0),止める(2.0),指摘(2.0),無理(2.0),ウクライナ(1.0),為る(1.0),供与(1.0), probability:0.043
# 4:ただ、結局所持するない*。
# node_id:830, node_words:所持(2.0),信じる(2.0),受診(1.0),しれる(1.0),れる(1.0),届け(1.0),必死(1.0),譲る(1.0),タバコ(1.0),釣る(1.0), probability:0.067
# 5:確認時は警察側の端末で専用サイトにアクセスするて、名前や生年月日、住所などから顔写真付きの本人データを呼び出すて、本人と一緒に確認とかだ良いのかなと。
# node_id:794, node_words:端末(6.0),身分(4.0),警察(3.0),お巡りさん(3.0),住所(3.0),チェック(3.0),写真(3.0),搭載(2.0),契約(2.0),サービス(2.0), probability:0.165
# 6:そうするば、不携帯での取締対象になるないし、利用する側も紛失リスクは下げるられるますしね。
# node_id:8, node_words:発行(27.0),紛失(12.0),場合(10.0),かかる(7.0),そう(6.0),週間(5.0),大変(5.0),病院(5.0),申請(5.0),万が一(5.0), probability:0.093
# 7:そもそも今も、仮に旅先で財布とかにいれるて紛失するた、警察に届け出るてもその後運転できるないって、現実的にどうだのよ思うているます。
# node_id:8, node_words:発行(27.0),紛失(12.0),場合(10.0),かかる(7.0),そう(6.0),週間(5.0),大変(5.0),病院(5.0),申請(5.0),万が一(5.0), probability:0.051
# 8:**とにかく、身分証は複数、系統の違うものは必要かなと思うます。
# node_id:5, node_words:身分(8.0),おかしい(8.0),無い(6.0),証明(6.0),付け(5.0),忘れる(4.0),落とす(3.0),認める(3.0),負う(3.0),当たり前(2.0), probability:0.071
# 9:現時点で代表格は運転免許証かなと。
# node_id:210, node_words:支持(5.0),上がる(3.0),付け(3.0),公的(3.0),絶対(3.0),順番(2.0),普及(2.0),ふざける(2.0),運転(2.0),確約(2.0), probability:0.025
# 10:加えるて警察なりで管理するれる公的身分証が加わるば運転するない人でも助かるかなと思う次第です。
# node_id:81, node_words:コピー(6.0),公的(6.0),認証(4.0),計画(4.0),やり方(3.0),対面(3.0),確認(3.0),思う(3.0),保管(2.0),時代(2.0), probability:0.097
# ------------------------------------------------------------------
# 0:一本化するには早いすぎる進行だと思う。
# node_id:116, node_words:中国(6.0),好き(2.0),狂気(2.0),恐い(2.0),移住(2.0),すぎ(2.0),沙汰(2.0),いとこ(2.0),真似(2.0),一族(2.0), probability:0.05
# 1:*
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.0
# 2:そもそもシステムの確立ができるているない状況だし*確立するのにある程度の年月は必要。
# node_id:846, node_words:確立(3.0),モデル(2.0),対処(2.0),都市(1.0),ここ(1.0),下がる(1.0),ダメージ(1.0),戸籍(1.0),アナログ(1.0),明らか(1.0), probability:0.143
# 3:**
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.0
# 4:そもそもアナログを廃止するというのも*ちょっとどうだのかと感じる。
# node_id:98, node_words:皆さん(5.0),オランダ(4.0),倒す(2.0),項目(2.0),慎重(2.0),宜しい(2.0),危なっかしい(2.0),お願い(2.0),ちかい(1.0),祈る(1.0), probability:0.041
# 5:*一本化するにするてちゃんと不足の事態の場合の*対処の体制はできるているんだうか？
# node_id:846, node_words:確立(3.0),モデル(2.0),対処(2.0),都市(1.0),ここ(1.0),下がる(1.0),ダメージ(1.0),戸籍(1.0),アナログ(1.0),明らか(1.0), probability:0.065
# 6:**代替としてアナログでの方法も多少面倒になるても*残すておくた方がいいように感じる。
# node_id:851, node_words:ヒューマン(5.0),エラー(5.0),連携(3.0),今度(2.0),すぎ(1.0),押し付ける(1.0),浮かぶ(1.0),たらい(1.0),漢字(1.0),入力(1.0), probability:0.031
# 7:*少なくとも*年ちょっとだすべて万全なんてことは無理かと。
# node_id:453, node_words:仕方(3.0),解決(2.0),ケース(2.0),愚策(2.0),止める(2.0),指摘(2.0),無理(2.0),ウクライナ(1.0),為る(1.0),供与(1.0), probability:0.043
# ------------------------------------------------------------------
# 0:*の作成は「任意」ですたよね。
# node_id:453, node_words:仕方(3.0),解決(2.0),ケース(2.0),愚策(2.0),止める(2.0),指摘(2.0),無理(2.0),ウクライナ(1.0),為る(1.0),供与(1.0), probability:0.043
# 1:*いるつから強制に変わるたのですうか。
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.0
# 2:*
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.0
# 3:また、カードナンバーが流出するないよう「必要だ時以外は携帯はするないで下さる」ですたよね。
# node_id:13, node_words:銀行(22.0),口座(19.0),携帯(14.0),開設(8.0),電話(7.0),本人(7.0),契約(6.0),ライセンス(3.0),作る(3.0),見え(2.0), probability:0.065
# 4:*健康保険証、免許証の紐付け、本人確認と必ず携帯するモノに変わるてますよね。
# node_id:13, node_words:銀行(22.0),口座(19.0),携帯(14.0),開設(8.0),電話(7.0),本人(7.0),契約(6.0),ライセンス(3.0),作る(3.0),見え(2.0), probability:0.111
# 5:*国民のコンセンサス取るたのですうか？
# node_id:871, node_words:中身(1.0),脅迫(1.0),暴走(1.0),決定(1.0),チンピラ(1.0),施策(1.0),改正(1.0),よい(1.0),崩壊(1.0),差し出す(1.0), probability:0.04
# 6:*
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.0
# 7:また、*を紛失するた時、病院に掛かると*割負担ですか？
# node_id:8, node_words:発行(27.0),紛失(12.0),場合(10.0),かかる(7.0),そう(6.0),週間(5.0),大変(5.0),病院(5.0),申請(5.0),万が一(5.0), probability:0.076
# 8:*免許不携帯になるますか？
# node_id:13, node_words:銀行(22.0),口座(19.0),携帯(14.0),開設(8.0),電話(7.0),本人(7.0),契約(6.0),ライセンス(3.0),作る(3.0),見え(2.0), probability:0.069
# 9:*確かに保険証や免許無いするたりするば、そうなるますけど、バラバラだあるば全部一遍に無くすリスクは回避するれるます。
# node_id:797, node_words:無くす(7.0),期限(3.0),前提(2.0),ただ(2.0),可能(2.0),イン(1.0),返納(1.0),縛る(1.0),投げる(1.0),利く(1.0), probability:0.16
# 10:*それから、無くすた場合の本人確認どうするのですうか？
# node_id:881, node_words:船舶(2.0),基地(2.0),貴方(2.0),それ(1.0),血税(1.0),厚木(1.0),沈没(1.0),横田(1.0),国政(1.0),始動(1.0), probability:0.059
# 11:*即時発行できるのですか？
# node_id:8, node_words:発行(27.0),紛失(12.0),場合(10.0),かかる(7.0),そう(6.0),週間(5.0),大変(5.0),病院(5.0),申請(5.0),万が一(5.0), probability:0.131
# 12:*手続きは簡単ですか？
# node_id:858, node_words:逮捕(2.0),守る(2.0),公平(2.0),民間(1.0),民営(1.0),お上(1.0),手続(1.0),民放(1.0),利権(1.0),取得(1.0), probability:0.019
# 13:*数々の問題を棚上げにするて、国民を不安に貶めるている*の紐付け、はっきり言うて不要です。
# node_id:453, node_words:仕方(3.0),解決(2.0),ケース(2.0),愚策(2.0),止める(2.0),指摘(2.0),無理(2.0),ウクライナ(1.0),為る(1.0),供与(1.0), probability:0.064
# 14:*単体のみの活用にするて下さる。
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.023
# ------------------------------------------------------------------
# 0:通信がうまいいくないたり、サーバーのトラブルで確認できるないた場合に警察官は運転することを認めることができるのか。
# node_id:8, node_words:発行(27.0),紛失(12.0),場合(10.0),かかる(7.0),そう(6.0),週間(5.0),大変(5.0),病院(5.0),申請(5.0),万が一(5.0), probability:0.042
# 1:大規模災害時など身分を証明するものもなくなる。
# node_id:5, node_words:身分(8.0),おかしい(8.0),無い(6.0),証明(6.0),付け(5.0),忘れる(4.0),落とす(3.0),認める(3.0),負う(3.0),当たり前(2.0), probability:0.125
# 2:緊急時、非常時に余計だトラブル、時間の無駄が発生するて被害は拡大するばかりだ。
# node_id:791, node_words:国家(2.0),出る(2.0),事実(2.0),分かる(2.0),日本(2.0),成立(2.0),メリット(2.0),気付く(2.0),関係(2.0),被害(2.0), probability:0.033
# 3:そう考えると今の免許証は身分証明として非常に優れるている。
# node_id:5, node_words:身分(8.0),おかしい(8.0),無い(6.0),証明(6.0),付け(5.0),忘れる(4.0),落とす(3.0),認める(3.0),負う(3.0),当たり前(2.0), probability:0.125
# ------------------------------------------------------------------
# 0:運転免許証と*が一体化するれるのも困るますね。
# node_id:453, node_words:仕方(3.0),解決(2.0),ケース(2.0),愚策(2.0),止める(2.0),指摘(2.0),無理(2.0),ウクライナ(1.0),為る(1.0),供与(1.0), probability:0.043
# 1:紛失するた場合、その日のうちに再発行するてもらえるばいいのですうが、そういうシステムができるまでは、一体化するべしだはあるますんね。
# node_id:8, node_words:発行(27.0),紛失(12.0),場合(10.0),かかる(7.0),そう(6.0),週間(5.0),大変(5.0),病院(5.0),申請(5.0),万が一(5.0), probability:0.233
# 2:運転を仕事にするている人が、*を紛失するた、一大事になるますよね。
# node_id:702, node_words:使用(4.0),仕事(3.0),役場(2.0),当方(2.0),平日(2.0),リーダー(2.0),クルー(1.0),取り締まり(1.0),温床(1.0),挿す(1.0), probability:0.088
# 3:再発行するれるまで運転の仕事ができるないのも痛手ですうし。
# node_id:8, node_words:発行(27.0),紛失(12.0),場合(10.0),かかる(7.0),そう(6.0),週間(5.0),大変(5.0),病院(5.0),申請(5.0),万が一(5.0), probability:0.119
# ------------------------------------------------------------------
# 0:デジタル化で世の中の色々だ物が便利になるのには賛成だが、*はどうだのだう。
# node_id:864, node_words:当たり前(2.0),世の中(2.0),官僚(1.0),大量(1.0),抗議(1.0),比較(1.0),事件(1.0),爆発(1.0),セキュリティ(1.0),歩き(1.0), probability:0.1
# 1:*なんだか、行く当たりばったりで物事を進める副作用や矛盾が起きることを考えるているのだうか。
# node_id:853, node_words:リーダー(2.0),携帯(2.0),起きる(2.0),歓迎(2.0),いける(2.0),財布(1.0),疲れる(1.0),障害(1.0),大丈夫(1.0),今度(1.0), probability:0.053
# 2:*どうして日本はこうだのだう。
# node_id:533, node_words:デジタル(12.0),対応(6.0),世界(5.0),企業(4.0),状態(4.0),日本(4.0),必須(3.0),優先(3.0),言える(3.0),大事(3.0), probability:0.022
# 3:*
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.0
# 4:なぜ将来を見据えるた構造改革を根本から見直すてできるないのだう。
# node_id:671, node_words:違反(3.0),白バイ(3.0),機械(3.0),専用(3.0),交通(3.0),パトカー(3.0),表面(2.0),車両(2.0),警察官(2.0),全国(2.0), probability:0.013
# 5:*
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.0
# 6:今あるものを使うて新しい何かするうとしても、そのシステムの限界を超えると問題が起きることはビジネスマンだ知るている。
# node_id:853, node_words:リーダー(2.0),携帯(2.0),起きる(2.0),歓迎(2.0),いける(2.0),財布(1.0),疲れる(1.0),障害(1.0),大丈夫(1.0),今度(1.0), probability:0.053
# 7:*お金がかかるからできるないというだ、起きるた問題の後始末にかかる時間とお金を考えるてみるては？
# node_id:8, node_words:発行(27.0),紛失(12.0),場合(10.0),かかる(7.0),そう(6.0),週間(5.0),大変(5.0),病院(5.0),申請(5.0),万が一(5.0), probability:0.058
# 8:*行政のシステムは、なによりも信頼が大事だと思うのは私だけですうか。
# node_id:880, node_words:効率(5.0),行政(3.0),徴収(3.0),本来(3.0),消える(1.0),豪語(1.0),ベール(1.0),身分(1.0),威力(1.0),ばらまく(1.0), probability:0.058
# ------------------------------------------------------------------
# 0:オランダに駐在するた時、オランダの運転免許証に書き換えするた際に日本の運転免許証を取り上げるられるますた。
# node_id:98, node_words:皆さん(5.0),オランダ(4.0),倒す(2.0),項目(2.0),慎重(2.0),宜しい(2.0),危なっかしい(2.0),お願い(2.0),ちかい(1.0),祈る(1.0), probability:0.115
# 1:日本の運転免許証と交換するたことになるます。
# node_id:210, node_words:支持(5.0),上がる(3.0),付け(3.0),公的(3.0),絶対(3.0),順番(2.0),普及(2.0),ふざける(2.0),運転(2.0),確約(2.0), probability:0.025
# 2:**
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.0
# 3:在オランダ日本大使館とオランダ政府との間で特別に日本の運転免許証を本人に返す約束ができるているたので、数カ月後に戻るてくるますた。
# node_id:98, node_words:皆さん(5.0),オランダ(4.0),倒す(2.0),項目(2.0),慎重(2.0),宜しい(2.0),危なっかしい(2.0),お願い(2.0),ちかい(1.0),祈る(1.0), probability:0.141
# 4:**
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.0
# 5:もし、*が運転免許証を兼ねるとなるば、免許の記載事項が明記するれるているないので外国で用を足すない。
# node_id:453, node_words:仕方(3.0),解決(2.0),ケース(2.0),愚策(2.0),止める(2.0),指摘(2.0),無理(2.0),ウクライナ(1.0),為る(1.0),供与(1.0), probability:0.064
# 6:記載するれるたとして、取り上げるられるて返却するれるないとなるた場合、帰国するた時、どうするばいいのですうかね？
# node_id:8, node_words:発行(27.0),紛失(12.0),場合(10.0),かかる(7.0),そう(6.0),週間(5.0),大変(5.0),病院(5.0),申請(5.0),万が一(5.0), probability:0.042
# 7:　外国の運転免許証で*を発行するてくれるのですうか？
# node_id:8, node_words:発行(27.0),紛失(12.0),場合(10.0),かかる(7.0),そう(6.0),週間(5.0),大変(5.0),病院(5.0),申請(5.0),万が一(5.0), probability:0.114
# 8:　**今の政府はこのようだことまで考えるているないですうね。
# node_id:868, node_words:コード(6.0),基本(5.0),単純(2.0),構築(2.0),ヒューマン(1.0),暗号(1.0),迷走(1.0),よう(1.0),裏面(1.0),誘導(1.0), probability:0.02
# ------------------------------------------------------------------
# 0:希望者だけ*で使える様にするだけにするて欲しい。
# node_id:453, node_words:仕方(3.0),解決(2.0),ケース(2.0),愚策(2.0),止める(2.0),指摘(2.0),無理(2.0),ウクライナ(1.0),為る(1.0),供与(1.0), probability:0.043
# 1:*紐付けは漢字一つの間違いもない紐付けするだ勝手にどうぞですが、免許証は免許証として単独で持つたい人まで巻き込むないで欲しい。
# node_id:5, node_words:身分(8.0),おかしい(8.0),無い(6.0),証明(6.0),付け(5.0),忘れる(4.0),落とす(3.0),認める(3.0),負う(3.0),当たり前(2.0), probability:0.085
# 2:*私、免許取得後無事故無違反ですが、今のマイナンバーの杜撰さみるにつけ、知るない間に勝手に点数削るれるて免停るになるたりあるんじゃないかと本気で思うます。
# node_id:851, node_words:ヒューマン(5.0),エラー(5.0),連携(3.0),今度(2.0),すぎ(1.0),押し付ける(1.0),浮かぶ(1.0),たらい(1.0),漢字(1.0),入力(1.0), probability:0.047
# 3:全てはシステムトラブルやヒューマンエラーですうが、責任逃れでたらい回しにするれる未来しか思う浮かぶない。
# node_id:851, node_words:ヒューマン(5.0),エラー(5.0),連携(3.0),今度(2.0),すぎ(1.0),押し付ける(1.0),浮かぶ(1.0),たらい(1.0),漢字(1.0),入力(1.0), probability:0.203
# 4:*
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.0
# 5:もちろん誰も責任取るないですうしね。
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.0
# 6:被害者だけが苦しむだけと。
# node_id:791, node_words:国家(2.0),出る(2.0),事実(2.0),分かる(2.0),日本(2.0),成立(2.0),メリット(2.0),気付く(2.0),関係(2.0),被害(2.0), probability:0.022
# 7:*なんでもむやみやたらに国が強制するてやるのは辞めるて欲しい。
# node_id:877, node_words:背番号(3.0),狂う(2.0),オレ(2.0),組織(2.0),拡大(1.0),まくる(1.0),過去(1.0),自分(1.0),いや(1.0),接待(1.0), probability:0.023
# ------------------------------------------------------------------
# 0:紛失問題は、常に、なんにでもあるだう。
# node_id:8, node_words:発行(27.0),紛失(12.0),場合(10.0),かかる(7.0),そう(6.0),週間(5.0),大変(5.0),病院(5.0),申請(5.0),万が一(5.0), probability:0.051
# 1:*国家試験免状もそうだ。
# node_id:8, node_words:発行(27.0),紛失(12.0),場合(10.0),かかる(7.0),そう(6.0),週間(5.0),大変(5.0),病院(5.0),申請(5.0),万が一(5.0), probability:0.034
# 2:*「紙で配布するれる、本人が保管する、何かあるば持参する」という現状が、*で単純になるば、書類の保管も不要だ、よほど便利になるようだ気がする。
# node_id:868, node_words:コード(6.0),基本(5.0),単純(2.0),構築(2.0),ヒューマン(1.0),暗号(1.0),迷走(1.0),よう(1.0),裏面(1.0),誘導(1.0), probability:0.059
# 3:*何事にも全て光と影がある訳だ、影だけを強調するて反対するのはどうだのか。
# node_id:864, node_words:当たり前(2.0),世の中(2.0),官僚(1.0),大量(1.0),抗議(1.0),比較(1.0),事件(1.0),爆発(1.0),セキュリティ(1.0),歩き(1.0), probability:0.05
# 4:*
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.0
# 5:多分、生涯変わるないとする指紋を登録する、本人確認の一助とするのは如何か。
# node_id:81, node_words:コピー(6.0),公的(6.0),認証(4.0),計画(4.0),やり方(3.0),対面(3.0),確認(3.0),思う(3.0),保管(2.0),時代(2.0), probability:0.065
# 6:*写真と指紋のダブル認識で、安全性が*と増すと思うが。
# node_id:81, node_words:コピー(6.0),公的(6.0),認証(4.0),計画(4.0),やり方(3.0),対面(3.0),確認(3.0),思う(3.0),保管(2.0),時代(2.0), probability:0.065
# ------------------------------------------------------------------
# 0:今は新規に銀行口座を作るとに、運転免許証か保険証が必要だた。
# node_id:13, node_words:銀行(22.0),口座(19.0),携帯(14.0),開設(8.0),電話(7.0),本人(7.0),契約(6.0),ライセンス(3.0),作る(3.0),見え(2.0), probability:0.217
# 1:*それが、運転免許証と保険証が*に完全統合するれるた後は、全ての新規銀行口座は、*が必要、すなわちマイナンバーと紐付く事になるます。
# node_id:13, node_words:銀行(22.0),口座(19.0),携帯(14.0),開設(8.0),電話(7.0),本人(7.0),契約(6.0),ライセンス(3.0),作る(3.0),見え(2.0), probability:0.207
# 2:**少なくとも*年後には、ほぼ**の銀行口座はマイナンバーに紐づくているですう。
# node_id:13, node_words:銀行(22.0),口座(19.0),携帯(14.0),開設(8.0),電話(7.0),本人(7.0),契約(6.0),ライセンス(3.0),作る(3.0),見え(2.0), probability:0.189
# 3:*誰が考えるたか知るないけど、遠大だ計画ですね。
# node_id:81, node_words:コピー(6.0),公的(6.0),認証(4.0),計画(4.0),やり方(3.0),対面(3.0),確認(3.0),思う(3.0),保管(2.0),時代(2.0), probability:0.043
# 4:日本の官僚もまだまだなかなか優秀です。
# node_id:864, node_words:当たり前(2.0),世の中(2.0),官僚(1.0),大量(1.0),抗議(1.0),比較(1.0),事件(1.0),爆発(1.0),セキュリティ(1.0),歩き(1.0), probability:0.05
# ------------------------------------------------------------------
# 0:記事にもある通り、*を失くいた時の本人確認や再発行の手順、かかる日にちはどうなるのですうか。
# node_id:8, node_words:発行(27.0),紛失(12.0),場合(10.0),かかる(7.0),そう(6.0),週間(5.0),大変(5.0),病院(5.0),申請(5.0),万が一(5.0), probability:0.174
# 1:**
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.0
# 2:今までは運転免許証や保険証、パスポートなどで本人確認ができるたから、万が一が起こるた時も何とか再発行に進むことができるますた。
# node_id:8, node_words:発行(27.0),紛失(12.0),場合(10.0),かかる(7.0),そう(6.0),週間(5.0),大変(5.0),病院(5.0),申請(5.0),万が一(5.0), probability:0.14
# 3:**マイナンバーに運転免許証や保険証を紐づけるのは構うないけれど、発行はそのまま続けるてほしいです。
# node_id:8, node_words:発行(27.0),紛失(12.0),場合(10.0),かかる(7.0),そう(6.0),週間(5.0),大変(5.0),病院(5.0),申請(5.0),万が一(5.0), probability:0.114
# 4:*ほぼ毎日運転するている私としては、たった一枚の身分証明書をずっと身につけるないてはいけるないのはリスクがあるすぎるだと思うます。
# node_id:5, node_words:身分(8.0),おかしい(8.0),無い(6.0),証明(6.0),付け(5.0),忘れる(4.0),落とす(3.0),認める(3.0),負う(3.0),当たり前(2.0), probability:0.125
# ------------------------------------------------------------------
# 0:僕はですけど、多少不便でも、リスクが少ない小さい方が絶対にいいです。
# node_id:853, node_words:リーダー(2.0),携帯(2.0),起きる(2.0),歓迎(2.0),いける(2.0),財布(1.0),疲れる(1.0),障害(1.0),大丈夫(1.0),今度(1.0), probability:0.053
# 1:*政府や官庁にはメリットが大きいのかもしれるますんが、一国民としては不安とリスクが大きいすぎるて、今のシステムレベルでは絶対に移行するたいないです。
# node_id:210, node_words:支持(5.0),上がる(3.0),付け(3.0),公的(3.0),絶対(3.0),順番(2.0),普及(2.0),ふざける(2.0),運転(2.0),確約(2.0), probability:0.062
# 2:*民間の販売するているシステムって、*だ事態も想定するてこれでもかうていろいろだテストを行いリリースするていると思うますが、現状の*はとりあえず作るたレベルで問題だらけです。
# node_id:210, node_words:支持(5.0),上がる(3.0),付け(3.0),公的(3.0),絶対(3.0),順番(2.0),普及(2.0),ふざける(2.0),運転(2.0),確約(2.0), probability:0.086
# 3:*それでもって問題起きるても国は責任とるないと断言するているのだから話になるないと思うます。
# node_id:881, node_words:船舶(2.0),基地(2.0),貴方(2.0),それ(1.0),血税(1.0),厚木(1.0),沈没(1.0),横田(1.0),国政(1.0),始動(1.0), probability:0.059
# 4:*
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.0
# 5:せめて明らかになるている国民の判断で譲れるないを解決する不安を解消するない限りリリースなどもってのほかです。
# node_id:210, node_words:支持(5.0),上がる(3.0),付け(3.0),公的(3.0),絶対(3.0),順番(2.0),普及(2.0),ふざける(2.0),運転(2.0),確約(2.0), probability:0.062
# ------------------------------------------------------------------
# 0:考え方を切り替えるて、運転免許証（運転経歴証明書）に*の機能をつけるばいいのに。
# node_id:210, node_words:支持(5.0),上がる(3.0),付け(3.0),公的(3.0),絶対(3.0),順番(2.0),普及(2.0),ふざける(2.0),運転(2.0),確約(2.0), probability:0.06
# 1:*
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.0
# 2:もちろん非保持者は*を*として使うば良い。
# node_id:786, node_words:義務(5.0),保持(3.0),続出(3.0),実質(2.0),強引(1.0),漏えい(1.0),法律(1.0),幼稚園(1.0),得る(1.0),切り替える(1.0), probability:0.06
# 3:*運転免許証保持者限定ですが、実務上長らく*カードとして通用するておる、転居するても最寄りの警察で簡単に処理するてもらえる。
# node_id:786, node_words:義務(5.0),保持(3.0),続出(3.0),実質(2.0),強引(1.0),漏えい(1.0),法律(1.0),幼稚園(1.0),得る(1.0),切り替える(1.0), probability:0.14
# 4:*保持者にとっては一番便利ですよ。
# node_id:786, node_words:義務(5.0),保持(3.0),続出(3.0),実質(2.0),強引(1.0),漏えい(1.0),法律(1.0),幼稚園(1.0),得る(1.0),切り替える(1.0), probability:0.06
# ------------------------------------------------------------------
# 0:*の普及のために保険証を廃止する更に運転免許証を廃止するとは手段と目的を取り違えるている。
# node_id:55, node_words:普及(15.0),ここ(5.0),ポイント(5.0),メリット(4.0),やり方(3.0),いやらしい(2.0),なくす(2.0),考え(2.0),外堀(2.0),抜け道(2.0), probability:0.127
# 1:**を持つことにメリットがあるば自然と普及するが、ポイントを付与するという飴をぶら下げるたり、それでもだめだ強制的に保険証や免許証を取り上げるぞと脅すをかける。
# node_id:55, node_words:普及(15.0),ここ(5.0),ポイント(5.0),メリット(4.0),やり方(3.0),いやらしい(2.0),なくす(2.0),考え(2.0),外堀(2.0),抜け道(2.0), probability:0.254
# 2:*そこまでやるないと普及するない*は必要だうか。
# node_id:55, node_words:普及(15.0),ここ(5.0),ポイント(5.0),メリット(4.0),やり方(3.0),いやらしい(2.0),なくす(2.0),考え(2.0),外堀(2.0),抜け道(2.0), probability:0.127
# 3:*市場経済ではメリットがないものはいずれ淘汰するれる。
# node_id:55, node_words:普及(15.0),ここ(5.0),ポイント(5.0),メリット(4.0),やり方(3.0),いやらしい(2.0),なくす(2.0),考え(2.0),外堀(2.0),抜け道(2.0), probability:0.051
# 4:*既にポイントをもらうた人は*は家の引き出しにしまうれるているだうし、保険証や運転免許証も抜け道があるばみんな抜け道に殺到するだう。
# node_id:55, node_words:普及(15.0),ここ(5.0),ポイント(5.0),メリット(4.0),やり方(3.0),いやらしい(2.0),なくす(2.0),考え(2.0),外堀(2.0),抜け道(2.0), probability:0.083
# 5:*困るのは既にシステムが確立するているのに新ただ対応を迫るれる医療機関や警察署だ。
# node_id:879, node_words:機器(4.0),有効(2.0),機関(2.0),配備(2.0),於く(2.0),医療(2.0),作業(2.0),存在(1.0),歓迎(1.0),重要(1.0), probability:0.138
# 6:そこに莫大だ無駄だお金が必要になる。
# node_id:880, node_words:効率(5.0),行政(3.0),徴収(3.0),本来(3.0),消える(1.0),豪語(1.0),ベール(1.0),身分(1.0),威力(1.0),ばらまく(1.0), probability:0.019
# 7:*常時使う保険証や運転免許証と普段は使うないけど無くすと困る*を一体化するというのは発想が貧困すぎる。
# node_id:797, node_words:無くす(7.0),期限(3.0),前提(2.0),ただ(2.0),可能(2.0),イン(1.0),返納(1.0),縛る(1.0),投げる(1.0),利く(1.0), probability:0.14
# ------------------------------------------------------------------
# 0:日本は世界的にも少子化が著しい進行するておる、まもなくアナログ対応では日常生活が対応できるないなる事は明らかです。
# node_id:533, node_words:デジタル(12.0),対応(6.0),世界(5.0),企業(4.0),状態(4.0),日本(4.0),必須(3.0),優先(3.0),言える(3.0),大事(3.0), probability:0.138
# 1:*従ってデジタル化は必須だ、全てが処理可能だ*は必須です。
# node_id:533, node_words:デジタル(12.0),対応(6.0),世界(5.0),企業(4.0),状態(4.0),日本(4.0),必須(3.0),優先(3.0),言える(3.0),大事(3.0), probability:0.102
# 2:*
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.0
# 3:今起こるている*の問題点はアナログ対応からデジタル化に移行する時に必ず起こるアナログ人間によるミスです。
# node_id:533, node_words:デジタル(12.0),対応(6.0),世界(5.0),企業(4.0),状態(4.0),日本(4.0),必須(3.0),優先(3.0),言える(3.0),大事(3.0), probability:0.14
# 4:これを否定するばデジタル化は不可能だ、*年もするば日本の行政はパンクする、日常生活が困難に直面する事は明白です。
# node_id:533, node_words:デジタル(12.0),対応(6.0),世界(5.0),企業(4.0),状態(4.0),日本(4.0),必須(3.0),優先(3.0),言える(3.0),大事(3.0), probability:0.12
# 5:*世界でデジタル化が最も遅れるている国の一つの日本は、まず追いつく事を優先するますう。
# node_id:533, node_words:デジタル(12.0),対応(6.0),世界(5.0),企業(4.0),状態(4.0),日本(4.0),必須(3.0),優先(3.0),言える(3.0),大事(3.0), probability:0.131
# 6:どんな仕組みも最初から最善だた事例は人類史にあるますん。
# node_id:870, node_words:記録(2.0),仕組み(2.0),特定(1.0),引き渡し(1.0),明確(1.0),給付(1.0),規格(1.0),印鑑(1.0),税理士(1.0),見せる(1.0), probability:0.083
# 7:継続的改善でより良いシステムにするていくますう。
# node_id:81, node_words:コピー(6.0),公的(6.0),認証(4.0),計画(4.0),やり方(3.0),対面(3.0),確認(3.0),思う(3.0),保管(2.0),時代(2.0), probability:0.011
# ------------------------------------------------------------------
# 0:未だに平成表記の運転免許証を所持するているのだが、このまま行くと最後の運転免許証所持者になるてしまうのかもしれるないな。
# node_id:830, node_words:所持(2.0),信じる(2.0),受診(1.0),しれる(1.0),れる(1.0),届け(1.0),必死(1.0),譲る(1.0),タバコ(1.0),釣る(1.0), probability:0.188
# 1:でもなぁ。
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.0
# 2:*はマスターキーみたいだものだ、普段持ち歩くものだはない気がするます。
# node_id:453, node_words:仕方(3.0),解決(2.0),ケース(2.0),愚策(2.0),止める(2.0),指摘(2.0),無理(2.0),ウクライナ(1.0),為る(1.0),供与(1.0), probability:0.043
# 3:*利便性とセキュリティは相反するものですので、どこでバランスするせるかを個人が選択できるようだシステムだというのになぁ。
# node_id:830, node_words:所持(2.0),信じる(2.0),受診(1.0),しれる(1.0),れる(1.0),届け(1.0),必死(1.0),譲る(1.0),タバコ(1.0),釣る(1.0), probability:0.1
# ------------------------------------------------------------------
# 0:春に厚木基地に行くますたが、免許証だけだは入れるないたようです。
# node_id:881, node_words:船舶(2.0),基地(2.0),貴方(2.0),それ(1.0),血税(1.0),厚木(1.0),沈没(1.0),横田(1.0),国政(1.0),始動(1.0), probability:0.176
# 1:*パスポートなり*だ*ですた。
# node_id:453, node_words:仕方(3.0),解決(2.0),ケース(2.0),愚策(2.0),止める(2.0),指摘(2.0),無理(2.0),ウクライナ(1.0),為る(1.0),供与(1.0), probability:0.043
# 2:*横田基地は免許証でも入れるますたけど。
# node_id:881, node_words:船舶(2.0),基地(2.0),貴方(2.0),それ(1.0),血税(1.0),厚木(1.0),沈没(1.0),横田(1.0),国政(1.0),始動(1.0), probability:0.176
# 3:*恐らくですが免許証は偽造するやすいんですう。
# node_id:13, node_words:銀行(22.0),口座(19.0),携帯(14.0),開設(8.0),電話(7.0),本人(7.0),契約(6.0),ライセンス(3.0),作る(3.0),見え(2.0), probability:0.005
# 4:*
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.0
# 5:ただ、免許証も一本化するだ即日発行はするてもらうたい。
# node_id:8, node_words:発行(27.0),紛失(12.0),場合(10.0),かかる(7.0),そう(6.0),週間(5.0),大変(5.0),病院(5.0),申請(5.0),万が一(5.0), probability:0.114
# ------------------------------------------------------------------
# 0:一つにするというメリットもあるんだうけど。
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.034
# 1:**纏めるリスクの方が勝つているように思える。**
# node_id:872, node_words:思える(2.0),年寄り(2.0),確率(2.0),纏める(2.0),勝つ(1.0),どこ(1.0),圧力(1.0),悪党(1.0),起こる(1.0),無言(1.0), probability:0.19
# 2:紛失というリスクは誰でもあることに対して、纏めるた後に*箇所で全て再発行できるのだうか。
# node_id:8, node_words:発行(27.0),紛失(12.0),場合(10.0),かかる(7.0),そう(6.0),週間(5.0),大変(5.0),病院(5.0),申請(5.0),万が一(5.0), probability:0.182
# 3:極端に*時間対応するてくれるのかな？**
# node_id:16, node_words:補完(4.0),検討(2.0),有益(2.0),速やか(2.0),保持(2.0),保存(2.0),時差(2.0),読み取り(2.0),対応(2.0),持ち運び(2.0), probability:0.057
# 4:無理に進めるぬともいいように思える事が、*政府は起こる得るリスク把握するぬに進めるうとすることがリスクだな、これ。
# node_id:872, node_words:思える(2.0),年寄り(2.0),確率(2.0),纏める(2.0),勝つ(1.0),どこ(1.0),圧力(1.0),悪党(1.0),起こる(1.0),無言(1.0), probability:0.143
# ------------------------------------------------------------------
# 0:問題が多発するているのに、ここまで強引に拙速にカードに集約するたいのは国民の為と言うより、カード関連業者との癒着そして国の管理強化の為と言うぬを得るない。
# node_id:786, node_words:義務(5.0),保持(3.0),続出(3.0),実質(2.0),強引(1.0),漏えい(1.0),法律(1.0),幼稚園(1.0),得る(1.0),切り替える(1.0), probability:0.08
# 1:*
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.0
# 2:もし違うと言うだ法的には任意のカードを姑息だ手段で実質義務化にするないで、正面から国民に理由を丁寧に説明する法律的に義務化するて下さる。
# node_id:786, node_words:義務(5.0),保持(3.0),続出(3.0),実質(2.0),強引(1.0),漏えい(1.0),法律(1.0),幼稚園(1.0),得る(1.0),切り替える(1.0), probability:0.309
# ------------------------------------------------------------------
# 0:カードの取得を義務づけるばシンプルだ分かるやすいのに、反対派の説得に自信がないたり、選挙に影響するから出来るないのかな。
# node_id:786, node_words:義務(5.0),保持(3.0),続出(3.0),実質(2.0),強引(1.0),漏えい(1.0),法律(1.0),幼稚園(1.0),得る(1.0),切り替える(1.0), probability:0.1
# 1:*義務だないものを取得するないと生活が成り立つないする。
# node_id:786, node_words:義務(5.0),保持(3.0),続出(3.0),実質(2.0),強引(1.0),漏えい(1.0),法律(1.0),幼稚園(1.0),得る(1.0),切り替える(1.0), probability:0.1
# 2:*政策の矛盾としか言えるますん。
# node_id:802, node_words:整備(5.0),政策(4.0),整える(3.0),インフラ(2.0),選択肢(2.0),いま(2.0),対策(2.0),クビ(2.0),しな(2.0),得る(2.0), probability:0.049
# 3:**公平ということを口実にするてシステムを複雑にするて、使うためには相当だ勉強が必要になる、結局使える人と使えるない人が出るてくるて不公平になる。
# node_id:858, node_words:逮捕(2.0),守る(2.0),公平(2.0),民間(1.0),民営(1.0),お上(1.0),手続(1.0),民放(1.0),利権(1.0),取得(1.0), probability:0.091
# 4:*そんなシステムばかりじゃないですか、この国は。
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.0
# 5:**も、公平性や個人情報を守るうとすると、複雑だ手続や届出などが必要だ、しかもそういうことができることを積極的に国民に知らせるぬ、一部の人しか権利を享受できるないものになるている。
# node_id:858, node_words:逮捕(2.0),守る(2.0),公平(2.0),民間(1.0),民営(1.0),お上(1.0),手続(1.0),民放(1.0),利権(1.0),取得(1.0), probability:0.094
# 6:*
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.0
# 7:いつものパターンが繰り返すれるのだはないですうか。
# node_id:830, node_words:所持(2.0),信じる(2.0),受診(1.0),しれる(1.0),れる(1.0),届け(1.0),必死(1.0),譲る(1.0),タバコ(1.0),釣る(1.0), probability:0.033
# 8:*
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.0
# 9:その最悪だシステムが構築するれるそうですね。
# node_id:868, node_words:コード(6.0),基本(5.0),単純(2.0),構築(2.0),ヒューマン(1.0),暗号(1.0),迷走(1.0),よう(1.0),裏面(1.0),誘導(1.0), probability:0.039
# ------------------------------------------------------------------
# 0:現状の*の記載は名前や住所に生年月日に個人番号といった固定情報の記載のみで『免許証情報の記載箇所』は存在するているない。
# node_id:2, node_words:番号(14.0),暗証(13.0),役所(8.0),記載(4.0),間違える(4.0),住所(3.0),設定(3.0),意識(3.0),交付(3.0),誕生(3.0), probability:0.17
# 1:***は『デジタル管理が前提』にある、万一、天災停電があるた際に電気を使う、通信を必要とする認証機器が使えるない状態で『どうやるて免許証対応』するのか。
# node_id:879, node_words:機器(4.0),有効(2.0),機関(2.0),配備(2.0),於く(2.0),医療(2.0),作業(2.0),存在(1.0),歓迎(1.0),重要(1.0), probability:0.138
# 2:**
# ...
# 2:*
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.0
# 3:今まで何か失くいても身分証明として免許証が当たり前だのに免許証も一体化するて*無くすたどうするの？
# node_id:5, node_words:身分(8.0),おかしい(8.0),無い(6.0),証明(6.0),付け(5.0),忘れる(4.0),落とす(3.0),認める(3.0),負う(3.0),当たり前(2.0), probability:0.143
# 4:*リスクを何も考えるてるない利権まみれの見切り発車だ？
# node_id:20, node_words:判断(5.0),おかしい(4.0),支持(4.0),発車(4.0),認証(4.0),利権(4.0),見切り(4.0),滅茶苦茶(3.0),存在(2.0),主義(2.0), probability:0.102
# 5:*
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.0
# 6:もう次勝てるないから滅茶苦茶やるて次の政権の足引っ張るつもりだの丸わかるだ？
# node_id:12, node_words:選挙(23.0),自民党(20.0),政権(17.0),与党(10.0),公明党(7.0),政治(7.0),たち(7.0),投票(6.0),潰す(4.0),行く(4.0), probability:0.052
# 7:*どこまで腐るてんだ自民党は？
# node_id:12, node_words:選挙(23.0),自民党(20.0),政権(17.0),与党(10.0),公明党(7.0),政治(7.0),たち(7.0),投票(6.0),潰す(4.0),行く(4.0), probability:0.068
# ------------------------------------------------------------------
# 0:こんなトラブルだらけだのに免許証までとか頭
# node_id:20, node_words:判断(5.0),おかしい(4.0),支持(4.0),発車(4.0),認証(4.0),利権(4.0),見切り(4.0),滅茶苦茶(3.0),存在(2.0),主義(2.0), probability:0.017
# 1:おかしいだ？
# node_id:5, node_words:身分(8.0),おかしい(8.0),無い(6.0),証明(6.0),付け(5.0),忘れる(4.0),落とす(3.0),認める(3.0),負う(3.0),当たり前(2.0), probability:0.071
# 2:*
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.0
# 3:今まで何か失くいても身分証明として免許証が当たり前だのに免許証も一体化するて*無くすたどうするの？
# node_id:5, node_words:身分(8.0),おかしい(8.0),無い(6.0),証明(6.0),付け(5.0),忘れる(4.0),落とす(3.0),認める(3.0),負う(3.0),当たり前(2.0), probability:0.143
# 4:*リスクを何も考えるてるない利権まみれの見切り発車だ？
# node_id:20, node_words:判断(5.0),おかしい(4.0),支持(4.0),発車(4.0),認証(4.0),利権(4.0),見切り(4.0),滅茶苦茶(3.0),存在(2.0),主義(2.0), probability:0.102
# 5:*
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.0
# 6:もう次勝てるないから滅茶苦茶やるて次の政権の足引っ張るつもりだの丸わかるだ？
# node_id:12, node_words:選挙(23.0),自民党(20.0),政権(17.0),与党(10.0),公明党(7.0),政治(7.0),たち(7.0),投票(6.0),潰す(4.0),行く(4.0), probability:0.052
# 7:*どこまで腐るてんだ自民党は？
# node_id:12, node_words:選挙(23.0),自民党(20.0),政権(17.0),与党(10.0),公明党(7.0),政治(7.0),たち(7.0),投票(6.0),潰す(4.0),行く(4.0), probability:0.068
# ------------------------------------------------------------------
# 0:いい加減にするないては何処かの国からの不正アクセスだけで国が終わるね。
# node_id:103, node_words:フォン(6.0),スマート(6.0),モバイル(5.0),不正(3.0),搭載(2.0),総理(1.0),早い(1.0),大元(1.0),大事(1.0),コピー(1.0), probability:0.062
# 1:*
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.0
# 2:この国の*いる*技術では国中の土地が某国の物になるているても対処できるないだう。
# node_id:817, node_words:無能(5.0),民主(3.0),主義(3.0),三流(2.0),原因(2.0),行う(2.0),ビジネスマン(2.0),二流(2.0),それ(2.0),行為(2.0), probability:0.062
# 3:*正に今の政府の連中は売国奴さ。
# node_id:876, node_words:庶民(2.0),芋づる(2.0),加入(1.0),不幸(1.0),悪い(1.0),プラス(1.0),無茶苦茶(1.0),突き進む(1.0),現在(1.0),決まる(1.0), probability:0.032
# 4:ひょっとしたら分かるてやるてるんじゃないの*
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.0
# ------------------------------------------------------------------
# 0:*持つてるないと口座も開けるない携帯の契約もできるないって？
# node_id:13, node_words:銀行(22.0),口座(19.0),携帯(14.0),開設(8.0),電話(7.0),本人(7.0),契約(6.0),ライセンス(3.0),作る(3.0),見え(2.0), probability:0.18
# 1:*は任意だしかも運転免許証より遥かに本人確認の信用度が低いのは日本国民みんな知るてるのに？
# node_id:3, node_words:信用(13.0),公安(4.0),管轄(4.0),お前(3.0),やり方(3.0),一切(3.0),実質(3.0),横行(3.0),取り扱い(3.0),渡す(2.0), probability:0.132
# 2:アホちゃうか？
# node_id:116, node_words:中国(6.0),好き(2.0),狂気(2.0),恐い(2.0),移住(2.0),すぎ(2.0),沙汰(2.0),いとこ(2.0),真似(2.0),一族(2.0), probability:0.025
# ------------------------------------------------------------------
# 0:「政府の動向が注視するれるます」
# node_id:858, node_words:逮捕(2.0),守る(2.0),公平(2.0),民間(1.0),民営(1.0),お上(1.0),手続(1.0),民放(1.0),利権(1.0),取得(1.0), probability:0.038
# 1:*マスコミが政府広報に成り下がるたことを自身さえ感じるているない。
# node_id:858, node_words:逮捕(2.0),守る(2.0),公平(2.0),民間(1.0),民営(1.0),お上(1.0),手続(1.0),民放(1.0),利権(1.0),取得(1.0), probability:0.019
# 2:*お上のするれるままで結構が江戸時代からの日本国民に刻むれるた*。
# node_id:871, node_words:中身(1.0),脅迫(1.0),暴走(1.0),決定(1.0),チンピラ(1.0),施策(1.0),改正(1.0),よい(1.0),崩壊(1.0),差し出す(1.0), probability:0.04
# ------------------------------------------------------------------
# 0:普通に考えるて逆だ！
# node_id:55, node_words:普及(15.0),ここ(5.0),ポイント(5.0),メリット(4.0),やり方(3.0),いやらしい(2.0),なくす(2.0),考え(2.0),外堀(2.0),抜け道(2.0), probability:0.017
# 1:*免許持つてる人はその免許証にマイナンバーを勝手にくっつけるいいだうが！
# node_id:859, node_words:考え直す(1.0),内容(1.0),退職(1.0),反旗(1.0),チェック(1.0),返納(1.0),利権(1.0),検挙(1.0),日本国(1.0),ぶる(1.0), probability:0.034
# 2:*マイナンバーがどこの管轄か知るねーけど、国交省より上の省だんだ！
# node_id:872, node_words:思える(2.0),年寄り(2.0),確率(2.0),纏める(2.0),勝つ(1.0),どこ(1.0),圧力(1.0),悪党(1.0),起こる(1.0),無言(1.0), probability:0.048
# 3:*役人の上下関係を国民に押し付けるんじゃねーよ、お前らの都合で国民に不便だ生活をするせるな。
# node_id:871, node_words:中身(1.0),脅迫(1.0),暴走(1.0),決定(1.0),チンピラ(1.0),施策(1.0),改正(1.0),よい(1.0),崩壊(1.0),差し出す(1.0), probability:0.115
# 4:*
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.0
# 5:そもそもお前らなんかより、お前らに給料くれるてやるてる国民が１番大事だんじゃねーのか、なにを偉いそうに好き勝手やるてんだよ、いい加減にする！
# node_id:116, node_words:中国(6.0),好き(2.0),狂気(2.0),恐い(2.0),移住(2.0),すぎ(2.0),沙汰(2.0),いとこ(2.0),真似(2.0),一族(2.0), probability:0.098
# ------------------------------------------------------------------
# 0:マイナンバー導入の動機が不純すぎるから、嫌になるます。
# node_id:116, node_words:中国(6.0),好き(2.0),狂気(2.0),恐い(2.0),移住(2.0),すぎ(2.0),沙汰(2.0),いとこ(2.0),真似(2.0),一族(2.0), probability:0.05
# 1:*
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.0
# 2:余計だ仕事を辞める増やすて、公務員とそれに紐づく税金泥棒を増やすたいだけ。
# node_id:651, node_words:税金(5.0),でる(4.0),今後(4.0),余計(3.0),増やす(3.0),納める(3.0),手間(3.0),かける(3.0),盗む(3.0),作れる(2.0), probability:0.088
# ------------------------------------------------------------------
# 0:まあ国家がアメリカ様に（べつの先にかわるてるかもしれるますんが）
# node_id:791, node_words:国家(2.0),出る(2.0),事実(2.0),分かる(2.0),日本(2.0),成立(2.0),メリット(2.0),気付く(2.0),関係(2.0),被害(2.0), probability:0.022
# 1:*お国の情報すべて提供するための貢物が*情報だので*カード*％普及が必要だのですよ
# node_id:55, node_words:普及(15.0),ここ(5.0),ポイント(5.0),メリット(4.0),やり方(3.0),いやらしい(2.0),なくす(2.0),考え(2.0),外堀(2.0),抜け道(2.0), probability:0.127
# 2:*家畜整理カードが*
# node_id:453, node_words:仕方(3.0),解決(2.0),ケース(2.0),愚策(2.0),止める(2.0),指摘(2.0),無理(2.0),ウクライナ(1.0),為る(1.0),供与(1.0), probability:0.062
# ------------------------------------------------------------------
# 0:紛失するた時のリスクが大きいすぎる*考えるた人達は、リスク管理能力が無いと思うよ！
# node_id:8, node_words:発行(27.0),紛失(12.0),場合(10.0),かかる(7.0),そう(6.0),週間(5.0),大変(5.0),病院(5.0),申請(5.0),万が一(5.0), probability:0.092
# 1:*原発は絶対安全って言うてるたのと同じだ、問題が発生するた想定外とでも言うのか？
# node_id:210, node_words:支持(5.0),上がる(3.0),付け(3.0),公的(3.0),絶対(3.0),順番(2.0),普及(2.0),ふざける(2.0),運転(2.0),確約(2.0), probability:0.049
# 2:アホとしか思えるますんねぇ！
# node_id:116, node_words:中国(6.0),好き(2.0),狂気(2.0),恐い(2.0),移住(2.0),すぎ(2.0),沙汰(2.0),いとこ(2.0),真似(2.0),一族(2.0), probability:0.025
# ------------------------------------------------------------------
# 0:免許更新も役所でやるてくれるのかよ？
# node_id:764, node_words:更新(24.0),ゴールド(4.0),即日(3.0),読み取り(2.0),検査(2.0),いく(2.0),こっち(2.0),手間(2.0),装置(2.0),政権(2.0), probability:0.255
# 1:岸田は頭が悪すぎ。
# node_id:116, node_words:中国(6.0),好き(2.0),狂気(2.0),恐い(2.0),移住(2.0),すぎ(2.0),沙汰(2.0),いとこ(2.0),真似(2.0),一族(2.0), probability:0.05
# 2:何故中国の悪いとこだけ真似する。
# node_id:116, node_words:中国(6.0),好き(2.0),狂気(2.0),恐い(2.0),移住(2.0),すぎ(2.0),沙汰(2.0),いとこ(2.0),真似(2.0),一族(2.0), probability:0.25
# 3:そんなに中国好きだ、老害二階と一緒に一族で中国に移住するよ！
# node_id:116, node_words:中国(6.0),好き(2.0),狂気(2.0),恐い(2.0),移住(2.0),すぎ(2.0),沙汰(2.0),いとこ(2.0),真似(2.0),一族(2.0), probability:0.457
# ------------------------------------------------------------------
# 0:免許更新も役所でやるてくれるのかよ？
# node_id:764, node_words:更新(24.0),ゴールド(4.0),即日(3.0),読み取り(2.0),検査(2.0),いく(2.0),こっち(2.0),手間(2.0),装置(2.0),政権(2.0), probability:0.255
# 1:岸田は頭が悪すぎ。
# node_id:116, node_words:中国(6.0),好き(2.0),狂気(2.0),恐い(2.0),移住(2.0),すぎ(2.0),沙汰(2.0),いとこ(2.0),真似(2.0),一族(2.0), probability:0.05
# 2:何故中国の悪いとこだけ真似する。
# node_id:116, node_words:中国(6.0),好き(2.0),狂気(2.0),恐い(2.0),移住(2.0),すぎ(2.0),沙汰(2.0),いとこ(2.0),真似(2.0),一族(2.0), probability:0.25
# 3:そんなに中国好きだ、老害二階と一緒に一族で中国に移住するよ！
# node_id:116, node_words:中国(6.0),好き(2.0),狂気(2.0),恐い(2.0),移住(2.0),すぎ(2.0),沙汰(2.0),いとこ(2.0),真似(2.0),一族(2.0), probability:0.457
# ------------------------------------------------------------------
# 0:本当に何の責任も負うぬに、自分たちのやるたい事だけ勝手に押し付けるていくというつもりだな。
# node_id:857, node_words:いく(3.0),結果(2.0),マジ(2.0),注ぐ(2.0),どこ(2.0),腐る(2.0),見える(2.0),役立つ(2.0),本来(2.0),購入(1.0), probability:0.071
# 1:*国が滅びるようが国民が死に絶えるうが、今やるたい事をやるたい放題に強制する。
# node_id:851, node_words:ヒューマン(5.0),エラー(5.0),連携(3.0),今度(2.0),すぎ(1.0),押し付ける(1.0),浮かぶ(1.0),たらい(1.0),漢字(1.0),入力(1.0), probability:0.062
# 2:**ら終わるてる。
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.0
# ------------------------------------------------------------------
# 0:そりゃ国はないも責任取るないって言うてるから、気楽に紐付けすせるけ自由に管理するよ。
# node_id:5, node_words:身分(8.0),おかしい(8.0),無い(6.0),証明(6.0),付け(5.0),忘れる(4.0),落とす(3.0),認める(3.0),負う(3.0),当たり前(2.0), probability:0.045
# 1:都合が悪いなるた消えるばいいんだから。
# node_id:853, node_words:リーダー(2.0),携帯(2.0),起きる(2.0),歓迎(2.0),いける(2.0),財布(1.0),疲れる(1.0),障害(1.0),大丈夫(1.0),今度(1.0), probability:0.026
# ------------------------------------------------------------------
# 0:まったくもつてアホの極みだね*運転免許で本人確認ができるないって事は運転免許自体が偽物だんだよね？
# node_id:858, node_words:逮捕(2.0),守る(2.0),公平(2.0),民間(1.0),民営(1.0),お上(1.0),手続(1.0),民放(1.0),利権(1.0),取得(1.0), probability:0.057
# 1:*だ、警察は免許みるても意味がないですよね？
# node_id:794, node_words:端末(6.0),身分(4.0),警察(3.0),お巡りさん(3.0),住所(3.0),チェック(3.0),写真(3.0),搭載(2.0),契約(2.0),サービス(2.0), probability:0.023
# ------------------------------------------------------------------
# 0:保険証も含めるて現行制度で誰も困るているないのにわざわざ弄る辺りが無能の極み。
# node_id:817, node_words:無能(5.0),民主(3.0),主義(3.0),三流(2.0),原因(2.0),行う(2.0),ビジネスマン(2.0),二流(2.0),それ(2.0),行為(2.0), probability:0.052
# 1:*
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.0
# 2:この事業の推進に関わるた人間は全てクビにするてもらうたい。
# node_id:864, node_words:当たり前(2.0),世の中(2.0),官僚(1.0),大量(1.0),抗議(1.0),比較(1.0),事件(1.0),爆発(1.0),セキュリティ(1.0),歩き(1.0), probability:0.05
# ------------------------------------------------------------------
# 0:顔写真がない＝*国人や第三者が他人のカードを使うて通院するたり車を運転するてるても本人だのかどうか確認できるない・・・。
# node_id:872, node_words:思える(2.0),年寄り(2.0),確率(2.0),纏める(2.0),勝つ(1.0),どこ(1.0),圧力(1.0),悪党(1.0),起こる(1.0),無言(1.0), probability:0.048
# 1:**最初からそれが狙いだんですか？
# node_id:881, node_words:船舶(2.0),基地(2.0),貴方(2.0),それ(1.0),血税(1.0),厚木(1.0),沈没(1.0),横田(1.0),国政(1.0),始動(1.0), probability:0.059
# ------------------------------------------------------------------
# 0:一体化は素晴らしいじゃないか**
# node_id:870, node_words:記録(2.0),仕組み(2.0),特定(1.0),引き渡し(1.0),明確(1.0),給付(1.0),規格(1.0),印鑑(1.0),税理士(1.0),見せる(1.0), probability:0.042
# 1:反対するてる奴は日本人じゃないだ？
# node_id:825, node_words:反発(5.0),日本人(4.0),選挙(4.0),移行(3.0),怒り(3.0),強行(3.0),自公(2.0),独裁(2.0),自民党(2.0),日本(2.0), probability:0.065
# 2:*
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.0
# 3:そんなに通名が嫌だ自国に帰るたどうですか？
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.0
# ------------------------------------------------------------------
# 0:なんか面倒になるてくるたなー
# node_id:797, node_words:無くす(7.0),期限(3.0),前提(2.0),ただ(2.0),可能(2.0),イン(1.0),返納(1.0),縛る(1.0),投げる(1.0),利く(1.0), probability:0.02
# 1:*いっそうの事出生するたマイクロチップ埋めるた？
# node_id:850, node_words:埋め込む(5.0),チップ(5.0),マイクロ(3.0),落とす(3.0),一体(3.0),高い(2.0),めちゃくちゃ(2.0),掛かる(2.0),人体(2.0),分かる(2.0), probability:0.127
# 2:*　バカだ政治家が行う失政に嫌でも付くあわに*。
# node_id:802, node_words:整備(5.0),政策(4.0),整える(3.0),インフラ(2.0),選択肢(2.0),いま(2.0),対策(2.0),クビ(2.0),しな(2.0),得る(2.0), probability:0.037
# ------------------------------------------------------------------
# 0:リスクは分散するって言葉を*に何から何まで紐付けるうとするてる人は知るないのかな。
# node_id:210, node_words:支持(5.0),上がる(3.0),付け(3.0),公的(3.0),絶対(3.0),順番(2.0),普及(2.0),ふざける(2.0),運転(2.0),確約(2.0), probability:0.062
# 1:馬鹿だのかな。
# node_id:651, node_words:税金(5.0),でる(4.0),今後(4.0),余計(3.0),増やす(3.0),納める(3.0),手間(3.0),かける(3.0),盗む(3.0),作れる(2.0), probability:0.009
# ------------------------------------------------------------------
# 0:一片の言葉尻を拡大解釈する、思い込む、決めつける、大騒ぎするて、それにそ*だそ*だと祭りのごとしノリまくるのが*。
# node_id:877, node_words:背番号(3.0),狂う(2.0),オレ(2.0),組織(2.0),拡大(1.0),まくる(1.0),過去(1.0),自分(1.0),いや(1.0),接待(1.0), probability:0.14
# ------------------------------------------------------------------
# 0:もう、狂うてるね。
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.0
# 1:自分たちが何をやるているのかさえ判断できるないなるてるのですう。
# node_id:20, node_words:判断(5.0),おかしい(4.0),支持(4.0),発車(4.0),認証(4.0),利権(4.0),見切り(4.0),滅茶苦茶(3.0),存在(2.0),主義(2.0), probability:0.042
# 2:ま、それもこれも、そういう*に投票するたオレの責任だんだけどね、オレの。
# node_id:877, node_words:背番号(3.0),狂う(2.0),オレ(2.0),組織(2.0),拡大(1.0),まくる(1.0),過去(1.0),自分(1.0),いや(1.0),接待(1.0), probability:0.089
# ------------------------------------------------------------------
# 0:無理です。
# node_id:453, node_words:仕方(3.0),解決(2.0),ケース(2.0),愚策(2.0),止める(2.0),指摘(2.0),無理(2.0),ウクライナ(1.0),為る(1.0),供与(1.0), probability:0.043
# 1:**に搭載なんて、*年経つてもできるそうにないし。
# node_id:103, node_words:フォン(6.0),スマート(6.0),モバイル(5.0),不正(3.0),搭載(2.0),総理(1.0),早い(1.0),大元(1.0),大事(1.0),コピー(1.0), probability:0.042
# 2:*
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.0
# 3:もういい加減、諦めるなさるよ。
# node_id:853, node_words:リーダー(2.0),携帯(2.0),起きる(2.0),歓迎(2.0),いける(2.0),財布(1.0),疲れる(1.0),障害(1.0),大丈夫(1.0),今度(1.0), probability:0.026
# 4:*能力ないんだから。
# node_id:791, node_words:国家(2.0),出る(2.0),事実(2.0),分かる(2.0),日本(2.0),成立(2.0),メリット(2.0),気付く(2.0),関係(2.0),被害(2.0), probability:0.011
# ------------------------------------------------------------------
# 0:ワクチン打つなさる。
# node_id:116, node_words:中国(6.0),好き(2.0),狂気(2.0),恐い(2.0),移住(2.0),すぎ(2.0),沙汰(2.0),いとこ(2.0),真似(2.0),一族(2.0), probability:0.025
# 1:コオロギ食べるなさる。
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.0
# 2:マイクロチップ体に打ち込むなさる。
# node_id:850, node_words:埋め込む(5.0),チップ(5.0),マイクロ(3.0),落とす(3.0),一体(3.0),高い(2.0),めちゃくちゃ(2.0),掛かる(2.0),人体(2.0),分かる(2.0), probability:0.113
# 3:←これ真剣に考えるているから恐い。
# node_id:116, node_words:中国(6.0),好き(2.0),狂気(2.0),恐い(2.0),移住(2.0),すぎ(2.0),沙汰(2.0),いとこ(2.0),真似(2.0),一族(2.0), probability:0.05
# ------------------------------------------------------------------
# 0:役人や政治家って、バカだの？？
# node_id:834, node_words:議員(8.0),役人(4.0),値上がり(3.0),破綻(3.0),仕組み(2.0),給付(2.0),メリット(2.0),自体(2.0),合格(2.0),バッチ(2.0), probability:0.053
# 1:*市井の*の生活が解るないの？？
# node_id:876, node_words:庶民(2.0),芋づる(2.0),加入(1.0),不幸(1.0),悪い(1.0),プラス(1.0),無茶苦茶(1.0),突き進む(1.0),現在(1.0),決まる(1.0), probability:0.032
# 2:*
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.0
# 3:そんな奴らが制度設計するちゃダメです。
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.069
# ------------------------------------------------------------------
# 0:日本が中国化しとる…
# node_id:116, node_words:中国(6.0),好き(2.0),狂気(2.0),恐い(2.0),移住(2.0),すぎ(2.0),沙汰(2.0),いとこ(2.0),真似(2.0),一族(2.0), probability:0.175
# 1:*
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.0
# 2:まさか、憲法より上にアホ自民を位置付けるたりするんやな？
# node_id:116, node_words:中国(6.0),好き(2.0),狂気(2.0),恐い(2.0),移住(2.0),すぎ(2.0),沙汰(2.0),いとこ(2.0),真似(2.0),一族(2.0), probability:0.075
# 3:*あゝ、恐いロシア…
# node_id:116, node_words:中国(6.0),好き(2.0),狂気(2.0),恐い(2.0),移住(2.0),すぎ(2.0),沙汰(2.0),いとこ(2.0),真似(2.0),一族(2.0), probability:0.025
# 4:*
# node_id:854, node_words:最初(3.0),一つ(3.0),ダメ(3.0),まとめる(3.0),振り回す(3.0),くっつける(2.0),活用(2.0),様々(2.0),根源(2.0),ツール(2.0), probability:0.0
# 5:まさに、狂気の沙汰や。
# node_id:116, node_words:中国(6.0),好き(2.0),狂気(2.0),恐い(2.0),移住(2.0),すぎ(2.0),沙汰(2.0),いとこ(2.0),真似(2.0),一族(2.0), probability:0.1
# ------------------------------------------------------------------
# 0:河野、岸田お前たちの頭狂うているのだはないのか、これ以上馬鹿だ政策は止める、狂気の沙汰としか見えるないぞ。
# node_id:116, node_words:中国(6.0),好き(2.0),狂気(2.0),恐い(2.0),移住(2.0),すぎ(2.0),沙汰(2.0),いとこ(2.0),真似(2.0),一族(2.0), probability:0.125
# ------------------------------------------------------------------

# %%
expandHlda.print_topic_multi_document(comment_list=comment_list, corpus=comment_dataset.comment_list, topic_id=708)
# Out:
# No.1
# 「国民の非難轟轟のマイナ保険証に加えて運転免許証もマイナンバーに一本化するなんてとんでもない話しです。個人情報を集約したマイナンバーを常に形態しなければならない事は国民にとってリスクしかありません。そもそも欧州をはじめとする諸外国はマイナンバーを制度化して失敗し結局、廃止にシテイマス。それなのに何故、政府自民は強行するのか。そんなにマイナ制度をやりたければ、政府自民議員だけで導入して、社会実験として資産や収入、口座、保険証、運転免許証などあらゆる情報を一本化して国民に不正なカネの動きがないか目が届く制度にすれば良いと思います。」
# 0.927
# No.2
# 「運転免許や保険証とかの個人の情報をマイナンバーに集約するというのはそれはそれでわからんことはないんだけども、それを物理的なカードに集約してしまうってのは、紛失の際のリスクや暗証番号を間違えたときの再設定とかを考慮すると、むりやり進める必要はないけども、どうして突っ走るのかね、自民党は本当のあほうなのか？、ファザコン河野も民主のせいというならさっさとやめれ」
# 0.853
# No.3
# 「保険証や免許証をマイナンバーカードに集約したい人もいるし、集約したくない人もいる。だから、選択肢を増やして、それぞれの移行状況を見ながら、その割合で決めればいいのに、一気にやってしまおうと、選択の自由を強引に奪おうとするから反発される。自由民主党じゃなく、不自由非民主党じゃんか。」
# 0.847
# No.4
# 「オランダに駐在した時、オランダの運転免許証に書き換えした際に日本の運転免許証を取り上げられました。日本の運転免許証と交換したことになります。在オランダ日本大使館とオランダ政府との間で特別に日本の運転免許証を本人に返す約束ができていたので、数カ月後に戻ってきました。もし、マイナンバーカードが運転免許証を兼ねるとなれば、免許の記載事項が明記されていないので外国で用を足さない。記載されたとして、取り上げられて返却されないとなった場合、帰国した時、どうすればいいのでしょうかね？　外国の運転免許証でマイナンバーカードを発行してくれるのでしょうか？　今の政府はこのようなことまで考えていないでしょうね。」
# 0.729
# No.5
# 「あらゆる情報がマイナンバーカードに集約されて、そのうち犬猫みたいにマイクロチップが埋め込まれるようになるのでしょうね。体に埋め込まれたら常時携帯、紛失防止、個人とのひも付けも完璧です・・・」
# 0.624
# No.6
# 「何より強制的に移行することに反発は出るわな。これまでも様々な事案が強行されて来たが、ついには国民ひとりひとりを雁字搦めにすべく動いて来た。これまでにないほどの外国人の入国や誰の仕業かわからない犯罪の多発などを考慮すれば、身分証明として国民にマイナカードを持たせることは特に問題はないはずで、それに様々な「証」を付随させるのも効率的ではある。しかしながら「証」以外の個人情報を巻き込もうとしていることは明白だ。この動きに対し、おそらくは国民のなす術はないだろう。さて、どうしたもんかのう(笑)」
# 0.608
# No.7
# 「とにかく、保険証も、運転免許証もマイナンバーカードに集約しないでほしい。うっかりマイナンバーカードをなくしたり、盗まれたら最悪ですよ！」
# 0.53
# No.8
# 「体から離脱するモノに全てを集約するのは恐ろしい。こうなったら人体にICチップを埋め込むしかないだろう。」
# 0.469
# No.9
# 「一本化するのは良いことだがカードに集約するってのがセンスない結局アナログかい！ということいっそスマホに入れられるとかそういう感じにしてほしいね」
# 0.423
# No.10
# 「法案成立により、LGBTの人はマイナカードの通名記載が認められたようですが、LGBTの人だけなんでしょうか。在日外国人の方の通名記載も認められるようになるのでしょうか。」
# 0.354
# No.11
# 「免許には、色んな情報が乗っている。見られて困る情報とも思えないよね？？あのカード一枚に入れる必要はない。」
# 0.333
# No.12
# 「これは、危険な発想である。1枚のカードに重要情報を集約したり本人確認機能をそこだけに集約した場合、紛失リスクが途轍もなく大きい。そして、システム上の欠陥があるため、情報漏洩や誤登録、本人の誤認など大きな問題を抱える。認証機能も他人を認証したり不完全なシステムであることが発覚した。このまま進めれば大混乱は必至である。」
# 0.327
# No.13
# 「政府は運転免許証だろうが、紙の健康保険証とかを全部マイナンバーカードに集約しようとしている。これマジで絶対やっちゃいかん。もし紛失した場合のリスクの説明が全然できてない。しかも免許証だけで本人確認もできないとなれば火に油を注ぐ結果になるのは目に見えてる。政府はどこまで腐っとるねん。こんな役立たずのマイナンバーカードはいらない！」
# 0.283
# No.14
# 「政府は運転免許証だろうが、紙の健康保険証とかを全部マイナンバーカードに集約しようとしている。これマジで絶対やっちゃいかん。もし紛失した場合のリスクの説明が全然できてない。しかも免許証だけで本人確認もできないとなれば火に油を注ぐ結果になるのは目に見えてる。政府はどこまで腐っとるねん。こんな役立たずのマイナンバーカードはいらない！」
# 0.283
# No.15
# 「海外に住んでますけどマイナンバーは自動返納されました。運転免許証は出国前に更新したから使える状態ではあるけど、、一時帰国したら色々めんどくさそう。マイナンバー作らない人はどうしたらよいのかしら。」
# 0.277
# No.16
# 「保険証にしろ運転免許証にしろぱっと見で有効期限や何が乗れるかなどの情報がよくわかる。マイナンバーカードに集約したら全く分からない。車検証のデジタル化みたいに、デジタル化したら紙がもう1枚増えましたなんて馬鹿なことをやりますか？」
# 0.2
# No.17
# 「このまま自民党一党独裁政権を維持していくためには、国民の監視管理が必要不可欠。まあ国民なんてチョロいから２万円くらいポイントやっとけば、ホイホイ飛びついてマイナを作るだろうと考えていたんだろうけど、ここにきてネット情報などで、国民が気がつきはじめた。少し、政府側の考えが安易で甘かった。」
# 0.179
# No.18
# 「社会は絶対混乱するぞ。免許証も個人情報は記載されているが、比較にならないほど大量の情報を内包しているカードの持ち歩きを強制するんだな。日進月歩の世の中、セキュリティ事件が爆発的に増えるぞ。その政策を考えている官僚はどれだけ視野が狭いんだ？ヤバすぎるというレベルじゃないぞ。またホリエモンあたりが「そんなのあたりまえじゃん」みたいなコメントするんだろうけど、ホリエモンの当たり前＝世の中の当たり前じゃないぞ。」
# 0.168
# No.19
# 「現状のマイナカードの記載は名前や住所に生年月日に個人番号といった固定情報の記載のみで『免許証情報の記載箇所』は存在していない。マイナカードは『デジタル管理が前提』にあり、万一、天災停電があった際に電気を使い、通信を必要とする認証機器が使えない状態で『どうやって免許証対応』するのか。今の医療機関で事故や意識不明で搬送された患者は暗証番号が入力出来るとは限らず、そこでマイナ保険証の有効確認も、対応ガイドラインも確立していない中途半端な状態で免許証一体型は有り得ない。早かれ遅かれマイナカード一体型免許証になるかもしれない。けど今の役所の情報管理体制や情報漏洩、システム不具合といった様々な情報管理体制を整えて安定してから記事の免許証の話をして欲しい。まあ･･･免許証とマイナカード比較だと主に免許証番号と個人番号の掲載があるか否かの違いと、更新手続きする場所の違いだと思うが。」
# 0.165
# No.20
# 「銀行口座　証券口座　確定申告　　健保証・・・になんで免許証まで一緒にするのか、持ち歩きの免許証です紛失・盗難は必ずあると断言できる。プロに掛かれば中身が丸見えになるかも知れない、恐ろしいことです。人間の歴史が始まって以来ここまで個人情報を一枚のカードに集約＝時の政府・時の王様が個人情報を一括把握できたことは無いのです。時の権力者とは常に批判的に対するのが基本です、民主国家だから総てお任せで良いはあり得ない、とくに改ざん+隠ぺいの自公政権です止めてくれ。」
# 0.134
# No.21
# 「リスクは分散する事が肝要なこの時代に、あえて重要な情報を1つに集約する愚行は甚だ理解できません。マイナカードの機能が停止してしまったとき、我々はどうやって自分の身分を証明したらいいのでしょうか？偽造マイナカードの存在が否定できないのに、カードを「見る」だけで身分を確認できるのでしょうか？免許証にしろ保険証にしろ一目で機能が分かり、煩雑な確認作業はあまりありませんでした。マイナカードに集約してしまえば免許の有効区分や有効期限の確認にICカードリーダーが必要になり、警ら隊や交通取り締まり時の免許確認で余計な作業と機器にお金が必要になります。保険証に於いても既にICチップを読み込む機器が必要になっていますが、その機器はほとんどの医療機関に配備されておらず、配備されている医療機関に於いても機器の不具合やマイナカードの保険証登録に看過できないミスが発生しています。」
# 0.125
# No.22
# 「一つに集約するとあらゆるリスクに晒されそう。それ以前に、結局マイナカードは国が都道府県、都道府県から市町村に通知を出して、市町村が発行したりデータを管理したりしています。市町村のは自治体なんかは人手がそんなにいるわけでなく、情報の管理が難しいと思う。多分、マイナカードは世界一情報の管理が甘く、国民の個人情報はダダ漏れになり、不利益を被るのだろう。それに対し、政府は全く責任はとらなく、第二の消えた年金となる可能性が非常に高い。岸田政権は過去最高の税収でも増税したり、最悪の少子化促進対策をしたり、世界中に税金ばら撒いたり、官邸で家族親戚でどんちゃん騒ぎをして特別感を感じたりしているけど、どうして支持する人が居るのが不思議に思う。個人的に利益があるのだろうかな。」
# 0.065
