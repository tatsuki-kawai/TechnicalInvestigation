# %%
import sys
sys.path.append('../Data')

import pandas as pd
import numpy as np
import time
from CommentDataset import CommentDataset

comment_list_name = "20230627_mynumbercard_untenmenkyosyou"
comment_list_path = "2023_06_27/" + comment_list_name + ".csv"

# 指定すべき文字コードはファイルによる(cp932 or utf-8)
df = pd.read_csv("../Data/yahoo/"+comment_list_path, encoding="cp932", header=None)
# comment_list = df[0][1:].to_numpy().tolist()
comment_list = df[0][1:].to_numpy().tolist()
comment_dataset = CommentDataset(comment_list)
comment_dataset.delete_comment_specified_string(50)
comment_list = comment_dataset.comment_list
comment_dataset.formatted_input_hlda(appear_tagging_list=["名詞", "形容詞", "動詞"], stop_tagging_list=["助詞", "助動詞", "非自立"])

# %%
from model.HldaModel import ExpandHldaModel

model_path = "model/pickle/2023_08_01/20230627_mynumbercard_untenmenkyosyou_default.pickle"
expandHlda = ExpandHldaModel(pickle_path=model_path)

# %%
expandHlda.print_nodes(n_words = 10, weights = False)
# Out:
# topic=0 level=0 (documents=530): 免許, れる, 運転, できる, 保険, 思う, 確認, 本人, 情報, カード,
#     topic=1 level=1 (documents=90): 国民, 政府, 言う, 日本, これ, それ, せる, 作る, 岸田, 政治,
#         topic=58 level=2 (documents=13): 認証, コピー, 指紋, 書類, 計画, 対面, 悪用, パスワード, 公的, やり方,
#         topic=145 level=2 (documents=7): 中国, 老害, 一族, 好き, 移住, いとこ, 真似, 支配, 保護, 人類,
#         topic=157 level=2 (documents=11): スマート, フォン, モバイル, 搭載, 変える, 恐ろしい, スマ, つる, どっち, 事故,
#         topic=628 level=2 (documents=10): エラー, それぞれ, 推し進める, 出る, 脆弱, 分ける, 網羅, 思う, 活用, ツール,
#         topic=678 level=2 (documents=2): 余計, でる, 勘弁, かける, 結果, 加減, 加入, 加わる, 加える, 功績,
#         topic=693 level=2 (documents=3): 想像, 流出, 利用, 危機, 無い, 市民, うける, 年貢, 潤う, ハッキング,
#         topic=729 level=2 (documents=6): 無能, ヒューマン, 行為, 危険, 行う, 磁気, 原因, 技術, 聴く, 売国奴,
#         topic=760 level=2 (documents=4): オランダ, 任意, 強引, 外国, 取り上げる, 準備, 帰国, 交換, 上がる, 委ねる,
#         topic=776 level=2 (documents=9): ダメ, くっつける, 警察官, 絡む, 一つ, ついてる, 方々, 捨てる, 改善, 倒す,
#         topic=781 level=2 (documents=5): 認める, 整備, インフラ, 対策, 心情, 成立, 法案, 優れる, 決める, 環境,
#         topic=783 level=2 (documents=7): 口座, 未来, 権力, 残る, 岸田, 証券, 天下り, 把握, めちゃくちゃ, 自治体,
#         topic=791 level=2 (documents=1): 普及, 値する, 普通, 身元, 今更, 商法, 学生, ごり押し, 無茶苦茶, 価値,
#         topic=798 level=2 (documents=7): 項目, 基本, 祈る, 多く, パイプ, 切る, 立場, 立つ, コメンテーター, 取り上げる,
#         topic=799 level=2 (documents=5): 軽視, 疑心暗鬼, 住民, 得体, 知れる, 接種, ツール, たくさん, 面倒い, 学業,
#     topic=3 level=1 (documents=105): 国民, 言う, これ, 政府, 作る, せる, 岸田, 信用, 自民党, 自分,
#         topic=17 level=2 (documents=9): 支持, 有る, 勝手, 総理, 公的, 証明, 間違い, 盗む, 聞く, 下がる,
#         topic=19 level=2 (documents=6): 関わる, 諮問, 仕向ける, 重ねる, なりふり, 事実, 来す, 化す, よい, 窓口,
#         topic=36 level=2 (documents=6): チップ, 交通, 住所, 専用, 表面, 記載, 違反, パトカー, 有効, 車両,
#         topic=51 level=2 (documents=6): 公安, 与える, 横行, 委員, 偽札, 崩れる, 管轄, 不正, つまる, 置ける,
#         topic=379 level=2 (documents=16): 議員, 国会, さん, 役人, 河野, 誤る, 無能, 太郎, 文雄, 払う,
#         topic=451 level=2 (documents=15): 任意, 義務, 実質, やり方, ふざける, ミス, 陰険, 同意, バイト, いやらしい,
#         topic=673 level=2 (documents=6): 値上がり, 給料, なれる, 近づく, あんた, 制度, 補助, 国々, 覇権, 全力,
#         topic=751 level=2 (documents=5): 端末, 見せる, 加える, 電子, 住所, サービス, 監視, 契約, 開始, 読み込む,
#         topic=780 level=2 (documents=6): 携帯, 各所, 場所, 負け, 支給, まみれる, 同様, 自治体, 譲る, 補助,
#         topic=786 level=2 (documents=4): ごまかし, 流れ, 誤謬, 譲る, かざす, 徹底的, いろいろ, 保証, 確認, 対策,
#         topic=788 level=2 (documents=5): 環境, セキュリティ, 理解, 通信, 優良, 弊害, 確認, 上げる, かむ, 発行,
#         topic=790 level=2 (documents=7): 対策, 整備, 示す, 整える, 居る, バッチ, 向ける, ただ, 合格, しな,
#         topic=797 level=2 (documents=4): 操作, 電子, 自治体, 従業, インストール, 重要, 使用, 発想, 当方, だし,
#         topic=801 level=2 (documents=5): 財務省, 原案, 軽い, 利益, 達す, ごと, ごり押し, 実行, 預金, 徴収,
#         topic=802 level=2 (documents=5): 普段, 写し, 抜け道, 保管, 無駄, もらう, 買える, 貧困, くい, 新た,
#     topic=6 level=1 (documents=88): 国民, 日本, 言う, 選挙, 自民党, 政権, 政府, これ, 政治, 国家,
#         topic=7 level=2 (documents=9): 保持, 補完, 統一, 賛成, 検討, スピード, 役人, 持ち運び, 流行, 速やか,
#         topic=116 level=2 (documents=19): 更新, ゴールド, ブルー, 即日, 会場, 信用度, 置く, アホ, 検査, オレ,
#         topic=447 level=2 (documents=12): 投票, 選挙, 政党, 彼ら, 時代, 強い, 衆議院, 自公, 強行, 結果,
#         topic=599 level=2 (documents=6): コメント, レベル, 大変, つまり, 比較, 過渡, 承知, 心底, 作れる, 必然,
#         topic=682 level=2 (documents=7): 起きる, 矛盾, 公平, 影響, 隠す, 始める, 行政, システム, お金, 改革,
#         topic=744 level=2 (documents=5): 犯罪, 履歴, クレジットカード, 売買, 体制, 減る, せる, 購入, 監視, 勤め先,
#         topic=777 level=2 (documents=10): アメリカ, 独裁, 優先, 奴隷, 民族, 必死, 歴史, 検問, 長い, 裕福,
#         topic=779 level=2 (documents=3): 狙い, 特定, スムーズ, 吸い上げる, 源泉, 操縦, 納税, でる, 通院, 暮らし,
#         topic=784 level=2 (documents=4): 民主, 決定, 閣議, 主義, 道路, 情けない, 湯水, 乗りまわす, 滑り落ちる, 負ける,
#         topic=787 level=2 (documents=4): 来る, 田舎, 無い, いま, 説明, 止める, 大臣, 若手, 後始末, 年齢,
#         topic=793 level=2 (documents=2): 見る, 私利, ゴリ押し, 今度, よる, ブロック, 大切, 保管, ここ, 突きつける,
#         topic=794 level=2 (documents=7): まとめる, 運行, 大型, 点呼, 断る, 失効, 資格, たくさん, 運送, 中型,
#     topic=8 level=1 (documents=126): 国民, 携帯, 言う, これ, 政府, 日本, 任意, それ, せる, 政治,
#         topic=9 level=2 (documents=32): 紛失, 発行, リスク, 無くす, 病院, 場合, 万が一, 簡単, 行ける, 書く,
#         topic=26 level=2 (documents=16): 銀行, 口座, 作る, 開設, 電話, 契約, 政府, ライセンス, 民間, バカ,
#         topic=161 level=2 (documents=7): アナログ, 増やす, 言える, 世界, デジタル, ついていける, 遅れる, 時点, 必須, 確立,
#         topic=193 level=2 (documents=4): 禁止, 本来, 許可, 大差, メリット, 自然, 多く, 撒く, ポイント, 壊す,
#         topic=696 level=2 (documents=11): チップ, 埋め込む, マイクロ, ここ, バカ, 肌身, 離す, 認識, 意図, 仕事,
#         topic=698 level=2 (documents=6): 与党, 潰す, 存在, 正しい, 内閣, 公明党, 事実, 衝撃, 次回, もっとも,
#         topic=704 level=2 (documents=12): 基本, コード, なに, 年寄り, 取り扱い, センター, 統一, 住民, 人的, マイ,
#         topic=731 level=2 (documents=4): 割合, 天下り, トラブル, 推奨, 在席, 掛ける, 過疎, 推し進める, 解らん, 突き進む,
#         topic=732 level=2 (documents=4): 効率, 行政, スピード, 太郎, 徴収, まずい, 結びつける, 物凄い, すごい, 定数,
#         topic=735 level=2 (documents=5): 増やす, 友達, 大勢, 共産党, 繰り返す, それぞれ, 戻る, 年金, 民度, 利他,
#         topic=739 level=2 (documents=5): 船舶, 順番, 続く, 物事, 理想, 着く, 甘い, 成る, 義務付ける, 発車,
#         topic=755 level=2 (documents=3): 芋づる, 登録, 期限, 悪い, みな, 番号, 結果, バラバラ, 縛る, クレジットカード,
#         topic=762 level=2 (documents=4): 対策, 盗難, 嫌がる, 言いきる, 痛い, いく, いくら, 認める, かわり, 方法,
#         topic=767 level=2 (documents=6): 撒く, 市町村, どん, ばら, 都道府県, アナログ, 赤ちゃん, 発行, 人手, 晒す,
#         topic=782 level=2 (documents=3): 機器, 配備, 作業, 得る, 於く, 取り締まり, 存在, 読み込む, 異議, 外濠,
#         topic=800 level=2 (documents=4): 統合, リリース, 民間, 自国, 販売, 大前提, 保護, 素晴らしい, 解消, 判断,
#     topic=11 level=1 (documents=121): 国民, 政府, 言う, せる, 自民党, これ, 政治, 政権, 選挙, 作る,
#         topic=14 level=2 (documents=15): 番号, 暗証, 記載, 役所, 高齢, 入力, 間違える, 住民, 住所, 付く,
#         topic=16 level=2 (documents=9): 若者, 費用, 腐る, 滅茶苦茶, 見切り, 通信, くい, おかしい, まみれ, 引っ張る,
#         topic=35 level=2 (documents=7): あげる, 作れる, 逃れ, マトモ, 破産, 詐欺, でる, 初期, ベール, ポイント,
#         topic=310 level=2 (documents=7): 指摘, ケース, それら, まわす, やつ, 外国, 気付く, 格納, 改悪, 陥れる,
#         topic=632 level=2 (documents=6): いく, 連携, 注ぐ, 集約, 説明, マジ, 腐る, リスク, 結果, 将来,
#         topic=681 level=2 (documents=5): 成立, 内閣, 上手い, 文句, 知る, 自信, 知れる, 場面, 病院, リスク,
#         topic=720 level=2 (documents=10): 説明, 不足, 競争, 続出, 有る, 本来, 加入, 行動, 強い, 流出,
#         topic=745 level=2 (documents=9): お巡りさん, だらけ, 連絡, 助かる, 電子, 現場, 検証, 山積, 論理, 携行,
#         topic=759 level=2 (documents=10): 手帳, 資産, 個人, 公安, 銀行, 閲覧, 自民, 議員, 母子, 貯金,
#         topic=766 level=2 (documents=11): 役場, 公的, 設置, 近い, 普及, オンライン, 日本, れる, 国政, まり,
#         topic=768 level=2 (documents=7): かける, お前, 役人, 照会, 引きずる, 解体, 管轄, 仕事, 加減, 被害,
#         topic=785 level=2 (documents=9): たち, かも, スポーツマン, 三流, 一流, 信用, ビジネスマン, 全員, 携帯, 読み込む,
#         topic=789 level=2 (documents=8): 公式, 犯罪, 苦情, 反対, そう, 官邸, 公明党, 返す, メール, 心配,
#         topic=795 level=2 (documents=8): 破綻, 違い, 振り回す, 沙汰, 狂気, 間違い, 得意, 経験, 合併, 根源,

# %%
expandHlda.get_topic_with_color(comment_list=comment_list, corpus=comment_dataset.comment_list, n_words=30)
# Out:
# 0:今の日本の運転免許証ってとても優秀だものだと思うんですけどね。
# node_id:628, node_words:エラー(4.0),それぞれ(4.0),推し進める(3.0),出る(3.0),脆弱(3.0),分ける(3.0),網羅(2.0),思う(2.0),活用(2.0),ツール(2.0),警官(2.0),危機(2.0),見直す(2.0),非常(2.0),徹底的(2.0),至上(1.0),外国(1.0),ひとりひとり(1.0),温床(1.0),常軌(1.0),陥る(1.0),所持(1.0),電脳(1.0),警視庁(1.0),恥ずかしい(1.0),ライン(1.0),提示(1.0),電気(1.0),アナログ(1.0),向ける(1.0), probability:0.025
# 1:数年に一度必ず本人出向くて更新するから身元確認にもなるき顔写真ついてるからすぐその場で本人確認できるし。
# node_id:116, node_words:更新(27.0),ゴールド(6.0),ブルー(4.0),即日(3.0),会場(2.0),信用度(2.0),置く(2.0),アホ(2.0),検査(2.0),オレ(2.0),知る(2.0),グリーン(2.0),装置(2.0),視力(2.0),期間(2.0),無くなる(1.0),ヶ月(1.0),出生(1.0),ども(1.0),主義(1.0),がわり(1.0),返答(1.0),太郎(1.0),聞く(1.0),個々(1.0),聞こえる(1.0),判明(1.0),民間(1.0),別人(1.0),一般(1.0), probability:0.189
# 2:なんにするあらゆることを一つだけに絞るとそれがダメになるた時にどうしようもなくなるのでリスクが大きいなると思うます。
# node_id:776, node_words:ダメ(6.0),くっつける(2.0),警察官(2.0),絡む(2.0),一つ(2.0),ついてる(2.0),方々(1.0),捨てる(1.0),改善(1.0),倒す(1.0),テレビ(1.0),東日本(1.0),大きい(1.0),クルー(1.0),悪い(1.0),我々(1.0),学ぶ(1.0),同義(1.0),わけ(1.0),ドミノ(1.0),交通(1.0),昭和(1.0),わける(1.0),しよう(1.0),隊員(1.0),電波(1.0),手放す(1.0),異例(1.0),警ら(1.0),リーダー(1.0), probability:0.17
# 3:昭和おっさんの記憶ですが、テレビとビデオをくっつけるたものは結局すたれるたし、ファミコンとディスクシステム？だたかな？、をくっつけるてもダメですたね。
# node_id:776, node_words:ダメ(6.0),くっつける(2.0),警察官(2.0),絡む(2.0),一つ(2.0),ついてる(2.0),方々(1.0),捨てる(1.0),改善(1.0),倒す(1.0),テレビ(1.0),東日本(1.0),大きい(1.0),クルー(1.0),悪い(1.0),我々(1.0),学ぶ(1.0),同義(1.0),わけ(1.0),ドミノ(1.0),交通(1.0),昭和(1.0),わける(1.0),しよう(1.0),隊員(1.0),電波(1.0),手放す(1.0),異例(1.0),警ら(1.0),リーダー(1.0), probability:0.189
# 4:一つダメになると他も使えるないなるので。
# node_id:776, node_words:ダメ(6.0),くっつける(2.0),警察官(2.0),絡む(2.0),一つ(2.0),ついてる(2.0),方々(1.0),捨てる(1.0),改善(1.0),倒す(1.0),テレビ(1.0),東日本(1.0),大きい(1.0),クルー(1.0),悪い(1.0),我々(1.0),学ぶ(1.0),同義(1.0),わけ(1.0),ドミノ(1.0),交通(1.0),昭和(1.0),わける(1.0),しよう(1.0),隊員(1.0),電波(1.0),手放す(1.0),異例(1.0),警ら(1.0),リーダー(1.0), probability:0.151
# ------------------------------------------------------------------
# 0:紛失時のリスクを*に集約するてしまうと、再発行するれるまで病院にも行けるない、車にも乗れるない、となるますね。
# node_id:9, node_words:紛失(31.0),発行(30.0),リスク(14.0),無くす(14.0),病院(13.0),場合(10.0),万が一(7.0),簡単(5.0),行ける(5.0),書く(5.0),そう(5.0),即時(4.0),かかる(4.0),怖い(4.0),乗れる(4.0),週間(4.0),その間(4.0),いう(3.0),一体化(3.0),ふざける(3.0),役所(3.0),複数(3.0),増える(3.0),確率(3.0),合体(2.0),証明(2.0),避ける(2.0),単体(2.0),前提(2.0),試験(2.0), probability:0.266
# 1:役所が休みの土日や盆暮れだと、相当生活に影響が出るそう。
# node_id:791, node_words:普及(7.0),値する(2.0),普通(2.0),身元(1.0),今更(1.0),商法(1.0),学生(1.0),ごり押し(1.0),無茶苦茶(1.0),価値(1.0),かむ(1.0),引ける(1.0),やり方(1.0),押しつけ(1.0),原付(1.0),筒抜け(1.0),影響(1.0),事足りる(1.0),デカ(1.0),割合(0.0),前進(0.0),加わる(0.0),前科(0.0),加える(0.0),割り(0.0),副作用(0.0),割高(0.0),功績(0.0),創造(0.0),創設(0.0), probability:0.037
# 2:資産の預け先を分散するのと同様、免許証や保険証はリスク分散の意味でも一本化は避けるべし。
# node_id:632, node_words:いく(3.0),連携(2.0),注ぐ(2.0),集約(2.0),説明(2.0),マジ(2.0),腐る(2.0),リスク(2.0),結果(2.0),将来(1.0),バカげる(1.0),保険(1.0),ワンマン(1.0),国交(1.0),方向(1.0),アホ(1.0),国家(1.0),取り上げる(1.0),想定(1.0),能力(1.0),本人(1.0),財産(1.0),させる(1.0),功績(0.0),動向(0.0),加える(0.0),創造(0.0),創設(0.0),加入(0.0),割高(0.0), probability:0.091
# 3:管理する政策側のメリットしかない、利用者側のリスクが大きいすぎです。
# node_id:632, node_words:いく(3.0),連携(2.0),注ぐ(2.0),集約(2.0),説明(2.0),マジ(2.0),腐る(2.0),リスク(2.0),結果(2.0),将来(1.0),バカげる(1.0),保険(1.0),ワンマン(1.0),国交(1.0),方向(1.0),アホ(1.0),国家(1.0),取り上げる(1.0),想定(1.0),能力(1.0),本人(1.0),財産(1.0),させる(1.0),功績(0.0),動向(0.0),加える(0.0),創造(0.0),創設(0.0),加入(0.0),割高(0.0), probability:0.061
# ------------------------------------------------------------------
# 0:運行管理者の補助者として、点呼と運転免許証の確認をするておる、券面の有効期限や免許するれるている車種、また裏書で免許停止になるているないかの確認を行う、免許失効や無免許運転や資格外運転の防止を行なうているが、運転免許証がマイナンバーカードに移行するてしまうと、これらの確認ができるないため、しっこした免許や所有する免許の条件等種類の確認が出来るないなる、無資格運転等の問題が起きる危険性がある。
# node_id:794, node_words:まとめる(4.0),運行(4.0),大型(3.0),点呼(2.0),断る(2.0),失効(2.0),資格(2.0),たくさん(2.0),運送(2.0),中型(2.0),発覚(2.0),特殊(2.0),種類(2.0),会社(2.0),券面(2.0),ミス(2.0),癒着(1.0),思い(1.0),事業(1.0),裏書(1.0),事故(1.0),かける(1.0),お金(1.0),自動車(1.0),制服(1.0),しっこし(1.0),自体(1.0),清い(1.0),ナンバ(1.0),報う(1.0), probability:0.245
# 1:貨物自動車運送事業法で運行管理者の方が点呼の責任を取るために、万が一警察の取り締まりや事故等で発覚するた場合には、運送会社と運行管理者はかなりの責任を取るするれる事になる。
# node_id:794, node_words:まとめる(4.0),運行(4.0),大型(3.0),点呼(2.0),断る(2.0),失効(2.0),資格(2.0),たくさん(2.0),運送(2.0),中型(2.0),発覚(2.0),特殊(2.0),種類(2.0),会社(2.0),券面(2.0),ミス(2.0),癒着(1.0),思い(1.0),事業(1.0),裏書(1.0),事故(1.0),かける(1.0),お金(1.0),自動車(1.0),制服(1.0),しっこし(1.0),自体(1.0),清い(1.0),ナンバ(1.0),報う(1.0), probability:0.208
# 2:制服は安易にマイナンバー制度化でマイナンバーカードにまとめるうとするているが、運転免許証の廃止は運行管理上の問題もある安易に廃止するてまとめるてしまうのは問題だと思う。
# node_id:794, node_words:まとめる(4.0),運行(4.0),大型(3.0),点呼(2.0),断る(2.0),失効(2.0),資格(2.0),たくさん(2.0),運送(2.0),中型(2.0),発覚(2.0),特殊(2.0),種類(2.0),会社(2.0),券面(2.0),ミス(2.0),癒着(1.0),思い(1.0),事業(1.0),裏書(1.0),事故(1.0),かける(1.0),お金(1.0),自動車(1.0),制服(1.0),しっこし(1.0),自体(1.0),清い(1.0),ナンバ(1.0),報う(1.0), probability:0.069
# ------------------------------------------------------------------
# 0:MAINA保険証だけだ、病院に行く時だけで使うないときは自宅保管でもいいけど、免許証が一体化となると常に携帯するないとだめになるますね。
# node_id:793, node_words:見る(2.0),私利(1.0),ゴリ押し(1.0),今度(1.0),よる(1.0),ブロック(1.0),大切(1.0),保管(1.0),ここ(1.0),突きつける(1.0),保険(1.0),ほる(1.0),多い(1.0),割高(0.0),加入(0.0),前提(0.0),加減(0.0),前科(0.0),前進(0.0),副作用(0.0),加わる(0.0),創設(0.0),加える(0.0),割り(0.0),功績(0.0),創造(0.0),割り振る(0.0),割合(0.0),加点(0.0),ｏｋ(0.0), probability:0.143
# 1:保険所1枚、免許証1枚だけだない紛失時は財産丸ごと落とすことになるますね。
# node_id:9, node_words:紛失(31.0),発行(30.0),リスク(14.0),無くす(14.0),病院(13.0),場合(10.0),万が一(7.0),簡単(5.0),行ける(5.0),書く(5.0),そう(5.0),即時(4.0),かかる(4.0),怖い(4.0),乗れる(4.0),週間(4.0),その間(4.0),いう(3.0),一体化(3.0),ふざける(3.0),役所(3.0),複数(3.0),増える(3.0),確率(3.0),合体(2.0),証明(2.0),避ける(2.0),単体(2.0),前提(2.0),試験(2.0), probability:0.096
# 2:怖い怖い（財産も持つてるないけど笑）
# node_id:632, node_words:いく(3.0),連携(2.0),注ぐ(2.0),集約(2.0),説明(2.0),マジ(2.0),腐る(2.0),リスク(2.0),結果(2.0),将来(1.0),バカげる(1.0),保険(1.0),ワンマン(1.0),国交(1.0),方向(1.0),アホ(1.0),国家(1.0),取り上げる(1.0),想定(1.0),能力(1.0),本人(1.0),財産(1.0),させる(1.0),功績(0.0),動向(0.0),加える(0.0),創造(0.0),創設(0.0),加入(0.0),割高(0.0), probability:0.03
# 3:紛失時に1回ですべて事足りるという解釈もあるますが、そうなるとMAINA紛失するて紛失にかかわる手続きすると口座も保険証も免許証もクレカも1度に全部、停止になるのかな・・・。
# node_id:9, node_words:紛失(31.0),発行(30.0),リスク(14.0),無くす(14.0),病院(13.0),場合(10.0),万が一(7.0),簡単(5.0),行ける(5.0),書く(5.0),そう(5.0),即時(4.0),かかる(4.0),怖い(4.0),乗れる(4.0),週間(4.0),その間(4.0),いう(3.0),一体化(3.0),ふざける(3.0),役所(3.0),複数(3.0),増える(3.0),確率(3.0),合体(2.0),証明(2.0),避ける(2.0),単体(2.0),前提(2.0),試験(2.0), probability:0.255
# 4:見つかるた時、再交付の時も1度の手続きですむだいいけど。
# node_id:9, node_words:紛失(31.0),発行(30.0),リスク(14.0),無くす(14.0),病院(13.0),場合(10.0),万が一(7.0),簡単(5.0),行ける(5.0),書く(5.0),そう(5.0),即時(4.0),かかる(4.0),怖い(4.0),乗れる(4.0),週間(4.0),その間(4.0),いう(3.0),一体化(3.0),ふざける(3.0),役所(3.0),複数(3.0),増える(3.0),確率(3.0),合体(2.0),証明(2.0),避ける(2.0),単体(2.0),前提(2.0),試験(2.0), probability:0.012
# 5:でも、安全を担保できるているない今の状況を見るば、これを*元で政府の制度にお任せるするのも怖い怖い。
# node_id:673, node_words:値上がり(3.0),給料(2.0),なれる(1.0),近づく(1.0),あんた(1.0),制度(1.0),補助(1.0),国々(1.0),覇権(1.0),全力(1.0),主義(1.0),我々(1.0),我が国(1.0),近い(1.0),ガソリン(1.0),汗水(1.0),国家(1.0),安心(1.0),降ろす(1.0),垂らす(1.0),民主(1.0),中国(1.0),下野(1.0),物価(1.0),政治(1.0),おかげ(1.0),与党(1.0),正す(1.0),根こそぎ(1.0),創設(0.0), probability:0.031
# ------------------------------------------------------------------
# 0:全部紐付けするたマイナンバーカードを紛失するて窓口での手続きの際、「本人を証明する物を出し手」と言うれるた何を出すのですうね。
# node_id:9, node_words:紛失(31.0),発行(30.0),リスク(14.0),無くす(14.0),病院(13.0),場合(10.0),万が一(7.0),簡単(5.0),行ける(5.0),書く(5.0),そう(5.0),即時(4.0),かかる(4.0),怖い(4.0),乗れる(4.0),週間(4.0),その間(4.0),いう(3.0),一体化(3.0),ふざける(3.0),役所(3.0),複数(3.0),増える(3.0),確率(3.0),合体(2.0),証明(2.0),避ける(2.0),単体(2.0),前提(2.0),試験(2.0), probability:0.102
# 1:ちなみにパスポートは持つないし、介護保険証も持つているますん。
# node_id:793, node_words:見る(2.0),私利(1.0),ゴリ押し(1.0),今度(1.0),よる(1.0),ブロック(1.0),大切(1.0),保管(1.0),ここ(1.0),突きつける(1.0),保険(1.0),ほる(1.0),多い(1.0),割高(0.0),加入(0.0),前提(0.0),加減(0.0),前科(0.0),前進(0.0),副作用(0.0),加わる(0.0),創設(0.0),加える(0.0),割り(0.0),功績(0.0),創造(0.0),割り振る(0.0),割合(0.0),加点(0.0),ｏｋ(0.0), probability:0.071
# ------------------------------------------------------------------
# 0:国が公的だ手続きや書類をデジタル化を目指すのは良い事だと思うけど、現実問題で国のデジタルレベルが民間よりもかなり劣るている現状が問題だと思う、国で管理をするのだあるば委託などはするぬに公務員が優秀だエンジニアになる必要があると思う。
# node_id:628, node_words:エラー(4.0),それぞれ(4.0),推し進める(3.0),出る(3.0),脆弱(3.0),分ける(3.0),網羅(2.0),思う(2.0),活用(2.0),ツール(2.0),警官(2.0),危機(2.0),見直す(2.0),非常(2.0),徹底的(2.0),至上(1.0),外国(1.0),ひとりひとり(1.0),温床(1.0),常軌(1.0),陥る(1.0),所持(1.0),電脳(1.0),警視庁(1.0),恥ずかしい(1.0),ライン(1.0),提示(1.0),電気(1.0),アナログ(1.0),向ける(1.0), probability:0.105
# ------------------------------------------------------------------
# 0:みなさん「デジタル社会の実現に向けるた重点計画*案*を読むでいるないから議論が変だ方向に向かうているます。
# node_id:58, node_words:認証(9.0),コピー(7.0),指紋(5.0),書類(4.0),計画(4.0),対面(3.0),悪用(3.0),パスワード(3.0),公的(3.0),やり方(3.0),重点(2.0),券面(2.0),思える(2.0),なりすます(2.0),如何(2.0),放題(2.0),他人(2.0),否定(1.0),滅びる(1.0),ノー(1.0),網膜(1.0),明らか(1.0),交代(1.0),下がり(1.0),隣国(1.0),単純(1.0),遅い(1.0),万が一(1.0),認識(1.0),静脈(1.0), probability:0.061
# 1:この計画には、非対面での本人確認を公的個人認証に一本化するということ、それから対面でも公的個人認証「など」を推進するて、コピーを取る現状のやり方をやめると書くれるているます。
# node_id:58, node_words:認証(9.0),コピー(7.0),指紋(5.0),書類(4.0),計画(4.0),対面(3.0),悪用(3.0),パスワード(3.0),公的(3.0),やり方(3.0),重点(2.0),券面(2.0),思える(2.0),なりすます(2.0),如何(2.0),放題(2.0),他人(2.0),否定(1.0),滅びる(1.0),ノー(1.0),網膜(1.0),明らか(1.0),交代(1.0),下がり(1.0),隣国(1.0),単純(1.0),遅い(1.0),万が一(1.0),認識(1.0),静脈(1.0), probability:0.341
# 2:本人確認書類のコピーを取るやり方は安全性を考えると将来的には廃止するれるべしだ、その代替手法は公的個人認証が一番使うやすいとは思うますが、運転免許証にも電子的に券面情報を取得できる機能があるので、それでも良いだうと考えるます。
# node_id:58, node_words:認証(9.0),コピー(7.0),指紋(5.0),書類(4.0),計画(4.0),対面(3.0),悪用(3.0),パスワード(3.0),公的(3.0),やり方(3.0),重点(2.0),券面(2.0),思える(2.0),なりすます(2.0),如何(2.0),放題(2.0),他人(2.0),否定(1.0),滅びる(1.0),ノー(1.0),網膜(1.0),明らか(1.0),交代(1.0),下がり(1.0),隣国(1.0),単純(1.0),遅い(1.0),万が一(1.0),認識(1.0),静脈(1.0), probability:0.272
# ------------------------------------------------------------------
# 0:では、銀行口座は今のうちに沢山作るておくか。
# node_id:26, node_words:銀行(22.0),口座(16.0),作る(11.0),開設(8.0),電話(6.0),契約(5.0),政府(4.0),ライセンス(3.0),民間(3.0),バカ(3.0),オンライン(3.0),過ぎる(2.0),違反(2.0),日本(2.0),新規(2.0),見え(2.0),携わる(2.0),やり方(2.0),確認(2.0),基本(2.0),都市(2.0),組み入れる(1.0),結局(1.0),受電(1.0),公表(1.0),通用(1.0),大手(1.0),づける(1.0),追い込む(1.0),一刻(1.0), probability:0.199
# 1:すでに大手都市銀行４行と地元都市銀行の口座は持つているので、どの銀行にするうかな。
# node_id:26, node_words:銀行(22.0),口座(16.0),作る(11.0),開設(8.0),電話(6.0),契約(5.0),政府(4.0),ライセンス(3.0),民間(3.0),バカ(3.0),オンライン(3.0),過ぎる(2.0),違反(2.0),日本(2.0),新規(2.0),見え(2.0),携わる(2.0),やり方(2.0),確認(2.0),基本(2.0),都市(2.0),組み入れる(1.0),結局(1.0),受電(1.0),公表(1.0),通用(1.0),大手(1.0),づける(1.0),追い込む(1.0),一刻(1.0), probability:0.371
# 2:地元信用金庫と農協かな。
# node_id:785, node_words:たち(7.0),かも(3.0),スポーツマン(2.0),三流(2.0),一流(2.0),信用(2.0),ビジネスマン(2.0),全員(2.0),携帯(2.0),読み込む(2.0),権利(1.0),囲む(1.0),人生(1.0),オークション(1.0),個々(1.0),誤る(1.0),民放(1.0),不可(1.0),多い(1.0),向き合う(1.0),選ぶ(1.0),群がる(1.0),電波(1.0),誰か(1.0),見せる(1.0),ミス(1.0),ウラ(1.0),車内(1.0),侮る(1.0),手配(1.0), probability:0.028
# 3:それ以上作るてもATMが近くにないから使えるない。
# node_id:720, node_words:説明(4.0),不足(4.0),競争(3.0),続出(2.0),有る(2.0),本来(2.0),加入(2.0),行動(2.0),強い(1.0),流出(1.0),天下り(1.0),処分(1.0),つく(1.0),減らす(1.0),投げつける(1.0),野党(1.0),それ(1.0),不利益(1.0),追求(1.0),並行(1.0),想定(1.0),乖離(1.0),信用(1.0),集団(1.0),怖い(1.0),法治(1.0),多く(1.0),切り込む(1.0),検討(1.0),記事(1.0), probability:0.015
# 4:家族名義の口座も作るておくう。
# node_id:26, node_words:銀行(22.0),口座(16.0),作る(11.0),開設(8.0),電話(6.0),契約(5.0),政府(4.0),ライセンス(3.0),民間(3.0),バカ(3.0),オンライン(3.0),過ぎる(2.0),違反(2.0),日本(2.0),新規(2.0),見え(2.0),携わる(2.0),やり方(2.0),確認(2.0),基本(2.0),都市(2.0),組み入れる(1.0),結局(1.0),受電(1.0),公表(1.0),通用(1.0),大手(1.0),づける(1.0),追い込む(1.0),一刻(1.0), probability:0.094
# 5:携帯電話は、契約するせるてもらえるないだ、その時点で解約で良いや。
# node_id:26, node_words:銀行(22.0),口座(16.0),作る(11.0),開設(8.0),電話(6.0),契約(5.0),政府(4.0),ライセンス(3.0),民間(3.0),バカ(3.0),オンライン(3.0),過ぎる(2.0),違反(2.0),日本(2.0),新規(2.0),見え(2.0),携わる(2.0),やり方(2.0),確認(2.0),基本(2.0),都市(2.0),組み入れる(1.0),結局(1.0),受電(1.0),公表(1.0),通用(1.0),大手(1.0),づける(1.0),追い込む(1.0),一刻(1.0), probability:0.063
# 6:ほとんど使うてるないから、金がもつたないと思うているた。
# node_id:776, node_words:ダメ(6.0),くっつける(2.0),警察官(2.0),絡む(2.0),一つ(2.0),ついてる(2.0),方々(1.0),捨てる(1.0),改善(1.0),倒す(1.0),テレビ(1.0),東日本(1.0),大きい(1.0),クルー(1.0),悪い(1.0),我々(1.0),学ぶ(1.0),同義(1.0),わけ(1.0),ドミノ(1.0),交通(1.0),昭和(1.0),わける(1.0),しよう(1.0),隊員(1.0),電波(1.0),手放す(1.0),異例(1.0),警ら(1.0),リーダー(1.0), probability:0.0
# 7:仕事用携帯電話で受電するて、PCの***だけで十分だと感じるている。
# node_id:780, node_words:携帯(1.0),各所(1.0),場所(1.0),負け(1.0),支給(1.0),まみれる(1.0),同様(1.0),自治体(1.0),譲る(1.0),補助(1.0),リスク(1.0),始まる(1.0),争奪(1.0),投げる(1.0),日本人(1.0),外国(1.0),企業(1.0),見づらい(1.0),危ない(1.0),一切(1.0),購入(1.0),賃金(1.0),節約(1.0),割り(0.0),創設(0.0),前提(0.0),創造(0.0),前進(0.0),前科(0.0),割高(0.0), probability:0.043
# ------------------------------------------------------------------
# 0:もう、ここまで一体化するれるのだあるば、*は、カード型に拘る必要が無位の出端。
# node_id:793, node_words:見る(2.0),私利(1.0),ゴリ押し(1.0),今度(1.0),よる(1.0),ブロック(1.0),大切(1.0),保管(1.0),ここ(1.0),突きつける(1.0),保険(1.0),ほる(1.0),多い(1.0),割高(0.0),加入(0.0),前提(0.0),加減(0.0),前科(0.0),前進(0.0),副作用(0.0),加わる(0.0),創設(0.0),加える(0.0),割り(0.0),功績(0.0),創造(0.0),割り振る(0.0),割合(0.0),加点(0.0),ｏｋ(0.0), probability:0.071
# 1:ドックタグ型にするて、ネックチェーンで、肌身離すぬ持ち歩くように、変えるたどうでしょうか。
# node_id:696, node_words:チップ(5.0),埋め込む(5.0),マイクロ(4.0),ここ(2.0),バカ(2.0),肌身(2.0),離す(2.0),認識(2.0),意図(1.0),仕事(1.0),怒る(1.0),埋設(1.0),離脱(1.0),手放せる(1.0),コオロギ(1.0),多数(1.0),不愉快(1.0),リモート(1.0),走り出す(1.0),方式(1.0),チェーン(1.0),公表(1.0),満たす(1.0),人体(1.0),譲る(1.0),気付く(1.0),給付(1.0),打ち込む(1.0),ドック(1.0),恐ろしい(1.0), probability:0.086
# 2:それとも、体にチップを埋設する方式にするとか、本人が意図するぬ手放せるない様だ、物にするないとね。
# node_id:696, node_words:チップ(5.0),埋め込む(5.0),マイクロ(4.0),ここ(2.0),バカ(2.0),肌身(2.0),離す(2.0),認識(2.0),意図(1.0),仕事(1.0),怒る(1.0),埋設(1.0),離脱(1.0),手放せる(1.0),コオロギ(1.0),多数(1.0),不愉快(1.0),リモート(1.0),走り出す(1.0),方式(1.0),チェーン(1.0),公表(1.0),満たす(1.0),人体(1.0),譲る(1.0),気付く(1.0),給付(1.0),打ち込む(1.0),ドック(1.0),恐ろしい(1.0), probability:0.114
# 3:肌身から離すから、落とすたり、無くすたりするのだから。
# node_id:696, node_words:チップ(5.0),埋め込む(5.0),マイクロ(4.0),ここ(2.0),バカ(2.0),肌身(2.0),離す(2.0),認識(2.0),意図(1.0),仕事(1.0),怒る(1.0),埋設(1.0),離脱(1.0),手放せる(1.0),コオロギ(1.0),多数(1.0),不愉快(1.0),リモート(1.0),走り出す(1.0),方式(1.0),チェーン(1.0),公表(1.0),満たす(1.0),人体(1.0),譲る(1.0),気付く(1.0),給付(1.0),打ち込む(1.0),ドック(1.0),恐ろしい(1.0), probability:0.057
# ------------------------------------------------------------------
# 0:建前だけ任意として政府は一切責任を負ううとするぬ、それでいて生活に必須だ健康保険や身分証明書などを人質に取る、実質的には強制するやり方が、あまりにも姑息だ不誠実だ。
# node_id:451, node_words:任意(12.0),義務(6.0),実質(5.0),やり方(4.0),ふざける(3.0),ミス(2.0),陰険(2.0),同意(2.0),バイト(2.0),いやらしい(2.0),埋める(2.0),遠まわし(2.0),本当(2.0),姑息(2.0),説明(2.0),写真(2.0),外堀(2.0),強引(2.0),拙速(1.0),大丈夫(1.0),持ち主(1.0),物理(1.0),関連(1.0),わけ(1.0),なに(1.0),丁寧(1.0),与える(1.0),諦める(1.0),法律(1.0),思う(1.0), probability:0.233
# 1:こんなやり方は信用できるないし、信用できるない人達に口座番号などの個人情報を渡すのは、危険極まりないと思う。
# node_id:785, node_words:たち(7.0),かも(3.0),スポーツマン(2.0),三流(2.0),一流(2.0),信用(2.0),ビジネスマン(2.0),全員(2.0),携帯(2.0),読み込む(2.0),権利(1.0),囲む(1.0),人生(1.0),オークション(1.0),個々(1.0),誤る(1.0),民放(1.0),不可(1.0),多い(1.0),向き合う(1.0),選ぶ(1.0),群がる(1.0),電波(1.0),誰か(1.0),見せる(1.0),ミス(1.0),ウラ(1.0),車内(1.0),侮る(1.0),手配(1.0), probability:0.149
# 2:民間のカード会社や金融機関は、消費者の信用を得るためにたいへんだ努力を行うているが、「マイナンバーカード」には、誠意の欠片もない、あるのは連日のトラブルと、国民を見下す上から目線だけだ。
# node_id:731, node_words:割合(2.0),天下り(2.0),トラブル(2.0),推奨(2.0),在席(1.0),掛ける(1.0),過疎(1.0),推し進める(1.0),解らん(1.0),突き進む(1.0),人口(1.0),構想(1.0),下がる(1.0),主流(1.0),辞職(1.0),都市(1.0),官庁(1.0),楽しみ(1.0),印象(1.0),怒り(1.0),コメント(1.0),生まれる(1.0),断言(1.0),対処(1.0),最近(1.0),密集(1.0),洗い出す(1.0),ここ(1.0),ゴリ押し(1.0),助ける(0.0), probability:0.061
# 3:国民の生活状況や健康状態、財産などの個人情報を政府に渡すことだ、さらなる増税や負担増を押し付けるられることは目に見えるている。
# node_id:759, node_words:手帳(5.0),資産(4.0),個人(4.0),公安(3.0),銀行(3.0),閲覧(3.0),自民(3.0),議員(3.0),母子(3.0),貯金(2.0),増税(2.0),複数(2.0),リスト(2.0),やり方(2.0),加える(2.0),表示(2.0),財産(2.0),公約(2.0),仕組み(2.0),会社(2.0),子ども(2.0),意思(2.0),年金(2.0),課税(1.0),金融(1.0),周り(1.0),文通(1.0),吸い取る(1.0),吸い上げる(1.0),さまざま(1.0), probability:0.058
# 4:こんな危険だ有害だ制度は、今すぐやめるべしだが、そのためには、今の総理大臣をはじめとするた政治家に、やめるてもらうことが欠くせるない。
# node_id:17, node_words:支持(6.0),有る(5.0),勝手(5.0),総理(5.0),公的(4.0),証明(3.0),間違い(3.0),盗む(3.0),聞く(3.0),下がる(2.0),事件(2.0),何処(2.0),来年(2.0),就任(2.0),回し(2.0),ゼロ(2.0),確約(2.0),多発(2.0),たらい(2.0),気楽(1.0),遣る(1.0),単独(1.0),消える(1.0),十分(1.0),共有(1.0),逃れ(1.0),アナログ(1.0),議論(1.0),保身(1.0),どこ(1.0), probability:0.065
# 5:そのためには、選挙で意思表示をすることが、国民がとれる一番の解決策だ。
# node_id:447, node_words:投票(6.0),選挙(5.0),政党(4.0),彼ら(3.0),時代(2.0),強い(2.0),衆議院(2.0),自公(2.0),強行(2.0),結果(2.0),成り下がる(2.0),危なっかしい(2.0),お願い(2.0),次回(2.0),慎重(2.0),交代(2.0),一部(2.0),放題(2.0),問う(2.0),バック(1.0),公共(1.0),マスコミ(1.0),事態(1.0),上がる(1.0),手遅れ(1.0),ついてる(1.0),既得(1.0),公約(1.0),表れ(1.0),刻む(1.0), probability:0.052
# ------------------------------------------------------------------
# 0:とも各紙の保険証廃止だけは止めるべしですう。
# node_id:793, node_words:見る(2.0),私利(1.0),ゴリ押し(1.0),今度(1.0),よる(1.0),ブロック(1.0),大切(1.0),保管(1.0),ここ(1.0),突きつける(1.0),保険(1.0),ほる(1.0),多い(1.0),割高(0.0),加入(0.0),前提(0.0),加減(0.0),前科(0.0),前進(0.0),副作用(0.0),加わる(0.0),創設(0.0),加える(0.0),割り(0.0),功績(0.0),創造(0.0),割り振る(0.0),割合(0.0),加点(0.0),ｏｋ(0.0), probability:0.071
# 1:きょうのテレビ欄で各局のワイドショーの項目をみるた、*という項目は一つもないた。
# node_id:798, node_words:項目(2.0),基本(1.0),祈る(1.0),多く(1.0),パイプ(1.0),切る(1.0),立場(1.0),立つ(1.0),コメンテーター(1.0),取り上げる(1.0),大事(1.0),不便(1.0),功績(1.0),いま(1.0),反則(1.0),さん(1.0),所有(1.0),維持(1.0),テレビ(1.0),待ち(1.0),乗せる(1.0),止める(1.0),完結(1.0),あと(1.0),鎮圧(1.0),停る(1.0),有力(1.0),もらえる(1.0),一つ(1.0),明確(1.0), probability:0.205
# 2:大いに失望するた。
# node_id:776, node_words:ダメ(6.0),くっつける(2.0),警察官(2.0),絡む(2.0),一つ(2.0),ついてる(2.0),方々(1.0),捨てる(1.0),改善(1.0),倒す(1.0),テレビ(1.0),東日本(1.0),大きい(1.0),クルー(1.0),悪い(1.0),我々(1.0),学ぶ(1.0),同義(1.0),わけ(1.0),ドミノ(1.0),交通(1.0),昭和(1.0),わける(1.0),しよう(1.0),隊員(1.0),電波(1.0),手放す(1.0),異例(1.0),警ら(1.0),リーダー(1.0), probability:0.0
# 3:つまり政府の方針は「鎮圧」にかたまるたってこと。
# node_id:798, node_words:項目(2.0),基本(1.0),祈る(1.0),多く(1.0),パイプ(1.0),切る(1.0),立場(1.0),立つ(1.0),コメンテーター(1.0),取り上げる(1.0),大事(1.0),不便(1.0),功績(1.0),いま(1.0),反則(1.0),さん(1.0),所有(1.0),維持(1.0),テレビ(1.0),待ち(1.0),乗せる(1.0),止める(1.0),完結(1.0),あと(1.0),鎮圧(1.0),停る(1.0),有力(1.0),もらえる(1.0),一つ(1.0),明確(1.0), probability:0.027
# 4:テレビ局も政権側からのパイプが切るれるた情報ももらえるないなる。
# node_id:798, node_words:項目(2.0),基本(1.0),祈る(1.0),多く(1.0),パイプ(1.0),切る(1.0),立場(1.0),立つ(1.0),コメンテーター(1.0),取り上げる(1.0),大事(1.0),不便(1.0),功績(1.0),いま(1.0),反則(1.0),さん(1.0),所有(1.0),維持(1.0),テレビ(1.0),待ち(1.0),乗せる(1.0),止める(1.0),完結(1.0),あと(1.0),鎮圧(1.0),停る(1.0),有力(1.0),もらえる(1.0),一つ(1.0),明確(1.0), probability:0.054
# 5:いまこそ国民世論の沸騰しかない、あと有力だコメンテーターやインフルエンサーが紙の保険証維持の立場に立つてくれることを祈るしかない
# node_id:798, node_words:項目(2.0),基本(1.0),祈る(1.0),多く(1.0),パイプ(1.0),切る(1.0),立場(1.0),立つ(1.0),コメンテーター(1.0),取り上げる(1.0),大事(1.0),不便(1.0),功績(1.0),いま(1.0),反則(1.0),さん(1.0),所有(1.0),維持(1.0),テレビ(1.0),待ち(1.0),乗せる(1.0),止める(1.0),完結(1.0),あと(1.0),鎮圧(1.0),停る(1.0),有力(1.0),もらえる(1.0),一つ(1.0),明確(1.0), probability:0.216
# ------------------------------------------------------------------
# 0:ついに出るますたね。
# node_id:451, node_words:任意(12.0),義務(6.0),実質(5.0),やり方(4.0),ふざける(3.0),ミス(2.0),陰険(2.0),同意(2.0),バイト(2.0),いやらしい(2.0),埋める(2.0),遠まわし(2.0),本当(2.0),姑息(2.0),説明(2.0),写真(2.0),外堀(2.0),強引(2.0),拙速(1.0),大丈夫(1.0),持ち主(1.0),物理(1.0),関連(1.0),わけ(1.0),なに(1.0),丁寧(1.0),与える(1.0),諦める(1.0),法律(1.0),思う(1.0), probability:0.01
# 1:*と個人のあらゆる情報を紐づけるて国が監視できる体制が。
# node_id:744, node_words:犯罪(3.0),履歴(2.0),クレジットカード(2.0),売買(2.0),体制(2.0),減る(2.0),せる(2.0),購入(2.0),監視(2.0),勤め先(2.0),バレ(2.0),戸籍(2.0),書き換え(2.0),社会(2.0),実施(1.0),経路(1.0),披露(1.0),総理(1.0),通院(1.0),連絡(1.0),かかわる(1.0),投薬(1.0),海外(1.0),就学(1.0),たどる(1.0),滞在(1.0),定期(1.0),防げる(1.0),物品(1.0),学校(1.0), probability:0.043
# 2:戸籍、勤め先、納税、健康保険証、通院投薬歴、運転免許、交通違反歴、保有するている車両、携帯電話番号、銀行口座と取引履歴。
# node_id:26, node_words:銀行(22.0),口座(16.0),作る(11.0),開設(8.0),電話(6.0),契約(5.0),政府(4.0),ライセンス(3.0),民間(3.0),バカ(3.0),オンライン(3.0),過ぎる(2.0),違反(2.0),日本(2.0),新規(2.0),見え(2.0),携わる(2.0),やり方(2.0),確認(2.0),基本(2.0),都市(2.0),組み入れる(1.0),結局(1.0),受電(1.0),公表(1.0),通用(1.0),大手(1.0),づける(1.0),追い込む(1.0),一刻(1.0), probability:0.241
# 3:個人的だ予測としていずれは学校就学、勤め先などの個人の職歴学歴、警察にある犯罪歴と指紋、パスポート、クレジットカード、ショッピングサイトやSNS、お店やレンタルショップの会員情報、通勤定期などなどもうなるだもあるです。
# node_id:744, node_words:犯罪(3.0),履歴(2.0),クレジットカード(2.0),売買(2.0),体制(2.0),減る(2.0),せる(2.0),購入(2.0),監視(2.0),勤め先(2.0),バレ(2.0),戸籍(2.0),書き換え(2.0),社会(2.0),実施(1.0),経路(1.0),披露(1.0),総理(1.0),通院(1.0),連絡(1.0),かかわる(1.0),投薬(1.0),海外(1.0),就学(1.0),たどる(1.0),滞在(1.0),定期(1.0),防げる(1.0),物品(1.0),学校(1.0), probability:0.207
# 4:これらが紐づけるられるとビックデータと*から得るられる関連情報を串刺しするて、誰がどの経路をたどるてどこへ行くたのか、誰と連絡を取るているて何を話すたのか、どんなものを検索するて何に興味があるて何を購入するたのかまで全てバレバレ。
# node_id:744, node_words:犯罪(3.0),履歴(2.0),クレジットカード(2.0),売買(2.0),体制(2.0),減る(2.0),せる(2.0),購入(2.0),監視(2.0),勤め先(2.0),バレ(2.0),戸籍(2.0),書き換え(2.0),社会(2.0),実施(1.0),経路(1.0),披露(1.0),総理(1.0),通院(1.0),連絡(1.0),かかわる(1.0),投薬(1.0),海外(1.0),就学(1.0),たどる(1.0),滞在(1.0),定期(1.0),防げる(1.0),物品(1.0),学校(1.0), probability:0.117
# 5:きっと*に忘れ物タグに使うているようだチップも搭載するんじゃないかな、末恐ろしい監視社会。
# node_id:696, node_words:チップ(5.0),埋め込む(5.0),マイクロ(4.0),ここ(2.0),バカ(2.0),肌身(2.0),離す(2.0),認識(2.0),意図(1.0),仕事(1.0),怒る(1.0),埋設(1.0),離脱(1.0),手放せる(1.0),コオロギ(1.0),多数(1.0),不愉快(1.0),リモート(1.0),走り出す(1.0),方式(1.0),チェーン(1.0),公表(1.0),満たす(1.0),人体(1.0),譲る(1.0),気付く(1.0),給付(1.0),打ち込む(1.0),ドック(1.0),恐ろしい(1.0), probability:0.1
# ------------------------------------------------------------------
# 0:免許証とマイナンバーカードの一体化が始まるた直後は、道路で行うれる検問では超大渋滞が予想するれるますね。
# node_id:19, node_words:関わる(5.0),諮問(1.0),仕向ける(1.0),重ねる(1.0),なりふり(1.0),事実(1.0),来す(1.0),化す(1.0),よい(1.0),窓口(1.0),権化(1.0),子供(1.0),予想(1.0),握る(1.0),気付け(1.0),卑劣(1.0),危険(1.0),安倍(1.0),気がつく(1.0),安心(1.0),安易(1.0),甘い(1.0),構う(1.0),ネット(1.0),集団(1.0),修学旅行(1.0),支障(1.0),飛びつく(1.0),愚行(1.0),受け取れる(1.0), probability:0.023
# 1:だって、免許証見るば済むようだ検問でもいちいち一人一人機械でカードを読むないなるないし、ひょっとすると暗証番号入力もあるかも知れるないし。
# node_id:14, node_words:番号(13.0),暗証(12.0),記載(5.0),役所(4.0),高齢(4.0),入力(3.0),間違える(3.0),住民(3.0),住所(3.0),付く(3.0),誕生(3.0),設定(2.0),機器(2.0),意識(2.0),不明(2.0),警察官(2.0),停電(2.0),向かう(2.0),犯罪(2.0),開ける(2.0),太郎(2.0),体制(2.0),伝える(2.0),体型(2.0),痴呆(2.0),整える(1.0),固定(1.0),暗い(1.0),故障(1.0),時期(1.0), probability:0.156
# 2:車での旅行も大変だ時代が到来する恐れあるですね。
# node_id:599, node_words:コメント(3.0),レベル(3.0),大変(2.0),つまり(1.0),比較(1.0),過渡(1.0),承知(1.0),心底(1.0),作れる(1.0),必然(1.0),見る(1.0),エラー(1.0),激しい(1.0),検討(1.0),日進月歩(1.0),結論(1.0),事件(1.0),今後(1.0),構図(1.0),官僚(1.0),様々(1.0),狭い(1.0),地獄(1.0),国力(1.0),きめる(1.0),働き手(1.0),懸念(1.0),世の中(1.0),散見(1.0),範囲(1.0), probability:0.04
# ------------------------------------------------------------------
# 0:何でもかんでも一体化するば良いものだはない！、運転免許証の更新はその日のうちに完結するがマイナンバーカードの更新は現段階では複雑。
# node_id:116, node_words:更新(27.0),ゴールド(6.0),ブルー(4.0),即日(3.0),会場(2.0),信用度(2.0),置く(2.0),アホ(2.0),検査(2.0),オレ(2.0),知る(2.0),グリーン(2.0),装置(2.0),視力(2.0),期間(2.0),無くなる(1.0),ヶ月(1.0),出生(1.0),ども(1.0),主義(1.0),がわり(1.0),返答(1.0),太郎(1.0),聞く(1.0),個々(1.0),聞こえる(1.0),判明(1.0),民間(1.0),別人(1.0),一般(1.0), probability:0.318
# 1:運転免許証と同じようだ更新手続きにするべしだある。
# node_id:116, node_words:更新(27.0),ゴールド(6.0),ブルー(4.0),即日(3.0),会場(2.0),信用度(2.0),置く(2.0),アホ(2.0),検査(2.0),オレ(2.0),知る(2.0),グリーン(2.0),装置(2.0),視力(2.0),期間(2.0),無くなる(1.0),ヶ月(1.0),出生(1.0),ども(1.0),主義(1.0),がわり(1.0),返答(1.0),太郎(1.0),聞く(1.0),個々(1.0),聞こえる(1.0),判明(1.0),民間(1.0),別人(1.0),一般(1.0), probability:0.189
# 2:よくわかるないのは免許停止処分時の免許取り上げる、免停解除後に引き渡しとなるがマイナンバーカードになるた場合の運用方法が明確だない。
# node_id:798, node_words:項目(2.0),基本(1.0),祈る(1.0),多く(1.0),パイプ(1.0),切る(1.0),立場(1.0),立つ(1.0),コメンテーター(1.0),取り上げる(1.0),大事(1.0),不便(1.0),功績(1.0),いま(1.0),反則(1.0),さん(1.0),所有(1.0),維持(1.0),テレビ(1.0),待ち(1.0),乗せる(1.0),止める(1.0),完結(1.0),あと(1.0),鎮圧(1.0),停る(1.0),有力(1.0),もらえる(1.0),一つ(1.0),明確(1.0), probability:0.054
# 3:すべての仕組みを理解しないで運用するうとするているところに今後もマイナンバーカードのトラブルが続くようだ気がする
# node_id:788, node_words:環境(2.0),セキュリティ(2.0),理解(2.0),通信(2.0),優良(1.0),弊害(1.0),確認(1.0),上げる(1.0),かむ(1.0),発行(1.0),分散(1.0),マイナー(1.0),確か(1.0),ヤボ(1.0),山岳(1.0),場所(1.0),落とす(1.0),場面(1.0),とこ(1.0),辞職(1.0),直行(1.0),使う(1.0),機能(1.0),警察官(1.0),えらい(1.0),長蛇(1.0),創設(0.0),前向き(0.0),割高(0.0),前提(0.0), probability:0.1
# ------------------------------------------------------------------
# 0:保険証との紐付けができるているないと自己負担になるのと同様に運転免許証の紐付けができるてナイト免許不携帯になる可能性がある。
# node_id:780, node_words:携帯(1.0),各所(1.0),場所(1.0),負け(1.0),支給(1.0),まみれる(1.0),同様(1.0),自治体(1.0),譲る(1.0),補助(1.0),リスク(1.0),始まる(1.0),争奪(1.0),投げる(1.0),日本人(1.0),外国(1.0),企業(1.0),見づらい(1.0),危ない(1.0),一切(1.0),購入(1.0),賃金(1.0),節約(1.0),割り(0.0),創設(0.0),前提(0.0),創造(0.0),前進(0.0),前科(0.0),割高(0.0), probability:0.087
# 1:マイナンバーカードと一体化するてしまうのは危ないと思う。
# node_id:780, node_words:携帯(1.0),各所(1.0),場所(1.0),負け(1.0),支給(1.0),まみれる(1.0),同様(1.0),自治体(1.0),譲る(1.0),補助(1.0),リスク(1.0),始まる(1.0),争奪(1.0),投げる(1.0),日本人(1.0),外国(1.0),企業(1.0),見づらい(1.0),危ない(1.0),一切(1.0),購入(1.0),賃金(1.0),節約(1.0),割り(0.0),創設(0.0),前提(0.0),創造(0.0),前進(0.0),前科(0.0),割高(0.0), probability:0.043
# ------------------------------------------------------------------
# 0:先日、郵便局で本人確認にマイナンバーカードを使うますたが、職員さんは裏の番号を見るてはいけるないらしい、他の人が裏面を見るないようにカードを持ち上げることもできるないので、さっと見るだけで確認を終えるているますた。
# node_id:793, node_words:見る(2.0),私利(1.0),ゴリ押し(1.0),今度(1.0),よる(1.0),ブロック(1.0),大切(1.0),保管(1.0),ここ(1.0),突きつける(1.0),保険(1.0),ほる(1.0),多い(1.0),割高(0.0),加入(0.0),前提(0.0),加減(0.0),前科(0.0),前進(0.0),副作用(0.0),加わる(0.0),創設(0.0),加える(0.0),割り(0.0),功績(0.0),創造(0.0),割り振る(0.0),割合(0.0),加点(0.0),ｏｋ(0.0), probability:0.143
# 1:正直このくらいのチェックだ偽造とか簡単そうだなぁ、と思うんですがどうだんですうね。というか詳しいチェックするちゃいけるない身分確認証って役に立つない気がする。
# node_id:58, node_words:認証(9.0),コピー(7.0),指紋(5.0),書類(4.0),計画(4.0),対面(3.0),悪用(3.0),パスワード(3.0),公的(3.0),やり方(3.0),重点(2.0),券面(2.0),思える(2.0),なりすます(2.0),如何(2.0),放題(2.0),他人(2.0),否定(1.0),滅びる(1.0),ノー(1.0),網膜(1.0),明らか(1.0),交代(1.0),下がり(1.0),隣国(1.0),単純(1.0),遅い(1.0),万が一(1.0),認識(1.0),静脈(1.0), probability:0.079
# ------------------------------------------------------------------
# 0:なぜマイナンバー「カード」に政府がこだわるのか理解出来るますん。
# node_id:788, node_words:環境(2.0),セキュリティ(2.0),理解(2.0),通信(2.0),優良(1.0),弊害(1.0),確認(1.0),上げる(1.0),かむ(1.0),発行(1.0),分散(1.0),マイナー(1.0),確か(1.0),ヤボ(1.0),山岳(1.0),場所(1.0),落とす(1.0),場面(1.0),とこ(1.0),辞職(1.0),直行(1.0),使う(1.0),機能(1.0),警察官(1.0),えらい(1.0),長蛇(1.0),創設(0.0),前向き(0.0),割高(0.0),前提(0.0), probability:0.067
# 1:速やかだ給付などのため、マイナンバーは必要だと思うます。
# node_id:787, node_words:来る(3.0),田舎(2.0),無い(2.0),いま(2.0),説明(2.0),止める(2.0),大臣(1.0),若手(1.0),後始末(1.0),年齢(1.0),だらけ(1.0),始める(1.0),よけい(1.0),過労(1.0),はいる(1.0),反旗(1.0),近い(1.0),モノ(1.0),無くなる(1.0),危険(1.0),便利(1.0),郵便(1.0),思う(1.0),周り(1.0),自足(1.0),購入(1.0),返納(1.0),答える(1.0),考え(1.0),担ぐ(1.0), probability:0.043
# 2:でも、物理カードを国民の大多数が持つことに、何の意味があるのですうか？
# node_id:681, node_words:成立(2.0),内閣(2.0),上手い(2.0),文句(2.0),知る(1.0),自信(1.0),知れる(1.0),場面(1.0),病院(1.0),リスク(1.0),書類(1.0),気軽(1.0),現在(1.0),逃げ(1.0),購入(1.0),メンバー(1.0),全員(1.0),多額(1.0),賠償(1.0),意味(1.0),閣議(1.0),計る(1.0),アメリカ(1.0),決定(1.0),持ち歩く(1.0),結果(1.0),併用(1.0),拳銃(1.0),打つ(1.0),割合(0.0), probability:0.03
# 3:リモートで各種手続きができるて便利というますが、それは税理士さんとか頻繁に公的手続きをする仕事の方の話だあるて、一般には、住民票を取ることすら数年に一度の方が多いのだはないかと思うます。
# node_id:787, node_words:来る(3.0),田舎(2.0),無い(2.0),いま(2.0),説明(2.0),止める(2.0),大臣(1.0),若手(1.0),後始末(1.0),年齢(1.0),だらけ(1.0),始める(1.0),よけい(1.0),過労(1.0),はいる(1.0),反旗(1.0),近い(1.0),モノ(1.0),無くなる(1.0),危険(1.0),便利(1.0),郵便(1.0),思う(1.0),周り(1.0),自足(1.0),購入(1.0),返納(1.0),答える(1.0),考え(1.0),担ぐ(1.0), probability:0.102
# 4:印鑑証明カードのように、必要だ人が取得できる仕組みで、何の不都合があるのですう？
# node_id:768, node_words:かける(2.0),お前(2.0),役人(2.0),照会(2.0),引きずる(2.0),解体(2.0),管轄(1.0),仕事(1.0),加減(1.0),被害(1.0),奴隷(1.0),大事(1.0),続ける(1.0),見切り(1.0),余計(1.0),プログラム(1.0),降ろす(1.0),無効(1.0),平気(1.0),求める(1.0),まみれ(1.0),疲れる(1.0),都合(1.0),間に合う(1.0),偉い(1.0),答え(1.0),発車(1.0),お互い(1.0),給料(1.0),事例(1.0), probability:0.045
# 5:百歩譲って、何かの理由で個人を特定するICチップを持つせるたいのだ、スマホのICチップに記録するとか、運転免許証のICチップに記録するとか、既に持つているICチップで一定のセキュリティ規格を満たすものだ何でも良いと思うますが、なぜマイナンバー「カード」に統合だのでしよう？
# node_id:696, node_words:チップ(5.0),埋め込む(5.0),マイクロ(4.0),ここ(2.0),バカ(2.0),肌身(2.0),離す(2.0),認識(2.0),意図(1.0),仕事(1.0),怒る(1.0),埋設(1.0),離脱(1.0),手放せる(1.0),コオロギ(1.0),多数(1.0),不愉快(1.0),リモート(1.0),走り出す(1.0),方式(1.0),チェーン(1.0),公表(1.0),満たす(1.0),人体(1.0),譲る(1.0),気付く(1.0),給付(1.0),打ち込む(1.0),ドック(1.0),恐ろしい(1.0), probability:0.279
# 6:いまいち、理解できるますん。
# node_id:788, node_words:環境(2.0),セキュリティ(2.0),理解(2.0),通信(2.0),優良(1.0),弊害(1.0),確認(1.0),上げる(1.0),かむ(1.0),発行(1.0),分散(1.0),マイナー(1.0),確か(1.0),ヤボ(1.0),山岳(1.0),場所(1.0),落とす(1.0),場面(1.0),とこ(1.0),辞職(1.0),直行(1.0),使う(1.0),機能(1.0),警察官(1.0),えらい(1.0),長蛇(1.0),創設(0.0),前向き(0.0),割高(0.0),前提(0.0), probability:0.067
# 7:持つてますけど。
# node_id:776, node_words:ダメ(6.0),くっつける(2.0),警察官(2.0),絡む(2.0),一つ(2.0),ついてる(2.0),方々(1.0),捨てる(1.0),改善(1.0),倒す(1.0),テレビ(1.0),東日本(1.0),大きい(1.0),クルー(1.0),悪い(1.0),我々(1.0),学ぶ(1.0),同義(1.0),わけ(1.0),ドミノ(1.0),交通(1.0),昭和(1.0),わける(1.0),しよう(1.0),隊員(1.0),電波(1.0),手放す(1.0),異例(1.0),警ら(1.0),リーダー(1.0), probability:0.0
# ------------------------------------------------------------------
# 0:マイナンバーカードを返納するている人が増えるているとの記事を読むますた。
# node_id:789, node_words:公式(2.0),犯罪(2.0),苦情(2.0),反対(2.0),そう(1.0),官邸(1.0),公明党(1.0),返す(1.0),メール(1.0),心配(1.0),漏れる(1.0),否定(1.0),そもそも(1.0),安定(1.0),ほける(1.0),岸田(1.0),ポイント(1.0),まじめ(1.0),ホームページ(1.0),起こる(1.0),限界(1.0),ゆるい(1.0),実装(1.0),国土(1.0),防止(1.0),意地(1.0),貰う(1.0),落とす(1.0),くん(1.0),総理(1.0), probability:0.023
# 1:作るてしまうた人達は、今からだも遅いないので、返納するて反対の意志を示すのが大事だと思うます。
# node_id:787, node_words:来る(3.0),田舎(2.0),無い(2.0),いま(2.0),説明(2.0),止める(2.0),大臣(1.0),若手(1.0),後始末(1.0),年齢(1.0),だらけ(1.0),始める(1.0),よけい(1.0),過労(1.0),はいる(1.0),反旗(1.0),近い(1.0),モノ(1.0),無くなる(1.0),危険(1.0),便利(1.0),郵便(1.0),思う(1.0),周り(1.0),自足(1.0),購入(1.0),返納(1.0),答える(1.0),考え(1.0),担ぐ(1.0), probability:0.064
# 2:貰うたポイントも返すないて良いそうですよ。
# node_id:193, node_words:禁止(3.0),本来(2.0),許可(1.0),大差(1.0),メリット(1.0),自然(1.0),多く(1.0),撒く(1.0),ポイント(1.0),壊す(1.0),銀行(1.0),世の中(1.0),めちゃくちゃ(1.0),忘れる(1.0),貼付(1.0),試験(1.0),証左(1.0),取得(0.0),前科(0.0),割高(0.0),割合(0.0),割り振る(0.0),受け取れる(0.0),割り(0.0),副作用(0.0),前進(0.0),受付(0.0),前提(0.0),創造(0.0),前向き(0.0), probability:0.05
# 3:そして今度の選挙では、自民党ではないMAINA一本化に否定的だ人に投票するますう。
# node_id:447, node_words:投票(6.0),選挙(5.0),政党(4.0),彼ら(3.0),時代(2.0),強い(2.0),衆議院(2.0),自公(2.0),強行(2.0),結果(2.0),成り下がる(2.0),危なっかしい(2.0),お願い(2.0),次回(2.0),慎重(2.0),交代(2.0),一部(2.0),放題(2.0),問う(2.0),バック(1.0),公共(1.0),マスコミ(1.0),事態(1.0),上がる(1.0),手遅れ(1.0),ついてる(1.0),既得(1.0),公約(1.0),表れ(1.0),刻む(1.0), probability:0.096
# ------------------------------------------------------------------
# 0:これ交通違反の取締りのときはどうするの。
# node_id:36, node_words:チップ(7.0),交通(4.0),住所(3.0),専用(3.0),表面(3.0),記載(3.0),違反(3.0),パトカー(3.0),有効(2.0),車両(2.0),性別(2.0),不都合(2.0),名前(2.0),乗る(2.0),入る(2.0),事項(2.0),白バイ(2.0),説明(2.0),取締り(2.0),怒る(1.0),現行(1.0),メッセージ(1.0),狂う(1.0),ちかい(1.0),場所(1.0),就職(1.0),氏名(1.0),路上(1.0),メリット(1.0),無くなる(1.0), probability:0.078
# 1:パトロール中に信号無視をするた車を発見するますた、車を停めるて免許証を提示するせるますた、MyNA免許証の表面には免許証としての情報は載るているますん、免許証としての情報を確認するためはICチップを読む専用の機械が必要です、でもパトカーにはその専用の機械がないて確認できるますんですた。
# node_id:36, node_words:チップ(7.0),交通(4.0),住所(3.0),専用(3.0),表面(3.0),記載(3.0),違反(3.0),パトカー(3.0),有効(2.0),車両(2.0),性別(2.0),不都合(2.0),名前(2.0),乗る(2.0),入る(2.0),事項(2.0),白バイ(2.0),説明(2.0),取締り(2.0),怒る(1.0),現行(1.0),メッセージ(1.0),狂う(1.0),ちかい(1.0),場所(1.0),就職(1.0),氏名(1.0),路上(1.0),メリット(1.0),無くなる(1.0), probability:0.16
# 2:こうした事態を避けるためには、全国に配属するれるているパトカーや白バイなどのすべての警察車両にICチップを読み取る専用の機械が必要になるということだよね。
# node_id:36, node_words:チップ(7.0),交通(4.0),住所(3.0),専用(3.0),表面(3.0),記載(3.0),違反(3.0),パトカー(3.0),有効(2.0),車両(2.0),性別(2.0),不都合(2.0),名前(2.0),乗る(2.0),入る(2.0),事項(2.0),白バイ(2.0),説明(2.0),取締り(2.0),怒る(1.0),現行(1.0),メッセージ(1.0),狂う(1.0),ちかい(1.0),場所(1.0),就職(1.0),氏名(1.0),路上(1.0),メリット(1.0),無くなる(1.0), probability:0.181
# 3:そうしないと交通違反の取締りすらできるないなるのだから。
# node_id:36, node_words:チップ(7.0),交通(4.0),住所(3.0),専用(3.0),表面(3.0),記載(3.0),違反(3.0),パトカー(3.0),有効(2.0),車両(2.0),性別(2.0),不都合(2.0),名前(2.0),乗る(2.0),入る(2.0),事項(2.0),白バイ(2.0),説明(2.0),取締り(2.0),怒る(1.0),現行(1.0),メッセージ(1.0),狂う(1.0),ちかい(1.0),場所(1.0),就職(1.0),氏名(1.0),路上(1.0),メリット(1.0),無くなる(1.0), probability:0.078
# 4:全国に何万台とある警察車両に搭載するのにどれだけの費用と年月がかかるのか。
# node_id:157, node_words:スマート(6.0),フォン(6.0),モバイル(5.0),搭載(4.0),変える(3.0),恐ろしい(2.0),スマ(2.0),つる(2.0),どっち(2.0),事故(1.0),税収(1.0),回りくどい(1.0),識別(1.0),強気(1.0),思惑(1.0),思う(1.0),バッシング(1.0),生きる(1.0),面倒くさい(1.0),アナウンス(1.0),くる(1.0),少額(1.0),新た(1.0),導入(1.0),国家(1.0),年金(1.0),釣る(1.0),さん(1.0),不正(1.0),安易(1.0), probability:0.065
# 5:はたしてマイナンバーカードと運転免許証との一体化にそれに見合うだけの効果があるか疑問だな。
# node_id:755, node_words:芋づる(2.0),登録(2.0),期限(2.0),悪い(1.0),みな(1.0),番号(1.0),結果(1.0),バラバラ(1.0),縛る(1.0),クレジットカード(1.0),のせる(1.0),信じる(1.0),平日(1.0),総理(1.0),不幸(1.0),裏切る(1.0),願い下げ(1.0),カード(1.0),譲る(1.0),保健所(1.0),区役所(1.0),マイナス(1.0),統一(1.0),適当(1.0),身動き(1.0),安全(1.0),河野(1.0),イメージ(1.0),解決(1.0),太鼓判(1.0), probability:0.022
# ------------------------------------------------------------------
# 0:確認手段は複数個用意するて奥方が、安全。
# node_id:786, node_words:ごまかし(1.0),流れ(1.0),誤謬(1.0),譲る(1.0),かざす(1.0),徹底的(1.0),いろいろ(1.0),保証(1.0),確認(1.0),対策(1.0),価値(1.0),電子(1.0),高まる(1.0),開発(1.0),きく(1.0),前進(0.0),前提(0.0),加減(0.0),加入(0.0),加わる(0.0),加える(0.0),前科(0.0),功績(0.0),割り(0.0),創造(0.0),創設(0.0),副作用(0.0),割高(0.0),加点(0.0),割り振る(0.0), probability:0.067
# 1:免許証ないときは、保険証と公的郵便物で本人確認とかもあるますたよね。
# node_id:793, node_words:見る(2.0),私利(1.0),ゴリ押し(1.0),今度(1.0),よる(1.0),ブロック(1.0),大切(1.0),保管(1.0),ここ(1.0),突きつける(1.0),保険(1.0),ほる(1.0),多い(1.0),割高(0.0),加入(0.0),前提(0.0),加減(0.0),前科(0.0),前進(0.0),副作用(0.0),加わる(0.0),創設(0.0),加える(0.0),割り(0.0),功績(0.0),創造(0.0),割り振る(0.0),割合(0.0),加点(0.0),ｏｋ(0.0), probability:0.071
# 2:そうやるてリスクは、重要だ事柄に関しては分散するせるものだと考えるます。
# node_id:632, node_words:いく(3.0),連携(2.0),注ぐ(2.0),集約(2.0),説明(2.0),マジ(2.0),腐る(2.0),リスク(2.0),結果(2.0),将来(1.0),バカげる(1.0),保険(1.0),ワンマン(1.0),国交(1.0),方向(1.0),アホ(1.0),国家(1.0),取り上げる(1.0),想定(1.0),能力(1.0),本人(1.0),財産(1.0),させる(1.0),功績(0.0),動向(0.0),加える(0.0),創造(0.0),創設(0.0),加入(0.0),割高(0.0), probability:0.091
# 3:一つしか手段がないと簡単に行き詰まりまります。
# node_id:766, node_words:役場(2.0),公的(2.0),設置(1.0),近い(1.0),普及(1.0),オンライン(1.0),日本(1.0),れる(1.0),国政(1.0),まり(1.0),報道(1.0),身動き(1.0),ほか(1.0),ばあちゃん(1.0),どれ(1.0),取れる(1.0),始め(1.0),始動(1.0),扱い(1.0),手間隙(1.0),安倍(1.0),選択(1.0),戦争(1.0),郵便(1.0),都合(1.0),鉄壁(1.0),容認(1.0),普段(1.0),解消(1.0),必死(1.0), probability:0.044
# 4:何より強靭だシステムとか鉄壁のシステムでもない限り電子系だけに頼るのは危険。
# node_id:735, node_words:増やす(2.0),友達(2.0),大勢(1.0),共産党(1.0),繰り返す(1.0),それぞれ(1.0),戻る(1.0),年金(1.0),民度(1.0),利他(1.0),社員(1.0),必須(1.0),安定(1.0),選択(1.0),選択肢(1.0),自由(1.0),自由民主党(1.0),低い(1.0),思い出す(1.0),流れ(1.0),止める(1.0),システム(1.0),不自由(1.0),言葉(1.0),奪う(1.0),労働(0.0),助ける(0.0),前向き(0.0),努力(0.0),削減(0.0), probability:0.071
# ------------------------------------------------------------------
# 0:そもそも、自民党政治と言うのは昔から利権の塊だあるますから、元々、国民の為に仕事はするておるますん。
# node_id:673, node_words:値上がり(3.0),給料(2.0),なれる(1.0),近づく(1.0),あんた(1.0),制度(1.0),補助(1.0),国々(1.0),覇権(1.0),全力(1.0),主義(1.0),我々(1.0),我が国(1.0),近い(1.0),ガソリン(1.0),汗水(1.0),国家(1.0),安心(1.0),降ろす(1.0),垂らす(1.0),民主(1.0),中国(1.0),下野(1.0),物価(1.0),政治(1.0),おかげ(1.0),与党(1.0),正す(1.0),根こそぎ(1.0),創設(0.0), probability:0.031
# 1:一部の奴の為に仕事をするておるますから一般庶民は何時も困るているます。
# node_id:447, node_words:投票(6.0),選挙(5.0),政党(4.0),彼ら(3.0),時代(2.0),強い(2.0),衆議院(2.0),自公(2.0),強行(2.0),結果(2.0),成り下がる(2.0),危なっかしい(2.0),お願い(2.0),次回(2.0),慎重(2.0),交代(2.0),一部(2.0),放題(2.0),問う(2.0),バック(1.0),公共(1.0),マスコミ(1.0),事態(1.0),上がる(1.0),手遅れ(1.0),ついてる(1.0),既得(1.0),公約(1.0),表れ(1.0),刻む(1.0), probability:0.043
# 2:何故、日本人は選挙になると自民党に投票するてしまうのか？
# node_id:447, node_words:投票(6.0),選挙(5.0),政党(4.0),彼ら(3.0),時代(2.0),強い(2.0),衆議院(2.0),自公(2.0),強行(2.0),結果(2.0),成り下がる(2.0),危なっかしい(2.0),お願い(2.0),次回(2.0),慎重(2.0),交代(2.0),一部(2.0),放題(2.0),問う(2.0),バック(1.0),公共(1.0),マスコミ(1.0),事態(1.0),上がる(1.0),手遅れ(1.0),ついてる(1.0),既得(1.0),公約(1.0),表れ(1.0),刻む(1.0), probability:0.096
# 3:非常に不思議でもあるますし、何故なのか？
# node_id:628, node_words:エラー(4.0),それぞれ(4.0),推し進める(3.0),出る(3.0),脆弱(3.0),分ける(3.0),網羅(2.0),思う(2.0),活用(2.0),ツール(2.0),警官(2.0),危機(2.0),見直す(2.0),非常(2.0),徹底的(2.0),至上(1.0),外国(1.0),ひとりひとり(1.0),温床(1.0),常軌(1.0),陥る(1.0),所持(1.0),電脳(1.0),警視庁(1.0),恥ずかしい(1.0),ライン(1.0),提示(1.0),電気(1.0),アナログ(1.0),向ける(1.0), probability:0.025
# 4:此のままだと日本は更に、とんでもない事になるて仕舞うますから、近いうちに衆議院選挙があるますから、自公に非常に危険ですし警戒をする必要があると思うているます。
# node_id:787, node_words:来る(3.0),田舎(2.0),無い(2.0),いま(2.0),説明(2.0),止める(2.0),大臣(1.0),若手(1.0),後始末(1.0),年齢(1.0),だらけ(1.0),始める(1.0),よけい(1.0),過労(1.0),はいる(1.0),反旗(1.0),近い(1.0),モノ(1.0),無くなる(1.0),危険(1.0),便利(1.0),郵便(1.0),思う(1.0),周り(1.0),自足(1.0),購入(1.0),返納(1.0),答える(1.0),考え(1.0),担ぐ(1.0), probability:0.122
# 5:政権交代を目標に我々日本人は頑張るないばなるますん。
# node_id:780, node_words:携帯(1.0),各所(1.0),場所(1.0),負け(1.0),支給(1.0),まみれる(1.0),同様(1.0),自治体(1.0),譲る(1.0),補助(1.0),リスク(1.0),始まる(1.0),争奪(1.0),投げる(1.0),日本人(1.0),外国(1.0),企業(1.0),見づらい(1.0),危ない(1.0),一切(1.0),購入(1.0),賃金(1.0),節約(1.0),割り(0.0),創設(0.0),前提(0.0),創造(0.0),前進(0.0),前科(0.0),割高(0.0), probability:0.043
# 6:今後、日本の舵取りを補うて貰うのは、れいわ新選組を中心とするた政権と致すます。
# node_id:447, node_words:投票(6.0),選挙(5.0),政党(4.0),彼ら(3.0),時代(2.0),強い(2.0),衆議院(2.0),自公(2.0),強行(2.0),結果(2.0),成り下がる(2.0),危なっかしい(2.0),お願い(2.0),次回(2.0),慎重(2.0),交代(2.0),一部(2.0),放題(2.0),問う(2.0),バック(1.0),公共(1.0),マスコミ(1.0),事態(1.0),上がる(1.0),手遅れ(1.0),ついてる(1.0),既得(1.0),公約(1.0),表れ(1.0),刻む(1.0), probability:0.035
# 7:皆さんも当然、意義は無いと思うますから絶対に皆の為に政権交代をしようじゃないですか。
# node_id:787, node_words:来る(3.0),田舎(2.0),無い(2.0),いま(2.0),説明(2.0),止める(2.0),大臣(1.0),若手(1.0),後始末(1.0),年齢(1.0),だらけ(1.0),始める(1.0),よけい(1.0),過労(1.0),はいる(1.0),反旗(1.0),近い(1.0),モノ(1.0),無くなる(1.0),危険(1.0),便利(1.0),郵便(1.0),思う(1.0),周り(1.0),自足(1.0),購入(1.0),返納(1.0),答える(1.0),考え(1.0),担ぐ(1.0), probability:0.085
# ------------------------------------------------------------------
# 0:免許証との一体化だけは賛成出来るないかな、こんなもん提示する時トラブル起きるの分かるてるしこんな穴だらけのシステムで情報が垂れ流しするれるたたまるたもんじゃないよな、それに一体化するれるた常に携帯するてるないちゃならぶし落とす可能性も高いなるのに再発行まで何ヶ月も掛かるて手続きもめちゃくちゃ面倒いさいくなるのは分かるてるのに民意を無視するて進めるなと言うたい
# node_id:9, node_words:紛失(31.0),発行(30.0),リスク(14.0),無くす(14.0),病院(13.0),場合(10.0),万が一(7.0),簡単(5.0),行ける(5.0),書く(5.0),そう(5.0),即時(4.0),かかる(4.0),怖い(4.0),乗れる(4.0),週間(4.0),その間(4.0),いう(3.0),一体化(3.0),ふざける(3.0),役所(3.0),複数(3.0),増える(3.0),確率(3.0),合体(2.0),証明(2.0),避ける(2.0),単体(2.0),前提(2.0),試験(2.0), probability:0.124
# ------------------------------------------------------------------
# 0:運転免許証をマイナンバーカードに組み込むじゃうと、日常運転する人は常時マイナンバーカードを携帯するとかナイト不携帯って事になるという事ですよね？
# node_id:780, node_words:携帯(1.0),各所(1.0),場所(1.0),負け(1.0),支給(1.0),まみれる(1.0),同様(1.0),自治体(1.0),譲る(1.0),補助(1.0),リスク(1.0),始まる(1.0),争奪(1.0),投げる(1.0),日本人(1.0),外国(1.0),企業(1.0),見づらい(1.0),危ない(1.0),一切(1.0),購入(1.0),賃金(1.0),節約(1.0),割り(0.0),創設(0.0),前提(0.0),創造(0.0),前進(0.0),前科(0.0),割高(0.0), probability:0.083
# 1:個人情報を詰め込むだカードを常時携帯するせるようだ行為を見過ごすて良いのか？
# node_id:780, node_words:携帯(1.0),各所(1.0),場所(1.0),負け(1.0),支給(1.0),まみれる(1.0),同様(1.0),自治体(1.0),譲る(1.0),補助(1.0),リスク(1.0),始まる(1.0),争奪(1.0),投げる(1.0),日本人(1.0),外国(1.0),企業(1.0),見づらい(1.0),危ない(1.0),一切(1.0),購入(1.0),賃金(1.0),節約(1.0),割り(0.0),創設(0.0),前提(0.0),創造(0.0),前進(0.0),前科(0.0),割高(0.0), probability:0.043
# 2:それとも不携帯の罰則を見直すてくれるのか？
# node_id:780, node_words:携帯(1.0),各所(1.0),場所(1.0),負け(1.0),支給(1.0),まみれる(1.0),同様(1.0),自治体(1.0),譲る(1.0),補助(1.0),リスク(1.0),始まる(1.0),争奪(1.0),投げる(1.0),日本人(1.0),外国(1.0),企業(1.0),見づらい(1.0),危ない(1.0),一切(1.0),購入(1.0),賃金(1.0),節約(1.0),割り(0.0),創設(0.0),前提(0.0),創造(0.0),前進(0.0),前科(0.0),割高(0.0), probability:0.043
# 3:マイナンバーカードには番号も記載するれるてるし、本当に必要だ時にしか携帯するたいないというのが本音です。
# node_id:14, node_words:番号(13.0),暗証(12.0),記載(5.0),役所(4.0),高齢(4.0),入力(3.0),間違える(3.0),住民(3.0),住所(3.0),付く(3.0),誕生(3.0),設定(2.0),機器(2.0),意識(2.0),不明(2.0),警察官(2.0),停電(2.0),向かう(2.0),犯罪(2.0),開ける(2.0),太郎(2.0),体制(2.0),伝える(2.0),体型(2.0),痴呆(2.0),整える(1.0),固定(1.0),暗い(1.0),故障(1.0),時期(1.0), probability:0.097
# ------------------------------------------------------------------
# 0:データの一元管理をマイナンバーシステムでするだけだ良いのだは？とも思うます。
# node_id:787, node_words:来る(3.0),田舎(2.0),無い(2.0),いま(2.0),説明(2.0),止める(2.0),大臣(1.0),若手(1.0),後始末(1.0),年齢(1.0),だらけ(1.0),始める(1.0),よけい(1.0),過労(1.0),はいる(1.0),反旗(1.0),近い(1.0),モノ(1.0),無くなる(1.0),危険(1.0),便利(1.0),郵便(1.0),思う(1.0),周り(1.0),自足(1.0),購入(1.0),返納(1.0),答える(1.0),考え(1.0),担ぐ(1.0), probability:0.043
# 1:個人的には、保険証、免許証、MAINAと3枚持ち歩くないて済むのは歓迎です。
# node_id:793, node_words:見る(2.0),私利(1.0),ゴリ押し(1.0),今度(1.0),よる(1.0),ブロック(1.0),大切(1.0),保管(1.0),ここ(1.0),突きつける(1.0),保険(1.0),ほる(1.0),多い(1.0),割高(0.0),加入(0.0),前提(0.0),加減(0.0),前科(0.0),前進(0.0),副作用(0.0),加わる(0.0),創設(0.0),加える(0.0),割り(0.0),功績(0.0),創造(0.0),割り振る(0.0),割合(0.0),加点(0.0),ｏｋ(0.0), probability:0.071
# 2:言うだ、指紋やら声紋やら顔やらの生体認証情報を登録するてるばカードすら必要ない、病院に通えるたり、車運転出来るたりするばいいね。
# node_id:58, node_words:認証(9.0),コピー(7.0),指紋(5.0),書類(4.0),計画(4.0),対面(3.0),悪用(3.0),パスワード(3.0),公的(3.0),やり方(3.0),重点(2.0),券面(2.0),思える(2.0),なりすます(2.0),如何(2.0),放題(2.0),他人(2.0),否定(1.0),滅びる(1.0),ノー(1.0),網膜(1.0),明らか(1.0),交代(1.0),下がり(1.0),隣国(1.0),単純(1.0),遅い(1.0),万が一(1.0),認識(1.0),静脈(1.0), probability:0.123
# 3:車自体に認証機能を搭載するてるば、無免許とか更新切れとかだと車が動くないばいいし、納税や還付も確定申告なんかするないても自動ですてくれるとか、給付金も手続きないだ給付するてくれるとかになるば便利ですね。
# node_id:116, node_words:更新(27.0),ゴールド(6.0),ブルー(4.0),即日(3.0),会場(2.0),信用度(2.0),置く(2.0),アホ(2.0),検査(2.0),オレ(2.0),知る(2.0),グリーン(2.0),装置(2.0),視力(2.0),期間(2.0),無くなる(1.0),ヶ月(1.0),出生(1.0),ども(1.0),主義(1.0),がわり(1.0),返答(1.0),太郎(1.0),聞く(1.0),個々(1.0),聞こえる(1.0),判明(1.0),民間(1.0),別人(1.0),一般(1.0), probability:0.189
# 4:あと国会議員や地方議員さんなんかは率先するて、デジタル化に取り組むでみるたいいですね。
# node_id:379, node_words:議員(16.0),国会(11.0),さん(7.0),役人(5.0),河野(4.0),誤る(4.0),無能(3.0),太郎(3.0),文雄(3.0),払う(2.0),政府(2.0),歓迎(2.0),つくる(2.0),必要(2.0),勝手(2.0),給付(2.0),現金(2.0),通える(2.0),起こる(2.0),一般(2.0),チェック(2.0),引き出す(2.0),基地(2.0),公明(1.0),できる(1.0),通り(1.0),通す(1.0),三昧(1.0),抱く(1.0),送る(1.0), probability:0.282
# 5:一円単位で使途を公開するとか、選挙投票出来るとか議員さんの評価を簡単にできる仕組みにも活用するてくださる。
# node_id:379, node_words:議員(16.0),国会(11.0),さん(7.0),役人(5.0),河野(4.0),誤る(4.0),無能(3.0),太郎(3.0),文雄(3.0),払う(2.0),政府(2.0),歓迎(2.0),つくる(2.0),必要(2.0),勝手(2.0),給付(2.0),現金(2.0),通える(2.0),起こる(2.0),一般(2.0),チェック(2.0),引き出す(2.0),基地(2.0),公明(1.0),できる(1.0),通り(1.0),通す(1.0),三昧(1.0),抱く(1.0),送る(1.0), probability:0.157
# 6:現状メリットが少ないのと、情報漏洩の懸念で歓迎するれるないのですうね。
# node_id:193, node_words:禁止(3.0),本来(2.0),許可(1.0),大差(1.0),メリット(1.0),自然(1.0),多く(1.0),撒く(1.0),ポイント(1.0),壊す(1.0),銀行(1.0),世の中(1.0),めちゃくちゃ(1.0),忘れる(1.0),貼付(1.0),試験(1.0),証左(1.0),取得(0.0),前科(0.0),割高(0.0),割合(0.0),割り振る(0.0),受け取れる(0.0),割り(0.0),副作用(0.0),前進(0.0),受付(0.0),前提(0.0),創造(0.0),前向き(0.0), probability:0.05
# 7:便利で住むやすい日本になるていくことを望むます。
# node_id:632, node_words:いく(3.0),連携(2.0),注ぐ(2.0),集約(2.0),説明(2.0),マジ(2.0),腐る(2.0),リスク(2.0),結果(2.0),将来(1.0),バカげる(1.0),保険(1.0),ワンマン(1.0),国交(1.0),方向(1.0),アホ(1.0),国家(1.0),取り上げる(1.0),想定(1.0),能力(1.0),本人(1.0),財産(1.0),させる(1.0),功績(0.0),動向(0.0),加える(0.0),創造(0.0),創設(0.0),加入(0.0),割高(0.0), probability:0.091
# ------------------------------------------------------------------
# 0:結局、運転免許証の更新制度は変わるないのですう？
# node_id:116, node_words:更新(27.0),ゴールド(6.0),ブルー(4.0),即日(3.0),会場(2.0),信用度(2.0),置く(2.0),アホ(2.0),検査(2.0),オレ(2.0),知る(2.0),グリーン(2.0),装置(2.0),視力(2.0),期間(2.0),無くなる(1.0),ヶ月(1.0),出生(1.0),ども(1.0),主義(1.0),がわり(1.0),返答(1.0),太郎(1.0),聞く(1.0),個々(1.0),聞こえる(1.0),判明(1.0),民間(1.0),別人(1.0),一般(1.0), probability:0.189
# 1:それなら、顔写真の更新も兼ねるて悪いはないと思うます。
# node_id:116, node_words:更新(27.0),ゴールド(6.0),ブルー(4.0),即日(3.0),会場(2.0),信用度(2.0),置く(2.0),アホ(2.0),検査(2.0),オレ(2.0),知る(2.0),グリーン(2.0),装置(2.0),視力(2.0),期間(2.0),無くなる(1.0),ヶ月(1.0),出生(1.0),ども(1.0),主義(1.0),がわり(1.0),返答(1.0),太郎(1.0),聞く(1.0),個々(1.0),聞こえる(1.0),判明(1.0),民間(1.0),別人(1.0),一般(1.0), probability:0.203
# 2:本人確認の媒体としても一定の効力はあるのですし。
# node_id:786, node_words:ごまかし(1.0),流れ(1.0),誤謬(1.0),譲る(1.0),かざす(1.0),徹底的(1.0),いろいろ(1.0),保証(1.0),確認(1.0),対策(1.0),価値(1.0),電子(1.0),高まる(1.0),開発(1.0),きく(1.0),前進(0.0),前提(0.0),加減(0.0),加入(0.0),加わる(0.0),加える(0.0),前科(0.0),功績(0.0),割り(0.0),創造(0.0),創設(0.0),副作用(0.0),割高(0.0),加点(0.0),割り振る(0.0), probability:0.067
# 3:*に免許証情報を加えるまでは構うないです。
# node_id:751, node_words:端末(4.0),見せる(2.0),加える(2.0),電子(2.0),住所(2.0),サービス(2.0),監視(2.0),契約(2.0),開始(1.0),読み込む(1.0),要求(1.0),下げる(1.0),手間(1.0),現実(1.0),整合(1.0),現時点(1.0),難しい(1.0),加わる(1.0),無知(1.0),身近(1.0),電波(1.0),氏名(1.0),万全(1.0),余計(1.0),障害(1.0),結局(1.0),複写(1.0),呼び出す(1.0),起動(1.0),変わる(1.0), probability:0.029
# 4:ただ、結局所持するない*。
# node_id:790, node_words:対策(4.0),整備(3.0),示す(3.0),整える(2.0),居る(2.0),バッチ(2.0),向ける(2.0),ただ(2.0),合格(2.0),しな(2.0),選択肢(2.0),意思(1.0),被害(1.0),保証(1.0),狭める(1.0),叶う(1.0),事実(1.0),家庭(1.0),お子さん(1.0),読み込む(1.0),梯子(1.0),時期(1.0),クビ(1.0),研究(1.0),明らか(1.0),やめる(1.0),名寄せ(1.0),金額(1.0),ロード(1.0),リーダー(1.0), probability:0.055
# 5:確認時は警察側の端末で専用サイトにアクセスするて、名前や生年月日、住所などから顔写真付きの本人データを呼び出すて、本人と一緒に確認とかだ良いのかなと。
# node_id:751, node_words:端末(4.0),見せる(2.0),加える(2.0),電子(2.0),住所(2.0),サービス(2.0),監視(2.0),契約(2.0),開始(1.0),読み込む(1.0),要求(1.0),下げる(1.0),手間(1.0),現実(1.0),整合(1.0),現時点(1.0),難しい(1.0),加わる(1.0),無知(1.0),身近(1.0),電波(1.0),氏名(1.0),万全(1.0),余計(1.0),障害(1.0),結局(1.0),複写(1.0),呼び出す(1.0),起動(1.0),変わる(1.0), probability:0.147
# 6:そうするば、不携帯での取締対象になるないし、利用する側も紛失リスクは下げるられるますしね。
# node_id:9, node_words:紛失(31.0),発行(30.0),リスク(14.0),無くす(14.0),病院(13.0),場合(10.0),万が一(7.0),簡単(5.0),行ける(5.0),書く(5.0),そう(5.0),即時(4.0),かかる(4.0),怖い(4.0),乗れる(4.0),週間(4.0),その間(4.0),いう(3.0),一体化(3.0),ふざける(3.0),役所(3.0),複数(3.0),増える(3.0),確率(3.0),合体(2.0),証明(2.0),避ける(2.0),単体(2.0),前提(2.0),試験(2.0), probability:0.15
# 7:そもそも今も、仮に旅先で財布とかにいれるて紛失するた、警察に届け出るてもその後運転できるないって、現実的にどうだのよ思うているます。
# node_id:9, node_words:紛失(31.0),発行(30.0),リスク(14.0),無くす(14.0),病院(13.0),場合(10.0),万が一(7.0),簡単(5.0),行ける(5.0),書く(5.0),そう(5.0),即時(4.0),かかる(4.0),怖い(4.0),乗れる(4.0),週間(4.0),その間(4.0),いう(3.0),一体化(3.0),ふざける(3.0),役所(3.0),複数(3.0),増える(3.0),確率(3.0),合体(2.0),証明(2.0),避ける(2.0),単体(2.0),前提(2.0),試験(2.0), probability:0.093
# 8:とにかく、身分証は複数、系統の違うものは必要かなと思うます。
# node_id:787, node_words:来る(3.0),田舎(2.0),無い(2.0),いま(2.0),説明(2.0),止める(2.0),大臣(1.0),若手(1.0),後始末(1.0),年齢(1.0),だらけ(1.0),始める(1.0),よけい(1.0),過労(1.0),はいる(1.0),反旗(1.0),近い(1.0),モノ(1.0),無くなる(1.0),危険(1.0),便利(1.0),郵便(1.0),思う(1.0),周り(1.0),自足(1.0),購入(1.0),返納(1.0),答える(1.0),考え(1.0),担ぐ(1.0), probability:0.043
# 9:現時点で代表格は運転免許証かなと。
# node_id:751, node_words:端末(4.0),見せる(2.0),加える(2.0),電子(2.0),住所(2.0),サービス(2.0),監視(2.0),契約(2.0),開始(1.0),読み込む(1.0),要求(1.0),下げる(1.0),手間(1.0),現実(1.0),整合(1.0),現時点(1.0),難しい(1.0),加わる(1.0),無知(1.0),身近(1.0),電波(1.0),氏名(1.0),万全(1.0),余計(1.0),障害(1.0),結局(1.0),複写(1.0),呼び出す(1.0),起動(1.0),変わる(1.0), probability:0.029
# 10:加えるて警察なりで管理するれる公的身分証が加わるば運転しない人でも助かるかなと思う次第です。
# node_id:766, node_words:役場(2.0),公的(2.0),設置(1.0),近い(1.0),普及(1.0),オンライン(1.0),日本(1.0),れる(1.0),国政(1.0),まり(1.0),報道(1.0),身動き(1.0),ほか(1.0),ばあちゃん(1.0),どれ(1.0),取れる(1.0),始め(1.0),始動(1.0),扱い(1.0),手間隙(1.0),安倍(1.0),選択(1.0),戦争(1.0),郵便(1.0),都合(1.0),鉄壁(1.0),容認(1.0),普段(1.0),解消(1.0),必死(1.0), probability:0.045
# ------------------------------------------------------------------
# 0:一本化するには早いすぎる進行だと思う。
# node_id:161, node_words:アナログ(5.0),増やす(3.0),言える(3.0),世界(2.0),デジタル(2.0),ついていける(2.0),遅れる(2.0),時点(2.0),必須(2.0),確立(2.0),明らか(2.0),進行(2.0),先進(1.0),妥当(1.0),継続(1.0),無視(1.0),ガン(1.0),動機(1.0),公務員(1.0),不純(1.0),やり遂げる(1.0),状況(1.0),投与(1.0),短期間(1.0),感じる(1.0),不足(1.0),徹底(1.0),著しい(1.0),民意(1.0),パンク(1.0), probability:0.025
# 1:そもそもシステムの確立ができるているない状況だし確立するのにある程度の年月は必要。
# node_id:161, node_words:アナログ(5.0),増やす(3.0),言える(3.0),世界(2.0),デジタル(2.0),ついていける(2.0),遅れる(2.0),時点(2.0),必須(2.0),確立(2.0),明らか(2.0),進行(2.0),先進(1.0),妥当(1.0),継続(1.0),無視(1.0),ガン(1.0),動機(1.0),公務員(1.0),不純(1.0),やり遂げる(1.0),状況(1.0),投与(1.0),短期間(1.0),感じる(1.0),不足(1.0),徹底(1.0),著しい(1.0),民意(1.0),パンク(1.0), probability:0.072
# 2:そもそもアナログを廃止するというのもちょっとどうだのかと感じる。
# node_id:161, node_words:アナログ(5.0),増やす(3.0),言える(3.0),世界(2.0),デジタル(2.0),ついていける(2.0),遅れる(2.0),時点(2.0),必須(2.0),確立(2.0),明らか(2.0),進行(2.0),先進(1.0),妥当(1.0),継続(1.0),無視(1.0),ガン(1.0),動機(1.0),公務員(1.0),不純(1.0),やり遂げる(1.0),状況(1.0),投与(1.0),短期間(1.0),感じる(1.0),不足(1.0),徹底(1.0),著しい(1.0),民意(1.0),パンク(1.0), probability:0.074
# 3:一本化するにするてちゃんと不足の事態の場合の対処の体制はできるているんだうか？
# node_id:720, node_words:説明(4.0),不足(4.0),競争(3.0),続出(2.0),有る(2.0),本来(2.0),加入(2.0),行動(2.0),強い(1.0),流出(1.0),天下り(1.0),処分(1.0),つく(1.0),減らす(1.0),投げつける(1.0),野党(1.0),それ(1.0),不利益(1.0),追求(1.0),並行(1.0),想定(1.0),乖離(1.0),信用(1.0),集団(1.0),怖い(1.0),法治(1.0),多く(1.0),切り込む(1.0),検討(1.0),記事(1.0), probability:0.06
# 4:代替としてアナログでの方法も多少面倒になるても残すておくた方がいいように感じる。
# node_id:161, node_words:アナログ(5.0),増やす(3.0),言える(3.0),世界(2.0),デジタル(2.0),ついていける(2.0),遅れる(2.0),時点(2.0),必須(2.0),確立(2.0),明らか(2.0),進行(2.0),先進(1.0),妥当(1.0),継続(1.0),無視(1.0),ガン(1.0),動機(1.0),公務員(1.0),不純(1.0),やり遂げる(1.0),状況(1.0),投与(1.0),短期間(1.0),感じる(1.0),不足(1.0),徹底(1.0),著しい(1.0),民意(1.0),パンク(1.0), probability:0.074
# 5:少なくとも1年ちょっとだすべて万全なんてことは無理かと。
# node_id:161, node_words:アナログ(5.0),増やす(3.0),言える(3.0),世界(2.0),デジタル(2.0),ついていける(2.0),遅れる(2.0),時点(2.0),必須(2.0),確立(2.0),明らか(2.0),進行(2.0),先進(1.0),妥当(1.0),継続(1.0),無視(1.0),ガン(1.0),動機(1.0),公務員(1.0),不純(1.0),やり遂げる(1.0),状況(1.0),投与(1.0),短期間(1.0),感じる(1.0),不足(1.0),徹底(1.0),著しい(1.0),民意(1.0),パンク(1.0), probability:0.025
# ------------------------------------------------------------------
# 0:マイナンバーカードの作成は「任意」ですたよね。
# node_id:451, node_words:任意(12.0),義務(6.0),実質(5.0),やり方(4.0),ふざける(3.0),ミス(2.0),陰険(2.0),同意(2.0),バイト(2.0),いやらしい(2.0),埋める(2.0),遠まわし(2.0),本当(2.0),姑息(2.0),説明(2.0),写真(2.0),外堀(2.0),強引(2.0),拙速(1.0),大丈夫(1.0),持ち主(1.0),物理(1.0),関連(1.0),わけ(1.0),なに(1.0),丁寧(1.0),与える(1.0),諦める(1.0),法律(1.0),思う(1.0), probability:0.117
# 1:いつから強制に変わるたのですうか。
# node_id:776, node_words:ダメ(6.0),くっつける(2.0),警察官(2.0),絡む(2.0),一つ(2.0),ついてる(2.0),方々(1.0),捨てる(1.0),改善(1.0),倒す(1.0),テレビ(1.0),東日本(1.0),大きい(1.0),クルー(1.0),悪い(1.0),我々(1.0),学ぶ(1.0),同義(1.0),わけ(1.0),ドミノ(1.0),交通(1.0),昭和(1.0),わける(1.0),しよう(1.0),隊員(1.0),電波(1.0),手放す(1.0),異例(1.0),警ら(1.0),リーダー(1.0), probability:0.0
# 2:また、カードナンバーが流出しないよう「必要だ時以外は携帯はするないで下さる」ですたよね。
# node_id:693, node_words:想像(2.0),流出(2.0),利用(1.0),危機(1.0),無い(1.0),市民(1.0),うける(1.0),年貢(1.0),潤う(1.0),ハッキング(1.0),報道(1.0),北朝鮮(1.0),バックアップ(1.0),膨大(1.0),罰則(1.0),納める(1.0),繋げる(1.0),ビッグ(1.0),欠ける(1.0),設ける(1.0),袖の下(1.0),能力(1.0),奴隷(1.0),前提(0.0),割り(0.0),副作用(0.0),前進(0.0),前科(0.0),助かる(0.0),前向き(0.0), probability:0.08
# 3:健康保険証、免許証の紐付け、本人確認と必ず携帯するモノに変わるてますよね。
# node_id:793, node_words:見る(2.0),私利(1.0),ゴリ押し(1.0),今度(1.0),よる(1.0),ブロック(1.0),大切(1.0),保管(1.0),ここ(1.0),突きつける(1.0),保険(1.0),ほる(1.0),多い(1.0),割高(0.0),加入(0.0),前提(0.0),加減(0.0),前科(0.0),前進(0.0),副作用(0.0),加わる(0.0),創設(0.0),加える(0.0),割り(0.0),功績(0.0),創造(0.0),割り振る(0.0),割合(0.0),加点(0.0),ｏｋ(0.0), probability:0.071
# 4:国民のコンセンサス取るたのですうか？
# node_id:794, node_words:まとめる(4.0),運行(4.0),大型(3.0),点呼(2.0),断る(2.0),失効(2.0),資格(2.0),たくさん(2.0),運送(2.0),中型(2.0),発覚(2.0),特殊(2.0),種類(2.0),会社(2.0),券面(2.0),ミス(2.0),癒着(1.0),思い(1.0),事業(1.0),裏書(1.0),事故(1.0),かける(1.0),お金(1.0),自動車(1.0),制服(1.0),しっこし(1.0),自体(1.0),清い(1.0),ナンバ(1.0),報う(1.0), probability:0.01
# 5:また、マイナンバーカードを紛失するた時、病院に掛かると10割負担ですか？
# node_id:9, node_words:紛失(31.0),発行(30.0),リスク(14.0),無くす(14.0),病院(13.0),場合(10.0),万が一(7.0),簡単(5.0),行ける(5.0),書く(5.0),そう(5.0),即時(4.0),かかる(4.0),怖い(4.0),乗れる(4.0),週間(4.0),その間(4.0),いう(3.0),一体化(3.0),ふざける(3.0),役所(3.0),複数(3.0),増える(3.0),確率(3.0),合体(2.0),証明(2.0),避ける(2.0),単体(2.0),前提(2.0),試験(2.0), probability:0.138
# 6:免許不携帯になるますか？
# node_id:780, node_words:携帯(1.0),各所(1.0),場所(1.0),負け(1.0),支給(1.0),まみれる(1.0),同様(1.0),自治体(1.0),譲る(1.0),補助(1.0),リスク(1.0),始まる(1.0),争奪(1.0),投げる(1.0),日本人(1.0),外国(1.0),企業(1.0),見づらい(1.0),危ない(1.0),一切(1.0),購入(1.0),賃金(1.0),節約(1.0),割り(0.0),創設(0.0),前提(0.0),創造(0.0),前進(0.0),前科(0.0),割高(0.0), probability:0.043
# ...
# ------------------------------------------------------------------
# 0:免許更新も役所でやるてくれるのかよ？
# node_id:116, node_words:更新(27.0),ゴールド(6.0),ブルー(4.0),即日(3.0),会場(2.0),信用度(2.0),置く(2.0),アホ(2.0),検査(2.0),オレ(2.0),知る(2.0),グリーン(2.0),装置(2.0),視力(2.0),期間(2.0),無くなる(1.0),ヶ月(1.0),出生(1.0),ども(1.0),主義(1.0),がわり(1.0),返答(1.0),太郎(1.0),聞く(1.0),個々(1.0),聞こえる(1.0),判明(1.0),民間(1.0),別人(1.0),一般(1.0), probability:0.196
# 1:岸田は頭が悪すぎ。
# node_id:789, node_words:公式(2.0),犯罪(2.0),苦情(2.0),反対(2.0),そう(1.0),官邸(1.0),公明党(1.0),返す(1.0),メール(1.0),心配(1.0),漏れる(1.0),否定(1.0),そもそも(1.0),安定(1.0),ほける(1.0),岸田(1.0),ポイント(1.0),まじめ(1.0),ホームページ(1.0),起こる(1.0),限界(1.0),ゆるい(1.0),実装(1.0),国土(1.0),防止(1.0),意地(1.0),貰う(1.0),落とす(1.0),くん(1.0),総理(1.0), probability:0.023
# 2:何故中国の悪いとこだけ真似する。
# node_id:145, node_words:中国(4.0),老害(2.0),一族(2.0),好き(2.0),移住(2.0),いとこ(2.0),真似(2.0),支配(1.0),保護(1.0),人類(1.0),殺到(1.0),我々(1.0),思える(1.0),部署(1.0),非難(1.0),自治体(1.0),利権(1.0),官僚(1.0),命令(1.0),希望(1.0),気づく(1.0),待つ(1.0),怖じる(1.0),本格(1.0),担当(1.0),大好き(1.0),職員(1.0),鉄槌(1.0),最大限(1.0),最悪(1.0), probability:0.205
# 3:そんなに中国好きだ、老害二階と一緒に一族で中国に移住するよ！
# node_id:145, node_words:中国(4.0),老害(2.0),一族(2.0),好き(2.0),移住(2.0),いとこ(2.0),真似(2.0),支配(1.0),保護(1.0),人類(1.0),殺到(1.0),我々(1.0),思える(1.0),部署(1.0),非難(1.0),自治体(1.0),利権(1.0),官僚(1.0),命令(1.0),希望(1.0),気づく(1.0),待つ(1.0),怖じる(1.0),本格(1.0),担当(1.0),大好き(1.0),職員(1.0),鉄槌(1.0),最大限(1.0),最悪(1.0), probability:0.372
# ------------------------------------------------------------------
# 0:免許更新も役所でやるてくれるのかよ？
# node_id:116, node_words:更新(27.0),ゴールド(6.0),ブルー(4.0),即日(3.0),会場(2.0),信用度(2.0),置く(2.0),アホ(2.0),検査(2.0),オレ(2.0),知る(2.0),グリーン(2.0),装置(2.0),視力(2.0),期間(2.0),無くなる(1.0),ヶ月(1.0),出生(1.0),ども(1.0),主義(1.0),がわり(1.0),返答(1.0),太郎(1.0),聞く(1.0),個々(1.0),聞こえる(1.0),判明(1.0),民間(1.0),別人(1.0),一般(1.0), probability:0.196
# 1:岸田は頭が悪すぎ。
# node_id:789, node_words:公式(2.0),犯罪(2.0),苦情(2.0),反対(2.0),そう(1.0),官邸(1.0),公明党(1.0),返す(1.0),メール(1.0),心配(1.0),漏れる(1.0),否定(1.0),そもそも(1.0),安定(1.0),ほける(1.0),岸田(1.0),ポイント(1.0),まじめ(1.0),ホームページ(1.0),起こる(1.0),限界(1.0),ゆるい(1.0),実装(1.0),国土(1.0),防止(1.0),意地(1.0),貰う(1.0),落とす(1.0),くん(1.0),総理(1.0), probability:0.023
# 2:何故中国の悪いとこだけ真似する。
# node_id:145, node_words:中国(4.0),老害(2.0),一族(2.0),好き(2.0),移住(2.0),いとこ(2.0),真似(2.0),支配(1.0),保護(1.0),人類(1.0),殺到(1.0),我々(1.0),思える(1.0),部署(1.0),非難(1.0),自治体(1.0),利権(1.0),官僚(1.0),命令(1.0),希望(1.0),気づく(1.0),待つ(1.0),怖じる(1.0),本格(1.0),担当(1.0),大好き(1.0),職員(1.0),鉄槌(1.0),最大限(1.0),最悪(1.0), probability:0.205
# 3:そんなに中国好きだ、老害二階と一緒に一族で中国に移住するよ！
# node_id:145, node_words:中国(4.0),老害(2.0),一族(2.0),好き(2.0),移住(2.0),いとこ(2.0),真似(2.0),支配(1.0),保護(1.0),人類(1.0),殺到(1.0),我々(1.0),思える(1.0),部署(1.0),非難(1.0),自治体(1.0),利権(1.0),官僚(1.0),命令(1.0),希望(1.0),気づく(1.0),待つ(1.0),怖じる(1.0),本格(1.0),担当(1.0),大好き(1.0),職員(1.0),鉄槌(1.0),最大限(1.0),最悪(1.0), probability:0.372
# ------------------------------------------------------------------
# 0:本当に何の責任も負うぬに、自分たちのやるたい事だけ勝手に押し付けるていくというつもりだな。
# node_id:785, node_words:たち(7.0),かも(3.0),スポーツマン(2.0),三流(2.0),一流(2.0),信用(2.0),ビジネスマン(2.0),全員(2.0),携帯(2.0),読み込む(2.0),権利(1.0),囲む(1.0),人生(1.0),オークション(1.0),個々(1.0),誤る(1.0),民放(1.0),不可(1.0),多い(1.0),向き合う(1.0),選ぶ(1.0),群がる(1.0),電波(1.0),誰か(1.0),見せる(1.0),ミス(1.0),ウラ(1.0),車内(1.0),侮る(1.0),手配(1.0), probability:0.097
# 1:国が滅びるようが国民が死に絶えるうが、今やるたい事をやるたい放題に強制する。
# node_id:58, node_words:認証(9.0),コピー(7.0),指紋(5.0),書類(4.0),計画(4.0),対面(3.0),悪用(3.0),パスワード(3.0),公的(3.0),やり方(3.0),重点(2.0),券面(2.0),思える(2.0),なりすます(2.0),如何(2.0),放題(2.0),他人(2.0),否定(1.0),滅びる(1.0),ノー(1.0),網膜(1.0),明らか(1.0),交代(1.0),下がり(1.0),隣国(1.0),単純(1.0),遅い(1.0),万が一(1.0),認識(1.0),静脈(1.0), probability:0.018
# 2:こいつら終わるてる。
# node_id:776, node_words:ダメ(6.0),くっつける(2.0),警察官(2.0),絡む(2.0),一つ(2.0),ついてる(2.0),方々(1.0),捨てる(1.0),改善(1.0),倒す(1.0),テレビ(1.0),東日本(1.0),大きい(1.0),クルー(1.0),悪い(1.0),我々(1.0),学ぶ(1.0),同義(1.0),わけ(1.0),ドミノ(1.0),交通(1.0),昭和(1.0),わける(1.0),しよう(1.0),隊員(1.0),電波(1.0),手放す(1.0),異例(1.0),警ら(1.0),リーダー(1.0), probability:0.0
# ------------------------------------------------------------------
# 0:そりゃ国はないも責任取るないって言うてるから、気楽に紐付けすせるけ自由に管理するよ。
# node_id:735, node_words:増やす(2.0),友達(2.0),大勢(1.0),共産党(1.0),繰り返す(1.0),それぞれ(1.0),戻る(1.0),年金(1.0),民度(1.0),利他(1.0),社員(1.0),必須(1.0),安定(1.0),選択(1.0),選択肢(1.0),自由(1.0),自由民主党(1.0),低い(1.0),思い出す(1.0),流れ(1.0),止める(1.0),システム(1.0),不自由(1.0),言葉(1.0),奪う(1.0),労働(0.0),助ける(0.0),前向き(0.0),努力(0.0),削減(0.0), probability:0.037
# 1:都合が悪いなるた消えるばいいんだから。
# node_id:768, node_words:かける(2.0),お前(2.0),役人(2.0),照会(2.0),引きずる(2.0),解体(2.0),管轄(1.0),仕事(1.0),加減(1.0),被害(1.0),奴隷(1.0),大事(1.0),続ける(1.0),見切り(1.0),余計(1.0),プログラム(1.0),降ろす(1.0),無効(1.0),平気(1.0),求める(1.0),まみれ(1.0),疲れる(1.0),都合(1.0),間に合う(1.0),偉い(1.0),答え(1.0),発車(1.0),お互い(1.0),給料(1.0),事例(1.0), probability:0.023
# ------------------------------------------------------------------
# 0:まったくもつてアホの極みだね
# node_id:632, node_words:いく(3.0),連携(2.0),注ぐ(2.0),集約(2.0),説明(2.0),マジ(2.0),腐る(2.0),リスク(2.0),結果(2.0),将来(1.0),バカげる(1.0),保険(1.0),ワンマン(1.0),国交(1.0),方向(1.0),アホ(1.0),国家(1.0),取り上げる(1.0),想定(1.0),能力(1.0),本人(1.0),財産(1.0),させる(1.0),功績(0.0),動向(0.0),加える(0.0),創造(0.0),創設(0.0),加入(0.0),割高(0.0), probability:0.03
# 1:運転免許で本人確認ができるないって事は運転免許自体が偽物だんだよね？
# node_id:786, node_words:ごまかし(1.0),流れ(1.0),誤謬(1.0),譲る(1.0),かざす(1.0),徹底的(1.0),いろいろ(1.0),保証(1.0),確認(1.0),対策(1.0),価値(1.0),電子(1.0),高まる(1.0),開発(1.0),きく(1.0),前進(0.0),前提(0.0),加減(0.0),加入(0.0),加わる(0.0),加える(0.0),前科(0.0),功績(0.0),割り(0.0),創造(0.0),創設(0.0),副作用(0.0),割高(0.0),加点(0.0),割り振る(0.0), probability:0.067
# 2:なら、警察は免許みるても意味がないですよね？
# node_id:681, node_words:成立(2.0),内閣(2.0),上手い(2.0),文句(2.0),知る(1.0),自信(1.0),知れる(1.0),場面(1.0),病院(1.0),リスク(1.0),書類(1.0),気軽(1.0),現在(1.0),逃げ(1.0),購入(1.0),メンバー(1.0),全員(1.0),多額(1.0),賠償(1.0),意味(1.0),閣議(1.0),計る(1.0),アメリカ(1.0),決定(1.0),持ち歩く(1.0),結果(1.0),併用(1.0),拳銃(1.0),打つ(1.0),割合(0.0), probability:0.03
# ------------------------------------------------------------------
# 0:保険証も含めるて現行制度で誰も困るているないのにわざわざ弄る辺りが無能の極み。
# node_id:793, node_words:見る(2.0),私利(1.0),ゴリ押し(1.0),今度(1.0),よる(1.0),ブロック(1.0),大切(1.0),保管(1.0),ここ(1.0),突きつける(1.0),保険(1.0),ほる(1.0),多い(1.0),割高(0.0),加入(0.0),前提(0.0),加減(0.0),前科(0.0),前進(0.0),副作用(0.0),加わる(0.0),創設(0.0),加える(0.0),割り(0.0),功績(0.0),創造(0.0),割り振る(0.0),割合(0.0),加点(0.0),ｏｋ(0.0), probability:0.071
# 1:この事業の推進に関わるた人間は全てクビにするてもらうたい。
# node_id:767, node_words:撒く(3.0),市町村(3.0),どん(3.0),ばら(3.0),都道府県(2.0),アナログ(2.0),赤ちゃん(2.0),発行(2.0),人手(1.0),晒す(1.0),支持(1.0),現行(1.0),データ(1.0),家族(1.0),詰め込む(1.0),突っ込む(1.0),甘い(1.0),関わる(1.0),クビ(1.0),推進(1.0),増税(1.0),湯水(1.0),難しい(1.0),見直す(1.0),特別(1.0),過去(1.0),対策(1.0),税収(1.0),居る(1.0),含める(1.0), probability:0.027
# ------------------------------------------------------------------
# 0:顔写真がない*国人や第三者が他人のカードを使うて通院するたり車を運転するてるても本人だのかどうか確認できるない・・・。
# node_id:779, node_words:狙い(1.0),特定(1.0),スムーズ(1.0),吸い上げる(1.0),源泉(1.0),操縦(1.0),納税(1.0),でる(1.0),通院(1.0),暮らし(1.0),投資(1.0),口座(1.0),コスト(1.0),割高(0.0),創造(0.0),創設(0.0),功績(0.0),加える(0.0),加わる(0.0),割り振る(0.0),割合(0.0),加減(0.0),割り(0.0),副作用(0.0),前進(0.0),前科(0.0),前提(0.0),前向き(0.0),削減(0.0),削る(0.0), probability:0.077
# 1:最初からそれが狙いだんですか？
# node_id:779, node_words:狙い(1.0),特定(1.0),スムーズ(1.0),吸い上げる(1.0),源泉(1.0),操縦(1.0),納税(1.0),でる(1.0),通院(1.0),暮らし(1.0),投資(1.0),口座(1.0),コスト(1.0),割高(0.0),創造(0.0),創設(0.0),功績(0.0),加える(0.0),加わる(0.0),割り振る(0.0),割合(0.0),加減(0.0),割り(0.0),副作用(0.0),前進(0.0),前科(0.0),前提(0.0),前向き(0.0),削減(0.0),削る(0.0), probability:0.077
# ------------------------------------------------------------------
# 0:一体化は素晴らしいじゃないか反対するてる奴は日本人じゃないだ？
# node_id:800, node_words:統合(2.0),リリース(2.0),民間(1.0),自国(1.0),販売(1.0),大前提(1.0),保護(1.0),素晴らしい(1.0),解消(1.0),判断(1.0),略す(1.0),名称(1.0),かう(1.0),日本人(1.0),移行(1.0),使用(1.0),明らか(1.0),業務(1.0),行い(1.0),帰る(1.0),小さい(1.0),想定(1.0),好き(1.0),容易(1.0),断言(1.0),強調(1.0),もってのほか(1.0),スマ(1.0),副作用(0.0),割高(0.0), probability:0.067
# 1:そんなに通り名が嫌だ自国に帰るたどうですか？
# node_id:800, node_words:統合(2.0),リリース(2.0),民間(1.0),自国(1.0),販売(1.0),大前提(1.0),保護(1.0),素晴らしい(1.0),解消(1.0),判断(1.0),略す(1.0),名称(1.0),かう(1.0),日本人(1.0),移行(1.0),使用(1.0),明らか(1.0),業務(1.0),行い(1.0),帰る(1.0),小さい(1.0),想定(1.0),好き(1.0),容易(1.0),断言(1.0),強調(1.0),もってのほか(1.0),スマ(1.0),副作用(0.0),割高(0.0), probability:0.033
# ------------------------------------------------------------------
# 0:なんか面倒になるてきたないそうの事出生するたマイクロチップ埋めるた？
# node_id:696, node_words:チップ(5.0),埋め込む(5.0),マイクロ(4.0),ここ(2.0),バカ(2.0),肌身(2.0),離す(2.0),認識(2.0),意図(1.0),仕事(1.0),怒る(1.0),埋設(1.0),離脱(1.0),手放せる(1.0),コオロギ(1.0),多数(1.0),不愉快(1.0),リモート(1.0),走り出す(1.0),方式(1.0),チェーン(1.0),公表(1.0),満たす(1.0),人体(1.0),譲る(1.0),気付く(1.0),給付(1.0),打ち込む(1.0),ドック(1.0),恐ろしい(1.0), probability:0.143
# 1:　バカだ政治家が行う失政に嫌でも付くあわに*。
# node_id:696, node_words:チップ(5.0),埋め込む(5.0),マイクロ(4.0),ここ(2.0),バカ(2.0),肌身(2.0),離す(2.0),認識(2.0),意図(1.0),仕事(1.0),怒る(1.0),埋設(1.0),離脱(1.0),手放せる(1.0),コオロギ(1.0),多数(1.0),不愉快(1.0),リモート(1.0),走り出す(1.0),方式(1.0),チェーン(1.0),公表(1.0),満たす(1.0),人体(1.0),譲る(1.0),気付く(1.0),給付(1.0),打ち込む(1.0),ドック(1.0),恐ろしい(1.0), probability:0.057
# ------------------------------------------------------------------
# 0:リスクは分散するって言葉をマイナンバーカードに何から何まで紐付けるうとするてる人は知るないのかな。
# node_id:632, node_words:いく(3.0),連携(2.0),注ぐ(2.0),集約(2.0),説明(2.0),マジ(2.0),腐る(2.0),リスク(2.0),結果(2.0),将来(1.0),バカげる(1.0),保険(1.0),ワンマン(1.0),国交(1.0),方向(1.0),アホ(1.0),国家(1.0),取り上げる(1.0),想定(1.0),能力(1.0),本人(1.0),財産(1.0),させる(1.0),功績(0.0),動向(0.0),加える(0.0),創造(0.0),創設(0.0),加入(0.0),割高(0.0), probability:0.061
# 1:馬鹿だのかな。
# node_id:720, node_words:説明(4.0),不足(4.0),競争(3.0),続出(2.0),有る(2.0),本来(2.0),加入(2.0),行動(2.0),強い(1.0),流出(1.0),天下り(1.0),処分(1.0),つく(1.0),減らす(1.0),投げつける(1.0),野党(1.0),それ(1.0),不利益(1.0),追求(1.0),並行(1.0),想定(1.0),乖離(1.0),信用(1.0),集団(1.0),怖い(1.0),法治(1.0),多く(1.0),切り込む(1.0),検討(1.0),記事(1.0), probability:0.015
# ------------------------------------------------------------------
# 0:一片の言葉尻を拡大解釈する、思い込む、決めつける、大騒ぎするて、それにソーダソーダと祭りのごとしノリまくるのが*。
# node_id:797, node_words:操作(2.0),電子(2.0),自治体(2.0),従業(2.0),インストール(2.0),重要(2.0),使用(2.0),発想(2.0),当方(2.0),だし(1.0),誤る(1.0),多く(1.0),変わる(1.0),られる(1.0),常設(1.0),決めつける(1.0),脱却(1.0),対話(1.0),デザイン(1.0),支援(1.0),必至(1.0),ユニバーサル(1.0),不完全(1.0),一片(1.0),使いこなす(1.0),不利益(1.0),祭り(1.0),事業(1.0),手間(1.0),ノリ(1.0), probability:0.119
# ------------------------------------------------------------------
# 0:もう、狂うてるね。
# node_id:776, node_words:ダメ(6.0),くっつける(2.0),警察官(2.0),絡む(2.0),一つ(2.0),ついてる(2.0),方々(1.0),捨てる(1.0),改善(1.0),倒す(1.0),テレビ(1.0),東日本(1.0),大きい(1.0),クルー(1.0),悪い(1.0),我々(1.0),学ぶ(1.0),同義(1.0),わけ(1.0),ドミノ(1.0),交通(1.0),昭和(1.0),わける(1.0),しよう(1.0),隊員(1.0),電波(1.0),手放す(1.0),異例(1.0),警ら(1.0),リーダー(1.0), probability:0.0
# 1:自分たちが何をやるているのかさえ判断できるないなるてるのですう。
# node_id:785, node_words:たち(7.0),かも(3.0),スポーツマン(2.0),三流(2.0),一流(2.0),信用(2.0),ビジネスマン(2.0),全員(2.0),携帯(2.0),読み込む(2.0),権利(1.0),囲む(1.0),人生(1.0),オークション(1.0),個々(1.0),誤る(1.0),民放(1.0),不可(1.0),多い(1.0),向き合う(1.0),選ぶ(1.0),群がる(1.0),電波(1.0),誰か(1.0),見せる(1.0),ミス(1.0),ウラ(1.0),車内(1.0),侮る(1.0),手配(1.0), probability:0.097
# 2:ま、それもこれも、そういう*に投票するたオレの責任だんだけどね、オレの。
# node_id:447, node_words:投票(6.0),選挙(5.0),政党(4.0),彼ら(3.0),時代(2.0),強い(2.0),衆議院(2.0),自公(2.0),強行(2.0),結果(2.0),成り下がる(2.0),危なっかしい(2.0),お願い(2.0),次回(2.0),慎重(2.0),交代(2.0),一部(2.0),放題(2.0),問う(2.0),バック(1.0),公共(1.0),マスコミ(1.0),事態(1.0),上がる(1.0),手遅れ(1.0),ついてる(1.0),既得(1.0),公約(1.0),表れ(1.0),刻む(1.0), probability:0.052
# ------------------------------------------------------------------
# 0:無理です。
# node_id:451, node_words:任意(12.0),義務(6.0),実質(5.0),やり方(4.0),ふざける(3.0),ミス(2.0),陰険(2.0),同意(2.0),バイト(2.0),いやらしい(2.0),埋める(2.0),遠まわし(2.0),本当(2.0),姑息(2.0),説明(2.0),写真(2.0),外堀(2.0),強引(2.0),拙速(1.0),大丈夫(1.0),持ち主(1.0),物理(1.0),関連(1.0),わけ(1.0),なに(1.0),丁寧(1.0),与える(1.0),諦める(1.0),法律(1.0),思う(1.0), probability:0.01
# 1:iPhoneに搭載なんて、100年経つてもできるそうに内侍。
# node_id:157, node_words:スマート(6.0),フォン(6.0),モバイル(5.0),搭載(4.0),変える(3.0),恐ろしい(2.0),スマ(2.0),つる(2.0),どっち(2.0),事故(1.0),税収(1.0),回りくどい(1.0),識別(1.0),強気(1.0),思惑(1.0),思う(1.0),バッシング(1.0),生きる(1.0),面倒くさい(1.0),アナウンス(1.0),くる(1.0),少額(1.0),新た(1.0),導入(1.0),国家(1.0),年金(1.0),釣る(1.0),さん(1.0),不正(1.0),安易(1.0), probability:0.065
# 2:もういい加減、諦めるなさるよ。
# node_id:768, node_words:かける(2.0),お前(2.0),役人(2.0),照会(2.0),引きずる(2.0),解体(2.0),管轄(1.0),仕事(1.0),加減(1.0),被害(1.0),奴隷(1.0),大事(1.0),続ける(1.0),見切り(1.0),余計(1.0),プログラム(1.0),降ろす(1.0),無効(1.0),平気(1.0),求める(1.0),まみれ(1.0),疲れる(1.0),都合(1.0),間に合う(1.0),偉い(1.0),答え(1.0),発車(1.0),お互い(1.0),給料(1.0),事例(1.0), probability:0.023
# 3:能力ないんだから。
# node_id:693, node_words:想像(2.0),流出(2.0),利用(1.0),危機(1.0),無い(1.0),市民(1.0),うける(1.0),年貢(1.0),潤う(1.0),ハッキング(1.0),報道(1.0),北朝鮮(1.0),バックアップ(1.0),膨大(1.0),罰則(1.0),納める(1.0),繋げる(1.0),ビッグ(1.0),欠ける(1.0),設ける(1.0),袖の下(1.0),能力(1.0),奴隷(1.0),前提(0.0),割り(0.0),副作用(0.0),前進(0.0),前科(0.0),助かる(0.0),前向き(0.0), probability:0.04
# ------------------------------------------------------------------
# 0:ワクチン打つなさる。
# node_id:776, node_words:ダメ(6.0),くっつける(2.0),警察官(2.0),絡む(2.0),一つ(2.0),ついてる(2.0),方々(1.0),捨てる(1.0),改善(1.0),倒す(1.0),テレビ(1.0),東日本(1.0),大きい(1.0),クルー(1.0),悪い(1.0),我々(1.0),学ぶ(1.0),同義(1.0),わけ(1.0),ドミノ(1.0),交通(1.0),昭和(1.0),わける(1.0),しよう(1.0),隊員(1.0),電波(1.0),手放す(1.0),異例(1.0),警ら(1.0),リーダー(1.0), probability:0.0
# 1:コオロギ食べるなさる。
# node_id:696, node_words:チップ(5.0),埋め込む(5.0),マイクロ(4.0),ここ(2.0),バカ(2.0),肌身(2.0),離す(2.0),認識(2.0),意図(1.0),仕事(1.0),怒る(1.0),埋設(1.0),離脱(1.0),手放せる(1.0),コオロギ(1.0),多数(1.0),不愉快(1.0),リモート(1.0),走り出す(1.0),方式(1.0),チェーン(1.0),公表(1.0),満たす(1.0),人体(1.0),譲る(1.0),気付く(1.0),給付(1.0),打ち込む(1.0),ドック(1.0),恐ろしい(1.0), probability:0.014
# 2:マイクロチップ体に打ち込むなさる。
# node_id:696, node_words:チップ(5.0),埋め込む(5.0),マイクロ(4.0),ここ(2.0),バカ(2.0),肌身(2.0),離す(2.0),認識(2.0),意図(1.0),仕事(1.0),怒る(1.0),埋設(1.0),離脱(1.0),手放せる(1.0),コオロギ(1.0),多数(1.0),不愉快(1.0),リモート(1.0),走り出す(1.0),方式(1.0),チェーン(1.0),公表(1.0),満たす(1.0),人体(1.0),譲る(1.0),気付く(1.0),給付(1.0),打ち込む(1.0),ドック(1.0),恐ろしい(1.0), probability:0.129
# 3:←これ真剣に考えるているから恐い。
# node_id:755, node_words:芋づる(2.0),登録(2.0),期限(2.0),悪い(1.0),みな(1.0),番号(1.0),結果(1.0),バラバラ(1.0),縛る(1.0),クレジットカード(1.0),のせる(1.0),信じる(1.0),平日(1.0),総理(1.0),不幸(1.0),裏切る(1.0),願い下げ(1.0),カード(1.0),譲る(1.0),保健所(1.0),区役所(1.0),マイナス(1.0),統一(1.0),適当(1.0),身動き(1.0),安全(1.0),河野(1.0),イメージ(1.0),解決(1.0),太鼓判(1.0), probability:0.022
# ------------------------------------------------------------------
# 0:役人や政治家って、バカだの？？
# node_id:768, node_words:かける(2.0),お前(2.0),役人(2.0),照会(2.0),引きずる(2.0),解体(2.0),管轄(1.0),仕事(1.0),加減(1.0),被害(1.0),奴隷(1.0),大事(1.0),続ける(1.0),見切り(1.0),余計(1.0),プログラム(1.0),降ろす(1.0),無効(1.0),平気(1.0),求める(1.0),まみれ(1.0),疲れる(1.0),都合(1.0),間に合う(1.0),偉い(1.0),答え(1.0),発車(1.0),お互い(1.0),給料(1.0),事例(1.0), probability:0.045
# 1:市井のふつーの生活が解るないの？？
# node_id:7, node_words:保持(5.0),補完(4.0),統一(3.0),賛成(3.0),検討(3.0),スピード(2.0),役人(2.0),持ち運び(2.0),流行(2.0),速やか(2.0),自己(2.0),かむ(2.0),保存(2.0),明示(2.0),時差(2.0),どちら(2.0),有益(2.0),代替(2.0),問題(1.0),つながり(1.0),簡単(1.0),来る(1.0),くっつける(1.0),たくさん(1.0),切り替える(1.0),奴ら(1.0),バカ(1.0),スムーズ(1.0),縄張り(1.0),権益(1.0), probability:0.013
# 2:そんな奴らが制度設計するちゃダメです。
# node_id:776, node_words:ダメ(6.0),くっつける(2.0),警察官(2.0),絡む(2.0),一つ(2.0),ついてる(2.0),方々(1.0),捨てる(1.0),改善(1.0),倒す(1.0),テレビ(1.0),東日本(1.0),大きい(1.0),クルー(1.0),悪い(1.0),我々(1.0),学ぶ(1.0),同義(1.0),わけ(1.0),ドミノ(1.0),交通(1.0),昭和(1.0),わける(1.0),しよう(1.0),隊員(1.0),電波(1.0),手放す(1.0),異例(1.0),警ら(1.0),リーダー(1.0), probability:0.113
# ------------------------------------------------------------------
# 0:日本が中国化しとる…
# node_id:145, node_words:中国(4.0),老害(2.0),一族(2.0),好き(2.0),移住(2.0),いとこ(2.0),真似(2.0),支配(1.0),保護(1.0),人類(1.0),殺到(1.0),我々(1.0),思える(1.0),部署(1.0),非難(1.0),自治体(1.0),利権(1.0),官僚(1.0),命令(1.0),希望(1.0),気づく(1.0),待つ(1.0),怖じる(1.0),本格(1.0),担当(1.0),大好き(1.0),職員(1.0),鉄槌(1.0),最大限(1.0),最悪(1.0), probability:0.103
# 1:まさか、憲法より上にアホ自民を位置付けるたりせんやな？
# node_id:632, node_words:いく(3.0),連携(2.0),注ぐ(2.0),集約(2.0),説明(2.0),マジ(2.0),腐る(2.0),リスク(2.0),結果(2.0),将来(1.0),バカげる(1.0),保険(1.0),ワンマン(1.0),国交(1.0),方向(1.0),アホ(1.0),国家(1.0),取り上げる(1.0),想定(1.0),能力(1.0),本人(1.0),財産(1.0),させる(1.0),功績(0.0),動向(0.0),加える(0.0),創造(0.0),創設(0.0),加入(0.0),割高(0.0), probability:0.03
# 2:あゝ、恐いロシア…まさに、狂気の沙汰や。
# node_id:795, node_words:破綻(5.0),違い(4.0),振り回す(2.0),沙汰(2.0),狂気(2.0),間違い(2.0),得意(2.0),経験(1.0),合併(1.0),根源(1.0),待つ(1.0),文化(1.0),多方面(1.0),机上(1.0),欠落(1.0),まとも(1.0),ユーザー(1.0),易い(1.0),素人(1.0),確実(1.0),しとる(1.0),創造(1.0),恐い(1.0),構想(1.0),自民(1.0),オンライン(1.0),位置付ける(1.0),ずば抜ける(1.0),無責任(1.0),言うまでもない(1.0), probability:0.088
# ------------------------------------------------------------------
# 0:河野、岸田お前たちの頭狂うているのだはないのか、これ以上馬鹿だ政策は止める、狂気の沙汰としか見えるないぞ。
# node_id:785, node_words:たち(7.0),かも(3.0),スポーツマン(2.0),三流(2.0),一流(2.0),信用(2.0),ビジネスマン(2.0),全員(2.0),携帯(2.0),読み込む(2.0),権利(1.0),囲む(1.0),人生(1.0),オークション(1.0),個々(1.0),誤る(1.0),民放(1.0),不可(1.0),多い(1.0),向き合う(1.0),選ぶ(1.0),群がる(1.0),電波(1.0),誰か(1.0),見せる(1.0),ミス(1.0),ウラ(1.0),車内(1.0),侮る(1.0),手配(1.0), probability:0.097
# ------------------------------------------------------------------

# %%
expandHlda.get_multi_topic_with_color(comment_list=comment_list, corpus=comment_dataset.comment_list, n_words=10)
