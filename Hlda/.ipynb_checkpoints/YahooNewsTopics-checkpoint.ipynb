# %%
import pandas as pd
import numpy as np
import time
from MyNLP import WordDividerMecab
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
df = pd.read_csv("data/2022_12_19/news_list_12_19.csv", encoding="cp932", header=None)
comment_list = []
row_data = df[2][1:].to_numpy().tolist()

temp_row_data = []
for text in row_data:
    if len(text) >= 0:
        temp_row_data.append(text)
row_data = temp_row_data

# 前処理
wd = WordDividerMecab()
stop_word_list = ["まだ", "ある", "なる", "なる", "する", "し", "する", "いる", "なっ", "せ", "い", "やる", "ない"]
for text in row_data:
    text = wd.wakati_text_delete(text=text, stop_word_list=stop_word_list)
    comment_list.append(text)

# 単語の集合(vocablury)の作成
vectorizer = TfidfVectorizer()
tfidf = vectorizer.fit_transform(comment_list)
voc = vectorizer.vocabulary_
voc = sorted(voc)

# HLDAの入力に合わせたリストの形状に変換する
corpus = []

for comment in comment_list:
    list = comment.split(" ")
    corpus.append(list)
filtered_corpus = []
for comment in corpus:
    filtered_comment = []
    for word in comment:
        if word in voc:
            filtered_comment.append(word)
    filtered_corpus.append(filtered_comment)

# 前処理で文字数がなくなったテキストがあるかのチェック
corpus = filtered_corpus
corpus = [comment for comment in corpus if len(comment) != 0]

# 単語の集合に対してindexを割り当てる
vocab_index = {}
for i, w in enumerate(voc):
    vocab_index[w] = i

# HLDAの入力に合わせてテキストを単語のindexで表す
new_corpus = []
corpus = [comment for comment in corpus if comment != '']
for sentence in corpus:
    new_sentence = []
    for word in sentence:
        word_idx = vocab_index[word]
        new_sentence.append(word_idx)
    new_corpus.append(new_sentence)

# %%
from hlda.sampler import HierarchicalLDA

#default
n_samples = 500       # no of iterations for the sampler
alpha = 10.0          # smoothing over level distributions
gamma = 1.0           # CRP smoothing parameter; number of imaginary customers at next, as yet unused table
eta = 0.1             # smoothing over topic-word distributions
num_levels = 3        # the number of levels in the tree
display_topics = 50   # the number of iterations between printing a brief summary of the topics so far
n_words = 7           # the number of most probable words to print for each topic after model estimation
with_weights = False  # whether to print the words with the weights

# %%
hlda = HierarchicalLDA(new_corpus, voc, alpha=alpha, gamma=gamma, eta=eta, num_levels=num_levels)
hlda.estimate(n_samples, display_topics=display_topics, n_words=n_words, with_weights=with_weights)
# Out:
# HierarchicalLDA sampling
#
# .................................................. 50
# topic=0 level=0 (documents=279): できる, 思う, いう, 発表, 行う, 見る, 日本,
#     topic=1 level=1 (documents=71): 放送, ケプラー, 選手, 意味, 公開, 終わる, 写真,
#         topic=2 level=2 (documents=11): ランキング, 翻訳, 字幕, 年間, 日本語, 厚切りジェイソン, 言語,
#         topic=10 level=2 (documents=16): アルゼンチン, 優勝, 滅私, 大会, フランス, 決勝, カタール,
#         topic=14 level=2 (documents=7): 直也, 描く, 映画, ノア, 監督, avatar, 紅蓮,
#         topic=15 level=2 (documents=9): 自分, チーム, フェラーリ, 浦和レッズ, 全て, シーズン, 藤原,
#         topic=17 level=2 (documents=7): 時間, レンズ, フルサイズ, 購入, 表示, 時計, シリーズ,
#         topic=28 level=2 (documents=5): アミノ酸, 粒子, 研究, 炭素質コンドライト, 流す, 分子, トイレ,
#         topic=37 level=2 (documents=6): 食べる, ハチ, アカシュモクザメ, 発見, 体内時計, 建物, 花粉,
#         topic=42 level=2 (documents=5): 舞踏, 参加, 少女, 眼差し, 今月, ラジオ日本, 古河,
#         topic=47 level=2 (documents=2): 被告, 遠山, 古典, 見える, 殺害, 懲役, 稚児,
#         topic=48 level=2 (documents=3): アプリ, 禁止, 脅威, 収集, 渋谷, データ, サウナ,
#     topic=3 level=1 (documents=42): データ, 地図, 石川県, 支店, 構築, 予約, 表示,
#         topic=4 level=2 (documents=3): 歩行, ニューロン, 敗血症, 改善, 宇宙ビジネス, 脊髄損傷, 回復,
#         topic=13 level=2 (documents=10): アナ, 思う, 出場, 紅白, 皆さん, お昼, コメント,
#         topic=18 level=2 (documents=6): 浸水, 業務, 予測, システム, 発生, 支援, 避難,
#         topic=26 level=2 (documents=8): コース, 社会, 環境, 高田, 審査, 入学, 理工学部,
#         topic=29 level=2 (documents=5): タクシー, 佐賀, 佐賀県, 運賃, 免許返納, 県内, ネタ,
#         topic=33 level=2 (documents=3): アプリ, ボード, デベロッパー, 描く, カメラ, くる, らく,
#         topic=36 level=2 (documents=3): メタバース, スパークリング, レモン, 広告, 映画館, イメージ, 体験,
#         topic=43 level=2 (documents=4): ペットボトル, ママ, キャップ, 出す, 閉める, パン粉, アイデア,
#     topic=5 level=1 (documents=93): 存在, 文明, 地球, 星人, 状態, しれる, 電波,
#         topic=6 level=2 (documents=16): アカウント, センサー, ポリシー, 接続, 削除, tweet, トラッキング,
#         topic=9 level=2 (documents=8): 馬体, 美浦, 診断, 有馬記念, 出走, 馬三郎, 栗東,
#         topic=11 level=2 (documents=8): ファッション, ブランド, 商品, 帽子, タウン, 販売, プラットフォーム,
#         topic=12 level=2 (documents=16): 発生, 警察, 運転, 事故, 大雪, 積雪, 死亡,
#         topic=16 level=2 (documents=6): 装備, グレー, ブラック, アシスト, 追加, 可能, 電源,
#         topic=19 level=2 (documents=9): 大会, 1分, 1勝, 2敗, 1敗, 優勝, ジュニア,
#         topic=22 level=2 (documents=20): 日銀, 影響, 前回, 政府, 決済, 受ける, 証券,
#         topic=34 level=2 (documents=6): メール, 研究, 仕事, 核融合, 磁場, エネルギー, アサヒ飲料,
#         topic=40 level=2 (documents=4): ホッキョクグマ, 箱根町, 同館, トロフィー, クリンチャー, 東山動植物園, フブキ,
#     topic=7 level=1 (documents=31): ファン, 区間, 自由, 開幕, 痛み, 専門家, 手作り,
#         topic=8 level=2 (documents=7): がん, 転移, 肺がん, がん検診, ステージ4, 治療, 放射線治療,
#         topic=27 level=2 (documents=6): 終日, 運転見合わせ, 上下, 上下線, 運休, 一部, 通行止め,
#         topic=30 level=2 (documents=6): 選手, eスポーツ, 大会, 東日本, 西澤, 開催, 勝利,
#         topic=35 level=2 (documents=3): 再生, 聴く, ボード, ネットワークオーディオ, 行なう, ストリーミング, 操作,
#         topic=39 level=2 (documents=5): サンゴ, 調査, 地点, ボート, 亜種, ヒシクイ, 鉄道,
#         topic=44 level=2 (documents=4): スタイル, こんにゃく, ガラス, テイラー, 再利用, 地区, 違う,
#     topic=20 level=1 (documents=17): 12月15日, 場合, エントリー, 記事, トレーディングカード, 1枚, 鮮やか,
#         topic=21 level=2 (documents=4): smartphone, グループ, 出荷, リリース, シリーズ, 忍者, 前年同期,
#         topic=38 level=2 (documents=4): 暗号, 資産, ドローン, トークン, 発行, プロジェクト, 保有,
#         topic=41 level=2 (documents=5): 天ぷら, 加える, かぶる, 入れる, 帆立, スープ, 料理,
#         topic=45 level=2 (documents=3): ソユーズ, 冷却, 宇宙船, 宇宙飛行士, 打ち上げる, トラブル, 漏れる,
#         topic=46 level=2 (documents=1): 防止, 鉄道, 南ア, 座屈, 効果, 軌道, 検証,
#     topic=23 level=1 (documents=25): 旅行, 配達, 回答, 登録, パートナー, 地域, 年末年始,
#         topic=24 level=2 (documents=11): 言う, 小雁, 柏木さん, チャンネル, 寛子, 男性, 否定,
#         topic=25 level=2 (documents=5): バイオマス, 協定, 植林, 市有, 森林組合, 産業, 間瀬,
#         topic=31 level=2 (documents=4): 東京, ホテル, 水素, 大会, 危機, 未来, オリエンタルホテル,
#         topic=32 level=2 (documents=5): 平均, 走る, 体力, 体操, 年収, 3年, オノマトペ,
# .................................................. 100
# topic=0 level=0 (documents=279): できる, 思う, いう, 発表, 見る, 行う, 写真,
#     topic=1 level=1 (documents=68): 旅行, 文明, 星人, 惑星, チーム, しれる, 選手,
#         topic=2 level=2 (documents=10): ランキング, 翻訳, 字幕, お金, 年間, 日本語, 言語,
#         topic=10 level=2 (documents=14): アルゼンチン, 大会, 滅私, 優勝, カタール, 決勝, フランス,
#         topic=14 level=2 (documents=8): 映画, ランキング, 監督, 描く, 年収, 公開, 平均,
#         topic=15 level=2 (documents=9): 自分, フェラーリ, 全て, 浦和レッズ, 藤原, シーズン, チーム,
#         topic=17 level=2 (documents=7): レンズ, シリーズ, フルサイズ, 購入, smartphone, 表示, 製品,
#         topic=28 level=2 (documents=5): 存在, ケプラー, 地球, 磁鉄鉱, アミノ酸, 炭素質コンドライト, 研究,
#         topic=42 level=2 (documents=4): スパークリング, イメージ, 映画館, レモン, 広告, メタバース, コンセプト,
#         topic=48 level=2 (documents=8): 移動, パターン, ルート, 亜種, コース, ヒシクイ, 参加者,
#         topic=60 level=2 (documents=3): アカシュモクザメ, 保育園, 遠山, 発見, 保育所, 保育士, 職員,
#     topic=3 level=1 (documents=56): 務める, 64, 情報通信研究機構, 今回, 可能性, 寄せる, 芸能リポーター,
#         topic=4 level=2 (documents=7): 研究, 歩行, ニューロン, 改善, わかる, 粒子, 刺激,
#         topic=13 level=2 (documents=13): アナ, 出場, 思う, 紅白, コメント, 出演, 皆さん,
#         topic=18 level=2 (documents=7): 浸水, 業務, 予測, 発生, システム, 対応, 支援,
#         topic=26 level=2 (documents=3): コース, 社会, 環境, 高田, 総合, 理工学部, 入学,
#         topic=29 level=2 (documents=8): タクシー, ネタ, 佐賀, 芸人, 佐賀県, 運賃, 舞踏,
#         topic=43 level=2 (documents=7): ペットボトル, ママ, 出す, キャップ, ホッキョクグマ, 閉める, 同館,
#         topic=51 level=2 (documents=6): 時間, メール, 仕事, 時計, 私たち, 意味, 経過,
#         topic=62 level=2 (documents=5): 核融合, エネルギー, プラズマ, 閉じ込める, 社史, 磁場, 方式,
#     topic=5 level=1 (documents=79): 19日, 状態, 全国, 配達, 凍結, 事故, 規制,
#         topic=6 level=2 (documents=15): アカウント, センサー, 接続, tweet, 削除, トラッキング, ポリシー,
#         topic=9 level=2 (documents=7): 馬体, 美浦, 診断, 有馬記念, 出走, 馬三郎, 栗東,
#         topic=11 level=2 (documents=8): ファッション, ブランド, 商品, プラットフォーム, 帽子, タウン, デザイナー,
#         topic=12 level=2 (documents=12): 発生, 警察, 運転, 大雪, 事故, 積雪, よる,
#         topic=16 level=2 (documents=5): 装備, ブラック, アシスト, 可能, グレー, シリーズ, エディション,
#         topic=19 level=2 (documents=9): 大会, 1勝, 1分, 2敗, 1敗, 優勝, ジュニア,
#         topic=22 level=2 (documents=15): 日銀, 前回, 影響, 受ける, 政府, 半導体, 見通し,
#         topic=40 level=2 (documents=4): 走る, 体操, 体力, オノマトペ, 男子, 女子, 平均,
#         topic=61 level=2 (documents=4): アプリ, デベロッパー, グループ, カメラ, くる, 新メンバー, らく,
#     topic=7 level=1 (documents=33): トライ, 選ぶ, ペナルティー, 年間, 始まる, ファン, 入浴,
#         topic=8 level=2 (documents=6): がん, 転移, 肺がん, ステージ4, がん検診, 治療, 放射線治療,
#         topic=27 level=2 (documents=5): 終日, 運転見合わせ, 上下, 上下線, 運休, 区間, 新津,
#         topic=30 level=2 (documents=5): 選手, eスポーツ, 大会, 東日本, 西澤, イベント, 開催,
#         topic=35 level=2 (documents=4): ボード, 対応, 再生, 聴く, アップデート, ストリーミング, オーディオ,
#         topic=39 level=2 (documents=5): 鉄道, サンゴ, 調査, 防止, 南ア, 地点, ボート,
#         topic=54 level=2 (documents=4): 放送, トップ, ラジオ日本, 全米, リスナー, 最終回, 番組,
#         topic=56 level=2 (documents=4): 渋谷, 寝る, アル, 古河, サウナ, 渡辺, 見える,
#     topic=20 level=1 (documents=25): リリース, ソワレ, 16日, 場合, エアロジェット, 中国, 買収,
#         topic=21 level=2 (documents=5): 米国, ワクチン, コロナ, 顧問, 建物, 医療, 大統領,
#         topic=38 level=2 (documents=5): 資産, 暗号, トークン, ドローン, 発行, プロジェクト, 決済,
#         topic=41 level=2 (documents=6): 天ぷら, 加える, 入れる, かぶる, 帆立, 料理, 焼く,
#         topic=45 level=2 (documents=4): ソユーズ, 冷却, 宇宙船, 宇宙飛行士, ロシア, 打ち上げる, トラブル,
#         topic=59 level=2 (documents=1): 直也, ノア, 夏菜, ゼッタイ, 鶴嶋乃愛, 不倫, 会社,
#         topic=63 level=2 (documents=4): クリンチャー, 宮本, povo, ニンジン, 収録, 勝てる, 灼熱,
#     topic=23 level=1 (documents=18): 登録, ドラマ, 作品, 一緒, 好き, たくさん, 大学,
#         topic=24 level=2 (documents=8): 言う, 小雁, 柏木さん, チャンネル, 寛子, 野沢, 否定,
#         topic=25 level=2 (documents=6): 作る, バイオマス, 協定, テイラー, ガラス, こんにゃく, 地区,
#         topic=31 level=2 (documents=4): 東京, ホテル, 子ども, 水素, 大会, 危機, 未来,
# .................................................. 150
# topic=0 level=0 (documents=279): できる, 思う, いう, 発表, 見る, 行う, 日本,
#     topic=1 level=1 (documents=69): 18日, キャリア, 伝える, 件数, 家族, 記録, マーケティング,
#         topic=2 level=2 (documents=10): ランキング, 翻訳, 字幕, お金, 年間, 日本語, 言語,
#         topic=10 level=2 (documents=12): アルゼンチン, 滅私, 大会, 選手, フランス, カタール, 優勝,
#         topic=14 level=2 (documents=7): 映画, ランキング, 平均, 年収, 描く, 監督, 公開,
#         topic=15 level=2 (documents=9): チーム, 自分, フェラーリ, 選手, 全て, 浦和レッズ, シーズン,
#         topic=17 level=2 (documents=7): レンズ, フルサイズ, 購入, シリーズ, 表示, 製品, カメラ,
#         topic=28 level=2 (documents=4): ケプラー, 存在, 磁鉄鉱, アミノ酸, 地球, 炭素質コンドライト, 分子,
#         topic=42 level=2 (documents=4): スパークリング, 動画, 今回, レモン, 映画館, 広告, 体験,
#         topic=48 level=2 (documents=7): 小雁, 寛子, 舞踏, 亜種, 参加者, ヒシクイ, 奄美,
#         topic=60 level=2 (documents=7): 米国, 医療, コロナ, 県内, 接種, ワクチン, 感染症,
#         topic=74 level=2 (documents=2): 直也, ノア, 夏菜, 原作, 伏瀬, 紅蓮, 転生したらスライムだった件,
#     topic=3 level=1 (documents=47): 規制, ルート, 路面, 事故, 64, 働く, 状態,
#         topic=4 level=2 (documents=5): 研究, 歩行, ニューロン, 改善, 粒子, 刺激, 敗血症,
#         topic=13 level=2 (documents=13): アナ, コメント, 出場, 紅白, 思う, 皆さん, 出演,
#         topic=18 level=2 (documents=8): 予測, 浸水, 対応, システム, 業務, データ, 支援,
#         topic=29 level=2 (documents=7): ネタ, ウエストランド, 芸人, 言う, 漫才, 佐賀, タクシー,
#         topic=43 level=2 (documents=6): ペットボトル, 作る, 出す, キャップ, ママ, アイデア, 閉める,
#         topic=51 level=2 (documents=5): 時間, メール, 仕事, 時計, 経過, タイマー, クロノグラフ,
#         topic=70 level=2 (documents=3): バイオマス, 協定, こんにゃく, 地区, 植林, 事業, 植える,
#     topic=5 level=1 (documents=72): 19日, 韓国, 停止, 大型, 出場, かかる, 東証株価指数,
#         topic=6 level=2 (documents=11): アカウント, ポリシー, 削除, tweet, 禁止, 投票, ロシア,
#         topic=9 level=2 (documents=7): 馬体, 美浦, 診断, 有馬記念, 馬三郎, 出走, 栗東,
#         topic=11 level=2 (documents=6): ファッション, ブランド, 帽子, 商品, タウン, 製作, プラットフォーム,
#         topic=12 level=2 (documents=10): 警察, 運転, 発生, 事故, よる, 大雪, 除雪,
#         topic=16 level=2 (documents=6): 装備, グレー, ブラック, アシスト, 標準, シリーズ, 新型,
#         topic=19 level=2 (documents=9): 大会, 1勝, 1分, 1敗, 2敗, 優勝, ジュニア,
#         topic=22 level=2 (documents=16): 日銀, 受ける, 影響, 前回, 政府, マイナス, 見通し,
#         topic=72 level=2 (documents=4): 走る, 体操, 体力, 全国, 平均, オノマトペ, 女子,
#         topic=75 level=2 (documents=3): コース, 社会, 環境, 高田, 総合, 入学, 理工学部,
#     topic=7 level=1 (documents=46): 旅行, 回答, 配達, パートナー, 年末年始, シーズン, 配信,
#         topic=8 level=2 (documents=8): がん, 転移, 肺がん, がん検診, ステージ4, 治療, 死亡,
#         topic=27 level=2 (documents=5): 運転見合わせ, 終日, 上下, 上下線, 運休, 区間, 通行止め,
#         topic=30 level=2 (documents=4): 選手, eスポーツ, 大会, 東日本, 西澤, 勝利, イベント,
#         topic=35 level=2 (documents=4): ボード, 対応, 再生, 聴く, オーディオ, 行なう, ストリーミング,
#         topic=39 level=2 (documents=5): 鉄道, サンゴ, 調査, 防止, 南ア, 地点, 座屈,
#         topic=54 level=2 (documents=5): 放送, 番組, 古河, ラジオ日本, トップ, 全米, リスナー,
#         topic=56 level=2 (documents=9): ホテル, ホッキョクグマ, オリエンタルホテル, 同館, 移動, 東山動植物園, フブキ,
#         topic=71 level=2 (documents=6): センサー, 接続, トラッキング, ワイヤレス, 出荷, 予定, smartphone,
#     topic=20 level=1 (documents=21): 文明, 星人, 地球, 惑星, しれる, 電波, 存在,
#         topic=21 level=2 (documents=6): クリンチャー, 保育園, 被告, 遠山, 虐待, 宮本, 職員,
#         topic=38 level=2 (documents=4): 資産, 暗号, トークン, ドローン, 発行, プロジェクト, 保有,
#         topic=41 level=2 (documents=6): 天ぷら, かぶる, 入れる, 加える, 帆立, 料理, 玉ねぎ,
#         topic=45 level=2 (documents=5): ソユーズ, 冷却, 宇宙飛行士, 宇宙船, 打ち上げる, 影響, トラブル,
#     topic=23 level=1 (documents=24): チャンネル, 遺産分割, 生命, 一緒, 作品, 期間, 牛角,
#         topic=24 level=2 (documents=5): 柏木さん, 言う, 男性, 吸う, 当時, アル, プロポーズ,
#         topic=31 level=2 (documents=5): 東京, 子ども, 危機, 水素, 大会, 世界, 未来,
#         topic=64 level=2 (documents=2): 核融合, 決済, エネルギー, プラズマ, 方式, 磁場, 閉じ込める,
#         topic=66 level=2 (documents=5): アプリ, 体験, デベロッパー, くる, カメラ, らく, メタバース,
#         topic=69 level=2 (documents=7): 登録, 車両, 規制, 予約, 新メンバー, 三太郎, ソワレ,
# .................................................. 200
# topic=0 level=0 (documents=279): できる, 思う, いう, 発表, 見る, 行う, 写真,
#     topic=1 level=1 (documents=68): 皆さん, 明かす, 女性, 流氷, 議論, 映る, 期待,
#         topic=2 level=2 (documents=9): 翻訳, 字幕, お金, ランキング, 日本語, 皮膚, 厚切りジェイソン,
#         topic=10 level=2 (documents=12): 選手, アルゼンチン, 大会, 滅私, 試合, フランス, カタール,
#         topic=14 level=2 (documents=12): ランキング, 映画, 登録, 監督, チャンネル, 平均, 年収,
#         topic=15 level=2 (documents=8): 自分, チーム, 思う, フェラーリ, 選手, 浦和レッズ, 全て,
#         topic=17 level=2 (documents=6): レンズ, 購入, フルサイズ, シリーズ, 製品, カメラ, 表示,
#         topic=28 level=2 (documents=5): ケプラー, 存在, 磁鉄鉱, アミノ酸, 地球, 分子, 炭素質コンドライト,
#         topic=42 level=2 (documents=5): メタバース, スパークリング, 体験, レモン, 広告, イメージ, 映画館,
#         topic=60 level=2 (documents=8): ホッキョクグマ, 東山動植物園, フブキ, 米国, 再開, コロナ, 同館,
#         topic=74 level=2 (documents=3): 直也, ノア, 夏菜, 伏瀬, 転生したらスライムだった件, 原作, 紅蓮,
#     topic=3 level=1 (documents=51): 文明, 星人, 地球, 存在, しれる, 電波, 私たち,
#         topic=4 level=2 (documents=4): 歩行, ニューロン, 改善, 粒子, わかる, 敗血症, 研究,
#         topic=13 level=2 (documents=12): アナ, 思う, 出場, 紅白, コメント, アナウンサー, アシスタント,
#         topic=18 level=2 (documents=9): 予測, 浸水, 業務, 発生, 地図, 支援, 統合,
#         topic=29 level=2 (documents=8): ネタ, ウエストランド, タクシー, 言う, 芸人, 漫才, 佐賀,
#         topic=43 level=2 (documents=7): ペットボトル, 作る, ママ, 出す, キャップ, アイデア, 閉める,
#         topic=51 level=2 (documents=7): 時間, メール, 仕事, 時計, 経過, 認知, クロノグラフ,
#         topic=77 level=2 (documents=4): 社史, 飛騨産業, 100年, 物語, 社員, 稚児, 創業,
#     topic=5 level=1 (documents=81): 19日, 18日, トロフィー, 1年, かかる, 取引, 渡辺,
#         topic=6 level=2 (documents=14): アカウント, ポリシー, 削除, tweet, 禁止, 投票, 私たち,
#         topic=9 level=2 (documents=8): 馬体, 美浦, 出走, 有馬記念, 診断, 馬三郎, 栗東,
#         topic=11 level=2 (documents=9): ファッション, ブランド, 商品, 帽子, タウン, プラットフォーム, パターン,
#         topic=12 level=2 (documents=13): 警察, 事故, よる, 発生, 運転, 大雪, 古河,
#         topic=16 level=2 (documents=6): 装備, グレー, ブラック, アシスト, 電源, 標準, シリーズ,
#         topic=19 level=2 (documents=10): 大会, 1勝, 1分, 1敗, 2敗, 優勝, 投手,
#         topic=22 level=2 (documents=13): 日銀, 前回, 影響, 政府, マイナス, 見通し, 半導体,
#         topic=72 level=2 (documents=5): 走る, 全国, 体力, 体操, 平均, オノマトペ, 女子,
#         topic=75 level=2 (documents=3): コース, 社会, 環境, 高田, 総合, 実現, 審査,
#     topic=7 level=1 (documents=41): 旅行, 回答, 舞踏, 年末年始, シーズン, エクスペディア, 用意,
#         topic=8 level=2 (documents=7): がん, 転移, 肺がん, がん検診, ステージ4, 治療, 診断,
#         topic=27 level=2 (documents=4): 運転見合わせ, 終日, 上下, 上下線, 運休, 区間, 新津,
#         topic=30 level=2 (documents=3): eスポーツ, 選手, 大会, 東日本, 西澤, 開催, 浦和レッズ,
#         topic=35 level=2 (documents=5): ボード, アプリ, 対応, 再生, 聴く, デベロッパー, 描く,
#         topic=54 level=2 (documents=7): 小雁, 放送, 寛子, 番組, リスナー, ラジオ日本, 出演,
#         topic=56 level=2 (documents=5): ソユーズ, 冷却, 研究, ロシア, 宇宙船, 宇宙飛行士, 打ち上げる,
#         topic=71 level=2 (documents=10): センサー, 接続, トラッキング, 予定, ワイヤレス, 出荷, smartphone,
#     topic=20 level=1 (documents=12): 兵庫県, メニュー, 橋梁, 従来, レシピ, 点検, 小海線,
#         topic=21 level=2 (documents=4): 鉄道, サンゴ, 調査, 南ア, 防止, 地点, ボート,
#         topic=38 level=2 (documents=3): 資産, 暗号, ドローン, トークン, 発行, プロジェクト, 保有,
#         topic=41 level=2 (documents=5): 天ぷら, 入れる, かぶる, 帆立, 加える, 料理, 焼く,
#     topic=23 level=1 (documents=26): 配達, パートナー, 中小企業, 新メンバー, プログラム, ツアー, 20年,
#         topic=24 level=2 (documents=7): 柏木さん, 言う, 男性, 吸う, 当時, ファン, かわいい,
#         topic=31 level=2 (documents=7): 東京, ホテル, 子ども, 水素, 大会, 危機, オリエンタルホテル,
#         topic=64 level=2 (documents=3): 核融合, エネルギー, プラズマ, バイオマス, 閉じ込める, 磁場, 方式,
#         topic=69 level=2 (documents=9): 車両, グループ, 予約, 利用, 期間, ヒシクイ, 亜種,
# .................................................. 250
# topic=0 level=0 (documents=279): できる, 思う, いう, 発表, 行う, 見る, 日本,
#     topic=1 level=1 (documents=67): 19日, 素晴らしい, キャリア, 迎える, 愛す, 可能性, 記録,
#         topic=2 level=2 (documents=9): 翻訳, 字幕, お金, ランキング, 年間, 日本語, 皮膚,
#         topic=10 level=2 (documents=12): アルゼンチン, 選手, 大会, 滅私, 試合, カタール, フランス,
#         topic=14 level=2 (documents=10): ランキング, 監督, 映画, 年収, 平均, 公開, 描く,
#         topic=15 level=2 (documents=9): 自分, チーム, フェラーリ, 選手, 浦和レッズ, 全て, シーズン,
#         topic=17 level=2 (documents=4): レンズ, フルサイズ, 購入, シリーズ, 製品, 表示, カメラ,
#         topic=28 level=2 (documents=4): ケプラー, 存在, 磁鉄鉱, アミノ酸, 地球, 分子, 研究,
#         topic=42 level=2 (documents=4): スパークリング, 映画館, 舞踏, 広告, イメージ, レモン, コンセプト,
#         topic=60 level=2 (documents=8): 米国, 新型コロナウイルス, コロナ, 再開, 医療, フクロウ, 接種,
#         topic=74 level=2 (documents=3): 直也, ノア, 夏菜, 原作, 伏瀬, 転生したらスライムだった件, 紅蓮,
#         topic=87 level=2 (documents=4): アル, 寝る, 性別, 古典, 稚児, 三陸, 経由,
#     topic=3 level=1 (documents=51): 配達, 人気, プログラム, 路面, ルート, パートナー, 回避,
#         topic=4 level=2 (documents=5): 研究, 歩行, ニューロン, 改善, わかる, 粒子, 刺激,
#         topic=13 level=2 (documents=12): アナ, 思う, 出場, 紅白, 番組, 皆さん, コメント,
#         topic=18 level=2 (documents=8): 業務, 浸水, 発生, システム, 予測, データ, 対応,
#         topic=29 level=2 (documents=8): ネタ, ウエストランド, 言う, 芸人, タクシー, 佐賀, 漫才,
#         topic=43 level=2 (documents=8): ペットボトル, ママ, キャップ, 作る, 出す, アイデア, スタイル,
#         topic=51 level=2 (documents=6): 時間, メール, 仕事, 体操, 全国, 体力, 時計,
#         topic=77 level=2 (documents=4): アカシュモクザメ, 保育園, 被告, 殺害, 遠山, 保育所, 保育士,
#     topic=5 level=1 (documents=70): 19日, 状態, 中国, 付ける, 大型, 国内, オフ,
#         topic=6 level=2 (documents=10): アカウント, ポリシー, 削除, tweet, 禁止, 私たち, 投票,
#         topic=9 level=2 (documents=7): 馬体, 美浦, 馬三郎, 有馬記念, 出走, 栗東, 診断,
#         topic=11 level=2 (documents=9): ファッション, ブランド, 商品, 帽子, プラットフォーム, タウン, 製作,
#         topic=12 level=2 (documents=10): 警察, 事故, 発生, 古河, カード, 除雪, 大滝,
#         topic=16 level=2 (documents=6): 装備, グレー, ブラック, アシスト, 追加, 電源, 標準,
#         topic=19 level=2 (documents=12): 大会, 1分, 1勝, 1敗, 2敗, 優勝, 投手,
#         topic=22 level=2 (documents=14): 日銀, 影響, 前回, 受ける, 政府, マイナス, 半導体,
#         topic=75 level=2 (documents=2): コース, 社会, 環境, 高田, 総合, 理工学部, 入学,
#     topic=7 level=1 (documents=43): 文明, 地球, 星人, 電波, 惑星, 存在, 生命,
#         topic=8 level=2 (documents=7): がん, 転移, 肺がん, 治療, ステージ4, がん検診, 診断,
#         topic=27 level=2 (documents=9): 終日, 運転見合わせ, 上下, 大雪, 上下線, 19日, 運休,
#         topic=30 level=2 (documents=5): eスポーツ, 選手, 大会, 東日本, 西澤, 開催, 浦和レッズ,
#         topic=35 level=2 (documents=4): アプリ, ボード, 対応, 再生, デベロッパー, 聴く, カメラ,
#         topic=54 level=2 (documents=3): 放送, ラジオ日本, 全米, トップ, リスナー, 番組, 湯川れい子,
#         topic=56 level=2 (documents=5): ソユーズ, 冷却, 宇宙船, 宇宙飛行士, ロシア, 漏れる, 打ち上げる,
#         topic=71 level=2 (documents=7): センサー, 接続, トラッキング, ワイヤレス, 出荷, 対応, smartphone,
#         topic=82 level=2 (documents=3): バイオマス, 協定, リリース, 植林, ソワレ, 事業, 森林組合,
#     topic=20 level=1 (documents=22): 旅行, 回答, シーズン, 年末年始, エクスペディア, 海外旅行, 行く,
#         topic=21 level=2 (documents=6): サンゴ, 調査, 地点, ボート, 鉄道, 実験, 守る,
#         topic=38 level=2 (documents=6): 暗号, 資産, トークン, ドローン, 発行, 決済, プロジェクト,
#         topic=41 level=2 (documents=4): 天ぷら, 入れる, かぶる, 帆立, スープ, 玉ねぎ, 料理,
#         topic=83 level=2 (documents=2): 鉄道, 防止, 南ア, 社史, 座屈, 効果, 100年,
#         topic=86 level=2 (documents=4): ホッキョクグマ, 東山動植物園, 同館, トロフィー, 箱根町, ハチ, フブキ,
#     topic=23 level=1 (documents=26): ピース, 一緒, 訪れる, 撮影, チキンマックナゲット, ソース, 私たち,
#         topic=24 level=2 (documents=5): 小雁, 柏木さん, 言う, 寛子, 男性, 吸う, 当時,
#         topic=31 level=2 (documents=4): ホテル, 東京, 大会, 未来, 水素, 子ども, 危機,
#         topic=64 level=2 (documents=6): 核融合, 進む, 閉じ込める, エネルギー, プラズマ, 流氷, しらせ,
#         topic=69 level=2 (documents=11): 登録, 車両, 予約, チャンネル, 管理, 参加者, 新メンバー,
# .................................................. 300
# topic=0 level=0 (documents=279): できる, 思う, いう, 発表, 見る, 行う, 写真,
#     topic=1 level=1 (documents=76): 地球, 文明, 星人, しれる, 惑星, 存在, 電波,
#         topic=2 level=2 (documents=9): 翻訳, 字幕, お金, ランキング, 年間, 日本語, 皮膚,
#         topic=10 level=2 (documents=13): アルゼンチン, 選手, 大会, 滅私, 試合, カタール, フランス,
#         topic=14 level=2 (documents=10): ランキング, 映画, 監督, 公開, 登録, 年収, 描く,
#         topic=15 level=2 (documents=8): 自分, 思う, フェラーリ, 選手, 全て, チーム, 浦和レッズ,
#         topic=17 level=2 (documents=4): レンズ, フルサイズ, 購入, シリーズ, カメラ, 表示, 製品,
#         topic=28 level=2 (documents=5): ケプラー, 存在, 磁鉄鉱, 考える, アミノ酸, 研究, 炭素質コンドライト,
#         topic=42 level=2 (documents=4): メタバース, スパークリング, 公開, 映画館, レモン, 広告, コンセプト,
#         topic=60 level=2 (documents=3): 決済, 核融合, エネルギー, 中国, プラズマ, 方式, 出資,
#         topic=74 level=2 (documents=6): 直也, ノア, 夏菜, 伏瀬, 転生したらスライムだった件, 原作, 紅蓮,
#         topic=87 level=2 (documents=8): クリンチャー, トロフィー, 箱根町, 保育園, 子ども, 思い, ベージュ,
#         topic=88 level=2 (documents=3): バイオマス, 20年, 協定, 植林, 被告, 遠山, 東部,
#         topic=95 level=2 (documents=3): 鉄道, 南ア, 防止, 社史, 座屈, 飛騨産業, 軌道,
#     topic=3 level=1 (documents=49): 配達, パートナー, 路面, ルート, 事故, スタイル, 支店,
#         topic=4 level=2 (documents=5): 研究, 歩行, ニューロン, わかる, 粒子, 改善, 刺激,
#         topic=13 level=2 (documents=11): 思う, アナ, コメント, 出場, 紅白, 出演, ステージ,
#         topic=18 level=2 (documents=8): 業務, 浸水, 予測, 対応, システム, 発生, 支援,
#         topic=29 level=2 (documents=8): ネタ, タクシー, ウエストランド, 言う, 芸人, 佐賀, 漫才,
#         topic=43 level=2 (documents=8): ペットボトル, ママ, 作る, キャップ, 出す, アイデア, パン粉,
#         topic=51 level=2 (documents=5): 時間, メール, 仕事, 時計, 経過, クロノグラフ, タイマー,
#         topic=77 level=2 (documents=4): ホッキョクグマ, アカシュモクザメ, 東山動植物園, 同館, フブキ, 移動, 寂しい,
#     topic=5 level=1 (documents=78): 19日, 大型, 半導体, 大手, 国内, 増加, アンケート,
#         topic=6 level=2 (documents=15): アカウント, ポリシー, 削除, tweet, 禁止, 投票, 私たち,
#         topic=9 level=2 (documents=8): 馬体, 美浦, 診断, 出走, 有馬記念, 馬三郎, 栗東,
#         topic=11 level=2 (documents=6): ファッション, ブランド, 商品, 帽子, タウン, プラットフォーム, 販売,
#         topic=12 level=2 (documents=14): 警察, よる, 発生, 古河, 運転, 事故, 自転車,
#         topic=16 level=2 (documents=6): 装備, ブラック, グレー, 新型, アシスト, エディション, 電源,
#         topic=19 level=2 (documents=12): 大会, 1分, 1勝, 2敗, 1敗, 優勝, ジュニア,
#         topic=22 level=2 (documents=10): 日銀, 前回, 政府, 懸念, マイナス, 後退, 銘柄,
#         topic=75 level=2 (documents=4): コース, 社会, 環境, 高田, 総合, 入学, 理工学部,
#         topic=94 level=2 (documents=3): 舞踏, 稚児, 性別, 建物, 古典, 庄内地域, 田村,
#     topic=7 level=1 (documents=36): 2回, 不妊, 携帯電話, 内山, 大雪, 既存, ハード,
#         topic=8 level=2 (documents=7): がん, 転移, 肺がん, ステージ4, がん検診, 治療, 放射線治療,
#         topic=27 level=2 (documents=7): 終日, 運転見合わせ, 上下, 上下線, 運休, 大雪, 区間,
#         topic=30 level=2 (documents=3): eスポーツ, 選手, 大会, 東日本, 西澤, 地域, 開催,
#         topic=35 level=2 (documents=4): ボード, 対応, 再生, 聴く, システム, ストリーミング, オーディオ,
#         topic=54 level=2 (documents=5): 放送, 全米, 番組, ラジオ日本, リスナー, トップ, 最終回,
#         topic=56 level=2 (documents=2): ソユーズ, 冷却, 宇宙飛行士, 宇宙船, 影響, 打ち上げる, 漏れる,
#         topic=71 level=2 (documents=7): センサー, 接続, トラッキング, ワイヤレス, 出荷, 予定, smartphone,
#         topic=93 level=2 (documents=1): 体力, 全国, 体操, オノマトペ, 平均, 男子, 走る,
#     topic=20 level=1 (documents=13): 販売, 兵庫県, 380円, メニュー, 季節, 点検, バランス,
#         topic=21 level=2 (documents=3): サンゴ, 調査, 地点, ボート, 守る, 方向, 実験,
#         topic=38 level=2 (documents=3): 資産, 暗号, ドローン, トークン, 発行, 保有, プロジェクト,
#         topic=41 level=2 (documents=5): 天ぷら, かぶる, 加える, 入れる, 帆立, 焼く, 玉ねぎ,
#         topic=96 level=2 (documents=2): アプリ, デベロッパー, カメラ, くる, 描く, らく, 渋谷,
#     topic=23 level=1 (documents=27): 旅行, 回答, シーズン, 一緒, 年末年始, エクスペディア, 2023年,
#         topic=24 level=2 (documents=5): 小雁, 柏木さん, 言う, 寛子, 男性, 当時, 吸う,
#         topic=31 level=2 (documents=4): 東京, ホテル, 子ども, 未来, 水素, 大会, 危機,
#         topic=64 level=2 (documents=6): 進む, 流氷, しらせ, 分子, 電子, 昭和基地, 薄膜,
#         topic=69 level=2 (documents=12): 利用, 期間, 車両, 予約, グループ, 導入, 新メンバー,
# .........................

# %%
import pickle
import gzip

def save_zipped_pickle(obj, filename, protocol=-1):
    with gzip.open(filename, 'wb') as f:
        pickle.dump(obj, f, protocol)
        
def load_zipped_pickle(filename):
    with gzip.open(filename, 'rb') as f:
        loaded_object = pickle.load(f)
        return loaded_object

# %%
save_zipped_pickle(hlda, 'model/2022_12_19/yahoo_topic_news_hlda_default.pickle')
#save_zipped_pickle(hlda, '2022_11_15/yahoo_hlda_default.pickle')

# %%
hlda = load_zipped_pickle('model/2022_12_19/yahoo_topic_news_hlda_default.pickle')
#hlda = load_zipped_pickle('2022_11_15/yahoo_hlda_default.pickle')
