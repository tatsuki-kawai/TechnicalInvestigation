# %%
import pandas as pd
import numpy as np
import time
from MyNLP import WordDividerMecab
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
df = pd.read_csv("data/2022_12_20/news_list_12_20_business_topic_500.csv", encoding="cp932", header=None)
comment_list = []
row_data = df[2][1:].to_numpy().tolist()

temp_row_data = []
for text in row_data:
    if len(text) >= 0:
        temp_row_data.append(text)
row_data = temp_row_data

# 前処理
wd = WordDividerMecab()
stop_word_list = ["まだ", "ある", "なる", "なる", "する", "し", "する", "いる", "なっ", "せ", "い", "やる", "ない", "画像", "参照"]
for text in row_data:
    text = wd.wakati_text_delete(text=text, stop_word_list=stop_word_list)
    comment_list.append(text)

# 単語の集合(vocablury)の作成
vectorizer = TfidfVectorizer()
tfidf = vectorizer.fit_transform(comment_list)
voc = vectorizer.vocabulary_
voc = sorted(voc)

# HLDAの入力に合わせたリストの形状に変換する
corpus = []

for comment in comment_list:
    list = comment.split(" ")
    corpus.append(list)
filtered_corpus = []
for comment in corpus:
    filtered_comment = []
    for word in comment:
        if word in voc:
            filtered_comment.append(word)
    filtered_corpus.append(filtered_comment)

# 前処理で文字数がなくなったテキストがあるかのチェック
corpus = filtered_corpus
corpus = [comment for comment in corpus if len(comment) != 0]

# 単語の集合に対してindexを割り当てる
vocab_index = {}
for i, w in enumerate(voc):
    vocab_index[w] = i

# HLDAの入力に合わせてテキストを単語のindexで表す
new_corpus = []
corpus = [comment for comment in corpus if comment != '']
for sentence in corpus:
    new_sentence = []
    for word in sentence:
        word_idx = vocab_index[word]
        new_sentence.append(word_idx)
    new_corpus.append(new_sentence)

# %%
from hlda.sampler import HierarchicalLDA


n_samples = 500       # no of iterations for the sampler
alpha = 10.0          # smoothing over level distributions
gamma = 10.0           # CRP smoothing parameter; number of imaginary customers at next, as yet unused table
eta = 0.1            # smoothing over topic-word distributions
num_levels = 3        # the number of levels in the tree
display_topics = 100   # the number of iterations between printing a brief summary of the topics so far
n_words = 10           # the number of most probable words to print for each topic after model estimation
with_weights = False  # whether to print the words with the weights

# %%
from hlda.sampler import HierarchicalLDA


n_samples = 500       # no of iterations for the sampler
alpha = 10.0          # smoothing over level distributions
gamma = 10.0           # CRP smoothing parameter; number of imaginary customers at next, as yet unused table
eta = 0.1            # smoothing over topic-word distributions
num_levels = 4        # the number of levels in the tree
display_topics = 100   # the number of iterations between printing a brief summary of the topics so far
n_words = 10           # the number of most probable words to print for each topic after model estimation
with_weights = False  # whether to print the words with the weights

# %%
from hlda.sampler import HierarchicalLDA


n_samples = 500       # no of iterations for the sampler
alpha = 10.0          # smoothing over level distributions
gamma = 10.0           # CRP smoothing parameter; number of imaginary customers at next, as yet unused table
eta = 0.1            # smoothing over topic-word distributions
num_levels = 4        # the number of levels in the tree
display_topics = 100   # the number of iterations between printing a brief summary of the topics so far
n_words = 10           # the number of most probable words to print for each topic after model estimation
with_weights = False  # whether to print the words with the weights

# %%
hlda = HierarchicalLDA(new_corpus, voc, alpha=alpha, gamma=gamma, eta=eta, num_levels=num_levels)
hlda.estimate(n_samples, display_topics=display_topics, n_words=n_words, with_weights=with_weights)
# Out:
# HierarchicalLDA sampling
#
# .................................................................................................... 100
# topic=0 level=0 (documents=475): できる, いう, 発表, 日本, 19日, 見る, 必要, 企業, 2022年, 行う,
#     topic=1 level=1 (documents=52): モデル, 新型, 搭載, 採用, デザイン, 価格, 設定, 使う, 最大, 専用,
#         topic=2 level=2 (documents=8): 扶養, 所得, 住民税, 税金, 世帯, 非課税, 家族, 金額, 場合, ふるさと納税,
#             topic=234 level=3 (documents=8): 生活保護, 場合, 自動車, 年金, 持ち家, 収入, 生活, 受給, 売却, 独身者,
#         topic=503 level=2 (documents=44): トヨタ, タイ, シート, 水素, スタンド, システム, ミニバン, カーボンニュートラル, バッテリー, 自転車,
#             topic=504 level=3 (documents=15): smartphone, 製品, カメラ, クリップ, 調理, 本体, 背面, ヘッドセット, 投入, 送信機,
#             topic=607 level=3 (documents=29): エンジン, 装備, クルマ, タイヤ, モデル, フォーチュナー, 性能, スポーツ, 空気, ボディ,
#     topic=7 level=1 (documents=7): 柔軟, ガス料金, 報告, 9月, 往来, 体験, 足元, 出席者, 入力, 11月19日,
#         topic=8 level=2 (documents=7): ツアー, 北京, 引き上げる, 1回, 南側, 大学, 住民, 訪日外国人, 2週間, 新型コロナウイルス,
#             topic=9 level=3 (documents=7): 旅行, コロナ, 上限, 支援, 料金, 観光, 宿泊, 全国, 補助, 感染,
#     topic=13 level=1 (documents=33): 最大, ドライバー, 年間, 搭載, 売上高, パック, ボルボカーズ, 小規模, 検出, 行う,
#         topic=128 level=2 (documents=8): 前年, 後継者, ランキング, 負債, 同月, 事業承継, 職種, 事業停止, 法的整理, 平均,
#             topic=129 level=3 (documents=8): 倒産, 危険性, 事業, 広告, メタ, アベマ, 農業, ゲーム, リスク, 業種,
#         topic=169 level=2 (documents=18): 17日, 立ち往生, 復旧, 通信障害, タイヤ, 集まる, 再開, ロク, 進める, きょう,
#             topic=296 level=3 (documents=7): 発生, 運休, 通行止め, 上下線, 一部, 架線, 区間, 新潟, 停電, 新潟県新潟市中央区,
#             topic=366 level=3 (documents=6): ウクライナ, 買収, 小野氏, 女性, ロシア, サントリー, 交渉, 提案, ミサイル, 飲料,
#             topic=665 level=3 (documents=5): デザイン, 三菱, 軽自動車, ディレクター, 1982年, アーティスティック, プロジェクト, モノ, 軌跡, 紹介,
#         topic=468 level=2 (documents=7): 電気料金, 倒産, 転嫁, 都道府県, 負債, 100件, 判明, 1年前, 破たん, 東京都,
#             topic=469 level=3 (documents=7): 値上げ, 景気, 薄皮, 見通し, 材料, 懸念, 悪化, 前年比, ミニパンシリーズ, 11月,
#     topic=19 level=1 (documents=235): 選手, 搭載, シリーズ, モデル, 最大, 思う, チーム, デザイン, 写真, ブランド,
#         topic=20 level=2 (documents=61): ファン, 時計, お金, 貯金, 平均, 手取り, 20代, 始める, 年収, 25万円,
#             topic=21 level=3 (documents=11): 着用, テレワーク, 回答, ウッド, マスク, 働く, 流行る, アイテム, 調査, 自分,
#             topic=172 level=3 (documents=22): トヨタ, 機能, ディスプレイ, 改良, 一部, 追加, 価格, 走行, クルマ, ドア,
#             topic=280 level=3 (documents=14): 賃上げ, 職員, 営業, 従業員, 検討, 日本生命, 方針, 顧客, 明らか, 要求,
#             topic=533 level=3 (documents=14): ポイント, 節約, ふるさと納税, プレゼント, 多い, 聞く, 毎月, 贈る, インターネット, 契約,
#         topic=22 level=2 (documents=60): マツダ, 開催, 分割, 協議, 15日, 東京オートサロン, 相続人, イベント, プログラム, 遺産分割,
#             topic=23 level=3 (documents=14): 車両, ファッション, カスタム, 落札, 参戦, クルマ, 出品, タウン, マシン, バイク,
#             topic=302 level=3 (documents=13): 保険証, 配達, 配送, 利用, 表示, 手続き, 事業者, 医療機関, マイナポータル, 医療費,
#             topic=476 level=3 (documents=2): 名称, 変更, 再生, ボード, 行なう, ストリーミング, ネットワークオーディオ, オーディオ, 川瀬, 聴く,
#             topic=663 level=3 (documents=31): インフレ, 予想, 述べる, 利上げ, 来年, インフレ率, 経済, ブルームバーグ, 指摘, ロイター,
#         topic=42 level=2 (documents=13): カーボンニュートラル, タイ, レース, 展示, スーパーフォーミュラ, 美容液, エンジン, ボタン, ビール, 耐久レース,
#             topic=455 level=3 (documents=13): 排出, バス, 天然ガス, 原油, 水素, サハリン, エネルギー, バー, 二酸化炭素, タクシー,
#         topic=90 level=2 (documents=16): 消費量, 法人税, 巡航ミサイル, いたずら, 天然ガス, 前向き, 19日, 上乗せ, 呈す, 泉沢,
#             topic=91 level=3 (documents=14): 防衛費, 方針, 総額, 政府, 評価, 予算案, 過去最大, 増税, 増額, 来年度,
#             topic=706 level=3 (documents=2): ホーム, ヘルメット, 方面, 横浜, かぶる, 自転車, 電車, ロープ, 既存, 筆者,
#         topic=112 level=2 (documents=56): 136円, 1ドル, 日銀, 午後5時, ニューヨーク, ユーロ, ドル, 前後, 円高, 免除,
#             topic=259 level=3 (documents=38): 週末, 銘柄, 日経平均株価, 売る, 営業日, 続落, 東証株価指数, 下落, 懸念, 終値,
#             topic=416 level=3 (documents=4): 撮影, アニメ, 監督, 背景, 制作, 配信, セル画, ブロック, 独占配信, 作る,
#             topic=708 level=3 (documents=7): インフルエンサー, ファイナンス, パーソナル, 金融, 教養, お金, 専門家, ネット, 知識, リーグ戦,
#             topic=724 level=3 (documents=7): 推す, 商品, メンズ, ブランド, グッズ, アパレル, 公式サイト, 購入, ラインアップ, 応援,
#         topic=252 level=2 (documents=26): メルセデス, 見直す, 12月15日, テクノロジー, 商業, 早期, 航空, 処理, 欧米, 航空会社,
#             topic=253 level=3 (documents=3): 明太子, 明太, セット, 福袋, 商品, 博多, 2023年, ふくや, めんたい, 無着色,
#             topic=536 level=3 (documents=6): サステナビリティ, 業務, 組織, プロセス, 変革, ファイナンス, ガイドライン, モッカ, 日本市場, 危機意識,
#             topic=703 level=3 (documents=7): 防止, 鉄道, グループ, 南ア, パナソニック, 納入, 技術協力, 航空機, 座屈, マクラーレン,
#             topic=710 level=3 (documents=5): 違反, 通知, 罰金, 事故, 厳しい, 付ける, ロンドン, 駐車, トラブル, 施設,
#             topic=727 level=3 (documents=5): 台湾, オフィス, 子会社, パーパス, 分断, グッド, カンパニー, 階級闘争, エリート, 行動,
#         topic=597 level=2 (documents=3): カウンタック, ミッション, パワートレーン, ミウラ, 全長, フェラーリ, 稼ぐ, ホイールベース, 置く, 漫画,
#             topic=598 level=3 (documents=3): 車検, 自動車, 位置, 貼る, 費用, 検査, ステッカー, 世帯, 確認, 標章,
#     topic=36 level=1 (documents=53): 米国, 日本時間, アリババ, ブルームバーグ, 価格, ツァイ, 共同, 同社, 上場, 先物,
#         topic=125 level=2 (documents=20): 市場, 償還, ラウンド, 送還, 株価, 来る, 始める, 来年1月, 出資, 原題,
#             topic=466 level=3 (documents=15): 資産, 暗号, 中国, 債券, 取引, 証券, 銀行, 決済, アンバー, ファイル,
#             topic=642 level=3 (documents=5): 高山, 絵本, 受賞, 佐藤, 童話, 日産, 大賞, 医療, 職人, 器具,
#         topic=223 level=2 (documents=33): チェンソーマン, ローソン, キャンペーン, リンク, tweet, 配布, 対象, 投稿, 凍結, 禁止,
#             topic=224 level=3 (documents=18): マスク, 投票, 辞任, teslla, トップ, ユーザー, 同氏, 問う, 買収, 投票結果,
#             topic=505 level=3 (documents=15): 販売, 抹茶, ソース, 玄米茶, クッキー, インパーフェクト, 大人, カカオ, コーヒー, 限定,
#     topic=39 level=1 (documents=38): マツダ, 新型, 低い, 労働生産性, 任期, 17日, 1970年, 結ぶ, 長安, 超える,
#         topic=40 level=2 (documents=32): 生産性, 135円, はるやま商事, 前後, 人口, 136円, 午後5時, 共同声明, 会見, 子ども,
#             topic=85 level=3 (documents=8): 一人, 料理, ソロ, 会長, 紳士服, 店主, 創業者, 以前, 飲食店, はるやま,
#             topic=558 level=3 (documents=18): 日銀, 政府, 日本, 黒田, 総裁, 金融緩和, 金利, 国債, 金融政策, 政策,
#             topic=602 level=3 (documents=6): クルマ, ミニバン, サブスクリプション, アウトドア, ユーザー, 新車, トヨタ, 車検, 初代, ホンダ,
#         topic=361 level=2 (documents=6): 新下関駅, 全景, 新設, 18時, 新駅, ハウステンボス, 夜間, 26分, 大鉈, 15m,
#             topic=362 level=3 (documents=6): ニシン, のぞみ, 特急, 往復, 運行, 列車, 短縮, 所要時間, 開業, ダイヤ改正,
#     topic=47 level=1 (documents=30): 生産, 新型, フォード, 台湾, 予定, モデル, 出資, フィエスタ, 九州, インテル,
#         topic=309 level=2 (documents=30): タイ, 従業員, 太陽光発電, ブリヂストン, タイヤ, パネル, 鄭州市, 感染拡大, 出店, 工程,
#             topic=327 level=3 (documents=27): 半導体, 工場, 製造, パワー, 建設, 操業, 増強, 工程, 東芝, 計画,
#             topic=725 level=3 (documents=3): カレーパン, トレンド, クリスマスケーキ, カレー, なかの, レシピ, 定番, パン, 有名, 専門店,
#     topic=57 level=1 (documents=21): ロジック, ピラミッド, 書く, 読み手, 構造, 変化, 人事, 文書, メッセージ, 売上,
#         topic=58 level=2 (documents=14): エンジニア, モビリティ, 高田, 産業, 部門, スマート, 審査, 障害者, 審査員, 横断歩道,
#             topic=59 level=3 (documents=14): 課題, ビジネス, 経営, 考える, 幹部, メール, 事業, ミドル, 変革, 実現,
#         topic=103 level=2 (documents=7): 離婚, 調停, 協議, 合意, 審判, 裁判, モラハラ, 離婚裁判, 生物, 事由,
#             topic=581 level=3 (documents=7): アルコール, 割る, 研究, 検知, 焦る, ケース, 魅力, 赤外線センサ, 条件, 採択,
#     topic=160 level=1 (documents=6): 租税条約, 更正, めぐる, 非上場, 過去最大, 海外事業, 持ち分, 反する, 第3四半期, 売る,
#         topic=161 level=2 (documents=6): 当てはまる, 課税, 裁量, 複数回, 投資, 外資系企業, 5つ, 1日, 集大成, 方針,
#             topic=162 level=3 (documents=6): 会社, 年齢, メキシコ, 当局, 中部電, 平均, 子会社, 中部電力, 税務, 計上,
# .................................................................................................... 200
# topic=0 level=0 (documents=475): できる, いう, 日本, 発表, 企業, 19日, 必要, 見る, 行う, 使う,
#     topic=1 level=1 (documents=44): モデル, 新型, 搭載, 採用, スポーツ, デザイン, 価格, エンジン, シリーズ, 仕様,
#         topic=2 level=2 (documents=6): 所得, 世帯, 住民税, 非課税, 場合, 金額, 均等割, 負担, 確認, 介護保険,
#             topic=234 level=3 (documents=6): 生活保護, 年齢, 自動車, 会社, 持ち家, 年金, 生活, 場合, 受給, 売却,
#         topic=503 level=2 (documents=38): シート, フォーチュナー, スタンド, トヨタ, 自転車, キャプテン, ハイラックス, 可能, タイ, 2列目,
#             topic=504 level=3 (documents=13): smartphone, カメラ, 製品, 対応, クリップ, 本体, 背面, 投入, ヘッドセット, 調理,
#             topic=607 level=3 (documents=25): 装備, ミニバン, 登場, クルマ, タイヤ, 空気, 初代, フル, グレード, 性能,
#     topic=7 level=1 (documents=2): 素手, 施策, 制度, 除く, 立て直し, 旅行会社, 配送, サービス, 11月25日, 急減,
#         topic=8 level=2 (documents=2): 消費者, 晶子, 6000円, 踏み切る, 顕著, 推移, 鎖国, ビザ, 思い出す, 2500円,
#             topic=9 level=3 (documents=2): 旅行, 全国, 支援, 観光, 宿泊, コロナ, インバウンド, 感染拡大, 最大, 5000円,
#     topic=13 level=1 (documents=30): 軽自動車, ミーティング, 回復, 自動車, 物品, 先行き, 掲載, 広告, 衝突, 運休,
#         topic=128 level=2 (documents=6): 後継者, 前年, メタ, 同月, 事業承継, 代表者, 違反, 11月, 不在, 金融機関,
#             topic=129 level=3 (documents=6): 倒産, 事業, 危険性, アベマ, 業種, 広告, ランキング, 農業, 赤字, リスク,
#         topic=169 level=2 (documents=17): タイヤ, 内藤, 胎内, 17日, 自己啓発書, 1969年, 依頼者, スウェーデン, 出版, 午前1時,
#             topic=296 level=3 (documents=9): 発生, 事故, 通行止め, 運休, 一部, 架線, 上下線, 新潟, 区間, 長岡,
#             topic=366 level=3 (documents=3): ウクライナ, 分断, 新しい, ラトビア, ロシア, 交渉, 階級闘争, 漁獲, トランプ, 割当,
#             topic=665 level=3 (documents=5): ファン, デザイン, 時計, 三菱, 売れる, モデル, コラボ, 企画, ブーム, 有名人,
#         topic=468 level=2 (documents=7): 電気料金, 都道府県, 倒産, 転嫁, 負債, 100件, 判明, 達す, 比べる, 販売価格,
#             topic=469 level=3 (documents=7): 値上げ, 薄皮, 景気, 見込む, 価格, 材料, クリームパン, 前年比, ミニパンシリーズ, 悪化,
#     topic=19 level=1 (documents=244): マツダ, ブランド, 開催, エンジン, 採用, 水素, 車両, 展示, タイ, モデル,
#         topic=20 level=2 (documents=74): 場合, 離婚, 扶養, 協議, 平均, 分割, 家族, 貯金, 手取り, 税金,
#             topic=21 level=3 (documents=6): テレワーク, 回答, 調査, 着用, ウッド, マスク, 新社会人, 入社, 流行る, アイテム,
#             topic=172 level=3 (documents=31): トヨタ, 搭載, 機能, ディスプレイ, 改良, 写真, 価格, 一部, 走行, 可能,
#             topic=280 level=3 (documents=15): 賃上げ, 職員, 営業, 検討, 明らか, 従業員, 方針, 制度, 日本生命, 自治体,
#             topic=533 level=3 (documents=15): ポイント, 節約, ふるさと納税, 多い, プレゼント, 寄付, インターネット, 今年, お金, 通信費,
#             topic=729 level=3 (documents=7): オフィス, 研究, 採択, パーパス, アサヒ飲料, 行動, カンパニー, グッド, 外部, 見える,
#         topic=22 level=2 (documents=59): 労働生産性, コロナ, 生産性, 新型コロナウイルス, 日本生産性本部, 感染, 以降, 企画, コロナ感染, 北京,
#             topic=23 level=3 (documents=11): カスタム, ファッション, 落札, タウン, クルマ, 出品, バイク, アルミ, 車両, フェラーリ,
#             topic=302 level=3 (documents=11): 保険証, 利用, 配送, 配達, 事業者, マイナポータル, 医療機関, 医療費, サイト, マイナンバーカード,
#             topic=476 level=3 (documents=3): 変更, 対応, 名称, 行なう, 再生, ボード, ネットワークオーディオ, ストリーミング, スーパーフォーミュラ, 荒川,
#             topic=663 level=3 (documents=34): インフレ, 経済, 述べる, 利上げ, 予想, インフレ率, 来年, ブルームバーグ, 低下, 米国,
#         topic=42 level=2 (documents=9): 石炭, ソファ, 製鉄, バス, 副産物, 瞬発力, 日産自動車, 太陽光, ハイブリッド車, 重量,
#             topic=455 level=3 (documents=9): 天然ガス, 排出, 原油, ロシア, サハリン, タクシー, 石油, 二酸化炭素, 有害物質, チタン,
#         topic=90 level=2 (documents=21): グループ, 選考, 小さい, 法人税, 延長, 日銀, 何度, 国内企業, 盛り込む, 7割,
#             topic=91 level=3 (documents=13): 防衛費, 総額, 政府, 予算案, 評価, 過去最大, 防衛, 方針, 防衛力, 増額,
#             topic=706 level=3 (documents=3): ホーム, ヘルメット, 方面, 横浜, かぶる, 自転車, 電車, ロープ, 武蔵小杉駅, 筆者,
#             topic=731 level=3 (documents=5): 小野氏, 買収, サントリー, 女性, 東芝, 飲料, 提案, 入社, キャリア, 既存,
#         topic=112 level=2 (documents=60): 136円, 1ドル, 日銀, ユーロ, 午後5時, 週明け, 前後, ドル, 円高, 現在,
#             topic=259 level=3 (documents=40): 週末, 銘柄, 日経平均株価, 19日, 営業日, 下落, 売る, 続落, 東証株価指数, 懸念,
#             topic=416 level=3 (documents=5): 撮影, アニメ, シリーズ, 背景, 配信, 監督, 制作, 作る, セル画, ブロック,
#             topic=708 level=3 (documents=6): 選手, 大会, チーム, 思う, 優勝, 試合, ユニホーム, アルゼンチン, くじ, ブランド,
#             topic=724 level=3 (documents=9): 推す, 商品, メンズ, グッズ, 銀座, アパレル, 集める, ショールーム, アイテム, 300円,
#         topic=252 level=2 (documents=16): 開発, 建物, 誘導, 新築, 韓国, 対地, 物件, 長距離, 算出, エージェント,
#             topic=253 level=3 (documents=3): 明太子, 明太, セット, 福袋, 博多, めんたい, ふくや, 商品, 無着色, 辛子明太子,
#             topic=536 level=3 (documents=7): ファイナンス, サステナビリティ, プロセス, 変革, 金融, パーソナル, 組織, ガイドライン, 知識, インフルエンサー,
#             topic=703 level=3 (documents=6): 鉄道, 防止, 南ア, 航空機, 技術協力, マクラーレン, 航空, 座屈, 納入, 輸出,
#         topic=597 level=2 (documents=5): 置く, カウンタック, ミッション, 透過率, パワートレーン, 漫画, 全長, サーキットの狼, フェラーリ, 移行,
#             topic=598 level=3 (documents=5): 車検, 位置, 貼る, 自動車, 検査, 電子版, 標章, ステッカー, 付ける, 1月,
#     topic=36 level=1 (documents=55): ブルームバーグ, アリババ, シリーズ, 1月, 創業, デニム, 上場, ニューヨーク, 原題, ディレクター,
#         topic=125 level=2 (documents=23): フィリピン, 売却, 香港, 資本, スクエア, 資本市場, オフショア, 国際, 先週, ドル,
#             topic=466 level=3 (documents=16): 資産, 暗号, 債券, 取引, 証券, 中国, 銀行, リスク, 決済, アンバー,
#             topic=642 level=3 (documents=7): 高山, 絵本, 佐藤, 日産, 受賞, 童話, 大賞, 作品, 医療, 器具,
#         topic=223 level=2 (documents=32): チェンソーマン, ローソン, キャンペーン, 配布, 店舗, パワー, プレゼント, 開始, 購入, 対象,
#             topic=224 level=3 (documents=20): マスク, 投票, 辞任, ユーザー, tweet, 投稿, トップ, teslla, 同氏, リンク,
#             topic=505 level=3 (documents=12): 抹茶, ソース, 玄米茶, 販売, 商品, インパーフェクト, クッキー, 加える, 大人, カカオ,
#     topic=39 level=1 (documents=39): 谷口, 内装, グレー, カラー, 人口, 採用, コンセプト, こだわる, シート, 表現,
#         topic=40 level=2 (documents=32): 免除, 台湾, 共同声明, 前後, 年収, 扶養, 全額, 条件, 範囲, 受ける,
#             topic=85 level=3 (documents=9): 一人, 料理, はるやまホールディングス, ソロ, 紳士服, はるやま商事, 食べる, 飲食店, はるやま, 以前,
#             topic=558 level=3 (documents=15): 日銀, 政府, 黒田, 総裁, 金融緩和, 金利, 金融政策, 国債, 政策, 大規模,
#             topic=602 level=3 (documents=8): クルマ, 費用, サブスクリプション, 自動車, ユーザー, 車検, 新車, アウトドア, 世帯, ミニバン,
#         topic=361 level=2 (documents=7): 施設, メリーゴーランド, 田舎, ランキング, 活性化, 住む, 2号, 廃校, ベスト, 東急,
#             topic=362 level=3 (documents=7): ニシン, のぞみ, 特急, 開業, 往復, 運行, ほか, 列車, 所要時間, 短縮,
#     topic=47 level=1 (documents=34): 新型, フォード, 生産, 従業員, モデル, フィエスタ, 投稿, ケルン, ドイツ, デザイン,
#         topic=309 level=2 (documents=34): 鴻海, 太陽光発電, パネル, 発電, 再生可能エネルギー, ブリヂストン, タイヤ, 2030年, 2026年, ライン,
#             topic=327 level=3 (documents=27): 半導体, 工場, 製造, パワー, 見込む, 生産, 台湾, 工程, 建設, 操業,
#             topic=725 level=3 (documents=7): クリスマスケーキ, カレーパン, カレー, トレンド, レシピ, シミ, パン, なかの, ローソン, オープン,
#     topic=57 level=1 (documents=20): ロジック, ピラミッド, 選手, 書く, 文書, 読み手, 売上, 人事, メッセージ, 日本人,
#         topic=58 level=2 (documents=15): エンジニア, 授かる, 戒名, 自分, 社会, 採用, 法名, 高田, 仏弟子, 審査,
#             topic=59 level=3 (documents=15): 課題, 考える, ビジネス, 経営, 事業, メール, 幹部, ミドル, 変革, 解決策,
#         topic=103 level=2 (documents=5): チェック, 比べる, 消毒, 顔認証, 資料, ミュージアム, 樋口泰行, 採用, 内部, 支払い,
#             topic=581 level=3 (documents=5): アルコール, 割る, 検知, 焦る, ケース, パナソニック, 赤外線センサ, 評価, 認定, アルバイト,
#     topic=160 level=1 (documents=7): 納税, 租税条約, 業績予想, 命じる, 気付く, 2026年, 研究開発, 株式, カメラ, 疑惑,
#         topic=161 level=2 (documents=7): 申し立て, 特別利益, 95億, 発電, 内藤尚志, 方針, 課税, 韓国, 連結, 建設,
#             topic=162 level=3 (documents=7): 通知, メキシコ, 違反, 中部電, 厳しい, 施設, 罰金, 駐車, 税務, 中部電力,
# .................................................................................................... 300
# topic=0 level=0 (documents=475): できる, いう, 日本, 19日, 発表, 企業, 必要, 見る, 行う, 場合,
#     topic=1 level=1 (documents=43): モデル, 価格, 搭載, スポーツ, 新型, 採用, デザイン, 登場, トヨタ, 性能,
#         topic=2 level=2 (documents=7): 離婚, 場合, 所得, 世帯, 住民税, 非課税, 調停, 条件, 金額, 均等割,
#             topic=234 level=3 (documents=7): 生活保護, 割る, ケース, 自動車, 持ち家, 受給, 売却, アルバイト, 年金, 生活,
#         topic=503 level=2 (documents=36): フォーチュナー, スタンド, 自転車, 使用, 免除, 両立, 乗せる, 取り付ける, 全額, 扶養,
#             topic=504 level=3 (documents=13): smartphone, カメラ, 製品, 本体, クリップ, 背面, 対応, ヘッドセット, 調理, 送信機,
#             topic=607 level=3 (documents=23): 装備, シート, ミニバン, タイヤ, クルマ, ホンダ, グレード, 空気, 初代, キャプテン,
#     topic=7 level=1 (documents=2): 交流, 多言語, 多い, 9月, 付加価値, 日本総研, 下品, 1月10日, 政府観光局, 不満の声,
#         topic=8 level=2 (documents=2): 好調, 強化, 旅客, 長い, 買い上げ, 県内, リスタート, 予算, 伴う, 晶子,
#             topic=9 level=3 (documents=2): 旅行, 全国, 支援, 観光, 宿泊, コロナ, インバウンド, 感染拡大, 補助, 日本人,
#     topic=13 level=1 (documents=30): 達す, 累計, 倒産, トラブル, ハンドル, 小規模, 2021年, 件数, 様子, 量産,
#         topic=128 level=2 (documents=5): 後継者, 前年, 同月, 11月, 事業承継, 負債, 要因, 2022年, 代表者, 34件,
#             topic=129 level=3 (documents=5): 倒産, 危険性, 業種, 農業, 発生, ランキング, 平均, リスク, 事業, 職種,
#         topic=169 level=2 (documents=15): 当時, 運転見合わせ, 依頼, 依頼者, スタリオン, 西日本, 衝突, 1969年, 抜け出せる, 木次線,
#             topic=296 level=3 (documents=10): 発生, 事故, 一部, 運休, 通行止め, 架線, 上下線, 新潟, 区間, 運転,
#             topic=665 level=3 (documents=5): ファン, デザイン, 時計, 三菱, コラボ, 売れる, 企画, モデル, 1982年, ブーム,
#         topic=468 level=2 (documents=10): 電気料金, 転嫁, 9月, 都道府県, 判明, 発表, 負債, 上限, 東京都, 販売価格,
#             topic=469 level=3 (documents=10): 値上げ, 薄皮, 景気, 価格, 見込む, 見通し, 材料, 懸念, 2022年, 売上高,
#     topic=19 level=1 (documents=258): 新型, 2023年, 開催, トヨタ, エンジン, 見る, マツダ, 水素, 予定, 採用,
#         topic=20 level=2 (documents=76): 扶養, 家族, 税金, 手取り, お金, 聞く, 25万円, 電源, 開発, 誘導,
#             topic=21 level=3 (documents=7): 回答, テレワーク, 調査, ウッド, 着用, 多い, 働く, マスク, 実施, ミニバン,
#             topic=172 level=3 (documents=34): 機能, 搭載, 改良, ディスプレイ, トヨタ, 可能, 一部, 価格, 写真, 電動,
#             topic=280 level=3 (documents=17): 賃上げ, 職員, 営業, 方針, 制度, 日本生命, 要求, 検討, メタ, 明らか,
#             topic=533 level=3 (documents=12): ポイント, 節約, ふるさと納税, インターネット, プレゼント, 今年, 寄付, 通信費, 贈る, 聞く,
#             topic=729 level=3 (documents=6): 開業, 進化, バス, クリスマス, プレゼント, 堅田, 楽しめる, 今年, メリーゴーランド, 遊ぶ,
#         topic=22 level=2 (documents=64): 労働生産性, アルゼンチン, 始める, バーチャル, つみたてる, 生産性, 感染, 日本生産性本部, 20代, 資産形成,
#             topic=23 level=3 (documents=13): カスタム, ファッション, 車両, 落札, フェラーリ, タウン, 出品, ブランド, バイク, 商品,
#             topic=302 level=3 (documents=12): 保険証, 利用, 配送, 配達, 事業者, 時間, マイナポータル, 医療費, 医療機関, メリット,
#             topic=476 level=3 (documents=5): 再生, オーディオ, ボード, ネットワークオーディオ, ストリーミング, 行なう, 川瀬, 荒川, メタバース, マクラーレン,
#             topic=663 level=3 (documents=34): インフレ, 予想, 利上げ, 上昇, 述べる, 経済, インフレ率, 低下, ブルームバーグ, 指数,
#         topic=42 level=2 (documents=12): 発電, 交渉, 出力, 安全保障, 再生可能エネルギー, 割当, リポート, 読み解く, 首相府, 無線通信,
#             topic=455 level=3 (documents=12): ウクライナ, ロシア, 天然ガス, 原油, タクシー, ロイター, サハリン, 石油, 石炭, ミサイル,
#         topic=90 level=2 (documents=25): 会長, 復興税, 予見, 新電力, 小部, 潜水艦, 出資, 確保, 国内企業, つく,
#             topic=91 level=3 (documents=13): 防衛費, 政府, 総額, 国債, 保有, 過去最大, 方針, 評価, 予算案, 増額,
#             topic=706 level=3 (documents=2): ホーム, ヘルメット, 方面, 横浜, かぶる, 電車, 自転車, ロープ, 十分, 既存,
#             topic=731 level=3 (documents=6): 会社, 年齢, 小野氏, 買収, サントリー, 女性, 平均, 提案, 東芝, 飲料,
#             topic=743 level=3 (documents=4): 研究, オフィス, 働く, アサヒ飲料, シミ, 採択, メラノサイト, グッド, 因子, カンパニー,
#         topic=112 level=2 (documents=60): 136円, 日銀, 1ドル, ユーロ, 前後, 午後5時, ドル, 現在, ニューヨーク, 135円,
#             topic=259 level=3 (documents=35): 週末, 銘柄, 日経平均株価, 売る, 営業日, 続落, 懸念, 東証株価指数, 下落, 業種,
#             topic=416 level=3 (documents=6): 撮影, アニメ, シリーズ, 背景, 監督, 配信, 制作, ブロック, セル画, 描く,
#             topic=708 level=3 (documents=8): 選手, チーム, 思う, 大会, アベマ, すごい, 優勝, アルゼンチン, 試合, 赤字,
#             topic=724 level=3 (documents=11): 推す, ブランド, 商品, デニム, グッズ, メンズ, 銀座, 購入, 集める, アイテム,
#         topic=252 level=2 (documents=16): 算出, 主張, 集団訴訟, 飛行, 提起, 自動車産業, 機体, 配慮, 訴訟, 航空,
#             topic=253 level=3 (documents=3): 明太子, 明太, セット, 福袋, 商品, 博多, めんたい, ふくや, 2023年, 辛子明太子,
#             topic=536 level=3 (documents=8): ファイナンス, サステナビリティ, 業務, プロセス, 組織, インフルエンサー, パーソナル, 金融, 変革, ガイドライン,
#             topic=703 level=3 (documents=5): 鉄道, 南ア, 防止, 納入, 座屈, 分断, 欧米, 階級闘争, 軌道, エリート,
#         topic=597 level=2 (documents=5): カウンタック, ミッション, 市民, パワートレーン, 魚沼市, 名称, 知名度, 来訪, 協議, 収める,
#             topic=598 level=3 (documents=5): 車検, 位置, 変更, 貼る, 自動車, 電子版, 検査, ステッカー, 標章, 付ける,
#     topic=36 level=1 (documents=51): 米国, ブルームバーグ, 同社, アリババ, ツァイ, 抜粋, 価格, 上場, 原題, 読む,
#         topic=125 level=2 (documents=25): 保有, 資本, 会社, 売却, アナリスト, 新規株式公開, 政府, 理財商品, 国際, 半数,
#             topic=466 level=3 (documents=20): 資産, 債券, 暗号, 取引, 株式, 証券, 中国, リスク, ドル, 決済,
#             topic=642 level=3 (documents=5): 高山, 絵本, 佐藤, 受賞, 童話, 日産, 大賞, 器具, 職人, 物語,
#         topic=223 level=2 (documents=26): チェンソーマン, キャンペーン, ローソン, 一部, 配布, クリアファイル, クッション, パワー, オリジナル, セミ,
#             topic=224 level=3 (documents=18): マスク, 投票, 辞任, tweet, ユーザー, 投稿, teslla, 同氏, トップ, リンク,
#             topic=505 level=3 (documents=8): 抹茶, 販売, ソース, 玄米茶, インパーフェクト, 大人, コーヒー, カカオ, クッキー, 税込,
#     topic=39 level=1 (documents=41): 物価, 人口, 子ども, 店主, 17日, 牛骨ラーメン, 作成, 地元, 繁忙, コース,
#         topic=40 level=2 (documents=36): 分割, 協議, 平均, 遺産分割, 相続, 相続人, 貯金, 授かる, 戒名, 年間,
#             topic=85 level=3 (documents=10): 一人, 料理, ソロ, はるやま商事, はるやまホールディングス, 紳士服, 食べる, 創業, はるやま, 飲食店,
#             topic=558 level=3 (documents=21): 日銀, 政府, 黒田, 総裁, 共同声明, 金融緩和, 金融政策, 日本, 金利, 大規模,
#             topic=602 level=3 (documents=5): クルマ, 費用, サブスクリプション, 車検, 自動車, 世帯, 新車, かかる, 保有, 補償,
#         topic=361 level=2 (documents=5): 臨時, 身欠きニシン, 豊岡, 開業, 到着, 食欲, 札幌, 1997年, 同車, 11分,
#             topic=362 level=3 (documents=5): ニシン, 特急, のぞみ, 往復, 運行, 列車, 短縮, ほか, 江戸時代, 定期,
#     topic=47 level=1 (documents=28): 生産, 出資, 九州, 京セラ, 鴻海, 太陽光発電, 大手, 台湾, タイ, タイヤ,
#         topic=309 level=2 (documents=28): 従業員, 計画, 次世代, 停止, 2030年, 鄭州市, 基盤, 用地, 研究開発, 施設,
#             topic=327 level=3 (documents=23): 半導体, 工場, 製造, パワー, 建設, 工程, 操業, 増強, 生産, 産業,
#             topic=725 level=3 (documents=5): クリスマスケーキ, カレーパン, トレンド, カレー, ディレクター, 発売, パン, パーパス, レシピ, なかの,
#     topic=57 level=1 (documents=15): ロジック, ピラミッド, 書く, 人事, 読み手, 売上, 文書, メッセージ, 変化, 日本人,
#         topic=58 level=2 (documents=12): エンジニア, モビリティ, 高田, 開発, 産業, 人材, いい, 障害者, スマート, 審査,
#             topic=59 level=3 (documents=12): 課題, ビジネス, 経営, 考える, 幹部, 事業, メール, ミドル, 企業, 変革,
#         topic=103 level=2 (documents=3): 例外, 微細, 協議会, プリンタ, 認定, 取材, 物体, パソコン, 問う, 工数,
#             topic=581 level=3 (documents=3): アルコール, 検知, 焦る, 赤外線センサ, 評価, 赤外線, 飲む, 表情, 顔認証, センサー,
#     topic=160 level=1 (documents=7): メキシコ, 中部電, 当局, 中部電力, オランダ, 更正, 売却, 申し立て, 課税, 命じる,
#         topic=161 level=2 (documents=7): 台湾, 違法, 疑い, 交通, 内閣, 主張, 作業部会, 移管, 大陸, 子会社,
#             topic=162 level=3 (documents=7): 通知, 違反, 罰金, 厳しい, 税務, 納付, 駐車, ルール, バスレーン, ロンドン,
# .................................................................................................... 400
# topic=0 level=0 (documents=475): できる, いう, 発表, 日本, 19日, 必要, 企業, 見る, 行う, 場合,
#     topic=1 level=1 (documents=40): モデル, スポーツ, 価格, 搭載, 採用, フォーチュナー, デザイン, エンジン, トヨタ, 専用,
#         topic=2 level=2 (documents=3): 結論, 面接, 対象者, 大筋, 引き上げ, 来年度, 30日, 外れる, 手当, 6000円,
#             topic=234 level=3 (documents=3): 生活保護, 持ち家, 自動車, 受給, 売却, 年金, 生活, 給付, 給付金, 介護保険,
#         topic=503 level=2 (documents=37): スタンド, 自転車, 乗せる, 使用, 両立, 投入, 新型, 状態, 車体, 1本,
#             topic=504 level=3 (documents=17): 対応, smartphone, カメラ, 製品, 再生, システム, 接続, 可能, オーディオ, 操作,
#             topic=607 level=3 (documents=20): 装備, シート, ミニバン, タイヤ, グレード, クルマ, ホンダ, 空気, 登場, フル,
#     topic=7 level=1 (documents=2): 強いる, 割ける, 便数, 旅先, 21年, 堅固, 出端, 打撃, 主任, 小売業,
#         topic=8 level=2 (documents=2): 延長, 7月22日, コロナ禍, 旅行者, 県内, 買い上げ, 動き出す, 顕著, 2019年, 徳島,
#             topic=9 level=3 (documents=2): 旅行, 支援, 全国, 観光, コロナ, 宿泊, インバウンド, 感染拡大, 補助, 需要,
#     topic=13 level=1 (documents=30): 倒産, 谷口, カラー, 負債, 内装, 達す, グレー, 2022年, こだわる, 表現,
#         topic=128 level=2 (documents=4): 後継者, 前年, 同月, 事業承継, 不在, とどまる, 30件, 10件, 平均, 銀行,
#             topic=129 level=3 (documents=4): 倒産, 危険性, 業種, 農業, ランキング, 職種, 発生, あり, 1位, 工事,
#         topic=169 level=2 (documents=15): 1982年, 当時, 規定, 量産, 二人, 日本車, カーデザイン, サッカー界, 登場, 冷戦,
#             topic=296 level=3 (documents=7): 発生, 運休, 通行止め, 架線, 上下線, 区間, 新潟, 方面, 停電, 長岡,
#             topic=665 level=3 (documents=8): デザイン, ファン, 時計, コラボ, 三菱, 売れる, ブランド, 企画, モノ, 性能,
#         topic=468 level=2 (documents=11): 料金, ホットミルク, ローソン, 入園, パーク, 撤廃, 破たん, ガス, 半額, 大阪ガス,
#             topic=469 level=3 (documents=11): 価格, 値上げ, 薄皮, 景気, 見通し, 見込む, 上限, 高騰, 企業, 懸念,
#     topic=19 level=1 (documents=251): 新型, モデル, エンジン, トヨタ, 見る, 予定, 日本, 欧州, デザイン, 水素,
#         topic=20 level=2 (documents=82): できる, 離婚, 扶養, 家族, 平均, 場合, 貯金, 年収, 税金, 手取り,
#             topic=21 level=3 (documents=8): テレワーク, 回答, 調査, 多い, ウッド, 着用, マスク, 聞く, 働く, 流行る,
#             topic=172 level=3 (documents=37): 搭載, 機能, 改良, 一部, 写真, トヨタ, ディスプレイ, 採用, 価格, 最大,
#             topic=280 level=3 (documents=18): 賃上げ, 職員, 方針, 明らか, 制度, 検討, 従業員, 顧客, 日本生命, メタ,
#             topic=533 level=3 (documents=12): ポイント, 節約, ふるさと納税, プレゼント, 寄付, インターネット, 今年, 決まる, 多い, 通信費,
#             topic=729 level=3 (documents=7): 割る, クリスマスケーキ, ケース, アルバイト, トレンド, 弁償, 進化, 裁判, 定番, 故意,
#         topic=22 level=2 (documents=56): 住民税, 所得, 世帯, 調査, 非課税, 金額, 1ドル, コロナ, マイナス, 以降,
#             topic=23 level=3 (documents=11): カスタム, ファッション, フェラーリ, 車両, 落札, ブランド, タウン, クルマ, バイク, 出品,
#             topic=302 level=3 (documents=11): 保険証, 配達, 配送, 利用, 事業者, 医療費, 商品, 検索, マイナポータル, 医療機関,
#             topic=663 level=3 (documents=34): インフレ, 利上げ, 経済, 述べる, 予想, 低下, インフレ率, 来年, 米国, 指数,
#         topic=42 level=2 (documents=11): 漁獲, 交渉, 風力, 割当, 太陽光, 買収, エアロジェット, バイ, 出足, 規制,
#             topic=455 level=3 (documents=11): ウクライナ, ロシア, 天然ガス, 原油, タクシー, サハリン, 燃料, ミサイル, 侵攻, ラトビア,
#         topic=90 level=2 (documents=22): 台湾, 名称, 変更, 財源, 子会社, 電気料金, 市民, 魚沼市, 清次, 比率,
#             topic=91 level=3 (documents=14): 防衛費, 政府, 総額, 方針, 過去最大, 国債, 増額, 予算案, 評価, 増税,
#             topic=731 level=3 (documents=4): メール, 会社, 年齢, 女性, 仕事, 小野氏, 人事, 平均, サントリー, 若い,
#             topic=752 level=3 (documents=4): 違反, 罰金, 厳しい, 通知, 駐車, 施設, 後日, ロンドン, 交通, 監視カメラ,
#         topic=112 level=2 (documents=59): 136円, 日銀, ユーロ, 購入, 午後5時, 共同声明, 世界, 修正, 135円, チェンソーマン,
#             topic=259 level=3 (documents=32): 銘柄, 週末, 日経平均株価, 売る, 営業日, 続落, 懸念, 下落, 東証株価指数, 終値,
#             topic=416 level=3 (documents=6): 撮影, アニメ, 配信, 背景, 監督, 制作, セル画, ブロック, シリーズ, 描く,
#             topic=708 level=3 (documents=8): 選手, チーム, 大会, 思う, アベマ, 優勝, アルゼンチン, ゲーム, 試合, ユニホーム,
#             topic=724 level=3 (documents=10): 推す, ブランド, 商品, デニム, メンズ, 銀座, ショールーム, グッズ, 300円, ハイエンドモデル,
#             topic=755 level=3 (documents=3): 軽自動車, 分断, ミーティング, 欧米, 階級闘争, エリート, トランプ, 労働者階級, ポピュリズム, 前大統領,
#         topic=252 level=2 (documents=21): ガイドライン, 算出, 誤解, 集団訴訟, 主張, 飛行, 改訂, 提起, 数値, 2件,
#             topic=253 level=3 (documents=4): 明太子, 明太, セット, 商品, 福袋, 博多, ふくや, めんたい, 2023年, 無着色,
#             topic=536 level=3 (documents=11): ファイナンス, サステナビリティ, 業務, プロセス, 組織, インフルエンサー, 金融, 電子版, パーソナル, 推進,
#             topic=703 level=3 (documents=6): 鉄道, 南ア, 防止, 座屈, シミ, 最終, 納入, 軌道, 因子, メラノサイト,
#     topic=36 level=1 (documents=57): 買収, 19日, マツダ, 当局, レーシング, スピリット, メキシコ, 提案, 取締役会, 東芝,
#         topic=125 level=2 (documents=29): 会社, 同社, 上場, フィリピン, イーサリアム, シリーズ, 承認, 一環, お呼び, フォータム,
#             topic=466 level=3 (documents=23): 資産, 取引, 暗号, 売却, 債券, 株式, 保有, 米国, 証券, リスク,
#             topic=642 level=3 (documents=6): 高山, 絵本, 童話, 佐藤, 日産, 受賞, 大賞, 医療, 職人, 器具,
#         topic=223 level=2 (documents=28): 開発, 分割, 相続人, 協議, チェンソーマン, 遺産分割, ローソン, キャンペーン, 誘導, 韓国,
#             topic=224 level=3 (documents=18): マスク, 投票, 辞任, ユーザー, トップ, tweet, 投稿, teslla, 同氏, リンク,
#             topic=505 level=3 (documents=10): 販売, 抹茶, ソース, 玄米茶, インパーフェクト, クッキー, 大人, カカオ, コーヒー, 加える,
#     topic=39 level=1 (documents=45): 置く, 144円, ブランド, ミッション, ディレクター, エンジン, 137円, 1ユーロ, 死去, 会長,
#         topic=40 level=2 (documents=40): 免除, 条件, 扶養, 見直し, 子ども, 全額, 所得, 親族, 会見, 年収,
#             topic=85 level=3 (documents=11): 研究, オフィス, はるやまホールディングス, 紳士服, パーパス, はるやま商事, 創業者, 創業, アサヒ飲料, 大手,
#             topic=558 level=3 (documents=21): 日銀, 政府, 黒田, 総裁, 共同声明, 金融政策, 金融緩和, 金利, 大規模, 1ドル,
#             topic=602 level=3 (documents=8): 車検, クルマ, 自動車, 位置, 費用, サブスクリプション, ユーザー, 検査, 貼る, 新車,
#         topic=361 level=2 (documents=5): 大阪駅, 山陰, 乗り入れ, 高山, 設立, 28分, 簑島, 食品, ダウン, 大鉈,
#             topic=362 level=3 (documents=5): ニシン, のぞみ, 特急, 往復, 運行, 列車, 所要時間, ほか, 短縮, ダイヤ改正,
#     topic=47 level=1 (documents=38): タイヤ, 太陽光発電, 進出, 用地, インテル, 再生可能エネルギー, グラフ, 新電力, 9月, 車両,
#         topic=309 level=2 (documents=38): 操業, 停止, 保有, 市内, 鄭州市, 取る, 開業, 地元, 電池, 排出,
#             topic=327 level=3 (documents=27): 半導体, 工場, 製造, パワー, 台湾, 生産, 建設, 見込む, 増強, 投資,
#             topic=725 level=3 (documents=8): 料理, 一人, ソロ, カレーパン, 食べる, 以前, カレー, オープン, レストラン, 人気,
#             topic=761 level=3 (documents=3): ホーム, ヘルメット, 方面, 横浜, かぶる, トラブル, 電車, 自転車, ロープ, 思う,
#     topic=57 level=1 (documents=12): ロジック, 書く, ピラミッド, 考える, 構造, 文書, メッセージ, 読み手, 日本人, 売上,
#         topic=58 level=2 (documents=9): エンジニア, モビリティ, 社会, 高田, 産業, 審査, 障害者, スマート, ベンチャー, 視点,
#             topic=59 level=3 (documents=9): 課題, 経営, ビジネス, 考える, 幹部, ミドル, 変革, 事業, 企業, 解決策,
#         topic=103 level=2 (documents=3): 帯びる, 取り出す, 外部, 行く, 人間関係, 協議会, 忘年会, 捉える, 形状, 多様,
#             topic=581 level=3 (documents=3): アルコール, 検知, 焦る, 赤外線センサ, 赤外線, 表情, 飲む, 顔認証, 存在, 実験,
# .................................................................................................... 500
# topic=0 level=0 (documents=475): できる, いう, 19日, 企業, 日本, 発表, 必要, 行う, 使う, 価格,
#     topic=1 level=1 (documents=44): モデル, スポーツ, フォーチュナー, デザイン, トヨタ, 登場, タイ, 採用, グレード, 搭載,
#         topic=2 level=2 (documents=6): 離婚, 場合, 所得, 住民税, 世帯, 非課税, 調停, 条件, 均等割, 金額,
#             topic=234 level=3 (documents=6): 生活保護, 自動車, 持ち家, 受給, 売却, 年金, 負担, 原則, 制度, 生活,
#         topic=503 level=2 (documents=38): スタンド, 自転車, 乗せる, 使用, 両立, 取り付ける, トラブル, 発売, 機種, 特別,
#             topic=504 level=3 (documents=17): smartphone, 対応, 製品, カメラ, システム, 再生, 可能, 接続, アプリ, クリップ,
#             topic=607 level=3 (documents=19): シート, ミニバン, 装備, タイヤ, クルマ, ホンダ, 空気, フル, キャプテン, 初代,
#             topic=781 level=3 (documents=2): ヘルメット, ウッド, かぶる, アイテム, 筆者, 子ども, やめる, 自転車, 自分, インテリアデザイン,
#     topic=7 level=1 (documents=2): 2019年, めど, 県内, クーポン, 規制緩和, 上る, 岸田, 高額, 円安, 24万人,
#         topic=8 level=2 (documents=2): 高坂, 交通, 切る, 急減, 小売業, 訪日外国人, 観光産業, 国境, 落ち込む, 4割,
#             topic=9 level=3 (documents=2): 旅行, 支援, 観光, 全国, コロナ, 宿泊, インバウンド, 感染拡大, 補助, 5000円,
#     topic=13 level=1 (documents=23): 三菱, デザイン, 1982年, 軌跡, 年齢, カーデザイン, 様子, 6位, イベント, 100件,
#         topic=128 level=2 (documents=6): 負債, 関連, 後継者, 11月, 前年, 都道府県, 事業承継, 同月, 累計, コロナ,
#             topic=129 level=3 (documents=6): 倒産, 危険性, 業種, ランキング, 農業, 達す, 職種, 発生, 平均, 3位,
#         topic=169 level=2 (documents=11): 立ち往生, 車両, 企画, 装着, 通信障害, 欠く, 午前1時, スタリオン, 旧車, 走る,
#             topic=296 level=3 (documents=7): 発生, 運休, 一部, 通行止め, 上下線, 架線, 新潟, 区間, 新潟県新潟市中央区, 停電,
#             topic=665 level=3 (documents=4): ファン, 時計, コラボ, 売れる, モデル, 着用, カラー, 有名人, ブーム, 生まれる,
#         topic=468 level=2 (documents=6): 入園, 悪化, チケット, 突出, 対策, 開く, 旅行, 体験, 内訳, 資源,
#             topic=469 level=3 (documents=6): 値上げ, 薄皮, 景気, 価格, 見込む, 見通し, 2023年, 懸念, 材料, 売上高,
#     topic=19 level=1 (documents=263): 新型, モデル, マツダ, エンジン, 見る, デザイン, 2023年, 予定, 発表, トヨタ,
#         topic=20 level=2 (documents=90): 扶養, できる, 家族, 年収, 対象, 協議, 平均, 場合, 免除, 分割,
#             topic=21 level=3 (documents=10): 多い, 調査, 聞く, 回答, テレワーク, 手取り, 着用, プレゼント, マスク, 満足,
#             topic=172 level=3 (documents=39): 搭載, 機能, 採用, 価格, トヨタ, 改良, 写真, ディスプレイ, 一部, 装備,
#             topic=280 level=3 (documents=22): 賃上げ, 職員, 営業, 方針, 制度, 検討, 日本生命, 明らか, 自治体, メタ,
#             topic=533 level=3 (documents=13): ポイント, 節約, ふるさと納税, 上限, 寄付, 料金, インターネット, 通信費, ガス, 負担,
#             topic=729 level=3 (documents=2): クリスマスケーキ, 進化, トレンド, 定番, なかの, 堅田, プレゼント, リカちゃん, 選び, 世代,
#             topic=775 level=3 (documents=4): カレーパン, 軽自動車, カレー, パン, ミーティング, 中盤, オープン, 時代, 出店, 専門店,
#         topic=22 level=2 (documents=56): コロナ, 労働生産性, 生産性, 日本生産性本部, コロナ感染, 落ち込む, 忘れる, 政策, 韓国経済, 地元,
#             topic=23 level=3 (documents=13): カスタム, 車両, フェラーリ, ファッション, 落札, タウン, 出品, ブランド, バイク, クルマ,
#             topic=302 level=3 (documents=11): 保険証, 利用, 配送, 配達, 地域, マイナポータル, 医療費, 医療機関, 検索, サイト,
#             topic=663 level=3 (documents=32): インフレ, 利上げ, 経済, 予想, 述べる, インフレ率, 来年, 低下, ブルームバーグ, 投資,
#         topic=42 level=2 (documents=11): 石炭, ミサイル, 漁獲, 消費量, 交渉, 当局, 読み解く, レンタカー, 割当, 17日,
#             topic=455 level=3 (documents=11): ウクライナ, ロシア, 天然ガス, 原油, タクシー, サハリン, 16日, 侵攻, エネルギー, 発電,
#         topic=90 level=2 (documents=27): 泉沢, 開業, モノ, 清次, プロジェクト, 選考, 三菱重工業, 広義, 1年前, 特色,
#             topic=91 level=3 (documents=13): 防衛費, 総額, 方針, 増加, 評価, 増額, 予算案, 過去最大, 増税, 政府,
#             topic=731 level=3 (documents=6): 会社, 年齢, 小野氏, 人事, 女性, 社長, 平均, グループ, サントリー, 社員,
#             topic=752 level=3 (documents=5): 違反, 施設, 罰金, 厳しい, 通知, 駐車, バス, 交通, 監視カメラ, ロンドン,
#             topic=786 level=3 (documents=3): 分断, 階級闘争, 新しい, アメリカ, エリート, 半額, 前大統領, 支配階級, ローソン, ホットミルク,
#         topic=112 level=2 (documents=62): 136円, 1ドル, ニューヨーク, 午後5時, 前後, 135円, 共同声明, 円高, 144円, マイナス,
#             topic=259 level=3 (documents=36): 週末, 銘柄, 日経平均株価, 売る, 営業日, 続落, 東証株価指数, 19日, 下落, 終値,
#             topic=416 level=3 (documents=6): 撮影, アニメ, 配信, 背景, 監督, 制作, シリーズ, セル画, ブロック, 描く,
#             topic=708 level=3 (documents=9): 選手, チーム, 思う, 大会, アベマ, 優勝, 試合, ゲーム, アルゼンチン, シーズン,
#             topic=724 level=3 (documents=9): 推す, ブランド, 商品, メンズ, デニム, 購入, 銀座, アパレル, グッズ, ショールーム,
#             topic=788 level=3 (documents=2): オフィス, 焦る, 赤外線センサ, 赤外線, 検知, グッド, カンパニー, 素子, 存在, 働く,
#         topic=252 level=2 (documents=17): モビリティ, 誤解, 産業, 航空機, マクラーレン, 技術協力, te, 提起, 集団訴訟, 本質,
#             topic=253 level=3 (documents=3): 明太子, 明太, セット, 福袋, 博多, 商品, めんたい, ふくや, 無着色, 辛子明太子,
#             topic=536 level=3 (documents=8): ファイナンス, サステナビリティ, 変革, インフルエンサー, プロセス, 組織, 電子版, パーソナル, 金融, 業務,
#             topic=703 level=3 (documents=6): ニシン, 防止, 鉄道, 南ア, 航空, 技術, 納入, 座屈, 江戸時代, 最終,
#     topic=36 level=1 (documents=61): 仮想通貨, 原題, ブルームバーグ, 抜粋, 16日, 天才, すくめる, ニューヨーク, 読む, アトラス,
#         topic=125 level=2 (documents=33): エンジニア, 台湾, 子会社, 上場, 北京, フィリピン, メタバース, 業績, 同社, 主要,
#             topic=466 level=3 (documents=26): 資産, 取引, 中国, 暗号, 売却, 会社, 債券, 保有, 株式, 米国,
#             topic=642 level=3 (documents=7): 高山, 絵本, 童話, 佐藤, 日産, 受賞, 大賞, 医療, 職人, 器具,
#         topic=223 level=2 (documents=28): チェンソーマン, ローソン, キャンペーン, 配布, 悪魔, パワー, マキマ, 税込, 購入, プレゼント,
#             topic=224 level=3 (documents=18): マスク, 投票, ユーザー, 辞任, tweet, トップ, teslla, 同氏, 投稿, 問う,
#             topic=505 level=3 (documents=10): 販売, 抹茶, ソース, 玄米茶, 加える, クッキー, インパーフェクト, カカオ, 大人, コーヒー,
#     topic=39 level=1 (documents=40): カウンタック, 置く, ミッション, 前方, エンジン, 作品, 行動, 定期, 1ドル, 概要,
#         topic=40 level=2 (documents=35): 名称, 始める, つみたてる, 20代, アーティスティック, 資産形成, 安定, 子ども, 定期的, 別荘,
#             topic=85 level=3 (documents=7): はるやまホールディングス, 会長, パーパス, 紳士服, 大手, 創業者, 創業, はるやま, はるやま商事, 死去,
#             topic=558 level=3 (documents=18): 日銀, 政府, 黒田, 総裁, 共同声明, 金融緩和, 金融政策, 国債, 金利, 大規模,
#             topic=602 level=3 (documents=10): 車検, クルマ, 自動車, 費用, 位置, サブスクリプション, 変更, ユーザー, 貼る, 検査,
#         topic=361 level=2 (documents=5): 新下関駅, はくたか, 延伸, ひとつ, シート, 始終, 午前10時, ひとくち, 滞在時間, 余裕,
#             topic=362 level=3 (documents=5): 方面, ホーム, 特急, のぞみ, 往復, 横浜, 列車, 運行, 所要時間, 短縮,
#     topic=47 level=1 (documents=33): 出資, 従業員, 提案, 鴻海, 買収, 太陽光発電, インテル, 2030年, 集団, 特別委員会,
#         topic=309 level=2 (documents=33): 九州, 地元, タイヤ, タイ, 検討, 市内, グラフ, ブリヂストン, 満州, 発表,
#             topic=327 level=3 (documents=25): 半導体, 工場, 製造, パワー, 生産, 台湾, 建設, 東芝, 工程, 増強,
#             topic=725 level=3 (documents=5): 一人, 料理, ソロ, 食べる, 人気, 以前, レストラン, 店主, 飲食店, 牛骨ラーメン,
#             topic=787 level=3 (documents=3): メール, 仕事, アサヒ飲料, 研究, 採択, チェック, 頻繁, 法政大学第二高等学校, 営業時間, 決める,
#     topic=57 level=1 (documents=9): ロジック, 構造, 書く, ピラミッド, 文書, メッセージ, 読み手, 日本人, 理解, 売上,
#         topic=58 level=2 (documents=6): 高田, 審査, 開発, 障害者, 社会, スマート, 横断歩道, 盲導, 審査員, プレゼン,
#             topic=59 level=3 (documents=6): 課題, 考える, 経営, ビジネス, 事業, 幹部, ミドル, 解決策, 変革, 新規,
#         topic=103 level=2 (documents=3): 基本的, 異性, 組み合わせ, 支店, 新年会, 沈黙, しよう, 個人, バイト, 支払い,
#             topic=581 level=3 (documents=3): アルコール, 割る, アルバイト, ケース, 検知, 弁償, 魅力, 評価, 顔認証, 表情,

# %%
import pickle
import gzip

def save_zipped_pickle(obj, filename, protocol=-1):
    with gzip.open(filename, 'wb') as f:
        pickle.dump(obj, f, protocol)
        
def load_zipped_pickle(filename):
    with gzip.open(filename, 'rb') as f:
        loaded_object = pickle.load(f)
        return loaded_object

# %%
save_zipped_pickle(hlda, 'model/2022_12_20/yahoo_business_topic_500news_hlda_level3_gamma10.pickle')
#save_zipped_pickle(hlda, '2022_11_15/yahoo_hlda_default.pickle')

# %%
hlda = load_zipped_pickle('model/2022_12_20/yahoo_business_topic_1000news_hlda_level3_gamma10.pickle')
#hlda = load_zipped_pickle('2022_11_15/yahoo_hlda_default.pickle')

# %%
hlda.print_nodes(n_words = 12, with_weights = False)
# Out:
# topic=0 level=0 (documents=928): できる, いう, 発表, 日本, 見る, 企業, 必要, 行う, 2022年, 高い, 場合, 多い,
#     topic=7 level=1 (documents=269): 利上げ, インフレ, 示す, 目標, 金利, 述べる, 見通し, 機能, 経済, 2023年, 変動, 長期,
#         topic=38 level=2 (documents=145): 日銀, 長期金利, 金利, 修正, 20日, 金融緩和, 総裁, 上昇, 市場, 一時, 拡大, 変動,
#         topic=122 level=2 (documents=66): モデル, 搭載, 採用, 装備, 新型, システム, スポーツ, グレード, 可能, トヨタ, 走行, 機能,
#         topic=144 level=2 (documents=9): 増税, 防衛費, 評価, 方針, 支持層, 増額, ブラックロック, 首相, 反撃, 能力, 安保, 泉沢,
#         topic=156 level=2 (documents=20): 開催, イベント, 展示, 車両, レース, 東京オートサロン, 15日, 落札, コンテンツ, カスタム, クルマ, マツダ,
#         topic=201 level=2 (documents=22): 販売, 商品, 値上げ, 店舗, ピース, ソース, ホットミルク, 大人, 抹茶, 薄皮, 牛乳, ローソン,
#         topic=382 level=2 (documents=7): スタジアム, モビリティ, 体験, 産業, ソフトバンク, シティ, ニューヨーク市, 特許, 知的財産権, アプリ, キャンペーン, ウェイモ,
#     topic=9 level=1 (documents=57): ドコモ, 指定, 結論, 開始, 連続, 三菱, 5か月, 残高, 川越, 昭和, 新幹線, 位置づける,
#         topic=18 level=2 (documents=8): 予算案, 当初, 調整, 総額, 来年度, 過去最大, 国債, 4000億円, 政府, 税収, 一般会計, 今年度,
#         topic=35 level=2 (documents=9): エンジニア, 売上高, 値上げ, パック, 供給, ごはん, ライン, 伸長, 改定, タコ焼き, 単価, 前年比,
#         topic=52 level=2 (documents=13): 年金, 制度, 所得, 免除, 場合, 生活保護, 世帯, 住民税, 納付, 非課税, 国民年金保険料, 受給,
#         topic=66 level=2 (documents=6): 開通, 御殿場, 工事, トンネル, 名称, 区間, 秦野, 全線, 変更, 高松, 予定, 2027年度,
#         topic=112 level=2 (documents=13): 列車, 方面, 特急, 平日, ホーム, 運行, 上り, 2本, 休日, 往復, 実施, 1本,
#         topic=365 level=2 (documents=8): 商品, ファン, 売れる, 時計, レビュー, ブランド, ウッド, トレンド, 進化, クリスマスケーキ, ブーム, コラボ,
#     topic=12 level=1 (documents=121): モデル, デザイン, 新型, 採用, エンジン, 内装, 発売, 仕様, 登場, 搭載, 設定, ほか,
#         topic=13 level=2 (documents=35): マスク, 投票, teslla, 辞任, 価格, トップ, 投稿, 同氏, 19日, 買収, ユーロ, 合意,
#         topic=19 level=2 (documents=45): 専用, 写真, サイズ, クルマ, ボディ, ベース, タイヤ, カラー, シート, スポーツ, スポーティ, フロント,
#         topic=114 level=2 (documents=7): アメリカドル, バンク, 国際, 由来, 基軸通貨, デジタル, 米国, 金融機関, 東南アジア, フィリピン, 事業者, 銀行,
#         topic=160 level=2 (documents=7): 追加, 表示, 子ども, 義務付ける, ゲーム, アレルギー, エピック, 引き起こす, くるみ, そば, フォートナイト, プライバシー保護,
#         topic=189 level=2 (documents=7): カメラ, 税込, ミラーレス, サクラ, ウレタン, センサー, シミ, 背面, 因子, リップ, 予約, メラノサイト,
#         topic=357 level=2 (documents=13): 配送, 荷物, アマゾン, 事業者, 配達, タクシー, 再配達, 下請け, 個数, 車両, 商品, 地域,
#         topic=447 level=2 (documents=2): ニシン, 東京ビッグサイト, 地下鉄, 有明, 臨海, 江戸時代, ルート, 都心部, 晴海, 結ぶ, 建設, 日本海,
#         topic=464 level=2 (documents=5): 保険証, クレーマー, 警察, 悪質, 弁護士, 調剤薬局, 医療機関, 薬局, 来る, 利用, 経営者, 診療報酬,
#     topic=16 level=1 (documents=114): 仕事, メール, 個人, 従業員, 所得, 納税義務, 学生, 失敗, キャリア, 顧客, 上司, 理解,
#         topic=29 level=2 (documents=9): 1位, ランクイン, 2位, ランキング, 3位, 人気, 習慣, ダイハツ, スズキ, 贈る, 5位, 4位,
#         topic=40 level=2 (documents=21): 考える, 課題, 経営, ビジネス, 事業, 幹部, 変革, 組織, 自分, ミドル, 方法, 企業,
#         topic=90 level=2 (documents=23): 賃上げ, 職員, 営業, メキシコ, 方針, はるやまホールディングス, 日本生命, 引き上げる, 当局, 17日, 大手, 税務,
#         topic=94 level=2 (documents=15): チェンソーマン, 推す, プレゼント, ローソン, キャンペーン, デンジ, 配布, 開始, 運転, パワー, マキマ, 早川アキ,
#         topic=191 level=2 (documents=14): 運休, 発生, 停電, 区間, 一部, 通行止め, ホテル, 大雪, 長岡, 架線, 上下線, 新潟,
#         topic=225 level=2 (documents=9): 場合, 離婚, 相続人, 請求, 協議, 分割, 相手, 不倫, 非課税, 不貞, 割る, 残業代,
#         topic=354 level=2 (documents=7): 飛行, 事故, 最終, 高田, ジェット旅客機, モデル, 機体, ボーイング, 審査, メルセデス, スマート, 旅客機,
#         topic=359 level=2 (documents=9): 仮想通貨取引所, 破綻, 債券, 労働生産性, インフルエンサー, 避難, 順位, 生産性, 劣後債, リスク, インフルエンサーマーケティング, 日本生産性本部,
#         topic=479 level=2 (documents=3): 痛み, 腰痛, 異常, 治療法, 分断, 銘柄, 著者, 富裕層, 病気, 身体, アメリカ, エリート,
#         topic=486 level=2 (documents=4): アルコール, 条件, 検知, 参加者, 表情, 評価, 飲む, すくめる, 天才, アトラス, 顔認証, 実験,
#     topic=21 level=1 (documents=75): 株価, 推移, ライン, 20日, 669円, 検索, トレンド, 6568円, 局面, 概算, 休暇, 安値,
#         topic=22 level=2 (documents=14): 貨物, 中国, コロナ, 運航, 路線, 往復, 荷動き, 空港, 旅客, 上海, 成田, 2019年,
#         topic=93 level=2 (documents=6): 罰金, 違反, 駐車場, 駐車, 通行, 厳しい, 禁止, 通知, 反則金, 支払い, 施設, 駐車違反,
#         topic=129 level=2 (documents=55): 日経平均株価, 営業日, 銘柄, 終値, 下落, 日経平均, 東京株式市場, 19日, 上昇, 懸念, 前日, 売る,
#     topic=27 level=1 (documents=25): 扶養, 税金, 家族, お金, お年玉, 所得, 独身者, 収入, 決まる, 老後, 節約, 親族,
#         topic=304 level=2 (documents=13): 年収, 平均, 多い, 手取り, 年齢, 都会, 場合, 金額, 回答, 調理, 貯金, 住む,
#         topic=373 level=2 (documents=5): 鹿山, バー, ベスト, 軽自動車, バーテンダー, オーナー, ディレクター, カスタム, アルミ, アーティスティック, カクテル, バイク,
#         topic=387 level=2 (documents=4): シリーズ, 配信, 独占配信, シーズン2, 109シネマズ, トム, シネマサンシャイン, 番組表, 番組, 独占, 上映, 1月1日,
#         topic=499 level=2 (documents=3): 防止, 鉄道, パーパス, 南ア, 座屈, 軌道, 納入, 枕木, アフリカ, 検証, 制定, 解き放つ,
#     topic=32 level=1 (documents=105): 19日, 経済, 中国, 銀行, 来年, 予想, 従業員, 指摘, 指数, 20日, 関連, ストラテジスト,
#         topic=70 level=2 (documents=36): 半導体, 工場, 倒産, 製造, 事業, パワー, 危険性, 建設, 生産, 業種, 負債, 工程,
#         topic=79 level=2 (documents=41): 資産, 暗号, 下落, ファンド, ドル, 仮想通貨, 取引, ブルームバーグ, 米国, よる, コイン, 原題,
#         topic=115 level=2 (documents=7): 開発, 戦闘機, 戦闘, イタリア, シグナス, イギリス, ヤマハ, 検査, 航空, システム, 技術, 技術協力,
#         topic=121 level=2 (documents=10): めんたい, 福袋, 明太子, セット, 商品, 2023年, 税込, 明太, クーポン, 博多, 辛子, 大戸屋,
#         topic=202 level=2 (documents=4): 車検, 自動車, 貼る, 費用, 位置, 電子, 検証, 検査, 電子版, 世帯, 情報, ステッカー,
#         topic=471 level=2 (documents=3): 再生, メタバース, ボード, オーディオ, ネットワークオーディオ, ストリーミング, 行なう, ソリューション, 荒川, 川瀬, 聴く, サンプリング,
#         topic=482 level=2 (documents=2): 風車, タワー, デカ, salesforce, 建設, 想像, 上空, サンフランシスコ, 立ち並ぶ, プロ, 大型, 神業,
#         topic=488 level=2 (documents=2): 歩く, 伊能忠敬, タダ, タカ, 歩数, キャラクター, 令和, 日本地図, ウォーキング, 応援, 完成, 筆者,
#     topic=36 level=1 (documents=124): 女性, お金, ロイター, 着用, 小野氏, エネルギー, マスク, 子ども, 減らす, サントリー, 発電, 石油,
#         topic=41 level=2 (documents=7): 料理, 食べる, 一人, 飲食店, ラーメン, ソロ, 吉野家, 創業者, ストーリー, ファン, お客様, 店主,
#         topic=60 level=2 (documents=6): 太陽光パネル, 建物, 物件, 煙突, 新築, 住宅, 相場, 中古, 区長, 浜田, 不動産, 周辺,
#         topic=61 level=2 (documents=18): ポイント, 節電, ふるさと納税, 電気代, プログラム, 節約, 上限, もらえる, 寄付, 自治体, 電気料金, 返礼,
#         topic=67 level=2 (documents=33): タイ, 排出, 水素, トヨタ, カーボンニュートラル, 採用, 製造, エンジン, 工場, 日産, フォーチュナー, 生産,
#         topic=89 level=2 (documents=15): テレワーク, 入社, 回答, 調査, 働く, 世帯, 新社会人, 実施, 若者, 不安, 富裕層, 60歳,
#         topic=102 level=2 (documents=17): アマゾン, 広告, メタ, 従業員, 欧州, 当局, 20日, 報告, 倉庫, クラシファイド, 違反, 売買,
#         topic=183 level=2 (documents=5): ヘルメット, 自転車, 焦る, 温度, パナソニック, サンスター, 体温, 赤外線センサ, かぶる, 赤外線, 検知, 筆者,
#         topic=259 level=2 (documents=11): 自分, 士業, 仕事, 年賀状, 教える, 勉強, 講座, フリースクール, 相手, 思う, 授かる, 戒名,
#         topic=358 level=2 (documents=12): 中国, ウクライナ, 人口, ステップ, ロシア, 原油, インド, 未来, 減る, 22年, 天然ガス, 年表,
#     topic=43 level=1 (documents=14): 買い替える, ライダー, バッテリー, 試乗, ヤマハ, 半分, 楽しめる, 幼稚園バス, ファン, 扱う, プレゼント, 速度,
#         topic=99 level=2 (documents=9): 信号, 矢印, 点灯, スタンド, バス, 装置, 給油, 場合, 故障, 確認, 自転車, 警告,
#         topic=423 level=2 (documents=5): 撮影, アニメ, 背景, フィルムカメラ, 制作, 絵本, ブロック, 日産, 童話, セル画, 作る, レゴ,
#     topic=50 level=1 (documents=12): 中辻, サッカー, スペイン, 財布, 閉じる, 無意味, 先輩, ヒット, 偉い, 逆転勝利, 奥さま, イギリス,
#         topic=145 level=2 (documents=8): 選手, アルゼンチン, 優勝, チーム, 大会, カタール, アベマ, 勝利, シーズン, 果たす, ゲーム, ドライバー,
#         topic=379 level=2 (documents=4): 認証, 数学, 高山, 佐藤, 職人, 器具, 問題, 東京大学, 理化学, 化学分析, 医療, 東大,
#     topic=54 level=1 (documents=12): ナンバープレート, 隠れる, トラブル, ナンバー, 行為, 別荘, 覆う, 内藤, 交通, 依頼者, ライトバン, 閑散,
#         topic=238 level=2 (documents=12): クルマ, タイヤ, サブスクリプション, 降雪, 地域, 走行, 凍結, 装着, エンジン, 立ち往生, 空気, 冬場,
