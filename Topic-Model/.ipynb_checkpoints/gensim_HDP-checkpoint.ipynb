# %%
import pandas as pd
import numpy as np
from MyNLP import WordDividerMecab
from gensim.corpora.dictionary import Dictionary
from gensim.models.ldamodel import LdaModel
from collections import defaultdict
from gensim.models import HdpModel

# %%
df = pd.read_csv("data/2022_09_22/comment_2022_09_22.csv", encoding="cp932", header=None)
comment_list = []
row_data = df[0][1:].to_numpy().tolist()
temp_row_data = []
for text in row_data:
    if len(text) >= 50:
        temp_row_data.append(text)
row_data = temp_row_data
wd = WordDividerMecab()
stop_word_list = ["まだ", "ある", "なる", "なる", "する", "し", "する", "いる", "なっ", "せ", "い", "やる", "ない"]
for text in row_data:
    if len(text) >= 10:
        text = wd.wakati_text_delete(text=text, stop_word_list=stop_word_list)
        comment_list.append(text)
dataset = [comment.split() for comment in comment_list]

# %%
dictionary = Dictionary(dataset)
print(len(dictionary))

dictionary.filter_extremes(no_below=3, no_above=0.1)
print(len(dictionary))

score_by_topic = defaultdict(int)
corpus = [dictionary.doc2bow(text) for text in dataset]
# Out:
# 1568
# 296

# %%
#common_corpus
#corpus

# %%
hdp = HdpModel(corpus=corpus, id2word=dictionary, gamma=0.5, eta=0.1)

# %%
# topic_info = hdp.print_topics(num_topics=50, num_words=10)
topic_info = hdp.get_topic()
# Out:
# [(0,
#   '0.017*こいつ + 0.015*研究 + 0.015*すごい + 0.013*目 + 0.013*仲 + 0.013*考える + 0.013*いく + 0.012*苦しむ + 0.012*捨てる + 0.012*父'),
#  (1,
#   '0.019*検死 + 0.017*謎 + 0.014*至る + 0.013*プロ + 0.013*命 + 0.013*混ぜる + 0.013*使用 + 0.011*待つ + 0.011*言える + 0.011*見る'),
#  (2,
#   '0.020*なのか + 0.019*自分 + 0.017*正直 + 0.017*容易 + 0.017*可能性 + 0.016*妻 + 0.016*研究 + 0.015*夫 + 0.013*幸せ + 0.013*犯人'),
#  (3,
#   '0.026*冤罪 + 0.019*捨てる + 0.018*悪い + 0.018*戦中 + 0.016*仕事 + 0.015*摂取 + 0.015*思える + 0.015*すごい + 0.013*今後 + 0.012*多い'),
#  (4,
#   '0.018*解明 + 0.017*注意 + 0.017*薬 + 0.016*勤務先 + 0.015*男 + 0.015*大切 + 0.014*気 + 0.014*開発 + 0.013*捜査 + 0.012*飲む'),
#  (5,
#   '0.020*動機 + 0.017*手 + 0.017*目 + 0.014*エリート + 0.013*違う + 0.013*確か + 0.013*社員 + 0.012*知識 + 0.012*気 + 0.012*命'),
#  (6,
#   '0.023*勤務先 + 0.019*生きる + 0.018*研究員 + 0.018*今 + 0.016*もったいない + 0.015*京都大学 + 0.014*警察 + 0.014*ロシア + 0.014*捜査 + 0.014*夫'),
#  (7,
#   '0.017*研究者 + 0.014*学歴 + 0.014*かわいそう + 0.014*体内 + 0.013*完全犯罪 + 0.013*不自然 + 0.012*分かる + 0.012*ばれる + 0.012*製薬 + 0.012*事故'),
#  (8,
#   '0.023*手段 + 0.023*プロ + 0.015*勉強 + 0.013*戦後 + 0.012*犯行 + 0.012*優秀 + 0.012*模試 + 0.011*盛る + 0.011*被害者 + 0.011*模倣犯'),
#  (9,
#   '0.017*模試 + 0.017*十分 + 0.016*ロシア + 0.016*続出 + 0.015*待つ + 0.015*気 + 0.015*可能 + 0.013*知れる + 0.013*高学歴 + 0.012*自宅'),
#  (10,
#   '0.032*学歴 + 0.019*方法 + 0.015*飲む + 0.014*メチルアルコール + 0.014*起訴 + 0.013*こいつ + 0.012*原因 + 0.011*手段 + 0.010*父 + 0.010*いう'),
#  (11,
#   '0.018*ケア + 0.018*バレる + 0.017*子ども + 0.016*明らか + 0.013*簡単 + 0.012*経歴 + 0.012*量 + 0.012*十分 + 0.012*呼ぶ + 0.011*飲む'),
#  (12,
#   '0.023*ホルムアルデヒド + 0.015*感じ + 0.014*残す + 0.013*難しい + 0.012*よい + 0.012*死亡 + 0.012*注意 + 0.011*離婚 + 0.011*痛み + 0.011*今'),
#  (13,
#   '0.020*すごい + 0.017*持つ + 0.016*学歴 + 0.014*原因 + 0.013*間違い + 0.013*選ぶ + 0.012*家族 + 0.012*出し手 + 0.011*将来 + 0.011*分かる'),
#  (14,
#   '0.024*お母さん + 0.022*毒性 + 0.021*失う + 0.017*ニュース + 0.014*捜査 + 0.014*悪い + 0.013*結果 + 0.013*否定 + 0.013*気の毒 + 0.013*漂白剤'),
#  (15,
#   '0.025*直ぐ + 0.022*捨てる + 0.018*人格 + 0.017*出る + 0.015*大手 + 0.014*良い + 0.012*いう + 0.012*考える + 0.011*検死 + 0.011*毒'),
#  (16,
#   '0.022*悪い + 0.020*大手 + 0.019*自死 + 0.016*疑問 + 0.015*殺人 + 0.015*方法 + 0.014*多い + 0.014*検死 + 0.012*男 + 0.012*いく'),
#  (17,
#   '0.022*事実 + 0.019*エタノール + 0.018*将来 + 0.016*理由 + 0.014*確か + 0.013*見える + 0.012*父 + 0.011*見る + 0.010*プロ + 0.010*離婚'),
#  (18,
#   '0.023*戦後 + 0.023*不思議 + 0.014*父親 + 0.014*奥様 + 0.013*勤務先 + 0.012*男 + 0.012*他 + 0.012*女 + 0.012*それなり + 0.012*ケア'),
#  (19,
#   '0.023*毒殺 + 0.016*日本 + 0.014*飲む + 0.014*命 + 0.013*人生 + 0.012*相手 + 0.012*解明 + 0.012*お子さん + 0.012*いう + 0.012*取る'),
#  (20,
#   '0.017*研究 + 0.013*検死 + 0.012*一 + 0.011*簡単 + 0.011*目 + 0.011*事故 + 0.011*結婚 + 0.011*明らか + 0.011*無い + 0.010*専門知識'),
#  (21,
#   '0.019*犯罪 + 0.018*知る + 0.016*戦後 + 0.016*うい + 0.016*ロシア + 0.015*証拠 + 0.015*偽装 + 0.014*ホルムアルデヒド + 0.013*出来る + 0.013*プロ'),
#  (22,
#   '0.019*想像 + 0.018*退職 + 0.017*残す + 0.016*不自然 + 0.016*知る + 0.016*捨てる + 0.015*ばれる + 0.013*ロシア + 0.013*別れる + 0.013*自死'),
#  (23,
#   '0.017*研究員 + 0.017*致死量 + 0.015*直ぐ + 0.015*盛る + 0.014*気 + 0.013*専門知識 + 0.013*完全犯罪 + 0.012*自宅 + 0.011*確定 + 0.010*事故'),
#  (24,
#   '0.019*研究者 + 0.018*動機 + 0.017*証拠 + 0.016*精神 + 0.015*捜査 + 0.015*小学生 + 0.013*手 + 0.012*失う + 0.011*やめる + 0.011*確定'),
#  (25,
#   '0.022*分かる + 0.021*取る + 0.020*特定 + 0.016*疑う + 0.013*結果 + 0.013*第一三共 + 0.012*新薬 + 0.012*段階 + 0.012*ケア + 0.012*相当'),
#  (26,
#   '0.017*飲む + 0.014*問題 + 0.014*製薬会社 + 0.014*手段 + 0.013*見つかる + 0.012*違う + 0.012*詳しい + 0.012*盛る + 0.012*残す + 0.011*間違い'),
#  (27,
#   '0.018*京都大学大学院 + 0.017*可能性 + 0.016*今後 + 0.015*悲しい + 0.014*違和感 + 0.012*幸せ + 0.012*結婚 + 0.010*子ども + 0.010*残る + 0.010*失明'),
#  (28,
#   '0.023*量 + 0.017*毒殺 + 0.016*自分 + 0.015*毒性 + 0.014*燃料 + 0.014*大学院 + 0.014*失明 + 0.012*ばれる + 0.012*ドラマ + 0.012*幸せ'),
#  (29,
#   '0.026*京都大学 + 0.016*事実 + 0.015*研究者 + 0.014*普通 + 0.014*痛み + 0.013*毒殺 + 0.013*そうだ + 0.013*方法 + 0.013*漂白剤 + 0.012*知識'),
#  (30,
#   '0.019*高学歴 + 0.016*簡単 + 0.016*技術 + 0.014*事実 + 0.014*悪い + 0.014*考える + 0.013*母 + 0.013*将来 + 0.012*やめる + 0.011*明らか'),
#  (31,
#   '0.019*見る + 0.014*間違い + 0.014*入る + 0.014*悲しい + 0.013*少量 + 0.013*続出 + 0.013*混ぜる + 0.013*不思議 + 0.012*経歴 + 0.012*亡くす'),
#  (32,
#   '0.018*分野 + 0.018*経歴 + 0.017*裁判 + 0.016*やめる + 0.016*バレる + 0.016*不倫 + 0.013*手段 + 0.013*前 + 0.013*人格 + 0.012*人生'),
#  (33,
#   '0.025*かわいそう + 0.020*相当 + 0.017*残念 + 0.017*京都大学 + 0.017*犯行 + 0.015*経歴 + 0.015*人格 + 0.014*レベル + 0.013*考える + 0.013*一'),
#  (34,
#   '0.025*京都大学 + 0.020*感じ + 0.018*妻 + 0.016*嫁 + 0.013*ただ + 0.013*仕事 + 0.012*レベル + 0.012*取る + 0.012*ばれる + 0.011*今'),
#  (35,
#   '0.023*話す + 0.019*製薬 + 0.018*別居 + 0.017*難しい + 0.015*母親 + 0.014*他殺 + 0.014*頭脳明晰 + 0.013*メチルアルコール + 0.012*可哀想 + 0.012*夫'),
#  (36,
#   '0.025*自白 + 0.017*至る + 0.016*人間 + 0.016*夫婦 + 0.015*相手 + 0.014*状況 + 0.012*冤罪 + 0.012*出し手 + 0.012*研究員 + 0.012*手'),
#  (37,
#   '0.030*量 + 0.020*薬 + 0.016*状況 + 0.015*命 + 0.015*分かる + 0.014*自殺 + 0.013*妻 + 0.013*大事 + 0.012*結果 + 0.011*事情'),
#  (38,
#   '0.016*…。 + 0.015*他 + 0.013*被害者 + 0.013*確か + 0.012*つく + 0.012*痛み + 0.012*裁判 + 0.012*生きる + 0.011*仲 + 0.011*難しい'),
#  (39,
#   '0.020*旦那 + 0.020*嫁 + 0.015*大事 + 0.014*頭脳明晰 + 0.013*誰か + 0.013*バレる + 0.013*博士号 + 0.012*書く + 0.012*小学生 + 0.011*人間'),
#  (40,
#   '0.018*違和感 + 0.018*京都大学 + 0.015*難しい + 0.014*研究者 + 0.013*お父さん + 0.012*大事 + 0.012*よい + 0.012*疑問 + 0.011*関係 + 0.011*逆'),
#  (41,
#   '0.027*正直 + 0.018*別居 + 0.018*製薬 + 0.015*他 + 0.015*今後 + 0.013*理由 + 0.012*中毒 + 0.012*取り扱い + 0.012*たくさん + 0.012*薬物'),
#  (42,
#   '0.018*真相 + 0.016*感じ + 0.015*自死 + 0.014*知れる + 0.014*最近 + 0.013*可哀想 + 0.013*素人 + 0.013*ホルムアルデヒド + 0.013*偽装 + 0.012*頭脳'),
#  (43,
#   '0.018*失う + 0.016*見る + 0.015*証拠 + 0.015*勉強 + 0.013*日本 + 0.013*命 + 0.013*凄い + 0.012*ドラマ + 0.012*京都大学大学院 + 0.011*怖い'),
#  (44,
#   '0.021*疑う + 0.017*起きる + 0.017*不憫 + 0.016*知る + 0.016*男 + 0.015*起訴 + 0.013*口 + 0.013*女 + 0.013*別居 + 0.012*嫌'),
#  (45,
#   '0.017*一番 + 0.016*犯罪 + 0.015*思える + 0.014*製薬 + 0.014*亡くす + 0.014*留学 + 0.013*病死 + 0.013*精神 + 0.012*やり方 + 0.012*社員'),
#  (46,
#   '0.022*相手 + 0.021*心配 + 0.018*燃料 + 0.015*研究員 + 0.013*薬物 + 0.012*冤罪 + 0.011*思える + 0.011*中毒 + 0.011*使用 + 0.011*呼ぶ'),
#  (47,
#   '0.029*難しい + 0.021*戦後 + 0.016*エリート + 0.016*別れる + 0.016*離婚 + 0.013*完全犯罪 + 0.013*可哀想 + 0.012*もったいない + 0.012*聞く + 0.012*揃う'),
#  (48,
#   '0.021*証拠 + 0.021*ホルムアルデヒド + 0.017*ものすごい + 0.016*ばれる + 0.016*精神 + 0.016*量 + 0.015*なのか + 0.015*お子さん + 0.014*母 + 0.014*知識'),
#  (49,
#   '0.019*出来る + 0.017*嫁 + 0.015*そうだ + 0.013*分かる + 0.013*知れる + 0.012*相手 + 0.012*悪い + 0.012*いく + 0.012*頭脳 + 0.011*女')]
