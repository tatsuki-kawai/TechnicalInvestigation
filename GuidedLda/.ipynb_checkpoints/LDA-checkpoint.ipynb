# %%
import sys
sys.path.append('../Data')

import pandas as pd
import numpy as np
import time
from CommentDataset import CommentDataset

import warnings
warnings.filterwarnings(action='ignore', category=UserWarning)
import gensim
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#データの読み込み
df = pd.read_csv("../Data/yahoo/2023_04_04/20230404_1.csv", encoding="cp932", header=None)
comment_list = df[0][1:].to_numpy().tolist()

# %%
# データの前処理
comment_dataset = CommentDataset(comment_list)
comment_dataset.delete_comment_specified_string(15)
comment_dataset.formatted_word_segmentation(stop_tagging_list=['格助詞', '副詞可能', '非自立'], appear_tagging_list=['名詞', '固有名詞', '一般'])
comment_dataset.comment_list = [comment.split() for comment in comment_dataset.comment_list]
print(comment_dataset.comment_list[0:3])
# Out:
# [['問題', '当該', '生徒', 'コーンロウ', '髪形', '学校', '側', '何', '相談', '卒業式', '髪形', 'コーンロウ', '多事', '民族的', 'アイデンティティ', '主張', '普通', '髪型'], ['在学中', '普通', '髪型', '卒業式', 'コーンロウ', '生徒', 'そりゃ', '教師', 'ダメ', '差別', '事前', 'ちゃんと', '親子', '担任', '教師', '相談', '問題', 'ニュース', '記事', '教師', '生徒', '差別', '勝手', 'しょうが', '…', '十手', 'これ', '感情', 'コメント', '炎上', 'SNS', 'コメント', 'ちゃんと', '確認', 'コメント', '…'], ['匿名', '攻撃', '攻撃', 'なのか', '？', '千原せいじ', '認識', '問い', '掛け', 'どこ', '誰か', '分からん', '返し', '論点', '生徒', '側', '話', '鵜呑み', '学校', '側', '言い分', 'アホ', '教師', '差別', '攻撃', 'それ', '？', '差別', '学校', '側', '対応', '何', '差別']]

# %%
# bag-of-words形式に変換
dictionary = gensim.corpora.Dictionary(comment_dataset.comment_list)

# dictionary.filter_extremes(no_below=1, no_above=0.1)

bow = [dictionary.doc2bow(line) for line in comment_dataset.comment_list]

# %%
# lda = gensim.models.ldamodel.LdaModel(corpus=bow, num_topics=2, id2word=dictionary)

# %%
def test_eta(eta, dictionary, ntopics, print_topics=True, print_dist=True):
    np.random.seed(42) # set the random seed for repeatability
    bow = [dictionary.doc2bow(line) for line in comment_dataset.comment_list] # get the bow-format lines with the set dictionary
    with (np.errstate(divide='ignore')):  # ignore divide-by-zero warnings
        model = gensim.models.ldamodel.LdaModel(
            corpus=bow, id2word=dictionary, num_topics=ntopics,
            random_state=42, chunksize=100, eta=eta,
            eval_every=-1, update_every=1,
            passes=150, alpha='auto', per_word_topics=True)
    # visuzlize the model term topics
    print('Perplexity: {:.2f}'.format(model.log_perplexity(bow)))
    if print_topics:
        # display the top terms for each topic
        for topic in range(ntopics):
            print('Topic {}: {}'.format(topic, [dictionary[w] for w,p in model.get_topic_terms(topic, topn=10)]))
    if print_dist:
        # display the topic probabilities for each document
        for line,bag in zip(comment_list,bow):
            doc_topics = ['({}, {:.1%})'.format(topic, prob) for topic,prob in model.get_document_topics(bag)]
            print('{} {}'.format(line, doc_topics))
            print('\n')
    return model

# %%
# test_eta('auto',dictionary,ntopics=2)

# %%
def create_eta(priors, etadict, ntopics):
    eta = np.full(shape=(ntopics, len(etadict)), fill_value=1) # create a (ntopics, nterms) matrix and fill with 1
    for word, topic in priors.items(): # for each word in the list of priors
        keyindex = [index for index,term in etadict.items() if term==word] # look up the word in the dictionary
        if (len(keyindex)>0): # if it's in the dictionary
            eta[topic,keyindex[0]] = 1e7  # put a large number in there
    eta = np.divide(eta, eta.sum(axis=0)) # normalize so that the probabilities sum to 1 over all topics
    return eta

# %%
apriori_original = {
    '学校':0, '教師':0, '卒業式':0, '生徒':0,
    'せいじ':1, '千原せいじ':1, '千原':1,
    'コーンロウ':2, '髪型':2,
    '匿名':3, '攻撃':3, 'SNS':3, '誹謗中傷':3, '論点':3,
    'お笑いタレント':4, '千原せいじ':4, 'さん':4, '2023年':4, '4月1日':4, 'Instagram':4, '更新':4, 'コメント欄':4, '批判':4, '声':4, '怒り':4, '反論':4
}
eta = create_eta(apriori_original, dictionary, 4)
test_eta(eta, dictionary, 4)
# Out:
# Perplexity: -1.06
# Topic 0: ['匿名', '？', '意見', '教師', '人', '名前', '自分', '*', '攻撃', 'SNS']
# Topic 1: ['？', '卒業式', 'コーンロウ', 'ダメ', '*', '髪型', '！', '人', '校則', '言葉']
# Topic 2: ['！', 'さん', '芸能人', '自分', 'それ', '千原せいじ', 'コメント', '*', '事', '…']
# Topic 3: ['髪型', '差別', '学校', '問題', '？', 'コーンロウ', 'それ', '的', '教師', '校則']
# この問題は当該生徒が以前から
# コーンロウの髪形にしていた訳でなく
# 学校側に何の相談も無く、
# 卒業式当日に髪形を突然コーンロウにして来た事にある。
# 民族的アイデンティティを主張するのであれば、何故　今までは普通の髪型だったのか。 ['(1, 98.7%)']
#
#
# 在学中は普通の髪型だったのに卒業式でコーンロウで生徒が現れたらそりゃあ教師も驚くでしょうし、ダメだと言うのも差別とは全く思いませんけどね。
# 事前にちゃんとこの親子が担任教師に相談していればこんな問題にもならかったと思います。
#
# せいじはニュース記事だけ見て、教師が生徒を差別していると勝手に思っているのでしょうが…せいじってこれまでも感情だけでコメントして炎上する事が度々ありますが、こういったSNSでコメントするならちゃんと確認してからコメントを書くべきだと思いますけど… ['(0, 21.0%)', '(1, 15.3%)', '(3, 63.6%)']
#
#
# 匿名で攻撃ってそもそも攻撃なのか？
#
# 千原せいじの認識はおかしいのではと言う問い掛けに対して、どこの誰か分からんと言う返しは論点逸らしとしか思えない。
#
# 生徒側だけの話を鵜呑みにして、学校側の言い分を聞かずにアホ教師だの差別だのと口汚く攻撃するから、それは違うんじゃないのか？と言っているだけだと思うが。
#
# そもそも差別だと言うのであれば、今回の学校側の対応の何が差別に当たるのかはっきり言ってもらいたい。 ['(0, 99.5%)']
#
#
# 事前の確認がないままやればこうなる可能性があることくらい当人もわかっていたのでは？
# わかってなかったら、重要な場面で確認を怠るとこういうことになるとわかっただけで人生の収穫になったと思います。 ['(0, 1.3%)', '(1, 97.7%)']
#
#
# 自分の意見を言うのは構わないと思いますが、何故、自分と違う意見の人間に対して攻撃的な物言いをするのかが分からない。
# 差別だと思うのなら、その理由を言えば良いだけで、先生に対して「アホ」という必要はないんじゃないかと思う。逆に差別ではないと思うのなら、その理由を言えば良いだけで、せいじさんに対して「大丈夫？」「勉強して」なんて言う必要はない。結局、お互いがお互いを攻撃し合って終わってしまう。そんなの虚しくない？ ['(0, 99.4%)']
#
#
# まずね、冷静に考えてもらいたい。
# 一人の人間が複数の人間を管理するのに精々10人位。それが１クラス30～40人。
# そりゃある程度、服装や髪型に制限かけんと、生徒の変化に気付きづらいし、抑制かけづらい。
#
# そもそも不良や目立ちたい人間は、ルールから逸脱したことに『オレすごいだろ』をみせたいだけで、ルール緩くしていったら、もっと悲惨な状態がうまれる。
#
# 風習や宗教等の理由があるかもしれんが、そこにはそこのルールがあり、そのルールを変えたいなら、そこの生徒が動かないと意味ない。
#
# 芸能人や脳科学者がイチイチ言うことではない。 ['(0, 93.8%)', '(3, 5.9%)']
#
#
# 有名人がInstagram、Twitterなどで発信すれば、有名度合につき発信力がつく。賛同する人もいれば、当然反対意見もつく。
# その反対意見等に対し「名を名乗れ」という有名人が時々いますが、それがフェアじゃないってことに何故気がつかないのだろう。
#
# YouTuberにもよくいるが、発信するエリアが大きいほど反対意見、中傷コメントもたくさんくる。
# そーゆーのが嫌なのであれば、ライブやテレビ番組、もしくは仲間内で語ればよい。
#
# 広い範囲で己の意見を語るっていうのはそういう事。
# 良い年して判らないかなー。 ['(0, 36.7%)', '(2, 63.0%)']
#
#
# ずっと前から繰り返し髪型で注意を受けていて、なおかつ卒業式の前にも髪が長すぎるから切って来いって3回注意されていたそうな。
#
# それでもルーツだ伝統だと言う形で主張を押し通したかったのであれば、保護者がもっと前から交渉すべきだったのでは？それだけの時間は十分あったでしょう。
#
# 民族的なことを理由にした特例を認めろというのであれば、交渉の機会は在学中の3年間全部対象にできるよね。3年も交渉を怠ったなら話にならんし、保護者も相手にされなかったなら卒業のタイミングだけ切り取られるのもおかしな話よな。 ['(1, 24.6%)', '(3, 74.9%)']
#
#
# 学校という公の場において、個人のワガママな主張を否定された後から、それを差別問題に絡めたのならば、むしろそういう個人の都合やワガママを差別に絡めた事の方が差別問題やコーンロウをルーツに持つ文化の方々に失礼だということではないですかね。つまり差別問題を言い訳に使った。
# その文化の方々、コーンロウをルーツに持つ方々がどういう思いでその髪型をしてきたのか。黒人文化圏の方々がどういう歴史を経てきたのか。そこに思いが馳せられず、卒業式という場を自己アピールの場に使おうと思ったのなら、その方がむしろ差別になりかねない。
# 本当に自分のルーツに敬意を持つ、そういう思いがあったのなら学校には事前に相談していれば良かったし、その学校からの返答に差別があったのなら、そこで初めて問題になるような事。
# 差別問題を自分の立場を立てていく事に使う事ほど非道な事はない。 ['(3, 99.6%)']
#
#
# 匿名とか誹謗中傷云々を盾に、差別かどうかという議論を置き去りにしている。ちゃんとまともに意見したいならそう言う隙を作らない批判の仕方をしないと、有名人側はこうやって自身を正しい方、真っ当な方だという立場に置いて言い放って議論をそっちの方に向けたり締めたりもできる。
#
# それはそれとして、批判はあるだろうが中高生くらいまでは多少の理不尽で縛られる、疑問に思う、戦う・・などそういうことを自発的に経験するのは大事だと思う。大人がそこに口を挟んでそういう経験をするきっかけを取り上げるのは勿体ない気がします。生徒たち自身がおかしいと思うなら生徒たちが戦えばいいのであって、代わりに大人が戦ってあげる必要はないと思う。
#
# そのうち、年上を敬えというのは理不尽とか、客である生徒には従業員や職員的立場の教師の方が敬語を使うべきとか言う話になりそう。 ['(0, 99.7%)']
#
#
# 匿名を理由に批判をする芸能人を時たま見掛けるが、本当に意味が分からない。
# 顔と名前を出していようが誹謗中傷などの行為が最低なのは変わらないし、逆に匿名だろうが筋がしっかり通っているなら意見として聞く価値がある。
# 内容で議論せず、匿名だからと一括りにして聞く耳を持たないやり方で意見を押し通す事が本当に正しいと思っているのだろうか？ ['(0, 65.0%)', '(1, 34.6%)']
#
#
# 結局、一般市民は自分の考えや思いを発言するには、匿名じゃないと出来ないんですよね
# 何故なら芸能人みたいに、自分自身、個人を晒してしまったら、守ってくれるものがないから（一般市民だと、会社が守ってくれるわけでもないし、知り合いに弁護士いないし）
# どこの誰か特定されてしまうのは、もっと怖いです
# 匿名だからこそ、言える自由もあると思います
# 匿名が許されなくなったら、有名人や政治家、権力や影響力がある人しかコメントや発言しなくなると思う ['(0, 47.3%)', '(2, 52.3%)']
#
#
# 世間で起きてる事を信憑性が不確かや切り取られたニュースで知り、いかにも全てを知ってるかのように、SNSで撒き散らし、反論されたら討論しようやって、順番が逆。まず真実を確かめてからでしょ！以前も飲食の宅配サービスで違った商品が届いたって宅配業者を批判していましたが、間違ったのは飲食店であって、まずは飲食店に連絡して解決するべきなのに、ただ話題になって注目されたいだけなのか？
# いい大人なんだから、しっかりして！ ['(0, 99.5%)']
#
#
# ほんとそれ！の一言に尽きます。
#
# 民族的アイデンティティと主張するなら、普段もその髪型だったはず！
# なぜ卒業式からでなければならなかったのか。なぜ卒業式の翌日からではダメだったのか。
# 学校を庇護するわけじゃないけど、日本人の卒業生が「侍的アイデンティティです」と言って、月代を入れて丁髷を結って来ても止められてたと思う。
# 差別でもなんでもない。むしろこうやって騒ぐ方が差別だと思う。 ['(1, 99.0%)']
#
#
# コーンロウの問題がどうかは別にして、匿名の返信が来るようなところで自分の意見を発信している以上匿名で来るのが当たり前な訳で。そこで同じ立場で話をしようと、相手に素性を明かすことを求めることは筋違いだと思います。
#
# いわば素性を明かしてるのは自分にメリットがあるからで、せいじさんのアカウントと分からなければフォロワーも圧倒的に減り発信力も低下します。それを避けるために自分が勝手に素性を明かしてやっているのであって、それが嫌ならせいじさんも裏アカでも作ってやればいいんじゃないでしょうか？ ['(0, 32.2%)', '(2, 67.5%)']
#
#
# 髪型を規制する校則が妥当かどうかは議論があると思うが、とりあえず本件は差別ではないと思う。他の子供は見逃したのにルーツが他と違う子供にだけ校則を適用したとかなら差別だが、本件はそうではないので。
#
# あと、自分は名前を明かしているのに匿名で意見を言うのはズルいというならば、自身も匿名でSNSをやってはどうだろうか？そうすれば匿名同士で同じ土俵になる。
#
# でも絶対にそうはしませんよね？芸能人は名前を売るため、マーケティングのためにSNSをやってるわけだから。逆に一般人は名前を明かすメリットが何もない。自分は名前を出したいから出してるだけなのに、相手の意見の内容を汲むこともなく、ただただ相手に名前を出せと言うのはちょっと違うんじゃないかと思いました。 ['(0, 54.8%)', '(1, 45.0%)']
#
#
# アイデンティティだ差別だと言うなら、どうして普段はその髪型をやらなかったのか。日本人の生徒が「日本人の心です」と言ってちょんまげ結ってきても怒られたと思うよ。
#
# なんの相談もなしに卒業式当日に華美で奇抜に見える髪型にしたことを咎められたにすぎないのに、そこに差別という一種の聖域を出してきて反論するのは卑怯そのもの。
# 攻撃という意味で言ったら、バカ教師という言葉を使うのもどうなんだろうね。 ['(0, 11.8%)', '(1, 87.9%)']
#
#
# この手の件は、とりあえず権力者側（学校側）を叩けばかっこいいと言うながらになりやすい。
# そして、それにタレントさんは乗りやすいと思う。
# 今回の件は、コーンロウに対するものではなく、校則に反した髪型にしてきた人に対するもので、コーンロウそのものにではない。
# 今回は校則を破った本人が責められるものだと思う。
# 校則イコール悪の構図を望みすぎる。 ['(1, 99.0%)']
#
#
# 何故有名人と同じ土俵に立たねばならないのか？有名であることと匿名であることはどちらも一長一短。その人の生き方や仕事によっても大きく変わる。その選択は自由でありどちらが正しいと言うことはない。
#
# 芸能人が匿名に向かって「身元を明かせ」と言うのは、その芸能人のファンに相手を叩かせる以外の意味はない。発言の内容が理に適っているなら誰が言ったかは問題無いはずなのだから。一方的に自身に有利な場に相手を引摺り出そうと言うのは一般に「卑劣」という。
#
# 加えて言えば匿名では説得力ない、というのはつまり発言内容より発言者の方が大切ということ。発言内容に言い返せず苦し紛れに話題をすり替える様は滑稽とも言える。単に見下してる一般人から図星をつかれて腹が立ったようにしか見えない。 ['(0, 39.7%)', '(1, 60.1%)']
#
#
# 本当に見た目だけで学校が差別したなら、せいじの考えは間違ってないと思うが、記事を正確に読み込んでない点、教師を悪者と決めつけている点、信念がなく反対意見を論破できない点、自分の非を認めず謝罪できない点、論点をずらして匿名を批判している点、反論をスルーできる器量の大きさのない点で間違っている。 ['(0, 76.8%)', '(1, 22.8%)']
#
#
# 今は古い校則が継続している問題もありますが、ある程度の校則を理解して入学したんじゃないでしょうか。
# 好きな髪型がしたいなら、それが認められている学校へ入学するべきかと。
# もしくは、在学中に校則を変える行動をすれば良かったと思います。
# 差別とか言う意見も分からなくは無いけど、ルールはルールですから。 ['(3, 98.7%)']
#
#
# 匿名だと他人を批判してはならないなんて決まりはない、過剰な批判や誹謗中傷はNGだけれど日本は言論の自由が認められた民主主義国家だ。
#
# そこを踏まえての全世界へ向けての意見発信をしたんでしょ？だったらこの記事に挙げられている程度の批判で匿名でとか何とか言うのはお門違いではないかなー？。
#
# SNSにUPしたものの、本人の期待に反して短絡的だという批判が集中したから逆切れしている様にしか思えない。
# そもそも炎上すると意味不明の過剰な攻撃される事なんて想定内でしょ。 ['(0, 37.8%)', '(1, 62.0%)']
#
#
# 千原せいじは芸能人で、コメントした人は
# 一般人でしょ
# それを「お前は俺の事　知ってるのに俺がお前の事を知らないのはおかしい　名乗れ…」って、千原せいじがコメントしたのは自分が芸能人で誰かしらに自分のコメント見て欲しかったからなのに、反対の意見をコメントされたら食ってかかるなんておかしいだろ。
# 三者三様　色々な意見があるのは当たり前の事なのに気に入らないからとインスタライブで対決しようなどと大人気なさ過ぎ。
# 意見されるのが嫌ならコメントしなければ良いのでは…芸能人だから知られて当然だし知られてるからコメントするのでは。
# 芸能人だからって訳ではないがもっと大人の対応出来ないならコメントしない方が良いのでは。 ['(2, 99.4%)']
#
#
# これは、意識というか、価値観の違いかも
# 髪型一つで、卒業式に出さない差別と捉えるか、事前に言うべきだったと捉えるか
# 卒業式だからこそ、その髪型にしたかったというのもあるかもしれないし
# それを許したら、何でもありになるというのも、以後の教育現場としての見解もあるかもしれない
# けれど、排他的では、何の変化も生まれないし、これから外国人を受け入れなければならない日本では、マズイとも考えるべきか
# 文化は大切だけど、それを踏まえて、受け入れる体制を整えないと差別と捉えられても仕方がない
# 日本の中の人が差別じゃないと言っても、全然意味をなさない ['(3, 99.2%)']
#
#
# 日本の学校でこの髪型にすると民族、国籍に関係なく締めだすであろうから差別ではないと思う。
# 髪型でこの扱いをすることが憲法で認められた人権の侵害に当たるかどうかが争点でしょうが、文科省や司法が憲法違反となる校則について具体的な指針をださないとこういった問題は解決しないでしょうね。
# 一応、法治国家なので個人がそれぞれの感覚で意見を言っても仕方ないでしょう。 ['(3, 99.2%)']
#
#
# 民族のポリシー ある髪型を侮辱されたっていう建前で、その前にあった生徒の問題点 っていうのを押し切ろうとするっていうやり方は卑怯だし 汚いと思う。 そこに関しては 、この芸能人の方は何も コメントすることはないのかなって思う。 最後だからこの髪型で 出席できるよう 生徒が学校側に お願いしたいっていう風に言うにしても 、 できるかどうかお願いする 下準備して 許されるかどうかわからないけど先生に 立ち合うってことはできたはずだからね。 ['(0, 8.9%)', '(3, 90.6%)']
#
#
# この人だけじゃないけど、意見言うだけなら、クソとかって暴言はいらない。茂木とかもボロカス言ってたけど。
# この件さ、あの生徒に全く非がないと言えるのかね。差別とかに話がすり替わってるけど校則の話だし。
# 父親のルーツか知らんが、当日にコーンロウにする必要はないし、そのルーツについて駄目って言ってる訳ではなかったはず。
# 卒業式の日に、隔離されて可哀想って言うそこに対しての同情票ですよね。
# こんな日だから怒られないだろうって確信犯。でも注意されてアップてね。
# 父親のルーツが大事なら事前に相談なりすべきだし。先生に限らず生徒も、えっ!?って思った人は多くいると思いますし。散々だなと思います。それこそ、表面的な同情で著名人からボロカス言われてね。せいじも反論してるけど、本当に恥ずかしいと思わないのでしょうか。 ['(1, 99.6%)']
#
#
# この話は世界的に保守的な考えが広がりすぎているからでは？。
# 今の世の中の流れのなかでこの記事を読むと千原のように考える人がたくさんいるのだろう。以前WHO事務局長が世界的サル痘が流行した時この病気がここまで感染拡大することの異常さが保守的な考えが急激に進んだことからきているかもしれないと嘆いたという記事があった。この記事を書い記者とこれを読んで差別だと思ったひとはある意味危険かもな。 ['(1, 99.3%)']
#
#
# 学校は規則を守ることの必要性も教える場ですし、規則を守らなければ罰則があるのも当然だと思います。
# 私はせいじさんが何故アホ教師と先生を侮辱するのか理解出来ない。
# それと匿名で人を攻撃するなと言われてますが、有名な人にアホ教師と言われた学校の先生も、同様にダメージを受けたのでは？
# 色々な意見があってもいいと思いますが、人を罵る言葉はマイナスでしかないと思います。 ['(0, 53.8%)', '(3, 45.9%)']
#
#
# 僕は学校側の対応が好きじゃ無いのでこの生徒に同情的な考えなんだけど、千原さんの言いようは嫌いだ。
# 自分はアホだのなんだのと口汚く教師を断罪して同じ程度の言葉が自身に向くと最低などと言う。
# 匿名で攻撃するのは最低だと言うが、そもそも実名匿名関係なく人を口汚く罵るのは良くないことだろ。自分は実名だから許されていると思ってるのか。
# 僕は匿名の方の背景あっての事って考えは聞く価値のある真っ当な意見だと思うから、匿名だから聞かないってのは思考停止だと思う。 ['(0, 99.6%)']
#
#
# この一件の元をたどるとどうも一概に「別席で卒業式を受けさせるなんてひどい」って話でもない…みたいね
#
# 最初は自分もそう思ってた側だけど事の詳細が見えてくると必ずしも生徒側が正しいという訳でもない事がチラチラと見えてきてるし…（それでもやはり別席は…と今でも少しは）
#
# そしてこういう話になると自分の地位を利用した芸能人が大声を出す訳だけどこの人たちも事の詳細が分かって言ってるのならまだしも自分みたいに感情論先走りで突っ走ってしまった以上引っ込みがつかなくなって違う方向に矛先を向けて誤魔化そうとしてるよね…
#
# 果たしてこの人（芸能人）たちがこの話をどう終わりにするか… ['(2, 88.2%)', '(3, 11.4%)']
#
#
# 要はコーンロウという髪型が卒業式に相応しくなかったわけでしょ。
#
# 卒業式で学校最後だからと甘えたクソガキ生徒に、最後だからって甘えるんじゃないと教えた大人のファインプレー。
#
# 最後まで叱ってやるのが教師の務めだと思うけどね。立派だわ。
#
# 自分の気持ちとしては、髪型作るのに時間と労力かかってるので、式には参加させてあげて、「社会に出たら、そんな甘い考え通じないぞ」って個別に伝えるかな。
#
# 必ずしも、白黒ハッキリしないといけない問題ではないと思う。 ['(3, 99.1%)']
#
#
# 事前に相談すればよかったというのは、そのとおりかもしれません。ようはコミュニケーション不足が問題なのでしょう。
#
# ただ、生徒はルールの範囲内で好きな髪型にしただけですから、髪型を理由に隔離して返事させなかったのはやりすぎでしょう。せいぜい最後列に並ばせるくらいに収めるべきで、返事もさせるべきでした。
#
# 「ルールを破った」という指摘が目立ちますが、この生徒は「空気を読まなかった」のでしょう。
#
# 教師は自分が信じる「高校生らしさ」が裏切られたことに動揺し、しかも式に出席されるとメンツを保てなくなると思い隔離したのでは？　であれば、それは教育的措置とは言えず、また、ルーツに関わる髪型ですから差別と言われても仕方ありません。
#
# 秩序が乱れることを嫌う人が多いようですね。「みんな我慢してルールに従っているのに…」という感覚が根本にあり、「ルールはつくるもの」という感覚が乏しいのだろうなと思います。 ['(3, 99.5%)']
#
#
# コメントの論点もズレてる気がするんだけど。
# あくまで「おそらく」ですが、せいじさんが怒っているのは
# 「否定された」事ではなく「勉強しろ」などの煽り文句を使って人を小馬鹿にする(攻撃する)のであるなら、名を名乗って喧嘩し合おうや！って事なんじゃないかなと。
# 「〇〇の理由で差別とは違うと思います」だけで終わってればこうはなってないのじゃないのかなと。
# もちろんせいじさんの主張も色々問題点はありますが、相手が変な(主観)事をしたら言ったりしたら馬鹿にしたり攻撃して良い。なんて事はないと思うし、芸能人が名を名乗れって言う背景にはおそらくここら辺が大きいのかなと思います。余計な一言がとにかく多いなーって印象 ['(0, 24.1%)', '(2, 75.6%)']
#
#
# この件、一般的な感覚としては当日にいきなりっていうのが不意打ちすぎて「伝統の～」とかは言い訳にしか思えないんだよね。だって日本の血も引いてるならちょんまげにしても良かった訳でしょ？何でコーンロウ一択なのか。
#
# 先生も大変だよね、多分保護者とかからも苦情来てるだろうしさらにネットや芸能人とかからも文句言われるんだから。 ['(0, 12.1%)', '(1, 87.5%)']
#
#
# まあ差別じゃないからねえ
# 差別と区別が分からない人なんだと思いましたね
# 例えば公平と平等が違うように差別と区別も違います
#
# 自分が芸能人という発信力を売りにしている商売をしているのであれば、発言にはもっと慎重になったほうがいいです
# 誰もコーンロウやルーツについて批判してませんよ
# そういった場でルーツという誇りがあるはずなのにそれを貫くための前準備を一切せず、目立ちたい欲に振り切り幾度とされた指導を無視して強硬的にやってきたから問題になってるだけです
# じゃあせいじさんは息子に
# 「日本人のルーツだからちょんまげで卒業式出る！教師には何も相談してない！」
# と言われた時、何の思慮もせずに諸手を上げて100%肯定の意だけで送り出せるんでしょうか
# それなら別にいいと思いますけど、ほぼ100%と言っていいほどそうじゃないでしょう
# 物事の背景をきちんと汲んだうえで発言しなさいな ['(2, 61.4%)', '(3, 38.3%)']
#
#
# この揉め事はどうでもいいけど、突然この問題騒がなくなったって事は、せいじさんのいう様な事じゃなかったってことなんじゃない？毎日がこれを報じたけど、学校側より生徒側への不信感が多かったし、人種差別に訴えたが、ほぼ受け入れてくれる感がなかった。いつもなら、ヤフコメ書かせない事が多い新聞社が書ける様にするのは、自分らに乗ってもらいたいからなのに、以外と乗ってくれないから、これ以上やる意味が無いって事なんじゃないの？ ['(1, 50.8%)', '(2, 48.5%)']
#
#
# 甚だ馬鹿らしい問題。ダメに決まってるでしょそんなもん。まず大丈夫って思ってること自体おかしいし、その髪型を貫きたいなら正々堂々と教師に対峙すれば良いだけの話。それでもダメなら今回の様にことさら話を大きくして「世の中の皆さんどうですか？」と問えば良い話。
# ただ学校側も隔離したり返事をさせないとかは教育としておかしいと思う。式当日でもなんらかしらの落とし所はあったはず。これは非難されて当然。 ['(1, 69.5%)', '(3, 29.8%)']
#
#
# 煽り運転の問題と同じように、
# スルーする能力がない人が増加してるのは、道具を使って他人を攻撃や嫌がらせする事でうっぷんを発散させたい、他人よりも上に立ちたい願望が強いから、なのか？
# 誰かの責任にして、自分は正しい、と思い込んでる人たちが身バレすることもなく、安全に他人を叩ける環境があることで、ケンカに勝った、みたいな気軽な優越感にも浸れますしね。ネットで他人を知る機会が多いが為に心の闇が広がってるんでしょうか？ ['(0, 16.7%)', '(1, 83.0%)']
#
#
# 実名を公表しているからといって、見ず知らずの赤の他人に「アホ」とか「クソ」とか、口汚い暴言を吐いて良いという事にはならないと思いますよ?
# ましてや自分の自由意思で「千原せいじ」という名前を公表し、自分の意見を公表している以上、相手が匿名だろうと実名だろうと、自分の意見に対する賛否両論に謝意を示すなり、反論するのが筋で、自分が素性を明かしているんだから、反対意見を言う人間も実名を明かして反論しろ!というのは、勘違いも甚だしいと思う。
# 口喧嘩で勝てない相手に「だったらお前も◯◯してみろよ!」と逆ギレしたお子ちゃま感が滲み出ている印象。
# 長野の公園問題でも、実情を良く理解していないインフルエンサーが、良く調べもしないで市側の対応を批判していた例もあるが、氏は実情を調べた上で「アホ」とか言っているのかも甚だ疑問だと感じています! ['(0, 99.7%)']
#
#
# 芸能人は顔出して意見言えば給料貰えるのに一般人は無給で顔出して意見しろは違うし、正論でさえもアンチや誹謗中傷はおかしいし、顔出せば誹謗中傷していいは間違い。
# 千原せいじさんは先生を猛烈批判してる。この先生の人生を駄目にしてしまったら責任とるなら、顔出さずに批判するなは言っていいと思う。 ['(0, 99.4%)']
#
#
# 今回のことは普段は普通の髪型で卒業式にいきなり髪型をしてきたということ。民族的なことでコーンロウが正装であるならば学校側に相談があってもいいはず。
# 単にそれを差別だという意見、当然だという意見それぞれがあってもいい内容だしどちらだと決めつけるのもどうかと思うけどなぁ。 ['(1, 29.8%)', '(3, 69.2%)']
#
#
# こういった問題は民主主義の限界だよ。
# 多数が否定したら否定されるのが民主主義だし、それを良しとしてきた日本においては変わるわけない。
# 少数派の若年層の意見を聞かない国なんだし少数派は黙る以外ないよ。
# 別に髪型なんて迷惑になるわけでもないし、どうでもいいしこの件だけでここまで話題になるのも本当に下らない。 ['(3, 98.9%)']
#
#
# >千原さんは「意見を責任持って発信してない奴。説得力ないやん」「インスタでライブしようぜ」と直接対峙を申し出た<
#
# あくまでも自分の非を認めず論点をズラして、芸能人でもない一般人をライブ中継に引っ張り出そうとする、その性根よな。
#
# せめて｢背景を確認もせず、馬鹿教師と暴言を吐いた事について謝罪してお詫び申し上げます｣と言った上で、｢それとは別に匿名で私に誹謗中傷をされた方は、インスタライブでとことん語りましょう｣くらい言えっての。 ['(0, 99.6%)']
#
#
# コーンロウの一件はまぁ、学校がもっと余裕ある対応すればよかったと思うのと同時に
# 生徒側も卒業式前からちゃんと話し合ってれば、こんな風にはなってなかったと思う。
# でも、千原せいじはちょっとズレてる気がする。この前のスッキリの件もそうだけど、見出しだけ見て、反応してないか？ ['(0, 41.9%)', '(1, 57.5%)']
#
#
# 攻撃というより意見じゃないの？
# 批判されたくないなら自分も匿名で発言したほうがいいんじゃないの？
# 芸能人として、責任を持ってコメントするなら自分の考えを述べるだけで批判コメントはスルーするなり、そういう考えもあるんですねくらいにコメントするなりしたほうがいいと思いますけどね。
# テレビで視聴者から苦情きて視聴者一人ひとりにあなたはどこの誰それですかなんて聞かないでしょ。 ['(0, 99.5%)']
#
#
# タレントが一般人に顔を出せと言うのは、対等に、面と向かって話をしようということなのでしょうが、それを言うなら、千原さんもsnsで教師をクソ呼ばわりしていないで、直接教師に面と向かって意見するべきでしょうね。あなたの顔と名前だけが知れているのは初めからで、教師にとっては、あなたが匿名の批判コメントに抱いているのと同じ気持ちを抱いていると思いますよ、そこまで言うなら直接言えよ、という。 ['(0, 99.4%)']
#
#
# 意見があって発言したのならちゃんとした持論だってあるのだろうに。ライブで言い負かしてやればいいだけなのにね。
# ヤフコメでも意気揚々とPTA改革を語る人いるけど、結局匿名だから語れるんであって、実際に地域や会社や学校の会議では考えてるふりしてだんまりなんでしょ？
# 言いたいことがあるなら言えばいいのに。黙っていたら何にもならない。発言することで新しい案だって生まれることもあるのに。 ['(0, 46.6%)', '(3, 53.0%)']
#
#
# なんで当日にいきなりしてきたの？
# 許可を得れば問題なかったのでは？
# という意見の方が多いけど、
# 特別な日だからこそ、してきたのでは？
# この髪型毎日維持するのとても大変だと思います。
# 許可いるのかな？民族的なことは、そういう文化のない私たちにはわかりにくいけどとても深い想いがあると思う。 ['(1, 98.8%)']
#
#
# 1部に調べてから発言しろ的な言葉が見られるが、調べなくても良い記事を書けとは何故ならないのだろうか？
# 以前、コメントで教えて下さいと言ったら調べろって言われました。言葉が通じないことに驚きましたね。せめて、これを見てみたら？とかこのワードで検索してはどうですか？が欲しかった。
# コーンロウがどんな意味なのか知りませんが、校則違反なら仕方ないかもですね。屁理屈捏ねて通せそうなら通したら良いと思いますが、とりあえず、学校は人を見た目で判断する場であることは明白です。そんな非常識な場でいくら理由を捏ねても理解してもらえないかもですね。
# 理解してもらえないから卒業したあとに自由があるのです。学校とは理不尽を押し付けられる場だと思います。 ['(1, 24.5%)', '(3, 75.0%)']
#
#
# 卒業式のコーンロウ生徒排除が差別かどうか、を議論したいなら
# 普通にお互い敬意を持って意見を述べ合えばいいのに。
# 日本人って議論＝ケンカだとらえている人が少なくないから、本題とは関係ない所で不必要な冷笑や侮辱的な言い回しを使って何とかして相手に心理的にダメージを与えようとする卑怯な戦法をとる人が結構多い。でいつの間にか感情VS感情の野蛮な言い合いになって議論そのものは何も進まないと。。 ['(1, 25.6%)', '(3, 73.9%)']
#
#
# この高校生の問題は差別ではないと思う。
# 卒業式の日だけこの髪型で来たら、日本人でも隅に座らされたと思う。
# 私の町では小学校の卒業式が段々と派手になり、袴は禁止、華美な格好も禁止になった。
# 人種差別では全くなく、私の町の「華美な格好禁止」と同じような事だと思う。 ['(1, 99.0%)']
#
#
# 千原せいじさんは、話の論点をすげ替えて、「名を名乗れ」という土俵に上げようとしている。
# そもそもインスタは匿名SNSで、有名人や有名になりたい人は実名や芸名でやってるのが基本。
# そこへ、実名（芸名かどうか知らないが）で書き込んで批判され、「名を名乗れ」と反撃するのは論点のすり替えだ。
#
# 匿名じゃなければ何を言ってもいいのかね？ ['(0, 66.8%)', '(2, 32.8%)']
#
#
# アフリカにルーツを持つ細川バレンタインさんが差別ではないと言った上でこう言ってるんだから、千原せいじさんは今回は間違えてる。
# ↓
# ナイジェリアにおける「コーンロウ」に対する一般的な認識として、「男性がやる場合は、バッドボーイ的なファッション　女性がやる場合は、社会的にそれがフォーマルに装える髪形として認知されています」と説明。「だから、女性ならばok　日本の学校ならば、女子は髪を伸ばして良い！ポニーテールも良い！みたいなのと同じです」とした ['(2, 67.9%)', '(3, 31.5%)']
#
#
# 批判する人（匿名）も反論する人（千原さん）も、
#
# 感情的になっている時点でまともな議論は出来ないと思いますので話をした所であまり意味は無いかもしれません。
#
# 逆に、ひろゆきさんあたりとディベートしてみてはいかがでしょうか？ ['(0, 54.3%)', '(2, 45.2%)']
#
#
# 私は23年ほど前に都立高校に通っていました。
# そこそこ偏差値の高い高校でしたが、コーンロウの友達結構いましたというか親友の女の子がコーンロウ。時にはアフロ
#
# 生徒の思想を大事にしてくれる先生が多く
# こらこらー。くらいで卒業式もコーンロウのまま出てました。別部屋にはされませんでした。
# 23年前にですよ！今は卒業式別にされちゃうんだ。とびっくりしました。
#
# 彼女もそうですが、みんないい子でしたよ。
# 髪型や制服の乱れとか関係ないじゃん。と私は思っています。
#
# 結局校則があってもやる人はやる。
# やらない人はやらないんですよ。 ['(1, 99.4%)']
#
#
# 汚ない言葉で言い返すのを見るのは単純に気分が悪いです。
# 感情に任せないで筋道立てて話せないのかな。その上での批判や議論ならばお互いにまだ冷静かつ有意義に話すことが出来るのでは。 ['(0, 1.2%)', '(1, 97.9%)']
#
#
# 目立ちたかっただけでしょ？
# 無断でやってるとこが悪質。
# 先生に断ってダメだったがこだわりがあってとかじゃない。
# よく校則に対して自由を説くのが流行りの風潮だが、校則が緩くなったばかりに寿司テロみたいにルール守れないやつがでてくる一面はないか？ ['(1, 98.8%)']
#
#
# 髪型の件がどうなのかは分からないですが、せいじさんが言っていることは一理ある。
# ネット上ではどこの誰か分からないことをいいことに、好き勝手言う人が一定数いるのは事実。
# 少なくともせいじさんはせいじさんであることを隠すことなく攻撃（批判）しているのだから、それはせいじさんの意見なので別に私は批判するつもりもない。学校側から抗議されたとしても、全てせいじさんの責任で対応すべきことだし、するでしょう。
# 意見を述べるのは自由でしょうが、攻撃的なことを発言するのであれば、自分の身分を晒せとは言いませんが、それくらいの覚悟のうえで言うべきだと思う。 ['(0, 53.8%)', '(2, 20.1%)', '(3, 25.9%)']
#
#
# せいじの対応は非常にお粗末だが、コーンロウで登校してきた彼に対する批判的コメントが多い世論には少し違和感がある。卒業式で他の学生から隔離したり呼名に返事をしないように指導するなど、やはり学校側の対応も少々行き過ぎではないか。
#
# 人種差別や異文化問題に摺り替えて世論を煽っているだけで個人のわがままを容認すべきではない、との意見が大半だが、今回の問題はむしろ黒人文化がどうこうではなく、一人の学生の晴れ舞台を大人の価値観で排除してしまったことにあるのではないか。確かに他の生徒とは違う個性的な髪型ではあるが、「目や耳、襟に髪の毛がかからないように」という校則に反しておらず、式を妨害するような行為もしていない。唯一、「高校生らしい清潔な髪型」に当たるかどうかという極めて主観的な判断基準で式の参加を認められなかったわけである。良くも悪くも個性より同調性を重視するという日本人の保守的思考の典型だと思う。 ['(3, 99.7%)']
#
#
# 千原せいじの反論は論点のすり替えで、批判されたことに何も答えていない。
# 相手が許容できそうにないことを要求するのみで、自分の芸能人としての発言の影響力は棚上げしている。
# 簡単に言うと橋下徹のやり方と同じだということ。 ['(2, 98.6%)']
#
#
# ルール守らんかったらどうなるの？ヤリ放になったら、秩序も無くなりますよ。差別とかいう言葉でモノ言ってるが、それ以前の問題です。完全に的を外しているのに、正論述べてる様に言うのはどうですかねぇ。アフリカやら何処やら行って色んな物を見て人として成長されたんだと思いますが、コレは全く違うよね。ルールを無視した事に全く触れないのはどうなの。元々、学校が嫌いとか、先生が嫌いとか思う所はあるかも知れんが、大人として考えた時に常識は何を基準に成されるのか。ルールが有ればそれが基準になる。こんな簡単な事なのに、無理強いや、ゴリ押しはみっともないですね。 ['(0, 28.2%)', '(3, 71.5%)']
#
#
# ＞＞匿名で
#
# そんなことを言い出したら、街頭インタビューを受けている人間は名前を出されないし、新聞の記事も署名記事ばかりとは限らない。下手をすると匿名記事さえある。また新聞社の行う世論調査も匿名だろう。
#
# この「千原せいじ」氏とやらは、街頭インタビューを受ける人間にまで「責任を持って発信」するために名前を公にせよと言うのだろうか。それとも街頭インタビューや世論調査は気楽なものだからと、大した価値を認めていないのだろうか。 ['(0, 35.8%)', '(2, 63.8%)']
#
#
# まあこれって学校にはその学校の規則っていうのがあるから、それに反しているのなら正さないといけない。
# ただ、この件って教師がその生徒出席させず2階に座らせ、名前を呼ばれても返事をするなってニュースだったと記憶してる。
# ここまでしなくても他に方法があったのではないか。人生でたった一度のイベントで返事すら許されないやり方は今の時代に見合ってないと思う。 ['(0, 5.3%)', '(3, 94.3%)']
#
#
# うーむ‥仮にタトゥを入れる文化が親のルーツやアイデンティティなら、千原せいじさんは認めはるんやなぁ‥なんとなく、差別とルールを勘違いしてはるような気がします。
# それと千原せいじさんは、自分と違う意見を排除し罵るのは構わないという事でしょうか‥
# すごく残念な方です。 ['(2, 23.4%)', '(3, 75.7%)']
#
#
# 矛先…
#
# そっちへ向いたかぁ～
# せいじ氏の事では無いですが
# 下記漫画より引用します
#
# 年がら年中ジーンズを着て
# これからは君たちの時代だと
# やたら若者に理解を示して
# 先生・先生と呼ばれている
# オジサン文化人がいるけど
#
# 個人的にはあまりいただけない
#
# こういう手合いに限って
# ちょっとでも自分に批判がましい事を
# 言った若者を延々と許さないから
#
# ～王様の仕立て屋より抜粋～
#
# せいじ氏の言い分は「論点ずらし」ですよねw ['(0, 99.5%)']
#
#
# 何言ってるのだか。
# 匿名の人の言ってることの方が正しいと思いますよね。
# 名前晒してたら何言ってもいいとは限りませんけどね。
# 特に影響力のある人は、ニュースの内容を良く理解してから答えた方が。 ['(0, 61.7%)', '(2, 37.4%)']
#
#
# そもそもコーンロウは校則違反じゃないのか？
# 伝統はわかるがさすがに高校生でコーンロウはないだろ
# 父親じゃなく母親の伝統で出席すれば問題無かったな
# 表現の自由があるとしても何でも自由ではない ['(1, 98.5%)']
#
#
# ペンギン騒動の時もだいぶおかしな事を言ってたし、基本的にはあんまり頭が良くないと思われる。大勢の意見を考察しながら持論を展開する事が出来ないので簡単に言えば小４ぐらいの学級会でクラス委員長には向かって意見するようなレベルの人。 ['(0, 99.2%)']
#
#
# そもそもタレントが一般人に対して顔を出せというのもちょっとね。
# タレントは顔を出す事にメリットがあるが一般人にはほとんど無い。
# あと、自分の意見が正しいと思うなら論理的反論をすればいいのに「クソだ」とかの言葉を使って同じ土俵に乗っている時点で説得力を無くすだけ。 ['(0, 60.1%)', '(1, 39.4%)']
#
#
# 意見交換に匿名もなんもないと思うが。名前、身元伏せたら説得力ない、という謎理論。有名人なら攻撃してええんか？
#
# それならたかが芸人で学校関係者、教師でもないやつが教師語るなよ、てなるわ。
#
# 立場ある奴の発言が説得力あるナシはわかるけど。それおまゆう、論点ずれ。 ['(0, 91.7%)', '(1, 7.9%)']
#
#
# 大衆の前に出てナンボの芸能人と一般人では、素性を曝すリスクが全然違う。なんなら芸能人にとっちゃ飯のタネだし。
# 同じ条件どころか自分の土俵で相手しようとしてるのエゲツないわ。
#
# 誹謗中傷は論外だけど、名前が売れてる人が発信すりゃプラスもマイナスも反応があるのは当たり前なんだから、マイナスが嫌なら発信しなけりゃいい。 ['(0, 31.8%)', '(2, 67.9%)']
#
#
# せいじさんも片方のコメントや意見だけしか見てないんじゃないの？これは、差別じゃなく区別でしょ。
#
# 日頃からじゃなく、卒業式当日にコーンロウとか、、、。ただただ、目立ちたいだけじゃん。
# なら、せいじさん真面目なドキュメンタリー番組とか警察２４時みたいな番組の収録日当日にスタジオに、ちょんまげで言ってみたら？やっぱりスタッフに止められると思うけど、やっている事はそんな感じ。 ['(3, 99.2%)']
#
#
# 匿名で批判するが直接話し合いするのは嫌という、ネット内だけで強いタイプがインスタ、Twitter、ヤフコメに沢山います。
# 安全地帯から揚げ足取りや正論で相手を叩くのは大好きだが、直接相手と話したり自分を明かす事はびびって出来ない。 ['(0, 25.6%)', '(1, 73.8%)']
#
#
# 発言に責任が伴う事とその意見が的を得ているかどうかは関係ないし、仕事も兼ねて実名でSNSやる有名人に説得力どうこう言われる筋合いはないと思う。
# タレントと違って何のメリットもないじゃん。 ['(0, 99.0%)']
#
#
# せいじは自分が
# 名も無き真面目な公立学校の一教師を
# インスタで攻撃してるやろ？
# そこのルールを守って何が悪い？
# 匿名じゃなきゃ、仕事を真っ当してる
# 真面目な個人を攻撃していいの？
# 本人同士に話聞いてから違うの？ ['(0, 99.4%)']
#
#
# 学校がダメならダメ
# 会社がダメならダメ
# 家族がダメならダメ
# 友達がダメならダメ
# そんなの当たり前じゃないですか？
# 嫌ならもっと大きなフィールド行きましょう！ ['(1, 98.7%)']
#
#
# 世間に向けて自分の考えを発信したんだから、それに対する反応があるのは仕方ない。反論されて腹立つなら世間に向けて発信しなければいいのに ['(0, 98.5%)']
#
#
# 自分達には反論が無いと思って発信しているのかな？
# 芸能人は何を言っても良いの？
# 反論してる方々が何故反論しているかも考えられ無いなら、SNSで発信しなければ良いだけ。 ['(0, 81.4%)', '(3, 17.8%)']
#
#
# よっぽど隔離された生徒が普段から素行がわるかったならこの措置は理解できる。
# その中でこの山梨の景色を楽しめるならくればいい。
# 状況次第だろうけど、 ['(0, 98.3%)']
#
#
# 多面的な物事の見方ができない人が「コイツは匿名だから卑怯」と決めつけてしまったら、もうそれ以上議論にはならない。現に本題は置き去りになっている。
# 仮に顔と名前を出したところで「お前勇気あるやん」みたいな見当違いの結論で終わりそう。 ['(0, 28.6%)', '(3, 71.0%)']
#
#
# 自分が有名人であり、その分見てくれる人が多い事が分かっててSNSやってるんじゃないのかな。それに対して匿名で反論来るのは当然だし、コーンロー問題が差別なんて言うズレズレの主張したら、そりゃこうなるよ。 ['(0, 70.0%)', '(1, 29.3%)']
#
#
# とはいえ、こちらにコメントしている皆さんも自分も、名前を出している人間に対して匿名でコソコソ批判の投稿をしている行いは非常に情けないことだという認識は常に持っておいたほうがいいと思う。自分も投稿するたび反省してる。 ['(0, 99.1%)']
#
#
# 内容的には間違ったことは言ってないんだけど、この方の言葉って何も響かない。反論するにしても言葉を選ばないと、反論ではなく只々喧嘩買ってるだけになってしまう。 ['(0, 1.3%)', '(1, 97.7%)']
#
#
# SNSでケンカ売るような発言して反論が来たら感情的になる。
# ご意見番気取りも良いですが、冷静な判断が出来ないならSNS止めた方が良いんじゃないですか。 ['(0, 49.7%)', '(1, 39.6%)', '(3, 10.2%)']
#
#
# その人間に対して匿名で意見するのはおかしいやろ
#
# 一理はあるんだがこーゆー意見ならインスタをオープンにする必要はないわな。
#
# ちなみにコーンロウの件はたしかに人種差別と取られかねない話だが一方で生徒側が事前に何も相談してないみたいなんでそら当日いきなりその髪型で現れたら単なる校則違反と判定されても仕方ないわ ['(0, 20.1%)', '(1, 54.2%)', '(3, 25.5%)']
#
#
# 一般人が顔出しでとか何言ってんだろ。
# 公の場で失言すれば社会的にもヤバいのに。
#
# ましてや今回はせいじさんの主張の方が、一般常識とズレている（差別ではない）との指摘に対しての返が、匿名は卑怯だとのこと。
# ただの論点ズラしとしか取れない。 ['(0, 99.1%)']
#
#
# なんで民族差別なのか不明。
# その場にはその場のルールがあっても良いと思う。
# そんなもの一々許していたら際限ないし、なんでもフリーにしなきゃになるね。
# その人がこれまでも、これからも一生その頭で暮らしていくなら理解するけどね。
# その場だけわざと騒ぎを大きくしたとしか思えないな。 ['(3, 98.6%)']
#
#
# 千原せいじさんはコメントに過剰反応するよりも、問題となってる学校に取材に行って話を聞くなりした方がよほど意味があると思うのですが ['(0, 1.1%)', '(2, 86.5%)', '(3, 12.0%)']
#
#
# せいじ、アカンやん
# 感情的になってるようにしか見えないね
# 「表に出ないチキンの言うことなんて間違っている」は典型的な詭弁だよ
# 属性攻撃っていうのよ、そういうの
# 物事の本質の部分で論破された時に陥りやすい状態で間違いを認めているようなもんだよ ['(0, 99.0%)']
#
#
# ご意見番になりたいのだろうか？この人。
# 誰が、この人の意見を必要としているのか？
#
# ゆた何とかと同じで、このネットニュースの配信元や、スポーツ紙程度ということくらいは知ってもらいたい。 ['(1, 98.4%)']
#
#
# 一般人と芸能人とでは同じ条件で交流は無理では？
# 千原さん側が匿名で芸能人の肩書きなしでどこまで
# 世間に意見出来るかやってみれば良いと思います。
# 何の得もない事をやるとは思えませんが。 ['(0, 99.1%)']
#
#
# 髪型にすることは何の問題もない。
# 卒業式に勝手にしてきたことが問題。
# 学校も教師も悪くないんだよ。
# この子自身がやったことだから仕方ない。
# それで済むことに、わざわざ火をつける必要はないと思うけど。 ['(3, 98.3%)']
#
#
# コーン頭がどうのというより
# その髪型でやったものガチにして済まそうという一連の行為が
# 幼稚で卑怯な感じがする。
# その行為に対して学校は教育の場なので
# 分別をつけるには毅然とした態度をとることも必要かと。 ['(0, 79.1%)', '(3, 20.3%)']
#
#
# 確かに一理有るが、この件では生徒側も良くない。何でも差別と言えばという感じになる。 ['(0, 1.7%)', '(3, 97.1%)']
#
#
# 問題の是非は一旦、置いといて、この自分のコメントもそうだが「匿名性を悪用」してのコメントになる。千原せいじを擁護するつもりはないが「反論は正論」だと思う。 ['(0, 1.0%)', '(1, 98.2%)']
#
#
# 仕方ないよ。例えば卒業式で突然前髪をツルツルにしてちょんまげを結って来たとしても、追い返されるでしょう。伝統だと喚いてもダメなものはだめです。場所と時代にそぐわないです。常識というものがありますからね。 ['(0, 1.2%)', '(1, 97.9%)']
#
#
# 以降のやり取りは別として、最初の千原氏の意見は明らかに間違っていると思うが。
#
# これ、やり合ったら論破されるやつ。 ['(0, 98.5%)']
#
#
# そもそも教師をSNSを使って安全圏から誹謗中傷してるのは千原せいじ、自分がクソ呼ばわりした教師がどんな人間か知ってて発言してんのか、一方的に発信された情報で見ず知らずの教師を自分のタレントとしての知名度使って誹謗中傷してる人間の意見の方が説得力ないわ。 ['(0, 99.3%)']
#
#
# 逆に匿名だからいいんじゃないか？せいじも。
# もし、せいじより社会的に立場のあるものだった場合、名を名乗ってこられたら困るだろ。匿名投稿してるものが、芸人なんかより弱者と思うな。 ['(0, 98.9%)']
#
#
# せいじさんらは、こうやって醜態さらしてもお金につながる、一般人にはメリットがない。ましてや攻撃してるわけでもないレベルだと思うしね。
# 同じ土俵に上がれと言うのなら、せめて場とギャラを準備してあげてからじゃないんですかね？ ['(0, 53.7%)', '(2, 45.5%)']
#
#
# 匿名でも何でも意見する事を否定する、千原の考えは方は間違っている　相対しても認めないはず ['(0, 78.2%)', '(3, 20.5%)']
#
#
# せいじは「俺は名前出して発言してるんやからお前らも名前出せや」って言いたいんやろうけどそれは違うんじゃないのかな？
#
# タレントってそもそも「不特定多数」の人達を相手に商売してるから成立してるんであってじゃあ逆にお前は１人１人個人個人をマンツーマンで相手にしてタレント活動出来るのか？それはタレントなのか？ってなるやん。
#
# 匿名の批判は全て攻撃だ、は考え違いも甚だしい。 ['(0, 74.8%)', '(2, 24.9%)']
#
#
# 喧嘩腰になってもけっきょく意見変えないでしょ
#
# 煽る前になぜそれは差別ではないのか?いや差別じゃないか。と考える時間を持ってもいいと思うけど
#
# 一度言い出したら引けないというのもわかりますけどけっきょく炎上して徳を下げることになりますよ ['(0, 1.2%)', '(3, 97.9%)']
#
#
# 今回の件に否定的な人たちが国体の整列もまともにせず開会の挨拶中にもスマホで写真を撮りまくってるのには好意的だったりするんだよね。もう完全に好き嫌いだけ。 ['(3, 98.4%)']
#
#
# 責任ある発言よりも感情的な発言の方が、この人は多いと思うけどね。
# 理屈じゃないから感情的な人ほど面倒なものはない。 ['(0, 58.4%)', '(3, 40.7%)']
#
#
# まぁコーンロウが伝統的な正装だなんて日本の一般常識じゃないから普通の教員は知らなくても仕方ない。
# 事前に申請して拒否されたならともかく
# それをぶっつけ本番でやられたら混乱もするでしょうに。 ['(3, 98.5%)']
#
#
# 「ルーツ」だからと「匿名」だからと生徒さんもせいじさんも正論風のものを盾にして論点をすり替えようとしてるのよね。 ['(0, 98.3%)']
#
#
# この件を認めてしまうと、父親が○○だからって奇抜な事をやる奴が出ると思う。
# だから、認めるけどやるなら普通の時もするとか一定のルールは必要になるよね。
# 本人が資料を集めるとかかな。父親のルーツでお祝い事にやる風習があるからやらせて欲しいなど。
# 今回のは色んな行けん読んだけど、生徒側がゴリ押ししたっぽいからな。 ['(0, 33.2%)', '(1, 66.3%)']
#
#
# 匿名の整合性の取れた意見に対しても論点を逸らす所は、今回の決めつけの暴論と同じでバランス感覚に欠ける。 ['(0, 97.5%)']
#
#
# そもそも髪型一つであーだこーだ問題にするのが古過ぎてナンセンス
# 別の問題行動を起こしたのならそれなりの対処をすれば良い隔離だろうが好きにしたら良い
#
# 髪型何か問題の域にも達しない
# しょうもない ['(2, 52.7%)', '(3, 46.3%)']
#
#
# 議論に名前は不要、だが正当性を逸し誹謗中傷を目的とする論争はもはや単なる口喧嘩でしかない、時間の無駄 ['(0, 98.3%)']
#
#
# 卒業式だから　校則に違反しても良いと勝手に判断してやらかしただけだろ。
# 差別とは関係ない　髪型について事前に学校と交渉しなかった生徒側が一方的に悪い。 ['(3, 98.3%)']
#
#
# 論点が違うけど そもそも何故コーンロウは駄目なの？ 一昔前 長髪の女子は三つ編みでみたいな事があったけど 編むのは良くても 編み込んじゃ駄目なんだ ヤンチャそうに見えるから？ それなら最近話題になってた ブラック校則のツーブロックと一緒だね ['(3, 98.6%)']
#
#
# セイジの発言が間違えてるのをセイジ本人が気づき論点をすり替えてるだけ。差別だの教師に対して強い口調で批判した手前、振り上げた拳を下ろす手段を批判者に変えただけ。カッコ悪い。 ['(0, 99.0%)']
#
#
# せいじさんももっと状況調べないとね。
# ネットニュースそのまま信用してる時点で同類かそれ以下でしょう。
# どこの誰かを晒せというのもそれで商売してるせいじさんとはそもそも立場違う訳だし。 ['(2, 98.3%)']
#
#
# いや、あんた知名度利用して教師バッシングしてるではないか
# 他者の意見にも傾聴する気持ちもないなら、
# わかった様な上から目線での発言は控えるといい。 ['(0, 98.6%)']
#
#
# 日本人が同じようにコーン頭にしてきてこれはうちの伝統だ言っても同じ対応だったと思うので人種差別には当たらないと思います。 ['(0, 21.4%)', '(1, 50.6%)', '(3, 27.4%)']
#
#
# 芸人なんだから、反論されたら面白おかしく返すぐらいのユーモアを持ってほしい。
# キレて暴言吐くなんてもってのほか。
# ま、そもそも弟含めて千原兄弟って面白いと思ったことがない。 ['(0, 21.3%)', '(2, 77.4%)']
#
#
# 個人的には学生を擁護する気持ちにはなれないけど、せいじさんにわざわざ文句付けにいくのはどうかと思う。人それぞれなんだから。 ['(0, 52.7%)', '(3, 46.0%)']
#
#
# だったらSNSなんかすな！
# どこの誰か分からんお客さんから金もろて飯食うんが芸人とちゃうんか？視聴者とかお客さんに文句言われたから言うて素人さん舞台上がらせてしまったら芸人としてあかんやろ。
# 芸人ならSNSだろうと舞台だろうとプライド持てよ。同じ条件にしたかったら最初からおどれが匿名でSNSやらんかい！下心でSNSなんかやるからそうなんねん！
# 素人と同じ土俵で同じ条件で戦いたいなら芸人辞めたほうがええで。
# ホンマ最近は要領得んイタイ芸人になってしまっとる ['(0, 42.0%)', '(2, 57.8%)']
#
#
# 人種差別とか伝統とか
# 全部後付けの言い訳やしな。
# 周りの同級生がどう思ったか知りたい。
# 普段から厄介者なら周りも呆れてるだろうし。 ['(0, 1.6%)', '(1, 37.0%)', '(2, 60.7%)']
#
#
# いるよな、否定されるとムキになって反論するヤツ。きまって論点コロコロ変えよるし。
# やるなら有名人にふさわしい知的なディベートしようや。 ['(0, 16.3%)', '(2, 82.7%)']
#
#
# どんな意見でも反対意見はあるもの。
#
# そこから建設的に議論するのが大人です。
#
# その反対意見にブチギレるって…。
#
# あなたの意見が常に正しいとは限らないんですよ。 ['(0, 99.0%)']
#
#
# 芸能人は匿名を批判するけど、
# 頼んでもいないのに勝手に名乗ってるだけでしょ？
# 名を売るって派手に生きる事を選んだ者の立場を
# 名を売らず慎ましく生きる事を選んだ者に押し付けるのはやめて欲しい。
# 芸能人こそ名乗らずに慎ましく生きろ。 ['(0, 87.2%)', '(2, 11.8%)']
#
#
# 匿名で人を攻撃することについて、同意。相手が特定の個人であると分かっているなら、匿名での批判はアンフェアだ。 ['(0, 98.5%)']
#
#
# 匿名で～って指摘してるが、問題はそこじゃなくて卒業式にいきなりそんな髪型をしてくる学生に対してルールに則って、秩序正しく問題を扱った教師に対して暴言吐いたことがブーメランになったることに気づいてないってこと。こいつ昔から薄っぺらいよな。 ['(0, 25.9%)', '(3, 73.5%)']
#
#
# 民主主義社会において、
# タレントや有名人じゃあるまいし
# 一般人が名前や顔を更さなけらば批判意見も言ってはいけないなど、あり得ない。
# 何処かの将軍様か。 ['(0, 98.8%)']
#
#
# この生徒が耳にかかってる髪を切れって言われてカチンときたんでしょ？
# それでこの派手な髪形ににしたってのが本当のところなんじゃないの？
# 普段からこの髪型なら分るけど卒業式でわざわざ浮く髪型はねぇ・・・
# 成人式でイキってるやつと何ら変わりないと思うんだけど。 ['(0, 19.1%)', '(1, 80.4%)']
#
#
# このお子さんは別にせっかくの卒業式だしという感じで学校に許可なくやっちゃっただけなんだろうし、全然ちょっとヤンチャしちゃったなぐらいでなんとも思わないけど。
# せいじのコメントは言葉尻取ったり、ただ状況を自分で決め付けて文句言ってるだけで賛同しかねる。 ['(0, 86.8%)', '(1, 12.5%)']
#
#
# 自分は顔も名前も出してるんだから意見言ってくる人も当然出せ！って言うのなら、自分のSNSへのReplyはそういう人限定にすればいい。 ['(0, 98.6%)']
#
#
# 芸能人は顔出ししてるから何を言っても許されて、一般人は名前を言わないと批判も許されないんだね。
# もし名前を言ったらSNSを使って他者に攻撃させるくせに。
# 芸のない面白くない芸人が偉そうにしてるんだからテレビもそりゃ衰退しますわ。 ['(0, 99.1%)']
#
#
# こいつがどこの誰かわからなくても、その意見はおかしいと言うコメントついてたと思うよ？
#
# たまたま名前売れてるだけで、マウント取ろうとしてるけど、論点ずらしも良いとこ。 ['(0, 98.6%)']
#
#
# 有名人は知名度や好感度アップのため、もともと匿名のSNSで
# 自分で勝手に名前と顔出してるだけだからなあ。
# 匿名で人を攻撃して最低！じゃなく、名前出してる自分が特殊なんだよ。 ['(0, 99.1%)']
#
#
# 私もコーンロウは別に問題ないと思う1人である。教師から圧力をかける権限はないはず。 ['(0, 1.7%)', '(3, 97.1%)']
#
#
# いきなり卒業生の中でちょんまげの袴姿で来たら隔離するでしょう。
#
# 私の先祖は武士でルーツに沿った衣装でござる
# ってゆうたって隔離でしょう。
#
# それにコーンロウって本来女性の髪型じゃないんですかね。 ['(1, 98.3%)']
#
#
# 全て自分の言ってることが正しいとでも思ってるのか？
# 反対意見に対して攻撃的な物言いは大丈夫なのか？
# 色々間違ってるな、この人。
# 都合が悪くなると名前を名乗れだの匿名は卑怯だの文句を言うけどそもそもそういう媒体を利用してるのはどっちなの？w ['(0, 99.2%)']
#
#
# せいじさんは今回のようにすぐに感情的になり声を荒げ、自分と反対の意見を大声を出して叩き潰そうとする姿勢がとても嫌い。 ['(0, 1.3%)', '(2, 97.6%)']
#
#
# 将来何するのかわからないけど、ずっとコーンロウで生きて欲しい。
# 注意されて反発で卒業式だけやってくるなんてダサすぎるから。 ['(0, 1.9%)', '(3, 96.7%)']
#
#
# 「何を言っているか」ではなく「誰が言っているか」で物事を判断する人は総じて愚かだ
# ということを東大の何とかいう教授が言ってたから間違いないと思う ['(0, 1.3%)', '(3, 97.7%)']
#
#
# この問題への是非はともかく、対等に討論しようという申し出から逃げるユーザーの姿勢もどうなんだろうな。そんなのヤフコメ民と変わらんわな。本気の意見なら偽りようの無い自分の声でぶつけないと。 ['(3, 98.5%)']
#
#
# ここのコメントもさ、必ず批判から入るよね？
# なんでもっと冷静に考えたコメント出来ないのかね。記事だけ
# 読んで全て分かったような ['(0, 1.5%)', '(1, 97.4%)']
#
#
# 同じステージに立って舌戦繰り広げたところでどっちも損するわな。
# 有名人はよく内容を把握してから発信しないとな。 ['(0, 1.7%)', '(2, 97.0%)']
#
#
# せいじさん、「責任」ってどうやってとるのですかね？　他人が責任を取るのは容易では無いですよ。
# 簡単に責任という言葉を発してほしくない。 ['(0, 98.1%)']
#
#
# 匿名じゃなければ何言ってもいいってものでもないでしょ
# 校則があるから教師もそうしただけかもしれないのに教師批判は間違ってるよ ['(0, 77.2%)', '(3, 21.2%)']
#
#
# そういう考えなら匿名は無視したらええやん。
# 同じレベルまで降りてやり合う必要がないし、やり合っても何も産まれないよ。 ['(0, 97.5%)']
#
#
# 千原せいじ氏の主張通りだと思う。
# まさにこれが原則で、この理念がありさえすれば、多くのネット中傷は防げる。しかし、中傷したがる人たちは、まったく理解できないでしょう。 ['(0, 98.8%)']
#
#
# 同じように実名でも良いけど。
# 多分、芸能人はファンに護ってもらえるけど、私を護ってくれる人はいないよね？対等じゃないよね？ ['(0, 74.0%)', '(1, 24.9%)']
#
#
# なんでこんなに自分と違う意見の人に攻撃的になるのか？
# 著名人に匿名でって匿名性守らなかったらそれこそ著名人だけのコンテンツになるけど？ ['(0, 34.3%)', '(1, 65.0%)']
#
#
# 芸能人は目立ちたいからデビューしてテレビ出てんだろ？一般人は目立ちたくないんだよ。それは意見も言っちゃいけないのか？目立ちたい人しか意見言っちゃいけないのか？ ['(0, 98.7%)']
#
#
# 千原さんも
# ゆたぼん親子も
# 匿名の批判意見に対して「匿名＝最低」という認識がひどすぎない？
#
# 件の教師を「あほな教師」
# 匿名というだけで「クソ」と誹謗中傷
#
# 顔を晒していれば何を言ってもいいのでしょうか？ ['(0, 82.0%)', '(3, 17.5%)']
#
#
# 芸人なら見られて、意見いわれるのは多少はしょうがない仕事だろ。
# 都合良く一般人されてもな～ ['(0, 97.5%)']
#
#
# 芸能人って自分らが切り取り記事されて怒るワリには
# こういうことについては切り取った部分だけで批判するのかね ['(0, 1.7%)', '(2, 97.0%)']
#
#
# まず普段から問題起こしてない子なら教師の対応も変わってると思うな ['(0, 41.6%)', '(1, 1.1%)', '(3, 56.4%)']
#
#
# そもそもこの件に関して、せいじには全く関係ない。
# 関係ないところに首突っ込んで注目されたいのかね
# それぐらいしかできることねーし。 ['(0, 52.5%)', '(1, 46.2%)']
#
#
# 匿名で誹謗中傷する人を擁護する気はさらさらないが
# 名前と顔を売って商売してる人と
# そうではない人が同じ土俵で話はできないよね・・・ ['(0, 99.0%)']
#
#
# 論点が違うんよなぁ
# 事の経緯を知った上でコメントしてますか？って意見してるのに、名前を名乗れは違うでしょ？ ['(0, 69.2%)', '(2, 29.5%)']
#
#
# 問題の一部分だけを知って、学校側の言い分も聞かずに一方的にバカ呼ばわりは学校とこいつが同じ条件になっていないですよね。 ['(0, 36.0%)', '(3, 63.0%)']
#
#
# 言い返せないからって論点すり替えてマウント取ろうとするのやめましょうよ…。もういい大人どころかベテランなんですから。 ['(0, 97.0%)', '(1, 1.1%)', '(3, 1.0%)']
#
#
# どこの誰が言ったかじゃない
#
# どの意見が正しいかだよ
# 差別じゃない
# 校則というものはそういうもの ['(0, 53.4%)', '(1, 1.1%)', '(3, 44.7%)']
#
#
# 物事の上っ面だけしか見ないで感情だけで発言するから問題になる事って多いんだよね。 ['(0, 2.6%)', '(1, 1.1%)', '(3, 95.4%)']
#
#
# 伝統的な髪型？
# いつからの….？
# まさかと思うけど、
# アメリカで戦後出来た髪型じゃないよね…？
# まぁ、アメリカじゃあそれでも伝統的かも知らんけどw
# 日本で伝統的って言われるとせめて明治くらいかな？ ['(3, 98.9%)']
#
#
# インターネットユーザーは対岸から石投げるのに慣れすぎだと思う ['(0, 3.2%)', '(1, 1.3%)', '(2, 94.2%)', '(3, 1.2%)']
#
#
# アンチに絡んでくる有名人は、他に関テレアナの新実がいます。エゴサした上で絡んでくるので、せいじ以上に凄いですね。 ['(0, 16.8%)', '(3, 81.7%)']
#
#
# 匿名で言いたい放題はダメだよね。
# 意見をいうのと誹謗中傷は違う。 ['(0, 55.6%)', '(1, 42.5%)', '(3, 1.0%)']
#
#
# まあ、匿名かどうかってことを除くとやってることはどっちもどっち。一番の被害者は学校の先生。 ['(0, 21.8%)', '(3, 76.5%)']
#
#
# 芸人が芸名でプロダクション立てて話すのと、一般人がハンドルネームで投稿するのと、同列なのか? ['(0, 43.3%)', '(2, 55.5%)']
#
#
# 匿名は無責任？
# なら何かあると匿名の関係者の話とやらを突っ込んでくるマスコミにも同じ事を言ってやったらどうだろう。
# 言動がゆたぼんと同レベル。 ['(0, 98.6%)']
#
#
# 匿名がダメならテレビ新聞にもダメなの多いじゃん
# まずそっち批判しないと
# 強い相手には何も言えないの？ってなっちゃう ['(0, 56.9%)', '(1, 26.2%)', '(2, 16.4%)']
#
#
# 匿名であっても名前を出していても結局批判をしていることに変わりない。 ['(0, 95.2%)', '(1, 1.7%)', '(2, 1.4%)', '(3, 1.6%)']
#
#
# 何処の誰か言えって、逆に相手見て立場変えるってことだよね。権威主義者かな？ ['(0, 98.1%)']
#
#
# せいじの論点のすり替えが情けない。
#
# 多分、印象操作された報道にまんまと乗っかり、教師に暴言吐いて引っ込みがつかないという、一番恥ずかしい状況なのでしょう。 ['(0, 75.7%)', '(2, 23.1%)']
#
#
# この内容を論じた所で何の意味があんねん！？
#
# もう結果は出てる事！！当人と学校の問題！ ['(0, 1.0%)', '(1, 53.6%)', '(2, 45.0%)']
#
#
# 千原せいじは問題の摩り替えだね！
# 匿名だろうが先にコメントしたのは千原せいじの方！
#
# 発信したなら批判コメントも許容するべきだ！ ['(0, 14.5%)', '(2, 84.6%)']
#
#
# 自分が勝手に顔出ししてるからって、匿名でもOKなSNSで何処の誰か名乗れっていうのはちょっとおかしくない？ ['(0, 98.3%)']
#
#
# そもそも匿名でやり取りする場に承認欲求丸出しで乗り込んできたのが芸能人なわけで ['(0, 97.5%)']
#
#
# 本名を言えばいいのか？住所まで言えばいいのか？互いに。 ['(0, 2.6%)', '(1, 95.5%)', '(3, 1.0%)']
#
#
# 差別って言われるだろうなそりゃ。
# 大事な卒業式だからこそ、自分たちのルーツをあらわす髪型にしたのに隔離されたわけだからな。
# これ海外なら暴動おきてるよ？ ['(0, 1.0%)', '(3, 98.2%)']
#
#
# 入社式のニュースやってましたが、こんな髪型、自由な服装な人はいませんでしたね笑笑
#
# 残念ですよね。それこそ、社会が認めてやれば学校もオッケーになるのでは？？ ['(3, 98.3%)']
#
#
# ネットじゃ仮名で会話することは普通だけどね。SNSにきたならSNSの空気ぐらい読めよ芸人。 ['(0, 37.7%)', '(1, 61.3%)']
#
#
# まずインスタで教師批判してる方がおかしい事に気が付いていない事が問題だろw ['(0, 97.5%)']
#
#
# 顔出しで名前出して攻撃するしてたら正義だとでも？最初から最後まですべてズレてる。 ['(0, 85.7%)', '(3, 13.1%)']
#
#
# それは知名度があって何処の誰だか分かってる芸能人だから言える事で
# 一般人が同じ土俵に立てと言われてもそりゃ躊躇するでしょ ['(0, 85.1%)', '(2, 13.7%)']
#
#
# 匿名の批判が許せないなら、匿名で批判できるSNSを使ってる意味ですね？ ['(0, 97.8%)']
#
#
# 事務所やファンに守られたタレントと同じ条件というのは無理な話。 ['(0, 73.3%)', '(1, 25.1%)']
#
#
# 嫌だったら、匿名禁止にしたらいいのに。。どれだけ人が集まるかは分かりませんが。 ['(0, 32.8%)', '(1, 30.6%)', '(2, 35.6%)', '(3, 1.0%)']
#
#
# ばか教師って言っといて「俺は自分の名前出して正しいこと言ってんだ」みたいな態度は通用しないとおもうけどね…
# 名前出しゃそれが免罪符になるとでも？(笑)
# 勘違いも甚だしいよ。 ['(0, 89.1%)', '(2, 10.2%)']
#
#
# 意見が正しいか間違ってるかに
# 匿名か実名かなんて一切関係ない
# 芸名だとその中間なのか ['(0, 81.5%)', '(2, 16.7%)']
#
#
# お笑い芸人が世間ズレしていて、お笑い芸人が何を言ってもやっても許されない流れになってる事に気がついてない。 ['(0, 22.9%)', '(1, 75.5%)']
#
#
# じゃあそんな場所で発信せずに身元わかるコメントしか受け付けないプラットフォームで発信せえよ。 ['(0, 2.2%)', '(1, 53.9%)', '(2, 43.1%)']
#
#
# せいじの理屈では実名で人を攻撃したら最低じゃないそうだ。 ['(0, 97.5%)']
#
#
# そもそもSNSで発言するとはそういうコト
#
# 一人ひとりにいちいち噛みついてるのもダサいが、なんの学習も反省もせずに「お前何処のどいつだ？」とか輩の台詞
#
# このオッさんは「私は○○在住の○○です」って名乗ったらどうする気なんだろう ['(0, 99.2%)']
#
#
# 名前晒して完全に論破した所で得られるのが千原せいじを論破した人なだけだからな。
# 何の得も無いわ。 ['(0, 98.1%)']
#
#
# それがsnsだとしか思わないなぁ
#
# 芸能人はいちいち反応しない方がいいよ。難しいだろうけど。 ['(0, 97.0%)', '(1, 1.1%)', '(3, 1.0%)']
#
#
# 驕り高ぶった芸能人の典型
# 無名の一般ピープルは匿名で当然 ['(0, 36.8%)', '(2, 61.4%)']
#
#
# 別に卒業式くらい許せよ。
# そう言う文化を取り入れただけだし。
# 文化まで否定するのはどうよ。 ['(0, 2.2%)', '(3, 96.2%)']
#
#
# これを許すと何でもありになってしまう。 ['(0, 6.0%)', '(1, 89.7%)', '(2, 2.0%)', '(3, 2.3%)']
#
#
# 差別かどうかが問題なのに
# 匿名でどうたら関係なくない？ ['(0, 52.5%)', '(1, 1.1%)', '(3, 45.5%)']
#
#
# 名前出せば人を攻撃していいわけじゃない。 ['(0, 95.2%)', '(1, 1.7%)', '(2, 1.4%)', '(3, 1.6%)']
#
#
# 千原さんの言葉が汚いから反感を買っているからでは？ ['(0, 2.2%)', '(1, 96.2%)']
#
#
# 直接だったら何言ってもいいわけではないけどな ['(0, 87.9%)', '(1, 4.4%)', '(2, 3.6%)', '(3, 4.1%)']
#
#
# 40年以上昔だけど私は普段から赤髪パンチだったので普通に卒業式出れたよ　その日だけ気合い入れてくる奴はダサいよ ['(0, 1.7%)', '(1, 97.1%)']
#
#
# 匿名じゃなくても人を攻撃するのは最低です ['(0, 97.0%)', '(1, 1.1%)', '(3, 1.0%)']
#
#
# 顔出ししてるから説得力ある訳じゃないですからね… ['(0, 95.2%)', '(1, 1.7%)', '(2, 1.4%)', '(3, 1.6%)']
#
#
# この髪型にする事は学校に相談をしなかったのはなんで？ってなる。 ['(0, 2.6%)', '(1, 1.1%)', '(3, 95.5%)']
#
#
# 日本なりのルールはあるんだけどね ['(0, 4.2%)', '(1, 1.7%)', '(2, 1.4%)', '(3, 92.7%)']
#
#
# 問題のすり替えが上手ですね ['(0, 24.9%)', '(1, 1.1%)', '(2, 73.0%)', '(3, 1.0%)']
#
#
# 芸能人で匿名じゃない分破格の値段を稼いでいますさらね。 ['(0, 43.1%)', '(1, 1.1%)', '(3, 54.9%)']
#
#
# 同じ条件なら芸能界を引退して一般人にならないと駄目だな。 ['(0, 3.2%)', '(1, 1.3%)', '(2, 94.2%)', '(3, 1.2%)']
#
#
# いつも怒ってるし変な事してるから噛み合わないんじゃないかな、何言っても。 ['(0, 2.6%)', '(1, 95.5%)', '(3, 1.0%)']
#
#
# 卒業式だしどんな髪型でも良くない？
# 今風の卒業式っぽくて良いと思うけどな～ ['(0, 97.5%)']
#
#
# 顔や名前をさらしてる人を攻撃するなら己もさらさなければフェアじゃない ['(0, 6.0%)', '(1, 2.5%)', '(2, 2.0%)', '(3, 89.5%)']
#
#
# 事前に相談していたら変わっていたかもしれない。 ['(0, 36.3%)', '(1, 33.5%)', '(2, 29.8%)']
#
#
# 言い方考えたら周りの反応も変わるんやない？
# この人何を勘違いしとんか知らん児言い方悪いけど何様のつもりで上からなん？ ['(0, 98.5%)']
#
#
# ＞「匿名で人を攻撃してるお前最低」「クソでした」
#
# 笑いの取れない芸人がSNSで人を攻撃してるようものか。。 ['(0, 95.2%)', '(1, 1.7%)', '(2, 1.4%)', '(3, 1.6%)']
#
#
# 名前を明かさないと意見が言えないなら選挙なんて出来んわな。 ['(0, 41.3%)', '(1, 1.1%)', '(2, 56.6%)', '(3, 1.0%)']
#
#
# 結局人を攻撃しているなら同類だよ
# 開き直ってる分かえってたちが悪い ['(0, 93.2%)', '(1, 2.5%)', '(2, 2.0%)', '(3, 2.3%)']
#
#
# 一般人は、事務所に守ってもらえないからね。 ['(0, 95.2%)', '(1, 1.7%)', '(2, 1.4%)', '(3, 1.6%)']
#
#
# 有名人の「名を名乗れ」マウント、そろそろしんどい ['(0, 99.1%)']
#
#
# 感性の問題かな。 ['(0, 46.6%)', '(1, 19.3%)', '(2, 15.9%)', '(3, 18.2%)']
#
#
# 千原せいじ
# 似てる
# 全く同じ
# 立花孝志と言うことがw
# 何処の誰？
# ライブで議論しようw
#
# そのうち立花孝志から選挙へ立候補してくれって要請くるよwww ['(0, 78.4%)', '(1, 19.7%)', '(3, 1.0%)']
#
#
# もうやりとりが既に大人げない ['(0, 42.8%)', '(1, 54.9%)', '(2, 1.1%)', '(3, 1.2%)']
#
#
# 言ったら言われる。
# それだけのこと。 ['(0, 10.6%)', '(1, 81.7%)', '(2, 3.6%)', '(3, 4.1%)']
#
#
# 匿名の輩と有名な輩が喧嘩しとる ['(0, 33.4%)', '(1, 1.7%)', '(2, 63.2%)', '(3, 1.6%)']
#
#
# 勝手に顔出してSNSやってる人間に何で合わせないといけないのか。 ['(0, 95.2%)', '(1, 1.7%)', '(2, 1.4%)', '(3, 1.6%)']
#
#
# 「法治国家」を勉強せい。 ['(0, 2.6%)', '(1, 1.1%)', '(2, 95.3%)', '(3, 1.0%)']
#
#
# 全く会話になってないやん ['(0, 64.9%)', '(1, 1.7%)', '(2, 31.8%)', '(3, 1.6%)']
#
#
# 批判コメが嫌ならsnsやめてください。 ['(0, 50.0%)', '(1, 2.5%)', '(2, 45.2%)', '(3, 2.3%)']
#
#
# せいじさん位単純に生きられたらいいなぁ ['(0, 4.2%)', '(1, 1.7%)', '(2, 1.4%)', '(3, 92.7%)']
#
#
# この髪型はダメだと思います ['(0, 99.7%)']
#
#
# 段々憎たらしい面になってきてるな！！ ['(0, 36.2%)', '(1, 44.0%)', '(2, 19.6%)']
#
#
# 芸能人だからといってどこの誰かまでは分からんけどな ['(3, 98.5%)']
#
#
# 記事そのものがまず読みにくい… ['(0, 69.2%)', '(3, 30.6%)']
#
#
# もうカッコ悪くて引っ込みがつかなくて本当は弱いくせにする気もない喧嘩を装って逃げているだけだわ。 ['(0, 36.9%)', '(1, 62.9%)']
#
#
# 素人の名前を知ってもしょうがないだろ ['(0, 11.9%)', '(3, 87.9%)']
#
#
# 干された理由わかるわ ['(3, 99.4%)']
#
#
# インスタライブせえよ ['(0, 99.7%)']
#
#
# 千原兄弟嫌いです。 ['(3, 98.8%)']
#
#
# 外野が盛り上がってますなぁw ['(0, 91.9%)', '(2, 7.9%)']
#
#
# 攻撃って…？ ['(0, 78.5%)', '(2, 21.1%)']
#
#
# 粗品に馬鹿にされるタイプの芸人 ['(3, 99.2%)']
#
#
# どうでもいいけど苦手なタイプ（笑） ['(0, 81.9%)', '(1, 17.7%)']
#
#
# 芸を身につけてから吠えなさい ['(1, 66.6%)', '(3, 32.7%)']
#
#
# 大人だけ揉めてる笑　子供には伝わりませんよ ['(0, 29.0%)', '(2, 70.5%)']
#
#
# この人芸人は辞めたの？ ['(0, 47.4%)', '(1, 52.4%)']
#
#
# せいじの言うとおり。 ['(2, 99.1%)']
#
#
# 匿名だとなぜ、議論することができないのか？
#
# 不思議だ。
#
# どこの誰かわからなくても議論は可能だし、どこの誰かわかったところでどっちみち知らない相手であり、やはり議論の中身には関係ない。
#
# 自分が真っ向から反論できないから、相手と絶対的に異なる立場を利用して、相手の意見を封じようとしている。
#
# 一般人は名や素性を明かせないだろうと、だから何も言うなと。
#
# 反論を許さないのなら、インスタのコメント欄を無くせばいい。
#
# 相手が異常者なら、ブロックもできる。
#
# 単に言い負かされて、腹が立ったから、それをねじ伏せて、自分の間違いを認めようとしない。
#
# それが「せいじ」という人間なんだろう。
#
# 人から何も言われたくなければ、まず自分が何も言わなければいい。 ['(0, 39.4%)', '(1, 60.4%)']
#
#
# そもそも千原せいじは弟と違って
# ズバズバ言いたい事平気で言うタイプ
# そういうタイプなんだから物事に配慮して言葉選んで
# 慎重に発言する人より批判コメ来るの当たり前でしょ
# 批判コメ来るのなんてわかりきってて言いたい事言ってんじゃないの
# もういい歳してるんだから自分がどういうタイプだか
# きちんと理解して批判コメに反論なんかしてないで
# スルースキル身につけた方がいいよ
# 感情にものを言わせて後先考えもせず言いたい事言ってる時点で
# 有名人としてそっちの方が本来恥ずかしいのに
# 匿名批判してるけど素性明かして自分晒してれば
# じゃあ言いたい事好きに言っていいのかいって言えばそうじゃないでしょ ['(0, 38.5%)', '(2, 61.2%)']
#
#
# 差別ではなくコミュニケーション不足が原因。
# 生徒は突然その髪型にした理由を説明すべきだったし、出来るならその髪型にする前に相談すべきだった。
# 教師は何故そうなったのか過程を知るべきだったのに理由を聞かずに排除した。
# このオッサンは熱くなりすぎ、少し頭冷やした方がいい。 ['(3, 99.2%)']
#
#
# うーん・・・
# この考え方は根本的に間違っていると思う
# 誹謗中傷を匿名でするのは卑怯で最低な行い
# それには同意する
#
# だが、批判は仕方がない話
#
# そして、根本的な話として実名なら何を言っても良いという話でもない
# 「アホな教師」「ただの差別」と誹謗中傷を行う事が実名でも良いと思っているんですかね・・・
# 学校には校則などのルールが存在します
# ルールを守らない奴がルーツやら人種やらを繋げて訴えるのは根本的な間違い
# そして、それを人種差別というのも根本的に誤り
#
# じゃあ、この学生がコーンロウで会社員になれるのか？
# 大半の会社は採用しないだろう
# それは差別でも何でもない
#
# ルーツやら人種やらを基準にすれば何をしても許される訳ではない
# 多くの人が共存する世界ではルールがあるのは当たり前だしある程度の自由を侵害されるのは仕方がない話
#
# そんな事も分からないんですかね・・・ ['(0, 54.5%)', '(1, 45.1%)']
#
#
# 話題のスリ替え＆優位な立場を利用した誹謗でしか無い。
# 千原せいじ氏には好感を持っていたが、ここ最近の短慮な発言で完全に嫌いになった。
#
# 先ずここで匿名云々と持ち出す時点で、痛い所を突かれた逆ギレ感しか無い。反論出来ないからキレる。
# 発言の内容自身は匿名だろうと記名だろうと変わらない。本来は内容に誤りや矛盾が有ったり、中身の無い暴言ならそれを指摘すれば良いし、内容に正しさを感じたなら素直に認めれば良い。結局反論出来ないが自分の誤りを認めたくないから話をスリ替える。キレる。
#
# また既に名が知れており、金銭的に余裕が有り、支援も受けやすい著名人と違い、一般人の身バレはリスクが高い。それが判っていて、優位な立場から「名乗れるものなら名乗ってみろ」と言っている。非常に姑息だ。
# 「身バレで起こった問題や不利益は全部オレが引き受けるから」と言うならまだしも、匿名を理由に意見を封殺するなど愚の骨頂だ。 ['(0, 55.1%)', '(2, 44.2%)']
#
#
# 端的に言って、校則違反を正し厳正に処理しただけ。
# 学校側の対応になんら非は無い。
# これを差別だなんだと騒いで、正当な意見を言っている者に対して、「匿名でほざいてないで出て来い」とか言ってる方がイカレてる。
# 顔から何から知れてる身分で、好きで勝手に喚いてんのは自分だろって感じ。
# 言論を脅迫して、身分をあかせだの卑怯だの言って停止させ様とするのなら、こいつが匿名で意見すれば良い。それならイーブンだろ。
# この生徒に関しては、それまで主張もして来なかった自身のルーツを、卒業式だからと突然姿形で主張をし校則を違反をしたのだから、例え卒業式とは言えど通常の出席方法をさせて貰えず、隔離された状況になるのは当然の報い。
# それを差別だ人権侵害だ等と、久しく履き違えた擁護をするから、これまた多様性とやらまで完全に履き違えたエセヒューマニストやフェミまで増えて来る。
# ジェンダー問題、LGBTQ理解、もういいわ。 ['(0, 75.4%)', '(2, 15.4%)', '(3, 9.0%)']
#
#
# 以前はせいじ様などと様付けしていたのに、韓国側の一方的悪質な横やりで日韓において問題が生じたとき、こんな奴らと付き合わんかったらええんやという意見をして以来批判の的にしているねえ、反日の在日朝鮮君たちよ。まあ在日朝鮮どうし仲良くやり給え。
#
# なんでもルールはルール、決められた規則を守らなければ秩序が乱れて、一つ認めれば我も我もとなってにっちもさっちもいかなくなる。どうしても規則に反論があるのなら事前に自分の意見を言って話し合うべきだね。それで不満ならその組織をやめればいいだけの話だよ。 ['(0, 15.8%)', '(3, 84.0%)']
#
#
# ＞＞「匿名で人を攻撃してるお前最低」「クソでした」「先ず何処の誰か言え」
# ↑
# 匿名の相手に反論されたくないなら不特定多数が反応撃るような環境でネットを利用しなければいい。
#
# 芸能人やYotuberの一部は匿名であることを卑劣かのように言うけど、あんたらは自分から好き好んで顔や名前を公に晒しているんじゃん。
# それを他人に押し付けられると何故思うのか全く理解できないわ。
#
# そもそもネットは近年では素性を晒している人が増えたとはいえ元々匿名の利用者が圧倒的多数。
# そこで意見を発信して反論が返って来て「匿名ガー」って幼稚にも程がある。
#
# 匿名利用者が許せないなら鍵でもつけて承認した名前を晒しているフォロワーのみがコメントできる仕様にでもすればいい。
# 誰にでも書き込めるような状態にしておいて相手が匿名であることに文句言うとかネットリテラシーが欠落している。 ['(0, 99.2%)']
#
#
# 攻撃してるのはこいつでは？
# それも被害者面して。
#
# この手の中学生くらいで精神年齢が停止してるチンピラは、もう少しくらい自分の加害について自覚ってものを持ったほうがいいと思う。
# まぁ、この手のずっと被害者面した加害者として生きてきたチンピラには無理な話だろうけども。 ['(0, 99.2%)']
#
#
# 私にとっては、匿名で攻撃してる人間も、名前出して攻撃してる人間も(せいじさん流に言うと)同じクソです。
#
# それならば、匿名で冷静なコメントをしてる人の方がよっぽどマシ。
#
# 事の本質は、匿名かどうかではなく、守られた立場での発言かどうかでもなく、発言の内容でしょ？
# 名前と顔を出してても間違えたことを言う人はいて、その人が匿名の人から指摘を受けたのに耳を傾けない。
# それはそれでクソです。
#
# 匿名の中にも学ぶべき意見はあるが、名前を出してても聞くに耐えない暴論はある。
# 私は『匿名だから耳を貸さない』より『暴論だから耳を貸さない』ほうがいいと思う。
#
# せいじさんは匿名全てをひとくくりに敵視して、意見を聞く、議論をする、考えるというような事を放棄してるだけじゃないですか？ ['(0, 54.2%)', '(1, 18.7%)', '(2, 27.0%)']
#
#
# あなたの不用意な発言で、影響を受けた複数の匿名者が学校に誹謗中傷する可能性がある事についてどう思いなんですかねえ…。
# 芸能人ってやたら社会問題に口を挟みたがるけど、影響というのを考えず片方の情報を鵜呑みして感情論で語るから余計ややこしくする疫病神だろ。 ['(0, 23.1%)', '(1, 49.9%)', '(3, 26.9%)']
#
#
# これは、せいじ側に分が無い。
# 校則違反もそうだし、ただ悪目立ちしたいだけで民族性などとは欺瞞。
# 黒人＝コーンローは完全にアメリカンアフリカンの話。アフリカンには多くの部族があり一括りにするのは白人も支援者も差別している。本当に民族性を唱えるならキンタ・クンテのことを調べてみればよいし、東岸と西岸での違いも学んでからにして欲しいものだ。 ['(2, 99.1%)']
#
#
# 千原せいじさんはSNSに向いてないと思いました。
# また、千原せいじさんは自分の勉強不足を指摘されても気づいて直すことが出来ない人だと思いました。
# 因みに、私はあくまでも匿名です。SNSで名前を名乗る必要性を感じないし、そんなリスクを負いたくないから。匿名がクソだと思っている人はどうぞ本名を晒してください。本人の自由ですから。 ['(0, 54.7%)', '(3, 44.7%)']
#
#
# いきなり民族の髪型ですって言われてOKはださんやろ。なぜ事前に教師に相談しない？皆さんはそこを突っ込んでいるのでは？
# 教師が有能か無能かはさて置き。
# 義務教育ではない高校を自分の意思で選んで入学したんだから、校則は守る義務がある。義務を守らず自由を勝手に唱えるのは、自由を履き違えているよ。 ['(0, 98.5%)']
#
#
# 個人的感想です。
# 弟のジュニアさんは常識やデリカシーがあり、自分が間違っていたら素直に謝る事ができるのにねぇ。
# 兄せいじは人の意見は聞かず、対立するしか能がない自己中。
# 兄弟でこんなに違うとは何というか・・器の違いっていうんでしょうかね。 ['(0, 52.2%)', '(2, 28.2%)', '(3, 19.2%)']
#
#
# 名前と電話番号書いてコメントしたらいいんですかね？
# で、気に入らないと思われたら殴り込みにでも来るんですか？それとも訴えるんでしょうか？
# 一般人は匿名でコメントしても影響力ってないし、知られてない分、守られないし対等な土俵には立ってないですから。
#
# 悪質なコメントした人間には法的開示責任もあるから問題ないと思いますが。
#
# 校則もある中でアホな教師と決めつけた千原さんの発言が悪影響あったとしたら、どこに住んでて家族構成まで知られて、晒されても責任取るんでしょうか？
#
# どんな責任の取り方したら満足ですかねぇ？ ['(0, 99.5%)']
#
#
# 有名人がその知名度と影響力を駆使して素人を口汚く罵るのも、相当な「攻撃力」だと思いますけど。
#
# 公園閉鎖の問題発生時、数人が起こした問題に対し「気持ち悪い街」「住みとうない」等と
#
# 我が県の自治体を「知名度」と「影響力」を用いて罵倒したこと、県民として忘れていませんからね。
#
# 我が県には来ないで下さい。
#
# 千原せいじさん。
#
# 一応さん付けしておきます。 ['(0, 99.2%)']
#
#
# せいじてたんなる芸人やろ？
# 私は貴方を1度も面白いと思ったこともなく、なんで
# 売れっ子みたいな扱いされ、偉そうにしてるのかなと思ってる
# 一市民ですが（笑）
#
# あんたは相手を匿名匿名っていうけど
# 自分が芸人だっていうだけで。住所とか個人情報さらして
# 仕事してる訳じゃないやん？
# むしろ、何かあれば事務所が守ってくれる立場。よね。
#
# 相手は一般人。なのに身元明らかにさせて、どうしたい？
# すしペロみたいに追い詰めたい？または、そうなるかもと
# 思わせたい？ファンネル使いたいか？！
#
# その言葉で委縮させようとしてるのがミエミエ。
# どこまでもいってもくそださい。
#
# 相手に個人情報だせっていうなら、あなたももっと詳しい
# 情報だすのよね？そうしないとフェアじゃないよ。 ['(0, 98.1%)']
#
#
# そのコメントが身体に危害を加えるような攻撃的なものでもなく、たんにオノレの無知と未確認による「バカ教師」呼ばわりをやんわり指摘しただけなのに何故「名を名乗れ」になるのかわからない。ホントこの人は何も知らない知識もない、なのにいつも発言が過激で自分の感情そのまま言葉に出すからタチが悪い。テレビでの有名人の発言が一個人を強烈なまでに攻撃することの危険性すら分かってない。だからテレビのコメンテーターにまったく適さない。そのへん弟の方が数万倍理解している。 ['(2, 88.0%)', '(3, 11.4%)']
#
#
# そもそもこんなことが議論の対象になることが全てを表している
# 子供が大人に逆らってみるのが思春期だと知らないのか
# 普段やらないことをこういう舞台でやるのが成人式でよくいる坊やたちだよ
# さらに区別と差別の認識がつけられない日本人が多すぎる、もはや日本の良識も常識も非常識になった
# これが差別ならば日本では外国のルーツ全て認めなければ整合性がとれずジャングルルーツの民族は裸で登校オッケーになるんか ['(0, 31.0%)', '(3, 68.6%)']
#
#
# 自分の意見に賛同しない、批判的コメントは全部クソというレッテル貼りで潰したら議論は成立しない
# 一般人が顔出しするリスクを負いたくないのは話の正誤とは関係ない
# 世間もせいじの意見を是々非々で受け取ってるのに相手を論破できないから全く別角度の圧力でねじ伏せにかかる姿はかなりみっともないと思うわ ['(0, 99.4%)']
#
#
# いつもは一般人的な上から目線のくせに、こういう時だけ、匿名を認めないのはフェアじゃないのでは？
#
# 一応は低レベルでも芸人という低名人なのに、一般人に同じ土俵に上がれというのはおかしい話。
#
# まぁ、この人は単なる低名人クレーマーでしょうけど。 ['(0, 66.6%)', '(1, 25.4%)', '(2, 7.9%)']
#
#
# まず世間に顔を晒して仕事してる人とそうじゃない人を同列に考えて顔出せはおかしい。
# ほんとに誹謗中傷なら顔出して言え！ってなるのは当たり前だけど、せいじは自分と違う意見を言う人に噛み付いてるだけじゃん。
# コーンロウの話は前もって学校と相談すればいいだけの事だったんだよ。
# それも分からないうちは何言っても説得力ないよ。
# ましてやクソ教師って話にならない。 ['(0, 59.1%)', '(1, 32.7%)', '(3, 8.0%)']
#
#
# 主張の正当性に実名か匿名かは関係無い。
# 匿名が人殺しは良く無いって言っても正しいし、実名が卒業式の日にだけハッチャケた髪型にした馬鹿生徒を擁護しようが正しくはならない。
# 文化だというなら、なぜ卒業式の日にだけしてきたのか？
# 本当に学校に自分のルーツの文化を認めさせたかったのなら、入学式からその髪型にして来て３年の学校生活の間に校則改定に尽力すれば良かっただけの話。
# ただ最後に校則違反をヤり逃げする気満々だっただけだろうに。
# そもそも親がアフリカ人ならともかく、アフリカ系アメリカ人のルーツとか言ってもな。
# 絶対にファッション以上の文化的知識なんて持って無いだろうこいつ。 ['(0, 1.3%)', '(1, 97.7%)']
#
#
# 目糞鼻糞ってやつかな。
# 匿名で罵詈雑言も、匿名ではなくても本件で教師に中傷するのも、相手から直接的な反撃を受けない事については大差無い。
#
# 真っ当な意見を発したつもりなら、匿名であることを指摘するのではなく、自分の正当性を示すべきではないだろうか？ ['(0, 1.3%)', '(3, 97.7%)']
#
#
# 何処の誰かをいってインスタで稼いでいるタレントと同等なのか？過激な意見で炎上商法でこの事を餌にしているとも思える。どう考えてもニースの一文で反応したけど後から正論が出て文句があったらどうどうと名を名乗れと言ってるだけ。いい年して話し方も知らないのか、わざとか。 ['(0, 76.8%)', '(1, 9.6%)', '(2, 13.4%)']
#
#
# 既に知名度あってある程度守られてる人からお前も名前晒せ！は単なる脅しとなんら変わらないのにも気づかないのかな？
# できれば名前晒して討論したいと思っていても出来ない人が多数。
# それは自身を守る手段が限定されていてそう簡単に個人情報を晒せないから。
# あなたは炎上しようが適当な事言ってれば良いけど、炎上上等の有名人に公の場所で誰からも守られてない人に個人情報晒してくるなら相手にしてやる！はなかなか酷いよねwww
# あと匿名に人権無い的な発言するなら全公開にしないで鍵アカで身内だけに発信してなよwww ['(0, 34.9%)', '(2, 64.4%)']
#
#
# 何処の誰かわかってたら、他人をクソ呼ばわりしても正しいとされるのか？
# 単なるクソ芸人が差別だなんだって騒ぐなや。
# 何故一方的に教師や学校だけをクソだと批判する？
# 当人は一度でも教師に相談したのか？一度でもコーンロウで登校したのか？
# 突然卒業式にコーンロウで出席して民族性を主張されても受け入れられるとでも思ったのか？
#
# 高校は義務教育ではない。
# それ故、高校には校則が存在している。内容を外野がとやかく言わずに、生徒会や保護者が校則を変える努力をしてるのか？
#
# まぁクソ芸人にそんなこと言っても始まらないがな。 ['(1, 99.0%)']
#
#
# 自身の倫理観は崩壊していてそれに見合う粗相をはたらいた上に
# 「俺って許されキャラやから」と不条理な寛容に甘んじてる時点で
# 唯一の長所とされる男気みたいなものも無様な代物なんだよね。
#
# 許されたのは、
# 「この見た目なら大目に見てあげようよ、可哀想だから」
# が理由なわけよ。
#
# 人間の根底の程度が激低なんだから、発信内容も然りすね。 ['(0, 57.5%)', '(2, 41.7%)']
#
#
# ならさ、この学生にも
#
# どこの誰だか明かしてから
# 学校の対応に文句言えや！と言って。
#
# 問題そこじゃないから
# 匿名＝間違い、じゃない
#
# 差別でも何でもない
# 生徒と親、でしょ ['(0, 57.2%)', '(1, 41.6%)']
#
#
# 逆立ちしても教師になれないお前が言うな（笑）
# 昨今の教師はコンプライアンスとかで叱るも難しい状況で教育しなきゃイカンし、大変だと思うぞ。 ['(1, 12.1%)', '(3, 86.7%)']
#
#
# せいじこそがクソ。一般人が名前とか言えるかアホ！それよりきちんと事の経緯をみれば差別でも何でもないのがわかる。私はこの学生こそクソな考えをしていると思う。こういう輩は卒業式に出さなくてもいい。 ['(1, 74.6%)', '(3, 24.1%)']
#
#
# 匿名の攻撃があって当たり前、そんな風に考えて下さいよ、てか、あんた誰？
#
# ネットは性悪説の温床であり性善説の墓場ですよ。いくら騒いでもいくら規制しても誹謗中傷はなくなりません。今後自殺者ももっと増えるでしょう。覚悟もなしにSNSで名を売ろうとしたり、マスコミがバイアスかかった誘導をする限りこの状況は変わりません。なお匿名は権利です。名乗る必要はありません。卑怯でもありません。 ['(0, 1.3%)', '(1, 97.7%)']
#
#
# 頭の悪い人間って、言葉を知らないから直ぐに「アホ」とか幼稚園児みたいな言葉を使うよね。
# それを指摘されると、匿名で～とか、違う話を始める。
# 難しいことがわからないなら、小学校のドリルから再スタートして頑張るか、書き込みしないで読むだけにしたら？ ['(0, 1.3%)', '(1, 97.7%)']
#
#
# 一般人にインスタでライブしろって何？
# 公開処刑でもしたいのかな。
# まずは自分の発言を見つめ直したほうが良いのではないでしょうか。 ['(1, 56.3%)', '(3, 42.5%)']
#
#
# この芸能人は見識も無さそうで感情を抑える事も出来なさそうだからな。まあ、らしいっちゃらしいかな。
# 因みにコーンロウに関してはアフリカにルーツをもつハーフのボクサー細川氏が、アフリカで男があの髪型で来たら単にイキっているって判断で向こうでもアウトだと発信しています。
# この時点で千原せいじの立場はありません。まあ彼も単にイキってる系のイメージですからね。ただ物を知らないで何かに誰かに噛み付くのは本当にみっともないってだけです。 ['(0, 85.9%)', '(3, 13.5%)']
#
#
# この高校生本人は、誰かに入れ知恵されたのかわからんけど、敢えて事前に学校に相談とかもしないで当日いきなりやる事で、問題提起したつもりちゃう？そしてマスゴミがコレだけ騒いでまんまと目論みは成功したと。ただ普通の感覚からすれば自分なら卒業式を棒に振ってでもやるだけのことやったんかな？入れ知恵した奴が一番得してるよな。せいじも騒ぐだけ後ろにおる奴喜ばすだけや、無視しとけ！ ['(0, 2.6%)', '(1, 20.8%)', '(3, 75.7%)']
#
#
# タレントとか有名人ってよく匿名の人間を批判するけど、そもそもお前らは名前を商売にしてんだろ。
# 名前を出すことが自分の仕事に繋がるから出してるだけだよね。
# 一方匿名の一般人は名前を出すことに何のメリットも無いから匿名なんだよ。
# それで自分は匿名の人間より上等だなんて勘違いしてる奴が多過ぎ。 ['(1, 98.3%)']
#
#
# 『お前』とか『バカか』等、攻撃的なコメントは如何なものかと思いますが、タレントだから素性は分かるだけで貴方が素人だったらコメントする際に『俺は何処何処の誰誰ってもんだ』と書いてからコメントしますか？
# 絶対にしませんよね。
# 素性が分かる人だからこそ『クソ教師ども』なんて発言は控えるべきだと思います。
# それに今回のコーンロウの件でも学校側の対応は悪くありません、生徒の方が卒業式で目立ちたいが為に父親のルーツであるコーンローを利用してる行為でリスペクトの欠片もない酷い行為だと思ってます。 ['(0, 86.7%)', '(1, 12.2%)']
#
#
# 匿名って、せいじは名前出すメリットがあるから名前出してるだけでしょ？
# 匿名の誰かさんは名前出すメリットあるの？
# デメリットしかないじゃん
# そんな立場の違いがあるのに名乗らないのはダメって論理は成り立たないでしょ
# 本当に頭悪いな ['(0, 52.9%)', '(1, 45.9%)']
#
#
# こんなクソ記事よりyoutubeで「徳井のせいで税務署が厳しくなった」って
# 発言のが取り上げるべき。税金の納付は厳しくて当然でしょ？
# 徳井のことがなければだまくらかしてたってこと？ ['(0, 96.3%)', '(1, 1.3%)', '(2, 1.1%)', '(3, 1.2%)']
#
#
# クソみたいなものでも学校には学校の文化があったので残念ながら今回はお引き取りいただくという事で。
#
# 入学を拒否するとか、普段の学校生活をまともに送らせてもらえないとかそういう話ならともかくですが。 ['(0, 17.0%)', '(1, 82.4%)']
#
#
# 教師に文句を言うのはおかしな話。
# 個人のこともだが、周りの事も考えて意見を言わないと。あと、こんな千原みたいな人に、コメントすることを許してることにも問題。
# こんなモラルのない男と誰も関わりたくないと思う。教師に言ったみたいに、この千原を例えるのなら、女好きの、全く面白くもないアホ芸人と言えるね。 ['(0, 3.2%)', '(1, 1.3%)', '(2, 94.2%)', '(3, 1.2%)']
#
#
# 人に対して「クソ」と平気で吐けるだけで、この人の人間レベルが分かるとゆうもの。
# テレビで顔を売って収入を得ている芸能人と一般人を同列に置いて考えるあたりにも知能の底がうかがえる。 ['(0, 99.4%)']
#
#
# 卒業式当日に髪形を突然コーンロウにしてくるのって民族的な何かが理由じゃなく、成人式の日にイカれた格好してくるアレな奴と同じ理由だろ？
# 差別っていう言葉を免罪符にするなよ。
# そして勉強不足のまま人に噛みつくこの人は只のイタい人。 ['(0, 98.8%)']
#
#
# どこの誰かもわからん奴らに大声で発言してるのはあなたですがね、、、
# それで誰かわからんから返信してくんなはもうSNSを理解していないのでやめとけ、、、害にしかならない ['(0, 4.2%)', '(1, 1.7%)', '(2, 92.5%)', '(3, 1.6%)']
#
#
# 千原せいじって会話のキャッチボールが出来ない人なんだね。
# 的を得た批判コメントに対して名前を名乗れとか誤魔化しで返してるだけだし。 ['(0, 85.1%)', '(3, 14.0%)']
#
#
# 校則違反とかを言うてるんやなくて
# 「コーンロウ」が清潔でないという判断が差別につながるんちゃう？！
# 日本風の感じでいえば、丸坊主姿がサルだっていえば、差別でしょう。 ['(3, 98.4%)']
#
#
# 私立高校はしょうがない
#
# が、公立の中学、高校で髪型に規制を掛けるのは意味不明昭和時代の悪しき文化
#
# 共生の時代だよね笑
# くだらね～ ['(0, 26.6%)', '(3, 71.8%)']
#
#
# まぁ、吉本芸人はこの程度。
# であれば、市井の庶民は一切政治批判ができないということになる。
# まぁ、イカれた大阪の考えは所詮この程度。 ['(0, 98.3%)']
#
#
# ルーツの問題にすり替えてはダメ。
# ただ単に卒業式に派手な髪にして目立ちたかっただけ。
# 後になってルーツを言い訳にするのくそダサイ。 ['(0, 66.3%)', '(1, 9.1%)', '(3, 24.2%)']
#
#
# 別にいいやん。父親の母国をリスペクトしての卒業式での髪型やから。髪型言うやったら教師の中でヅラしてるやつはどうなん？それこそ大きな違反やん。生徒を欺いて。 ['(1, 98.4%)']
#
#
# 芸能人の立場利用して学校の教師をアホ呼ばわりしてるからしっぺ返し食らってるだけでしょ。最初に誹謗中傷したのはこの人
# どっちもどっちだよ。
# 少なくともここの教師はアホと言われるような悪い事してない ['(0, 2.6%)', '(1, 1.1%)', '(2, 95.3%)', '(3, 1.0%)']
#
#
# 差別かどうかは判断しませんが、どっちもどっちで
# 言い争いの内容が低次元。 ['(0, 98.6%)']
#
#
# 何で同じ土俵で戦う必要がある？
# 自分が間違ってないと思うならそれでいいじゃん
#
# やってることが厨房のヤンキー崩れ
#
# 他人の意見に耳を傾けられなくなったら、ただのボケ老人 ['(0, 63.2%)', '(2, 35.1%)']
#
#
# 内容批判されてるのにそれには答えず実名だから何言ってもいいみたいな頭おかしいこと平然という奴やばすぎだろ。 ['(0, 98.9%)']
#
#
# ほなインスタライブなんかするなやって話。発信してるのはお前。垂れ流しといて突っ込まれたら論点すり替えてキレる。子供か。 ['(0, 56.9%)', '(1, 41.7%)']
#
#
# そもそも匿名の意見はゴミなので反応しなくていいと思います。 ['(0, 58.7%)', '(1, 1.7%)', '(2, 1.4%)', '(3, 38.1%)']
#
#
# え？じゃあ色んな施設や店舗、事務所から離れた一角にある
# 「ご意見箱」のようなものは「最低のクソ箱」ってこと？ｗ
# 匿名のどこが駄目なの？
# 個人情報出している奴なら間違ったことを正しいと言えるのか？ｗ ['(0, 97.0%)', '(1, 1.1%)', '(3, 1.0%)']
#
#
# とにかくせいじの負けで決まりでしょ。ただ受け入れられないんだな。変なプライドの為に。 ['(0, 1.7%)', '(3, 97.1%)']
#
#
# よく匿名で発言は卑怯というが、
# 勝手に本名だして発言してるだけですよねｗ
# あなた自身も匿名で発信することは可能です
# まさか匿名でないと偉いと思ってるのでしょうか？ｗｗ
#
# この方は「アホな教師撲滅」と発言しますが、
# 自分で手を下さないで煽るだけ煽るやつが一番卑怯だと思います ['(0, 98.6%)']
#
#
# 明らかな間違いを正す指摘をされて攻撃とか言っちゃうのちょっとなぁ
# なんか某少年革命家(笑)みたいで嫌いだわ
# そもそも不倫するようなヤツが語るなよって思うんだけどw ['(0, 2.6%)', '(1, 39.8%)', '(2, 56.6%)', '(3, 1.0%)']
#
#
# なんかイタイですね。チンピラが因縁つけるのに通じるものを感じます。 ['(0, 2.6%)', '(1, 1.1%)', '(2, 95.3%)', '(3, 1.0%)']
#
#
# 匿名どうのこうのではない
# 学校で頑張っている教師を侮辱しているわけだから
# 教師は反論も出来ないんだから
# 酷いコメントだよ
# 馬鹿芸能人は発言するなよ ['(0, 60.9%)', '(1, 37.2%)', '(3, 1.0%)']
#
#
# 校則違反を続けた上でこの行い。
# これを了承する方が「民族差別」ですよ？
# 「この民族は日本文化にそぐわない野蛮な民族だ」って事ですからね。
# 日本人として扱う以上、日本人と同等の扱いをしないと。 ['(0, 97.0%)', '(1, 1.1%)', '(3, 1.0%)']
#
#
# これは生徒側が悪いと思う ['(0, 1.9%)', '(1, 96.7%)']
#
#
# せいじやからしゃあない。正面的な感覚で生きてる人やから。本質まで見ようとせんもんなー。 ['(0, 98.6%)']
#
#
# まぁ正論言おうと間違った事言おうとsnsっつー掃き溜めは掃き溜めでしか無い訳だし、そんな所でバカが賢者になり得る事などある訳無いのだからエネルギーの無駄よ。 ['(0, 28.3%)', '(1, 1.3%)', '(2, 69.1%)', '(3, 1.2%)']
#
#
# せいじってレベル低くてもうSNS利用しない方がいいよ。レベル低くても著名人なんだからさ自分の発信には責任持てよって感じやな。 ['(0, 98.5%)']
#
#
# これのどこが差別なんだよ。
# この少年だけ特別か？普段は普通の髪型してんのに、何で卒業式の時にいきなりコーンロウとかしてんだ？って話しだろ。
# 最低とかクソとか偉そうに言うなよ。 ['(0, 2.2%)', '(2, 96.1%)']
#
#
# せいじにまともに絡むから変な話になる。
# 元々話が通じる相手ではない。 ['(0, 95.2%)', '(1, 1.7%)', '(2, 1.4%)', '(3, 1.6%)']
#
#
# 顔を出した芸能人の意見が必ず正しいわけじゃない
# そこを勘違いしてないか？
# この人こそ無関係の教師をバカ呼ばわりしてるし
# ちょっと頭を冷やしたら ['(0, 3.2%)', '(1, 94.5%)', '(2, 1.1%)', '(3, 1.2%)']
#
#
# どっちみち、教育現場には何の影響力もない存在ということは間違いない。 ['(0, 2.6%)', '(1, 1.1%)', '(3, 95.5%)']
#
#
# ただの差別じゃないですよね。この人ちゃんと理解してるのかしら？その上、アホだのクソだの…言葉に品がないというか、理解できんのなら発言しないでほしい。 ['(0, 2.6%)', '(1, 1.1%)', '(2, 95.3%)', '(3, 1.0%)']
#
#
# 匿名じゃなけりゃ何言ってもいいという風潮でも作りたいんか？
# 匿名だろうが姿明かしてようが暴言吐いてることを突けよ ['(0, 2.6%)', '(1, 1.1%)', '(3, 95.5%)']
#
#
# スマホに遊ばれています。インスタやめれば？ ['(0, 29.3%)', '(3, 69.8%)']
#
#
# 芸人ごときには匿名で十分だと思いますが？何か。 ['(0, 12.0%)', '(2, 87.0%)']
#
#
# コーンロウって黒人の方達の正装の時にする髪型なの？違うよね…目立ちたいだけでしょ。 ['(0, 1.9%)', '(1, 96.7%)']
#
#
# あんたもおんなじではない？関係ない部外者が当事者の教師ににバカ教師と言うことはいいの？なんかこういう発言する芸能人はなんかずれてる。 ['(0, 98.6%)']
#
#
# これは千原さんが、ぶが悪いからキレてますね。 ['(0, 2.6%)', '(1, 1.1%)', '(2, 95.3%)', '(3, 1.0%)']
#
#
# 芸能人ていつもそればっかりだね
# 全部肯定してほしいんだったら北の将軍様にでもなったらよろしいやん ['(0, 25.9%)', '(3, 72.4%)']
#
#
# それに対して攻撃している貴方も最低！ ['(0, 3.2%)', '(1, 94.5%)', '(2, 1.1%)', '(3, 1.2%)']
#
#
# 匿名と対話したくないなら最初から匿名SNSに来るな ['(0, 97.8%)']
#
#
# あんたの住所と携帯電話番号教えてくれたら直接お話しますよってことじゃね！？ ['(0, 4.2%)', '(1, 1.7%)', '(2, 92.5%)', '(3, 1.6%)']
#
#
# 断片的な情報だけで、名前も顔も知らない教師をクソ呼ばわりした挙げ句。
# 文句言われたら、匿名は卑怯だって（笑） ['(0, 6.0%)', '(1, 89.6%)', '(2, 2.0%)', '(3, 2.3%)']
#
#
# アフリカ好きなせいじさんたからだよね？
# 背景を知れって、そう言う事。 ['(0, 1.7%)', '(3, 97.1%)']
#
#
# 匿名性が売りのツール使って勝手に芸能人が発信してんのに実名さらせとか意味わからん。こんな奴のインスタみるなよ。 ['(0, 2.2%)', '(2, 96.1%)']
#
#
# 今後も起こりうる。
# まず身分をあかせ！
# 当たり前。出来ないやつが言うな。
# 正々堂々と生きろ。 ['(0, 96.3%)', '(1, 1.3%)', '(2, 1.1%)', '(3, 1.2%)']
#
#
# 匿名を怒るなら、インスタのコメント読むなや。 ['(0, 95.2%)', '(1, 1.7%)', '(2, 1.4%)', '(3, 1.6%)']
#
#
# バレないから、言いたい放題は、卑怯なやり方ばれますよ必ず！ ['(0, 1.5%)', '(1, 97.4%)']
#
#
# コーンロウで葬儀に来た人いたけど別になんも思わなかったなー ['(0, 93.2%)', '(1, 2.5%)', '(2, 2.0%)', '(3, 2.3%)']
#
#
# 元々せいじは感じ悪いからテレビ向けやないやろ。 ['(0, 1.3%)', '(2, 97.6%)']
